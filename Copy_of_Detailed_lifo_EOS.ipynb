# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayTaori/Lifo_step1/blob/main/Copy_of_Detailed_lifo_EOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt
import time
import calendar
df_open = pd.read_csv('/content/et_open_alldata.csv')
df_close = pd.read_csv('/content/et_close_alldata.csv')
df_close['Close Datetime'] = pd.to_datetime(df_close['Close_unix_timestamp'],dayfirst=True,unit='s')
df_open['Open Datetime'] = pd.to_datetime(df_open['Open_unix_timestamp'],dayfirst=True,unit='s')
df_close_btc = df_close[df_close['Close Action'] =='Buy EOS']
df_open_btc = df_open[df_open['Open Action'] =='Buy EOS']
df_close_btc_original = df_close_btc
df_open_btc_original = df_open_btc
df_close_btc.reset_index(inplace=True)
df_close_btc = df_close_btc.drop('index', axis=1)
df_close_btc.reset_index(inplace=True)
df_close_btc.rename(columns={'index':'Original_Close_index'},inplace=True)
df_open_btc.reset_index(inplace=True)
df_open_btc = df_open_btc.drop('index', axis=1)
df_open_btc.reset_index(inplace=True)
df_open_btc.rename(columns={'index':'Original_Open_index'},inplace=True)
data_btc = {}
df_lifo_btc = pd.DataFrame(data_btc, 
                           columns=['Original_Open_index','Original_Close_index',
                                    'Open Position ID', 'Close Position ID',
                                    'Open Units','Close Units','Spread_Eur',
                                    'Open Amount_Eur','Amount_close_Eur',
                                    'Open Datetime', 'Close Datetime',
                                    'Open Rate_Eur', 'Close Rate_Eur',
                                    'Open Action', 'Close Action', 
                                    'Open Amount','Close Rate', 'Open Rate',
                                    'Close Spread', 'Close Profit USD',
                                    'Close_Date','Open_Date',
                                    'Close_unix_timestamp','EurOpen_y', 
                                    'EurHigh_y','EurLow_y', 'EurClose_y',
                                    'EurWeekday_y', 'Open_unix_timestamp',
                                    'EurOpen_x', 'EurHigh_x','EurLow_x', 
                                    'EurClose_x','EurWeekday_x'
                                    ]
                           )

# %%
df_open[df_open['Open Datetime'] == pd.NaT]
# Out:
# Empty DataFrame
# Columns: [Open Position ID, Open Action, Open Amount, Open Units, Open Datetime, Open Rate, Open_Date, Open_unix_timestamp, EurOpen_x, EurHigh_x, EurLow_x, EurClose_x, EurWeekday_x, Open Amount_Eur, Open Rate_Eur]
# Index: []

# %%
df_close[df_close['Close Datetime'] == pd.NaT]
# Out:
# Empty DataFrame
# Columns: [Close Position ID, Close Action, Close Units, Close Datetime, Close Rate, Close Spread, Close Profit USD, Close_Date, Close_unix_timestamp, EurOpen_y, EurHigh_y, EurLow_y, EurClose_y, EurWeekday_y, Close Rate_Eur, Amount_close_Eur, Spread_Eur]
# Index: []

# %%
df_close['Close Action'].unique()
# Out:
# array(['Buy Bitcoin', 'Buy Ethereum', 'Buy XRP', 'Buy Tezos', 'Buy EOS',
#        'Buy Cardano', 'Buy Litecoin', 'Buy Build and Build', 'Buy TRON',
#        'Buy Dogecoin', 'Buy Chainlink', 'Buy Uniswap', 'Buy Polygon',
#        'Buy Stellar', 'Buy Decentraland', 'Buy Aave', 'Buy IOTA',
#        'Buy Shiba (in millions)', 'Buy Enjin', 'Buy Maker',
#        'Buy Algorand', 'Buy Solana', 'Buy Polkadot', 'Buy Songbird'],
#       dtype=object)

# %%
# Let's build a index selector for df_close_btc
close_unit_index = 0
value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
final_close_unit_index = df_open_btc.shape[0]
fruit_list = list(range(400))
serial_number_for_loop = 0
serial_number_if_loop = 0
serial_number_elif_loop_1 = 0
serial_number_elif_loop_2 = 0
serial_number_else_loop = 0
for x in fruit_list:#while close_unit_index < final_close_unit_index:
  serial_number_for_loop = serial_number_for_loop + 1
  print('For loop run number:',serial_number_for_loop)
  i = 0
  #if value_close_units == 0:
  #  i = 1
  #else:
  #  i = 0
  print('i =',i)
  close_unit_index = close_unit_index + i
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  # How to set up an upper limit on this variable?? use df.shape[0]
  # Choosing first row from df_close_btc where the units are = values_of_units
  # Assign it as new DF
  # change the reset the index and the drop the 'index' column
  df_latest_row_from_close = df_close_btc[close_unit_index:(close_unit_index+1)]
  df_latest_row_from_close.reset_index(inplace=True)
  current_close_index = df_latest_row_from_close.at[0,'index']
  df_latest_row_from_close = df_latest_row_from_close.drop('index',axis=1)
  # Get the datetime value from the df_latest_row_from_close
  close_unit_datetime = df_close_btc.loc[close_unit_index,'Close Datetime']
  print('close_unit_datetime:',close_unit_datetime)
  # find all the transaction datetimes from df_open that were opened before the close_unit_datetime
  open_datetimes_b4 = df_open_btc['Open Datetime'][df_open_btc['Open Datetime'] < close_unit_datetime]
  #Latest datetime beofore close datetime
  open_datetime_lifo = open_datetimes_b4.max()
  #if open_datetime_lifo == pd.NaT:
  #  break
  #else:
  #  continue
  print('open_datetime_lifo:',open_datetime_lifo)
  '''
  Remember that even if only one value for open_datetime_lifo is chosen
  this can still result in chosing more than one rows in that case last row 
  should be chosen
  '''
  # Corresponding row for the open_datetime_lifo 
  # let's make a new DF
  df_latest_last_row_open = df_open_btc[df_open_btc['Open Datetime'] == open_datetime_lifo]
  df_latest_last_row_open = df_latest_last_row_open[::-1]
  df_latest_last_row_open = df_latest_last_row_open[0:1]
  df_latest_last_row_open.reset_index(inplace=True)
  current_open_index = df_latest_last_row_open.at[0,'index']
  df_latest_last_row_open = df_latest_last_row_open.drop('index', axis=1)
  value_open_units = df_latest_last_row_open.loc[0,'Open Units']
  print('value_close_units:',value_close_units, 'value_open_units:',value_open_units)
  abs_diff_open_close_units = abs(value_close_units - value_open_units)
  print('abs_diff_open_close_units:',abs_diff_open_close_units)
  value_open_amount = df_latest_last_row_open.loc[0,'Open Amount_Eur']
  value_close_amount = df_latest_row_from_close.loc[0,'Amount_close_Eur']
  value_close_spread_eur = df_latest_row_from_close.loc[0,'Spread_Eur']
  close_Rate_eur = df_latest_row_from_close.loc[0,'Close Rate_Eur']
  open_Rate_eur = df_latest_last_row_open.loc[0,'Open Rate_Eur']
  #Remember that 'Open_index' and 'Close_index' columns host original indices
  # This is important as df_open_btc starts to drop rows the original indices will come in handy 
  # And in case of df_close_btc this should remain equal to the indices from DataFrame
  original_open_index = df_latest_last_row_open.at[0, 'Original_Open_index']
  #Remeber that earlier defined close_unit_index is the index of units from df_close_btc DataFrame
  # close_index should essentially be equal in integer value of close_unit_index
  close_index = df_latest_row_from_close.at[0, 'Original_Close_index']
  is_it_equal = close_unit_index == close_index
  print('(close_unit_index = close_index) is:',is_it_equal)
  if value_close_units > value_open_units:
    serial_number_if_loop = serial_number_if_loop + 1
    print('If_loop run number:',serial_number_if_loop)
    #First lets extract all the values from open DF df_latest_last_row_open
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
    df_open_btc = df_open_btc.drop(current_open_index,axis=0)
    #Then reset index and drop the new column 'index' in df_open_btc
    df_open_btc.reset_index(inplace=True)
    df_open_btc = df_open_btc.drop('index',axis=1)
    #Now lets work on the Close_side
    #First define the changed values for df_latest_row_from_close
    changed_value_close_units = value_open_units
    changed_value_close_amount = changed_value_close_units * close_Rate_eur
    changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    df_latest_row_from_close.at[0,'Close Units'] = changed_value_close_units
    df_latest_row_from_close.at[0,'Amount_close_Eur'] = changed_value_close_amount
    df_latest_row_from_close.at[0,'Spread_Eur'] = changed_value_close_spread
    # Now lets extract all the values from df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
    df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('If_loop run number:',serial_number_if_loop,'finished')
  elif value_close_units < value_open_units:
    serial_number_elif_loop_1 = serial_number_elif_loop_1 + 1
    print('Elif_loop_1 run number:', serial_number_elif_loop_1)
    ## First lets extract all the values form close DF df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    #First define the changed values for df_latest_row_from_close
    ## In elif statement changed values are same as we made only one change
    changed_value_close_units = value_close_units # value_open_units in if statement was here change to value_close_unit
    changed_value_close_amount = changed_value_close_units * close_Rate_eur
    changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
    # and after that change the value of units and amount and spread in original df_close_btc
    df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
    df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    df_latest_row_from_close.at[0,'Close Units'] = changed_value_close_units
    df_latest_row_from_close.at[0,'Amount_close_Eur'] = changed_value_close_amount
    df_latest_row_from_close.at[0,'Spread_Eur'] = changed_value_close_spread
    # Now lets extract all the values from df_latest_row_from_close
    ## Now lets work on the values from open DF df_latest_last_row_lifo
    ## Remember we want to get back the values in the df_latest_row_from_close 
    ## we will have to assign changed_values for open_units and open_amount
    changed_value_open_units = value_close_units
    changed_value_open_amount = changed_value_open_units * open_Rate_eur
    df_latest_last_row_open.at[0,'Open Units'] = changed_value_close_units
    df_latest_last_row_open.at[0,'Open Amount_Eur'] = changed_value_close_amount
    ##After the values are changed extract the values which will then be reported
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    ## and then this time change the original values in the df_open_units
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_open_btc.at[current_open_index,'Open Units'] = value_open_units - changed_value_open_units
    df_open_btc.at[current_open_index,'Open Amount_Eur'] = value_open_amount - changed_value_open_amount
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_1 run number:', serial_number_elif_loop_1, 'finished')
  elif value_close_units == value_open_units:
    serial_number_elif_loop_2 = serial_number_elif_loop_2 + 1
    if value_close_units == 0:
      print('We are running value_close_units == 0 condition')
      print('This is in the Elif_loop_number_2:',serial_number_elif_loop_2)
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      print('We are breaking')
      break
    else:
      #First lets extract all the values from open DF df_latest_last_row_open
      newth_list_open_half = df_latest_last_row_open.to_dict('records')
      newth_dict_open_half = newth_list_open_half[0]
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      ### Second lets extract all the values form close DF df_latest_row_from_close
      newth_list_close_half = df_latest_row_from_close.to_dict('records')
      newth_dict_close_half = newth_list_close_half[0]
      #First define the changed values for df_latest_row_from_close
      changed_value_close_units = value_open_units
      changed_value_close_amount = changed_value_close_units * close_Rate_eur
      changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
      # and after that change the value of units and amount in original df_open_btc
      df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
      df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
      df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_2 run number:', serial_number_elif_loop_2, 'finished')
  else:
    serial_number_else_loop = serial_number_else_loop + 1
    print('Do we need to write more code? The answer is a: BIG YES!!')
    print('Or on second thought this is a silly mistake!!!')
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('serial_number_else_loop:', serial_number_else_loop, 'finished')
    print('We are breaking here!!')
    break
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  if value_close_units == 0:
    i = 1
  else:
    i = 0
  print('i =',i)
  close_unit_index = close_unit_index + i
  print('For loop run number:',serial_number_for_loop,'finished')
  print('****************************************')
# Out:
# For loop run number: 1
# i = 0
# close_unit_datetime: 2020-05-23 20:21:15
# open_datetime_lifo: 2020-05-21 16:33:22
# value_close_units: 9.960159 value_open_units: 9.960159
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 9.960159
# value_open_units: 9.960159
# close_unit_index: 0
# Elif_loop_2 run number: 1 finished
# i = 1
# For loop run number: 1 finished
# ****************************************
# For loop run number: 2
# i = 0
# close_unit_datetime: 2020-05-23 20:21:15
# open_datetime_lifo: 2020-05-20 20:17:24
# value_close_units: 9.541985 value_open_units: 9.541985
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 9.541985
# value_open_units: 9.541985
# close_unit_index: 1
# Elif_loop_2 run number: 2 finished
# i = 1
# For loop run number: 2 finished
# ****************************************
# For loop run number: 3
# i = 0
# close_unit_datetime: 2020-10-08 05:04:53
# open_datetime_lifo: 2020-09-25 12:41:08
# value_close_units: 10.080645 value_open_units: 9.803922
# abs_diff_open_close_units: 0.2767230000000005
# (close_unit_index = close_index) is: True
# If_loop run number: 1
# value_close_units: 10.080645
# value_open_units: 9.803922
# close_unit_index: 2
# If_loop run number: 1 finished
# i = 0
# For loop run number: 3 finished
# ****************************************
# For loop run number: 4
# i = 0
# close_unit_datetime: 2020-10-08 05:04:53
# open_datetime_lifo: 2020-09-23 20:44:03
# value_close_units: 0.2767230000000005 value_open_units: 10.080645
# abs_diff_open_close_units: 9.803922
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 1
# value_close_units: 0.2767230000000005
# value_open_units: 10.080645
# close_unit_index: 2
# Elif_loop_1 run number: 1 finished
# i = 1
# For loop run number: 4 finished
# ****************************************
# For loop run number: 5
# i = 0
# close_unit_datetime: 2020-10-08 05:04:53
# open_datetime_lifo: 2020-09-23 20:44:03
# value_close_units: 8.960573 value_open_units: 9.803922
# abs_diff_open_close_units: 0.8433489999999999
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 2
# value_close_units: 8.960573
# value_open_units: 9.803922
# close_unit_index: 3
# Elif_loop_1 run number: 2 finished
# i = 1
# For loop run number: 5 finished
# ****************************************
# For loop run number: 6
# i = 0
# close_unit_datetime: 2020-10-08 05:04:53
# open_datetime_lifo: 2020-09-23 20:44:03
# value_close_units: 9.803922 value_open_units: 0.8433489999999999
# abs_diff_open_close_units: 8.960573
# (close_unit_index = close_index) is: True
# If_loop run number: 2
# value_close_units: 9.803922
# value_open_units: 0.8433489999999999
# close_unit_index: 4
# If_loop run number: 2 finished
# i = 0
# For loop run number: 6 finished
# ****************************************
# For loop run number: 7
# i = 0
# close_unit_datetime: 2020-10-08 05:04:53
# open_datetime_lifo: 2020-09-14 14:26:03
# value_close_units: 8.960573 value_open_units: 8.960573
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 8.960573
# value_open_units: 8.960573
# close_unit_index: 4
# Elif_loop_2 run number: 3 finished
# i = 1
# For loop run number: 7 finished
# ****************************************
# For loop run number: 8
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-30 16:52:05
# value_close_units: 10.59322 value_open_units: 7.598784
# abs_diff_open_close_units: 2.9944360000000003
# (close_unit_index = close_index) is: True
# If_loop run number: 3
# value_close_units: 10.59322
# value_open_units: 7.598784
# close_unit_index: 5
# If_loop run number: 3 finished
# i = 0
# For loop run number: 8 finished
# ****************************************
# For loop run number: 9
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-23 21:46:20
# value_close_units: 2.9944360000000003 value_open_units: 29.411765
# abs_diff_open_close_units: 26.417329
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 3
# value_close_units: 2.9944360000000003
# value_open_units: 29.411765
# close_unit_index: 5
# Elif_loop_1 run number: 3 finished
# i = 1
# For loop run number: 9 finished
# ****************************************
# For loop run number: 10
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-23 21:46:20
# value_close_units: 8.116883 value_open_units: 26.417329
# abs_diff_open_close_units: 18.300446
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 4
# value_close_units: 8.116883
# value_open_units: 26.417329
# close_unit_index: 6
# Elif_loop_1 run number: 4 finished
# i = 1
# For loop run number: 10 finished
# ****************************************
# For loop run number: 11
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-23 21:46:20
# value_close_units: 18.939394 value_open_units: 18.300446
# abs_diff_open_close_units: 0.6389479999999992
# (close_unit_index = close_index) is: True
# If_loop run number: 4
# value_close_units: 18.939394
# value_open_units: 18.300446
# close_unit_index: 7
# If_loop run number: 4 finished
# i = 0
# For loop run number: 11 finished
# ****************************************
# For loop run number: 12
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-22 17:37:07
# value_close_units: 0.6389479999999992 value_open_units: 7.98722
# abs_diff_open_close_units: 7.348272000000001
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 5
# value_close_units: 0.6389479999999992
# value_open_units: 7.98722
# close_unit_index: 7
# Elif_loop_1 run number: 5 finished
# i = 1
# For loop run number: 12 finished
# ****************************************
# For loop run number: 13
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-22 17:37:07
# value_close_units: 9.689922 value_open_units: 7.348272000000001
# abs_diff_open_close_units: 2.3416499999999987
# (close_unit_index = close_index) is: True
# If_loop run number: 5
# value_close_units: 9.689922
# value_open_units: 7.348272000000001
# close_unit_index: 8
# If_loop run number: 5 finished
# i = 0
# For loop run number: 13 finished
# ****************************************
# For loop run number: 14
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-21 13:56:26
# value_close_units: 2.3416499999999987 value_open_units: 8.116883
# abs_diff_open_close_units: 5.775233000000001
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 6
# value_close_units: 2.3416499999999987
# value_open_units: 8.116883
# close_unit_index: 8
# Elif_loop_1 run number: 6 finished
# i = 1
# For loop run number: 14 finished
# ****************************************
# For loop run number: 15
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-21 13:56:26
# value_close_units: 7.98722 value_open_units: 5.775233000000001
# abs_diff_open_close_units: 2.211986999999999
# (close_unit_index = close_index) is: True
# If_loop run number: 6
# value_close_units: 7.98722
# value_open_units: 5.775233000000001
# close_unit_index: 9
# If_loop run number: 6 finished
# i = 0
# For loop run number: 15 finished
# ****************************************
# For loop run number: 16
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-08 18:40:10
# value_close_units: 2.211986999999999 value_open_units: 9.689922
# abs_diff_open_close_units: 7.477935
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 7
# value_close_units: 2.211986999999999
# value_open_units: 9.689922
# close_unit_index: 9
# Elif_loop_1 run number: 7 finished
# i = 1
# For loop run number: 16 finished
# ****************************************
# For loop run number: 17
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-08 18:40:10
# value_close_units: 17.004049 value_open_units: 7.477935
# abs_diff_open_close_units: 9.526113999999998
# (close_unit_index = close_index) is: True
# If_loop run number: 7
# value_close_units: 17.004049
# value_open_units: 7.477935
# close_unit_index: 10
# If_loop run number: 7 finished
# i = 0
# For loop run number: 17 finished
# ****************************************
# For loop run number: 18
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-07 14:01:36
# value_close_units: 9.526113999999998 value_open_units: 18.939394
# abs_diff_open_close_units: 9.413280000000002
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 8
# value_close_units: 9.526113999999998
# value_open_units: 18.939394
# close_unit_index: 10
# Elif_loop_1 run number: 8 finished
# i = 1
# For loop run number: 18 finished
# ****************************************
# For loop run number: 19
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-07 14:01:36
# value_close_units: 29.411765 value_open_units: 9.413280000000002
# abs_diff_open_close_units: 19.998484999999995
# (close_unit_index = close_index) is: True
# If_loop run number: 8
# value_close_units: 29.411765
# value_open_units: 9.413280000000002
# close_unit_index: 11
# If_loop run number: 8 finished
# i = 0
# For loop run number: 19 finished
# ****************************************
# For loop run number: 20
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-03 12:41:13
# value_close_units: 19.998484999999995 value_open_units: 10.59322
# abs_diff_open_close_units: 9.405264999999995
# (close_unit_index = close_index) is: True
# If_loop run number: 9
# value_close_units: 19.998484999999995
# value_open_units: 10.59322
# close_unit_index: 11
# If_loop run number: 9 finished
# i = 0
# For loop run number: 20 finished
# ****************************************
# For loop run number: 21
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-03 03:11:51
# value_close_units: 9.405264999999995 value_open_units: 10.638298
# abs_diff_open_close_units: 1.233033000000006
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 9
# value_close_units: 9.405264999999995
# value_open_units: 10.638298
# close_unit_index: 11
# Elif_loop_1 run number: 9 finished
# i = 1
# For loop run number: 21 finished
# ****************************************
# For loop run number: 22
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-03 03:11:51
# value_close_units: 7.598784 value_open_units: 1.233033000000006
# abs_diff_open_close_units: 6.365750999999994
# (close_unit_index = close_index) is: True
# If_loop run number: 10
# value_close_units: 7.598784
# value_open_units: 1.233033000000006
# close_unit_index: 12
# If_loop run number: 10 finished
# i = 0
# For loop run number: 22 finished
# ****************************************
# For loop run number: 23
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-02 22:28:56
# value_close_units: 6.365750999999994 value_open_units: 17.004049
# abs_diff_open_close_units: 10.638298000000004
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 10
# value_close_units: 6.365750999999994
# value_open_units: 17.004049
# close_unit_index: 12
# Elif_loop_1 run number: 10 finished
# i = 1
# For loop run number: 23 finished
# ****************************************
# For loop run number: 24
# i = 0
# close_unit_datetime: 2020-12-16 09:07:10
# open_datetime_lifo: 2020-11-02 22:28:56
# value_close_units: 10.638298 value_open_units: 10.638298000000004
# abs_diff_open_close_units: 3.552713678800501e-15
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 11
# value_close_units: 10.638298
# value_open_units: 10.638298000000004
# close_unit_index: 13
# Elif_loop_1 run number: 11 finished
# i = 1
# For loop run number: 24 finished
# ****************************************
# For loop run number: 25
# i = 0
# close_unit_datetime: 2020-12-20 16:07:03
# open_datetime_lifo: 2020-12-19 17:11:29
# value_close_units: 79.36508 value_open_units: 79.36508
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 79.36508
# value_open_units: 79.36508
# close_unit_index: 14
# Elif_loop_2 run number: 4 finished
# i = 1
# For loop run number: 25 finished
# ****************************************
# For loop run number: 26
# i = 0
# close_unit_datetime: 2020-12-21 03:32:42
# open_datetime_lifo: 2020-12-19 17:11:29
# value_close_units: 79.365079 value_open_units: 79.365079
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 79.365079
# value_open_units: 79.365079
# close_unit_index: 15
# Elif_loop_2 run number: 5 finished
# i = 1
# For loop run number: 26 finished
# ****************************************
# For loop run number: 27
# i = 0
# close_unit_datetime: 2020-12-28 14:14:13
# open_datetime_lifo: 2020-12-24 07:24:28
# value_close_units: 74.626866 value_open_units: 10.460251
# abs_diff_open_close_units: 64.16661500000001
# (close_unit_index = close_index) is: True
# If_loop run number: 11
# value_close_units: 74.626866
# value_open_units: 10.460251
# close_unit_index: 16
# If_loop run number: 11 finished
# i = 0
# For loop run number: 27 finished
# ****************************************
# For loop run number: 28
# i = 0
# close_unit_datetime: 2020-12-28 14:14:13
# open_datetime_lifo: 2020-12-23 18:07:11
# value_close_units: 64.16661500000001 value_open_units: 74.626866
# abs_diff_open_close_units: 10.460251
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 12
# value_close_units: 64.16661500000001
# value_open_units: 74.626866
# close_unit_index: 16
# Elif_loop_1 run number: 12 finished
# i = 1
# For loop run number: 28 finished
# ****************************************
# For loop run number: 29
# i = 0
# close_unit_datetime: 2020-12-28 14:14:13
# open_datetime_lifo: 2020-12-23 18:07:11
# value_close_units: 10.460251 value_open_units: 10.460251
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 10.460251
# value_open_units: 10.460251
# close_unit_index: 17
# Elif_loop_2 run number: 6 finished
# i = 1
# For loop run number: 29 finished
# ****************************************
# For loop run number: 30
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-22 20:00:12
# value_close_units: 30.597826 value_open_units: 9.191176
# abs_diff_open_close_units: 21.40665
# (close_unit_index = close_index) is: True
# If_loop run number: 12
# value_close_units: 30.597826
# value_open_units: 9.191176
# close_unit_index: 18
# If_loop run number: 12 finished
# i = 0
# For loop run number: 30 finished
# ****************************************
# For loop run number: 31
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-22 13:47:25
# value_close_units: 21.40665 value_open_units: 9.328358
# abs_diff_open_close_units: 12.078292
# (close_unit_index = close_index) is: True
# If_loop run number: 13
# value_close_units: 21.40665
# value_open_units: 9.328358
# close_unit_index: 18
# If_loop run number: 13 finished
# i = 0
# For loop run number: 31 finished
# ****************************************
# For loop run number: 32
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-20 10:13:08
# value_close_units: 12.078292 value_open_units: 30.597826
# abs_diff_open_close_units: 18.519534
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 13
# value_close_units: 12.078292
# value_open_units: 30.597826
# close_unit_index: 18
# Elif_loop_1 run number: 13 finished
# i = 1
# For loop run number: 32 finished
# ****************************************
# For loop run number: 33
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-20 10:13:08
# value_close_units: 9.191176 value_open_units: 18.519534
# abs_diff_open_close_units: 9.328358
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 14
# value_close_units: 9.191176
# value_open_units: 18.519534
# close_unit_index: 19
# Elif_loop_1 run number: 14 finished
# i = 1
# For loop run number: 33 finished
# ****************************************
# For loop run number: 34
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-20 10:13:08
# value_close_units: 9.689922 value_open_units: 9.328358
# abs_diff_open_close_units: 0.36156399999999955
# (close_unit_index = close_index) is: True
# If_loop run number: 14
# value_close_units: 9.689922
# value_open_units: 9.328358
# close_unit_index: 20
# If_loop run number: 14 finished
# i = 0
# For loop run number: 34 finished
# ****************************************
# For loop run number: 35
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-20 00:02:17
# value_close_units: 0.36156399999999955 value_open_units: 8.865248
# abs_diff_open_close_units: 8.503684
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 15
# value_close_units: 0.36156399999999955
# value_open_units: 8.865248
# close_unit_index: 20
# Elif_loop_1 run number: 15 finished
# i = 1
# For loop run number: 35 finished
# ****************************************
# For loop run number: 36
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-20 00:02:17
# value_close_units: 106.007067 value_open_units: 8.503684
# abs_diff_open_close_units: 97.50338300000001
# (close_unit_index = close_index) is: True
# If_loop run number: 15
# value_close_units: 106.007067
# value_open_units: 8.503684
# close_unit_index: 21
# If_loop run number: 15 finished
# i = 0
# For loop run number: 36 finished
# ****************************************
# For loop run number: 37
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-16 15:39:34
# value_close_units: 97.50338300000001 value_open_units: 8.62069
# abs_diff_open_close_units: 88.88269300000002
# (close_unit_index = close_index) is: True
# If_loop run number: 16
# value_close_units: 97.50338300000001
# value_open_units: 8.62069
# close_unit_index: 21
# If_loop run number: 16 finished
# i = 0
# For loop run number: 37 finished
# ****************************************
# For loop run number: 38
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-16 09:29:59
# value_close_units: 88.88269300000002 value_open_units: 106.007067
# abs_diff_open_close_units: 17.12437399999999
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 16
# value_close_units: 88.88269300000002
# value_open_units: 106.007067
# close_unit_index: 21
# Elif_loop_1 run number: 16 finished
# i = 1
# For loop run number: 38 finished
# ****************************************
# For loop run number: 39
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-16 09:29:59
# value_close_units: 8.62069 value_open_units: 17.12437399999999
# abs_diff_open_close_units: 8.50368399999999
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 17
# value_close_units: 8.62069
# value_open_units: 17.12437399999999
# close_unit_index: 22
# Elif_loop_1 run number: 17 finished
# i = 1
# For loop run number: 39 finished
# ****************************************
# For loop run number: 40
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-16 09:29:59
# value_close_units: 8.865248 value_open_units: 8.50368399999999
# abs_diff_open_close_units: 0.3615640000000102
# (close_unit_index = close_index) is: True
# If_loop run number: 17
# value_close_units: 8.865248
# value_open_units: 8.50368399999999
# close_unit_index: 23
# If_loop run number: 17 finished
# i = 0
# For loop run number: 40 finished
# ****************************************
# For loop run number: 41
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-11 14:07:16
# value_close_units: 0.3615640000000102 value_open_units: 9.689922
# abs_diff_open_close_units: 9.328357999999989
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 18
# value_close_units: 0.3615640000000102
# value_open_units: 9.689922
# close_unit_index: 23
# Elif_loop_1 run number: 18 finished
# i = 1
# For loop run number: 41 finished
# ****************************************
# For loop run number: 42
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2021-01-11 14:07:16
# value_close_units: 9.328358 value_open_units: 9.328357999999989
# abs_diff_open_close_units: 1.0658141036401503e-14
# (close_unit_index = close_index) is: True
# If_loop run number: 18
# value_close_units: 9.328358
# value_open_units: 9.328357999999989
# close_unit_index: 24
# If_loop run number: 18 finished
# i = 0
# For loop run number: 42 finished
# ****************************************
# For loop run number: 43
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: 2020-11-02 22:28:56
# value_close_units: 1.0658141036401503e-14 value_open_units: 3.552713678800501e-15
# abs_diff_open_close_units: 7.105427357601002e-15
# (close_unit_index = close_index) is: True
# If_loop run number: 19
# value_close_units: 1.0658141036401503e-14
# value_open_units: 3.552713678800501e-15
# close_unit_index: 24
# If_loop run number: 19 finished
# i = 0
# For loop run number: 43 finished
# ****************************************
# For loop run number: 44
# i = 0
# close_unit_datetime: 2021-01-25 10:47:14
# open_datetime_lifo: NaT
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-31737fe42a41> in <module>
#      51   df_latest_last_row_open = df_latest_last_row_open[0:1]
#      52   df_latest_last_row_open.reset_index(inplace=True)
# ---> 53   current_open_index = df_latest_last_row_open.at[0,'index']
#      54   df_latest_last_row_open = df_latest_last_row_open.drop('index', axis=1)
#      55   value_open_units = df_latest_last_row_open.loc[0,'Open Units']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2273             return self.obj.loc[key]
#    2274
# -> 2275         return super().__getitem__(key)
#    2276
#    2277     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2220
#    2221         key = self._convert_key(key)
# -> 2222         return self.obj._get_value(*key, takeable=self._takeable)
#    2223
#    2224     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3577
#    3578         try:
# -> 3579             loc = engine.get_loc(index)
#    3580             return series._values[loc]
#    3581         except AttributeError:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
df_lifo_btc
# Out:
#    Original_Open_index Original_Close_index Open Position ID  \
# 0                    4                    0        629296363
# 1                    4                    1        629296363
# 2                    3                    1        629176503
# 3                    3                    2        629176503
# 4                    2                    2        629095067
# 5                    2                    3        629095067
# 6                    1                    3        629094901
# 7                    0                    3        628420941
# 8                    9                    5        667526154
# 9                    9                    6        667526154
# 10                   9                    7        667526154
# 11                   9                    8        667526154
# 12                   8                    8        665029664
# 13                   8                    9        665029664
# 14                   7                    9        645125709
# 15                   6                    9        640092094
# 16                   5                    9        637940593
#
#    Close Position ID  Open Units  Close Units  Spread_Eur  Open Amount_Eur  \
# 0          628420941   35.573263    35.573263    0.900228        88.971311
# 1          629176503    1.652661     1.652661    0.041549         3.957258
# 2          629176503    7.847263     7.847263    0.197287        19.626574
# 3          629094901    1.652661     1.652661    0.041794         3.987117
# 4          629094901   16.872719    16.872719    0.426692        42.199894
# 5          629296363    1.669149     1.669149    0.042012         4.062038
# 6          629296363   18.525380    18.525380    0.466282        45.706012
# 7          629296363   17.031395    17.031395    0.428678        42.596754
# 8          637940593    8.454801     8.454801    0.221150        22.158525
# 9          640092094    8.756261     8.756261    0.229996        22.948598
# 10         645125709    9.530345     9.530345    0.247688        24.893518
# 11         667526154  148.778760   148.778760    4.064062       341.025357
# 12         667526154   26.741407    26.741407    0.730472        72.201103
# 13         665029664   16.494358    16.494358    0.452214        34.067443
# 14         665029664    9.530345     9.530345    0.261287        22.073009
# 15         665029664    8.756261     8.756261    0.240064        22.152005
# 16         665029664    8.454801     8.454801    0.231799        22.329503
#
#     Amount_close_Eur       Open Datetime  ... EurHigh_y  EurLow_y  EurClose_y  \
# 0          88.971311 2020-05-22 06:22:15  ...  1.095530  1.088613    1.095290
# 1           4.133425 2020-05-22 06:22:15  ...  1.095530  1.088613    1.095290
# 2          19.626574 2020-05-21 19:04:57  ...  1.095530  1.088613    1.095290
# 3           4.133425 2020-05-21 19:04:57  ...  1.095530  1.088613    1.095290
# 4          42.199894 2020-05-21 16:21:32  ...  1.095530  1.088613    1.095290
# 5           4.174663 2020-05-21 16:21:32  ...  1.095530  1.088613    1.095290
# 6          46.333319 2020-05-21 16:21:11  ...  1.095530  1.088613    1.095290
# 7          42.596754 2020-05-21 03:56:21  ...  1.095530  1.088613    1.095290
# 8          22.158525 2020-07-07 16:47:54  ...  1.137048  1.130454    1.131004
# 9          22.948598 2020-07-07 16:47:54  ...  1.137048  1.130454    1.131004
# 10         24.893518 2020-07-07 16:47:54  ...  1.137048  1.130454    1.131004
# 11        401.698779 2020-07-07 16:47:54  ...  1.137048  1.130454    1.131004
# 12         72.201103 2020-07-03 18:52:20  ...  1.137048  1.130454    1.131004
# 13         44.679400 2020-07-03 18:52:20  ...  1.137048  1.130454    1.131004
# 14         25.815500 2020-06-11 17:03:49  ...  1.137048  1.130454    1.131004
# 15         23.718685 2020-06-07 17:06:22  ...  1.137048  1.130454    1.131004
# 16         22.902100 2020-06-04 10:19:12  ...  1.137048  1.130454    1.131004
#
#    EurWeekday_y Open_unix_timestamp  EurOpen_x  EurHigh_x  EurLow_x  \
# 0      Saturday          1590128535   1.095242   1.095530  1.088613
# 1      Saturday          1590128535   1.095242   1.095530  1.088613
# 2      Saturday          1590087897   1.097936   1.100873  1.093948
# 3      Saturday          1590087897   1.097936   1.100873  1.093948
# 4      Saturday          1590078092   1.097936   1.100873  1.093948
# 5      Saturday          1590078092   1.097936   1.100873  1.093948
# 6      Saturday          1590078071   1.097936   1.100873  1.093948
# 7      Saturday          1590033381   1.097936   1.100873  1.093948
# 8        Monday          1594140474   1.131030   1.133658  1.126037
# 9        Monday          1594140474   1.131030   1.133658  1.126037
# 10       Monday          1594140474   1.131030   1.133658  1.126037
# 11       Monday          1594140474   1.131030   1.133658  1.126037
# 12       Monday          1593802340   1.123974   1.125113  1.122108
# 13       Monday          1593802340   1.123974   1.125113  1.122108
# 14       Monday          1591895029   1.136868   1.140017  1.132605
# 15       Monday          1591549582   1.133723   1.138395  1.128566
# 16       Monday          1591265952   1.123722   1.136054  1.119595
#
#     EurClose_x  EurWeekday_x
# 0     1.095290        Friday
# 1     1.095290        Friday
# 2     1.098298      Thursday
# 3     1.098298      Thursday
# 4     1.098298      Thursday
# 5     1.098298      Thursday
# 6     1.098298      Thursday
# 7     1.098298      Thursday
# 8     1.131286       Tuesday
# 9     1.131286       Tuesday
# 10    1.131286       Tuesday
# 11    1.131286       Tuesday
# 12    1.123785        Friday
# 13    1.123785        Friday
# 14    1.136544      Thursday
# 15    1.133787        Sunday
# 16    1.123595      Thursday
#
# [17 rows x 34 columns]

# %%
df_open_btc
# Out:
# Empty DataFrame
# Columns: [Original_Open_index, Open Position ID, Open Action, Open Amount, Open Units, Open Datetime, Open Rate, Open_Date, Open_unix_timestamp, EurOpen_x, EurHigh_x, EurLow_x, EurClose_x, EurWeekday_x, Open Amount_Eur, Open Rate_Eur]
# Index: []

# %%
df_close_btc
# Out:
#     Original_Close_index  Close Position ID Close Action   Close Units  \
# 0                      0          629101489      Buy EOS  0.000000e+00
# 1                      1          628368727      Buy EOS  0.000000e+00
# 2                      2          739586978      Buy EOS  0.000000e+00
# 3                      3          729784180      Buy EOS  0.000000e+00
# 4                      4          741011298      Buy EOS  0.000000e+00
# 5                      5          779003547      Buy EOS  0.000000e+00
# 6                      6          802412596      Buy EOS  0.000000e+00
# 7                      7          784963737      Buy EOS  0.000000e+00
# 8                      8          785145983      Buy EOS  0.000000e+00
# 9                      9          802610700      Buy EOS  0.000000e+00
# 10                    10          778755165      Buy EOS  0.000000e+00
# 11                    11          804816103      Buy EOS  0.000000e+00
# 12                    12          814175893      Buy EOS  0.000000e+00
# 13                    13          778833788      Buy EOS  0.000000e+00
# 14                    14          840641021      Buy EOS  0.000000e+00
# 15                    15          840576951      Buy EOS  0.000000e+00
# 16                    16          847510147      Buy EOS  0.000000e+00
# 17                    17          848001932      Buy EOS  0.000000e+00
# 18                    18          908929216      Buy EOS  0.000000e+00
# 19                    19          917277834      Buy EOS  0.000000e+00
# 20                    20          887642979      Buy EOS  0.000000e+00
# 21                    21          904490934      Buy EOS  0.000000e+00
# 22                    22          904551579      Buy EOS  0.000000e+00
# 23                    23          908518383      Buy EOS  0.000000e+00
# 24                    24          915180628      Buy EOS  7.105427e-15
#
#         Close Datetime  Close Rate  Close Spread  Close Profit USD  \
# 0  2020-05-23 20:21:15        2.54          0.74              0.30
# 1  2020-05-23 20:21:15        2.54          0.71             -0.76
# 2  2020-10-08 05:04:53        2.59          0.77              1.11
# 3  2020-10-08 05:04:53        2.59          0.68             -1.79
# 4  2020-10-08 05:04:53        2.59          0.75              0.39
# 5  2020-12-16 09:07:10        2.80          0.87              4.66
# 6  2020-12-16 09:07:10        2.80          0.67             -2.27
# 7  2020-12-16 09:07:10        2.80          1.56              3.03
# 8  2020-12-16 09:07:10        2.80          0.80              2.13
# 9  2020-12-16 09:07:10        2.80          0.66             -2.64
# 10 2020-12-16 09:07:10        2.80          1.40              5.61
# 11 2020-12-16 09:07:10        2.80          2.42            -17.65
# 12 2020-12-16 09:07:10        2.80          0.63             -3.72
# 13 2020-12-16 09:07:10        2.80          0.88              4.79
# 14 2020-12-20 16:07:03        3.26          7.62              8.73
# 15 2020-12-21 03:32:42        3.17          7.41              1.59
# 16 2020-12-28 14:14:13        2.81          6.16              9.70
# 17 2020-12-28 14:14:13        2.81          0.86              4.39
# 18 2021-01-25 10:47:14        2.67          2.41             -2.75
# 19 2021-01-25 10:47:14        2.67          0.72             -0.46
# 20 2021-01-25 10:47:14        2.67          0.76              0.87
# 21 2021-01-25 10:47:14        2.67          8.33            -16.96
# 22 2021-01-25 10:47:14        2.67          0.68             -1.98
# 23 2021-01-25 10:47:14        2.67          0.70             -1.33
# 24 2021-01-25 10:47:14        2.67          0.73             -0.09
#
#           Close_Date  Close_unix_timestamp  EurOpen_y  EurHigh_y  EurLow_y  \
# 0   23/05/2020 00:00            1590265275   1.095242   1.095530  1.088613
# 1   23/05/2020 00:00            1590265275   1.095242   1.095530  1.088613
# 2   08/10/2020 00:00            1602133493   1.176554   1.178134  1.173530
# 3   08/10/2020 00:00            1602133493   1.176554   1.178134  1.173530
# 4   08/10/2020 00:00            1602133493   1.176554   1.178134  1.173530
# 5   16/12/2020 00:00            1608109630   1.215377   1.221300  1.214698
# 6   16/12/2020 00:00            1608109630   1.215377   1.221300  1.214698
# 7   16/12/2020 00:00            1608109630   1.215377   1.221300  1.214698
# 8   16/12/2020 00:00            1608109630   1.215377   1.221300  1.214698
# 9   16/12/2020 00:00            1608109630   1.215377   1.221300  1.214698
# 10  16/12/2020 00:00            1608109630   1.215377   1.221300  1.214698
# 11  16/12/2020 00:00            1608109630   1.215377   1.221300  1.214698
# 12  16/12/2020 00:00            1608109630   1.215377   1.221300  1.214698
# 13  16/12/2020 00:00            1608109630   1.215377   1.221300  1.214698
# 14  20/12/2020 00:00            1608480423   1.226196   1.226843  1.222718
# 15  21/12/2020 00:00            1608521562   1.221061   1.223466  1.213077
# 16  28/12/2020 00:00            1609164853   1.220703   1.225200  1.218353
# 17  28/12/2020 00:00            1609164853   1.220703   1.225200  1.218353
# 18  25/01/2021 00:00            1611571634   1.216856   1.218600  1.211725
# 19  25/01/2021 00:00            1611571634   1.216856   1.218600  1.211725
# 20  25/01/2021 00:00            1611571634   1.216856   1.218600  1.211725
# 21  25/01/2021 00:00            1611571634   1.216856   1.218600  1.211725
# 22  25/01/2021 00:00            1611571634   1.216856   1.218600  1.211725
# 23  25/01/2021 00:00            1611571634   1.216856   1.218600  1.211725
# 24  25/01/2021 00:00            1611571634   1.216856   1.218600  1.211725
#
#     EurClose_y EurWeekday_y  Close Rate_Eur  Amount_close_Eur    Spread_Eur
# 0     1.095290     Saturday        2.318513     -3.447660e-09  0.000000e+00
# 1     1.095290     Saturday        2.318513     -6.854485e-09  0.000000e+00
# 2     1.176747     Thursday        2.198392      1.837365e-09  0.000000e+00
# 3     1.176747     Thursday        2.198392      3.319336e-09  0.000000e+00
# 4     1.176747     Thursday        2.198392     -3.423871e-09  0.000000e+00
# 5     1.215430    Wednesday        2.292639     -2.241022e-09  0.000000e+00
# 6     1.215430    Wednesday        2.292639     -1.185054e-09  0.000000e+00
# 7     1.215430    Wednesday        2.292639     -3.114504e-10  0.000000e+00
# 8     1.215430    Wednesday        2.292639      3.051299e-09  0.000000e+00
# 9     1.215430    Wednesday        2.292639     -1.695019e-09  0.000000e+00
# 10    1.215430    Wednesday        2.292639      7.725451e-09  0.000000e+00
# 11    1.215430    Wednesday        2.292639      6.870881e-09  0.000000e+00
# 12    1.215430    Wednesday        2.292639     -2.586946e-09  0.000000e+00
# 13    1.215430    Wednesday        2.292639      7.322679e-09  0.000000e+00
# 14    1.226272       Sunday        2.657227      6.842745e-08  0.000000e+00
# 15    1.221613       Monday        2.591000      6.020628e-08  0.000000e+00
# 16    1.220510       Monday        2.293503     -6.353832e-08  0.000000e+00
# 17    1.220510       Monday        2.293503     -6.198601e-09  0.000000e+00
# 18    1.216945       Monday        2.191039      3.620855e-10  0.000000e+00
# 19    1.216945       Monday        2.191039      4.827129e-09  0.000000e+00
# 20    1.216945       Monday        2.191039     -8.960327e-10  0.000000e+00
# 21    1.216945       Monday        2.191039      4.611488e-08  0.000000e+00
# 22    1.216945       Monday        2.191039      1.021071e-09  0.000000e+00
# 23    1.216945       Monday        2.191039      4.485466e-10  3.469447e-18
# 24    1.216945       Monday        2.191039     -3.141108e-09  4.440892e-16

# %%
df_lifo_btc.dtypes

# %%
df_lifo_btc['time_difference'] = df_lifo_btc['Close Datetime'] - df_lifo_btc['Open Datetime']
df_lifo_btc['time_difference_days'] = df_lifo_btc['time_difference'] / np.timedelta64(1, 'D')
df_lifo_btc_taxable = df_lifo_btc[df_lifo_btc['time_difference_days'] < 365]
df_lifo_btc_taxable_2020 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1609455599]
df_lifo_btc_taxable_2020_2021 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1640991599]
df_lifo_btc_taxable_2021 = df_lifo_btc_taxable_2020_2021[df_lifo_btc_taxable_2020_2021['Close_unix_timestamp'] > 1609455599]
df_lifo_btc_taxable_2022 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] > 1640991599]
print('Sum of all open positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Amount_close_Eur'].sum())
# Out:
# Sum of all open positions for the year 2020 in eur: 500.54041708305465
# Sum of all closed positions for the year 2020 in eur: 489.94077561674317
# Sum of all open positions for the year 2021 in eur: 404.5724357508013
# Sum of all closed positions for the year 2021 in eur: 399.42701980314115
# Sum of all open positions for the year 2022 in eur: 0.0
# Sum of all closed positions for the year 2022 in eur: 0.0
