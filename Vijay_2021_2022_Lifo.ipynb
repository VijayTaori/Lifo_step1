# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayTaori/Lifo_step1/blob/main/Vijay_2021_2022_Lifo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt
import time
import calendar

# %%
df_shweta_2021 = pd.read_excel('/content/etoro-account-statement-1-1-2021-12-31-2021.xlsx',sheet_name=1)
df_shweta_2022 = pd.read_excel('/content/etoro-account-statement-1-1-2022-12-31-2022_Pandas.xlsx',sheet_name=1)
df_eur2usd = pd.read_csv('/content/eur_usd_all_plus_weekends.csv')
df_eur2usd['Date'] = pd.to_datetime(df_eur2usd['Date'],dayfirst=True)
df_21_open = df_shweta_2021[['Position ID', 
                'Action', 'Amount', 'Units', 'Open Date', 'Open Rate']]
df_22_open = df_shweta_2022[['Position ID', 
                'Action', 'Amount', 'Units', 'Open Date', 'Open Rate']]
df_21_close = df_shweta_2021[['Position ID', 
                'Action', 'Units', 'Close Date', 
                'Close Rate','Spread', 'Profit']]
df_22_close = df_shweta_2022[['Position ID', 
                'Action', 'Units', 'Close Date', 
                'Close Rate','Spread', 'Profit']]    
df_21_open['Open Date'] = pd.to_datetime(df_21_open['Open Date'],dayfirst=True)
df_22_open['Open Date'] = pd.to_datetime(df_22_open['Open Date'],dayfirst=True)
df_21_close['Close Date'] = pd.to_datetime(df_21_close['Close Date'],dayfirst=True)
df_22_close['Close Date'] = pd.to_datetime(df_22_close['Close Date'],dayfirst=True)                     
def datetime2date(date_time):
  date = date_time.date()
  return date
df_21_open['Date'] = df_21_open['Open Date'].map(datetime2date)
df_22_open['Date'] = df_22_open['Open Date'].map(datetime2date)
df_21_close['Date'] = df_21_close['Close Date'].map(datetime2date)
df_22_close['Date'] = df_22_close['Close Date'].map(datetime2date)

# %%
df_21_open['Date'] = pd.to_datetime(df_21_open['Date'],dayfirst=True)
df_21_close['Date'] = pd.to_datetime(df_21_close['Date'],dayfirst=True)
df_22_open['Date'] = pd.to_datetime(df_22_open['Date'],dayfirst=True)
df_22_close['Date'] = pd.to_datetime(df_22_close['Date'],dayfirst=True)

# %%
df_et_open = pd.concat([df_21_open,df_22_open])
df_et_close = pd.concat([df_21_close,df_22_close])
df_et_open.reset_index(inplace=True)
df_et_open = df_et_open.drop('index',axis=1)
df_et_close.reset_index(inplace=True)
df_et_close = df_et_close.drop('index',axis=1)

# %%
df_find_na = df_et_open # use the DataFrame for which you would like to find NANs
columns_df_find_na = df_find_na.columns
def find_null_values(column_name):
  print('The number of null values in column {} are:'.format(column_name),len(np.where(df_find_na.isna()[column_name])[0]))
  print('And their integer location is:', np.where(df_find_na.isna()[column_name])[0])
null_values = [find_null_values(y) for y in columns_df_find_na]
# Out:
# The number of null values in column Position ID are: 0
# And their integer location is: []
# The number of null values in column Action are: 0
# And their integer location is: []
# The number of null values in column Amount are: 0
# And their integer location is: []
# The number of null values in column Units are: 0
# And their integer location is: []
# The number of null values in column Open Date are: 0
# And their integer location is: []
# The number of null values in column Open Rate are: 0
# And their integer location is: []
# The number of null values in column Date are: 0
# And their integer location is: []

# %%
df_find_na = df_et_close # use the DataFrame for which you would like to find NANs
columns_df_find_na = df_find_na.columns
def find_null_values(column_name):
  print('The number of null values in column {} are:'.format(column_name),len(np.where(df_find_na.isna()[column_name])[0]))
  print('And their integer location is:', np.where(df_find_na.isna()[column_name])[0])
null_values = [find_null_values(y) for y in columns_df_find_na]
# Out:
# The number of null values in column Position ID are: 0
# And their integer location is: []
# The number of null values in column Action are: 0
# And their integer location is: []
# The number of null values in column Units are: 0
# And their integer location is: []
# The number of null values in column Close Date are: 0
# And their integer location is: []
# The number of null values in column Close Rate are: 0
# And their integer location is: []
# The number of null values in column Spread are: 0
# And their integer location is: []
# The number of null values in column Profit are: 0
# And their integer location is: []
# The number of null values in column Date are: 0
# And their integer location is: []

# %%
def convert2UnixTimestamp(date_time):
  unix_timestamp = time.mktime(date_time.timetuple())
  return unix_timestamp

# %%
df_et_close['close_unix_timestamp'] = df_et_close['Close Date'].map(convert2UnixTimestamp)
df_et_open['open_unix_timestamp'] = df_et_open['Open Date'].map(convert2UnixTimestamp)

# %%
df_et_close_eur1 = pd.merge(df_et_close, df_eur2usd, on='Date', how='left')
df_et_open_eur1 = pd.merge(df_et_open, df_eur2usd, on='Date', how='left')

# %%
np.where(df_et_open_eur1.isna())
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
np.where(df_et_close_eur1.isna())
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df_et_open_eur1['Amount_Eur'] = df_et_open_eur1['Amount']/df_et_open_eur1['Low']
df_et_open_eur1['Open Rate_Eur'] = df_et_open_eur1['Open Rate']/df_et_open_eur1['Low']
df_et_close_eur1['Close Rate_Eur'] = df_et_close_eur1['Close Rate']/df_et_close_eur1['High']
df_et_close_eur1['Amount_close_Eur'] = df_et_close_eur1['Close Rate_Eur']*df_et_close_eur1['Units']
df_et_close_eur1['Spread_Eur'] = df_et_close_eur1['Spread']/df_et_close_eur1['Low']

# %%
df_et_open_eur1.rename(columns={'Position ID': 'Open Position ID',
                                'Action':'Open Action', 'Amount':'Open Amount',
                                'Units':'Open Units',
                                'Open Date':'Open Datetime',
                                'Date':'Open_Date', 
                                'Amount_Eur':'Open Amount_Eur',
                                'open_unix_timestamp':'Open_unix_timestamp',
                                'Open':'EurOpen_x', 'High':'EurHigh_x',
                                'Low':'EurLow_x','Close':'EurClose_x',
                                'Weekday':'EurWeekday_x'},
                       inplace=True)

# %%
df_et_close_eur1.rename(columns={'Position ID': 'Close Position ID',
                                 'Action':'Close Action', 'Units':'Close Units',
                                 'Spread':'Close Spread',
                                 'Close Date':'Close Datetime',
                                 'Date':'Close_Date',
                                 'Profit':'Close Profit USD',
                                 'close_unix_timestamp':'Close_unix_timestamp',
                                 'Open':'EurOpen_y', 'High':'EurHigh_y',
                                 'Low':'EurLow_y',
                                 'Close':'EurClose_y','Weekday':'EurWeekday_y'},
                        inplace=True)

# %%
df_et_open_eur1.sort_values(by='Open_unix_timestamp',inplace=True)
df_et_open_eur1.reset_index(inplace=True)
df_et_open_eur1 = df_et_open_eur1.drop('index', axis=1)
df_et_close_eur1.sort_values(by='Close_unix_timestamp',inplace=True)
df_et_close_eur1.reset_index(inplace=True)
df_et_close_eur1 = df_et_close_eur1.drop('index', axis=1)
df_open = df_et_open_eur1
df_close = df_et_close_eur1
df_close['Close Action'].unique()
# Out:
# array(['Buy Tezos', 'Buy Ethereum', 'Buy Bitcoin', 'Buy Cardano',
#        'Buy Litecoin', 'Buy Gold', 'Buy Silver', 'Buy Copper',
#        'Buy Tesla Motors, Inc.', 'Buy Amazon.com Inc',
#        'Buy Meta Platforms Inc', 'Sell Tesla Motors, Inc.', 'Buy XRP',
#        'Buy Apple', 'Buy Roku Inc', 'Buy Block Inc.', 'Buy EOS',
#        'Buy Zoom Video Communications Inc', 'Buy SPX500', 'Buy NASDAQ100',
#        'Buy Nano Dimension Ltd', 'Buy Bed Bath & Beyond Inc',
#        'Buy Cenntro Electric Group Limited', 'Buy ARK Innovation ETF',
#        'Buy ARK Next Generation Internet ETF',
#        'Buy ARK Fintech Innovation ETF', 'Buy Enphase Energy Inc.',
#        'Buy Palantir Technologies Inc.', 'Buy Lemonade Inc.',
#        'Buy Build and Build', 'Buy Coinbase Global Inc', 'Buy TRON',
#        'Buy Dogecoin', 'Buy Chainlink', 'Buy Uniswap', 'Buy Nio Inc.',
#        'Buy Polygon', 'Buy Stellar', 'Buy Decentraland', 'Buy Aave',
#        'Buy IOTA', 'Buy Shiba (in millions)', 'Buy Enjin', 'Buy Maker',
#        'Buy Algorand', 'Buy Solana', 'Sell MicroStrategy Incorporated',
#        'Sell NASDAQ100 Index', 'Buy Polkadot', 'Buy NASDAQ100 Index',
#        'Buy MicroStrategy Incorporated', 'Sell SPX500 Index',
#        'Buy Songbird'], dtype=object)

# %%
df_close['Close Datetime'] = pd.to_datetime(df_close['Close_unix_timestamp'],dayfirst=True,unit='s')
df_open['Open Datetime'] = pd.to_datetime(df_open['Open_unix_timestamp'],dayfirst=True,unit='s')
df_close_btc = df_close[df_close['Close Action'] =='Buy Cardano']
df_open_btc = df_open[df_open['Open Action'] =='Buy Cardano']
df_close_btc_original = df_close_btc
df_open_btc_original = df_open_btc
df_close_btc.reset_index(inplace=True)
df_close_btc = df_close_btc.drop('index', axis=1)
df_close_btc.reset_index(inplace=True)
df_close_btc.rename(columns={'index':'Original_Close_index'},inplace=True)
df_open_btc.reset_index(inplace=True)
df_open_btc = df_open_btc.drop('index', axis=1)
df_open_btc.reset_index(inplace=True)
df_open_btc.rename(columns={'index':'Original_Open_index'},inplace=True)
data_btc = {}
df_lifo_btc = pd.DataFrame(data_btc, 
                           columns=['Original_Open_index','Original_Close_index',
                                    'Open Position ID', 'Close Position ID',
                                    'Open Units','Close Units','Spread_Eur',
                                    'Open Amount_Eur','Amount_close_Eur',
                                    'Open Datetime', 'Close Datetime',
                                    'Open Rate_Eur', 'Close Rate_Eur',
                                    'Open Action', 'Close Action', 
                                    'Open Amount','Close Rate', 'Open Rate',
                                    'Close Spread', 'Close Profit USD',
                                    'Close_Date','Open_Date',
                                    'Close_unix_timestamp','EurOpen_y', 
                                    'EurHigh_y','EurLow_y', 'EurClose_y',
                                    'EurWeekday_y', 'Open_unix_timestamp',
                                    'EurOpen_x', 'EurHigh_x','EurLow_x', 
                                    'EurClose_x','EurWeekday_x'
                                    ]
                           )
# Let's build a index selector for df_close_btc
close_unit_index = 0
value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
final_close_unit_index = df_open_btc.shape[0]
serial_number_for_loop = 0
serial_number_if_loop = 0
serial_number_elif_loop_1 = 0
serial_number_elif_loop_2 = 0
serial_number_else_loop = 0
while close_unit_index < final_close_unit_index:
  serial_number_for_loop = serial_number_for_loop + 1
  print('For loop run number:',serial_number_for_loop)
  i = 0
  print('i =',i)
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  # How to set up an upper limit on this variable?? use df.shape[0]
  # Choosing first row from df_close_btc where the units are = values_of_units
  # Assign it as new DF
  # change the reset the index and the drop the 'index' column
  df_latest_row_from_close = df_close_btc[close_unit_index:(close_unit_index+1)]
  df_latest_row_from_close.reset_index(inplace=True)
  current_close_index = df_latest_row_from_close.at[0,'index']
  df_latest_row_from_close = df_latest_row_from_close.drop('index',axis=1)
  # Get the datetime value from the df_latest_row_from_close
  close_unit_datetime = df_close_btc.loc[close_unit_index,'Close Datetime']
  print('close_unit_datetime:',close_unit_datetime)
  # find all the transaction datetimes from df_open that were opened before the close_unit_datetime
  open_datetimes_b4 = df_open_btc['Open Datetime'][df_open_btc['Open Datetime'] < close_unit_datetime]
  #Latest datetime beofore close datetime
  open_datetime_lifo = open_datetimes_b4.max()
  #if open_datetime_lifo == pd.NaT:
  #  break
  #else:
  #  continue
  print('open_datetime_lifo:',open_datetime_lifo)
  '''
  Remember that even if only one value for open_datetime_lifo is chosen
  this can still result in chosing more than one rows in that case last row 
  should be chosen
  '''
  # Corresponding row for the open_datetime_lifo 
  # let's make a new DF
  df_latest_last_row_open = df_open_btc[df_open_btc['Open Datetime'] == open_datetime_lifo]
  df_latest_last_row_open = df_latest_last_row_open[::-1]
  df_latest_last_row_open = df_latest_last_row_open[0:1]
  df_latest_last_row_open.reset_index(inplace=True)
  current_open_index = df_latest_last_row_open.at[0,'index']
  df_latest_last_row_open = df_latest_last_row_open.drop('index', axis=1)
  value_open_units = df_latest_last_row_open.loc[0,'Open Units']
  print('value_close_units:',value_close_units, 'value_open_units:',value_open_units)
  abs_diff_open_close_units = abs(value_close_units - value_open_units)
  print('abs_diff_open_close_units:',abs_diff_open_close_units)
  value_open_amount = df_latest_last_row_open.loc[0,'Open Amount_Eur']
  value_close_amount = df_latest_row_from_close.loc[0,'Amount_close_Eur']
  value_close_spread_eur = df_latest_row_from_close.loc[0,'Spread_Eur']
  close_Rate_eur = df_latest_row_from_close.loc[0,'Close Rate_Eur']
  open_Rate_eur = df_latest_last_row_open.loc[0,'Open Rate_Eur']
  #Remember that 'Open_index' and 'Close_index' columns host original indices
  # This is important as df_open_btc starts to drop rows the original indices will come in handy 
  # And in case of df_close_btc this should remain equal to the indices from DataFrame
  original_open_index = df_latest_last_row_open.at[0, 'Original_Open_index']
  #Remeber that earlier defined close_unit_index is the index of units from df_close_btc DataFrame
  # close_index should essentially be equal in integer value of close_unit_index
  close_index = df_latest_row_from_close.at[0, 'Original_Close_index']
  is_it_equal = close_unit_index == close_index
  print('close_unit_index for current loop is:',close_unit_index)
  print('(close_unit_index = close_index) is:',is_it_equal)
  if value_close_units > value_open_units:
    serial_number_if_loop = serial_number_if_loop + 1
    print('If_loop run number:',serial_number_if_loop)
    #First lets extract all the values from open DF df_latest_last_row_open
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
    df_open_btc = df_open_btc.drop(current_open_index,axis=0)
    #Then reset index and drop the new column 'index' in df_open_btc
    df_open_btc.reset_index(inplace=True)
    df_open_btc = df_open_btc.drop('index',axis=1)
    #Now lets work on the Close_side
    #First define the changed values for df_latest_row_from_close
    changed_value_close_units = value_open_units
    changed_value_close_amount = changed_value_close_units * close_Rate_eur
    changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    df_latest_row_from_close.at[0,'Close Units'] = changed_value_close_units
    df_latest_row_from_close.at[0,'Amount_close_Eur'] = changed_value_close_amount
    df_latest_row_from_close.at[0,'Spread_Eur'] = changed_value_close_spread
    # Now lets extract all the values from df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
    df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('If_loop run number:',serial_number_if_loop,'finished')
  elif value_close_units < value_open_units:
    serial_number_elif_loop_1 = serial_number_elif_loop_1 + 1
    print('Elif_loop_1 run number:', serial_number_elif_loop_1)
    ## First lets extract all the values form close DF df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    #First define the changed values for df_latest_row_from_close
    ## In elif statement changed values are same as we made only one change
    # and after that change the value of units and amount and spread in original df_close_btc
    df_close_btc.at[close_unit_index,'Close Units'] = 0
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = 0
    df_close_btc.at[close_unit_index,'Spread_Eur'] = 0
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    # Now lets extract all the values from df_latest_row_from_close
    ## Now lets work on the values from open DF df_latest_last_row_lifo
    ## Remember we want to get back the values in the df_latest_row_from_close 
    ## we will have to assign changed_values for open_units and open_amount
    changed_value_open_units = value_close_units
    changed_value_open_amount = changed_value_open_units * open_Rate_eur
    print('changed_value_open_units:',changed_value_open_units)
    df_latest_last_row_open.at[0,'Open Units'] = changed_value_open_units
    df_latest_last_row_open.at[0,'Open Amount_Eur'] = changed_value_open_amount
    ##After the values are changed extract the values which will then be reported
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    ## and then this time change the original values in the df_open_units
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_open_btc.at[current_open_index,'Open Units'] = value_open_units - changed_value_open_units
    df_open_btc.at[current_open_index,'Open Amount_Eur'] = value_open_amount - changed_value_open_amount
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_1 run number:', serial_number_elif_loop_1, 'finished')
  elif value_close_units == value_open_units:
    serial_number_elif_loop_2 = serial_number_elif_loop_2 + 1
    if value_close_units == 0:
      print('We are running value_close_units == 0 condition')
      print('This is in the Elif_loop_number_2:',serial_number_elif_loop_2)
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      print('We are breaking')
      break
    else:
      #First lets extract all the values from open DF df_latest_last_row_open
      newth_list_open_half = df_latest_last_row_open.to_dict('records')
      newth_dict_open_half = newth_list_open_half[0]
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      ### Second lets extract all the values form close DF df_latest_row_from_close
      newth_list_close_half = df_latest_row_from_close.to_dict('records')
      newth_dict_close_half = newth_list_close_half[0]
      ## and then this time change the original values in the df_open_units
      newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
      # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
      df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
      #First define the changed values for df_latest_row_from_close
      changed_value_close_units = value_open_units
      changed_value_close_amount = changed_value_close_units * close_Rate_eur
      changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
      # and after that change the value of units and amount in original df_open_btc
      df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
      df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
      df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_2 run number:', serial_number_elif_loop_2, 'finished')
  else:
    serial_number_else_loop = serial_number_else_loop + 1
    print('Do we need to write more code? The answer is a: BIG YES!!')
    print('Or on second thought this is a silly mistake!!!')
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('serial_number_else_loop:', serial_number_else_loop, 'finished')
    print('We are breaking here!!')
    break
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  if value_close_units < 1.0e-10:
    i = 1
  else:
    i = 0
  print('i =',i)
  print('close_unit_index for current loop was:',close_unit_index)
  close_unit_index = close_unit_index + i
  print('close_unit_index for next loop is:',close_unit_index)
  print('Total if loops:',serial_number_if_loop)
  print('Total elif_1 loops:',serial_number_elif_loop_1)
  print('Total elif_2 loops:',serial_number_elif_loop_2)
  print('Total else loops:',serial_number_else_loop)
  print('For loop run number:',serial_number_for_loop,'finished')
  if df_close_btc['Close Units'].sum() < 1.0e-10:
    close_unit_index = final_close_unit_index
  else:
    continue
  print('****************************************')
print('df_lifo_btc sum of open units:',df_lifo_btc['Open Units'].sum())
print('df_lifo_btc sum of close units:',df_lifo_btc['Close Units'].sum())
print('df_open_btc_original sum of open units:',df_open_btc_original['Open Units'].sum())
print('df_close_btc_original sum of close units:',df_close_btc_original['Close Units'].sum())
df_lifo_btc['time_difference'] = df_lifo_btc['Close Datetime'] - df_lifo_btc['Open Datetime']
df_lifo_btc['time_difference_days'] = df_lifo_btc['time_difference'] / np.timedelta64(1, 'D')
df_lifo_btc_taxable = df_lifo_btc[df_lifo_btc['time_difference_days'] < 365]
df_lifo_btc_taxable_2020 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1609455599]
df_lifo_btc_taxable_2020_2021 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1640991599]
df_lifo_btc_taxable_2021 = df_lifo_btc_taxable_2020_2021[df_lifo_btc_taxable_2020_2021['Close_unix_timestamp'] > 1609455599]
df_lifo_btc_taxable_2022 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] > 1640991599]
print('Sum of all open positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Amount_close_Eur'].sum())
# Out:
# For loop run number: 1
# i = 0
# close_unit_datetime: 2021-01-03 20:27:47
# open_datetime_lifo: 2021-01-03 14:32:21
# value_close_units: 1030.927835 value_open_units: 979.911808
# abs_diff_open_close_units: 51.01602700000001
# close_unit_index for current loop is: 0
# (close_unit_index = close_index) is: True
# If_loop run number: 1
# value_close_units: 1030.927835
# value_open_units: 979.911808
# close_unit_index: 0
# If_loop run number: 1 finished
# i = 0
# close_unit_index for current loop was: 0
# close_unit_index for next loop is: 0
# Total if loops: 1
# Total elif_1 loops: 0
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 1 finished
# For loop run number: 2
# i = 0
# close_unit_datetime: 2021-01-03 20:27:47
# open_datetime_lifo: 2021-01-03 12:01:24
# value_close_units: 51.01602700000001 value_open_units: 1030.927835
# abs_diff_open_close_units: 979.911808
# close_unit_index for current loop is: 0
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 1
# changed_value_open_units: 51.01602700000001
# value_close_units: 51.01602700000001
# value_open_units: 1030.927835
# close_unit_index: 0
# Elif_loop_1 run number: 1 finished
# i = 1
# close_unit_index for current loop was: 0
# close_unit_index for next loop is: 1
# Total if loops: 1
# Total elif_1 loops: 1
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 2 finished
# For loop run number: 3
# i = 0
# close_unit_datetime: 2021-01-03 20:27:52
# open_datetime_lifo: 2021-01-03 12:01:24
# value_close_units: 1074.113856 value_open_units: 979.911808
# abs_diff_open_close_units: 94.20204799999999
# close_unit_index for current loop is: 1
# (close_unit_index = close_index) is: True
# If_loop run number: 2
# value_close_units: 1074.113856
# value_open_units: 979.911808
# close_unit_index: 1
# If_loop run number: 2 finished
# i = 0
# close_unit_index for current loop was: 1
# close_unit_index for next loop is: 1
# Total if loops: 2
# Total elif_1 loops: 1
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 3 finished
# For loop run number: 4
# i = 0
# close_unit_datetime: 2021-01-03 20:27:52
# open_datetime_lifo: 2021-01-01 14:13:37
# value_close_units: 94.20204799999999 value_open_units: 2689.618074
# abs_diff_open_close_units: 2595.416026
# close_unit_index for current loop is: 1
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 2
# changed_value_open_units: 94.20204799999999
# value_close_units: 94.20204799999999
# value_open_units: 2689.618074
# close_unit_index: 1
# Elif_loop_1 run number: 2 finished
# i = 1
# close_unit_index for current loop was: 1
# close_unit_index for next loop is: 2
# Total if loops: 2
# Total elif_1 loops: 2
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 4 finished
# For loop run number: 5
# i = 0
# close_unit_datetime: 2021-01-03 20:48:25
# open_datetime_lifo: 2021-01-01 14:13:37
# value_close_units: 979.911808 value_open_units: 2595.416026
# abs_diff_open_close_units: 1615.504218
# close_unit_index for current loop is: 2
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 3
# changed_value_open_units: 979.911808
# value_close_units: 979.911808
# value_open_units: 2595.416026
# close_unit_index: 2
# Elif_loop_1 run number: 3 finished
# i = 1
# close_unit_index for current loop was: 2
# close_unit_index for next loop is: 3
# Total if loops: 2
# Total elif_1 loops: 3
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 5 finished
# For loop run number: 6
# i = 0
# close_unit_datetime: 2021-01-03 20:48:30
# open_datetime_lifo: 2021-01-01 14:13:37
# value_close_units: 2689.618074 value_open_units: 1615.504218
# abs_diff_open_close_units: 1074.113856
# close_unit_index for current loop is: 3
# (close_unit_index = close_index) is: True
# If_loop run number: 3
# value_close_units: 2689.618074
# value_open_units: 1615.504218
# close_unit_index: 3
# If_loop run number: 3 finished
# i = 0
# close_unit_index for current loop was: 3
# close_unit_index for next loop is: 3
# Total if loops: 3
# Total elif_1 loops: 3
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 6 finished
# For loop run number: 7
# i = 0
# close_unit_datetime: 2021-01-03 20:48:30
# open_datetime_lifo: 2021-01-01 08:52:58
# value_close_units: 1074.113856 value_open_units: 554.938957
# abs_diff_open_close_units: 519.174899
# close_unit_index for current loop is: 3
# (close_unit_index = close_index) is: True
# If_loop run number: 4
# value_close_units: 1074.113856
# value_open_units: 554.938957
# close_unit_index: 3
# If_loop run number: 4 finished
# i = 0
# close_unit_index for current loop was: 3
# close_unit_index for next loop is: 3
# Total if loops: 4
# Total elif_1 loops: 3
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 7 finished
# For loop run number: 8
# i = 0
# close_unit_datetime: 2021-01-03 20:48:30
# open_datetime_lifo: 2020-12-31 15:17:08
# value_close_units: 519.174899 value_open_units: 549.450549
# abs_diff_open_close_units: 30.27565000000004
# close_unit_index for current loop is: 3
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 4
# changed_value_open_units: 519.174899
# value_close_units: 519.174899
# value_open_units: 549.450549
# close_unit_index: 3
# Elif_loop_1 run number: 4 finished
# i = 1
# close_unit_index for current loop was: 3
# close_unit_index for next loop is: 4
# Total if loops: 4
# Total elif_1 loops: 4
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 8 finished
# For loop run number: 9
# i = 0
# close_unit_datetime: 2021-01-03 20:48:38
# open_datetime_lifo: 2020-12-31 15:17:08
# value_close_units: 549.450549 value_open_units: 30.27565000000004
# abs_diff_open_close_units: 519.174899
# close_unit_index for current loop is: 4
# (close_unit_index = close_index) is: True
# If_loop run number: 5
# value_close_units: 549.450549
# value_open_units: 30.27565000000004
# close_unit_index: 4
# If_loop run number: 5 finished
# i = 0
# close_unit_index for current loop was: 4
# close_unit_index for next loop is: 4
# Total if loops: 5
# Total elif_1 loops: 4
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 9 finished
# For loop run number: 10
# i = 0
# close_unit_datetime: 2021-01-03 20:48:38
# open_datetime_lifo: 2020-12-30 20:01:26
# value_close_units: 519.174899 value_open_units: 1074.113856
# abs_diff_open_close_units: 554.938957
# close_unit_index for current loop is: 4
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 5
# changed_value_open_units: 519.174899
# value_close_units: 519.174899
# value_open_units: 1074.113856
# close_unit_index: 4
# Elif_loop_1 run number: 5 finished
# i = 1
# close_unit_index for current loop was: 4
# close_unit_index for next loop is: 5
# Total if loops: 5
# Total elif_1 loops: 5
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 10 finished
# For loop run number: 11
# i = 0
# close_unit_datetime: 2021-01-03 20:49:11
# open_datetime_lifo: 2020-12-30 20:01:26
# value_close_units: 554.938957 value_open_units: 554.938957
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 5
# (close_unit_index = close_index) is: True
# value_close_units: 554.938957
# value_open_units: 554.938957
# close_unit_index: 5
# Elif_loop_2 run number: 1 finished
# i = 1
# close_unit_index for current loop was: 5
# close_unit_index for next loop is: 6
# Total if loops: 5
# Total elif_1 loops: 5
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 11 finished
# For loop run number: 12
# i = 0
# close_unit_datetime: 2021-02-02 20:56:41
# open_datetime_lifo: 2021-01-23 20:28:31
# value_close_units: 230.167296 value_open_units: 76.077768
# abs_diff_open_close_units: 154.08952799999997
# close_unit_index for current loop is: 6
# (close_unit_index = close_index) is: True
# If_loop run number: 6
# value_close_units: 230.167296
# value_open_units: 76.077768
# close_unit_index: 6
# If_loop run number: 6 finished
# i = 0
# close_unit_index for current loop was: 6
# close_unit_index for next loop is: 6
# Total if loops: 6
# Total elif_1 loops: 5
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 12 finished
# For loop run number: 13
# i = 0
# close_unit_datetime: 2021-02-02 20:56:41
# open_datetime_lifo: 2021-01-21 09:46:23
# value_close_units: 154.08952799999997 value_open_units: 242.467311
# abs_diff_open_close_units: 88.37778300000002
# close_unit_index for current loop is: 6
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 6
# changed_value_open_units: 154.08952799999997
# value_close_units: 154.08952799999997
# value_open_units: 242.467311
# close_unit_index: 6
# Elif_loop_1 run number: 6 finished
# i = 1
# close_unit_index for current loop was: 6
# close_unit_index for next loop is: 7
# Total if loops: 6
# Total elif_1 loops: 6
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 13 finished
# For loop run number: 14
# i = 0
# close_unit_datetime: 2021-02-02 20:56:49
# open_datetime_lifo: 2021-01-21 09:46:23
# value_close_units: 68.119891 value_open_units: 88.37778300000002
# abs_diff_open_close_units: 20.257892000000027
# close_unit_index for current loop is: 7
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 7
# changed_value_open_units: 68.119891
# value_close_units: 68.119891
# value_open_units: 88.37778300000002
# close_unit_index: 7
# Elif_loop_1 run number: 7 finished
# i = 1
# close_unit_index for current loop was: 7
# close_unit_index for next loop is: 8
# Total if loops: 6
# Total elif_1 loops: 7
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 14 finished
# For loop run number: 15
# i = 0
# close_unit_datetime: 2021-02-02 20:56:56
# open_datetime_lifo: 2021-01-21 09:46:23
# value_close_units: 76.077768 value_open_units: 20.257892000000027
# abs_diff_open_close_units: 55.81987599999998
# close_unit_index for current loop is: 8
# (close_unit_index = close_index) is: True
# If_loop run number: 7
# value_close_units: 76.077768
# value_open_units: 20.257892000000027
# close_unit_index: 8
# If_loop run number: 7 finished
# i = 0
# close_unit_index for current loop was: 8
# close_unit_index for next loop is: 8
# Total if loops: 7
# Total elif_1 loops: 7
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 15 finished
# For loop run number: 16
# i = 0
# close_unit_datetime: 2021-02-02 20:56:56
# open_datetime_lifo: 2021-01-21 06:44:52
# value_close_units: 55.81987599999998 value_open_units: 230.167296
# abs_diff_open_close_units: 174.34742
# close_unit_index for current loop is: 8
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 8
# changed_value_open_units: 55.81987599999998
# value_close_units: 55.81987599999998
# value_open_units: 230.167296
# close_unit_index: 8
# Elif_loop_1 run number: 8 finished
# i = 1
# close_unit_index for current loop was: 8
# close_unit_index for next loop is: 9
# Total if loops: 7
# Total elif_1 loops: 8
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 16 finished
# For loop run number: 17
# i = 0
# close_unit_datetime: 2021-02-20 01:35:47
# open_datetime_lifo: 2021-02-15 07:44:22
# value_close_units: 273.224044 value_open_units: 29.705323
# abs_diff_open_close_units: 243.518721
# close_unit_index for current loop is: 9
# (close_unit_index = close_index) is: True
# If_loop run number: 8
# value_close_units: 273.224044
# value_open_units: 29.705323
# close_unit_index: 9
# If_loop run number: 8 finished
# i = 0
# close_unit_index for current loop was: 9
# close_unit_index for next loop is: 9
# Total if loops: 8
# Total elif_1 loops: 8
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 17 finished
# For loop run number: 18
# i = 0
# close_unit_datetime: 2021-02-20 01:35:47
# open_datetime_lifo: 2021-02-14 10:09:57
# value_close_units: 243.518721 value_open_units: 119.526363
# abs_diff_open_close_units: 123.992358
# close_unit_index for current loop is: 9
# (close_unit_index = close_index) is: True
# If_loop run number: 9
# value_close_units: 243.518721
# value_open_units: 119.526363
# close_unit_index: 9
# If_loop run number: 9 finished
# i = 0
# close_unit_index for current loop was: 9
# close_unit_index for next loop is: 9
# Total if loops: 9
# Total elif_1 loops: 8
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 18 finished
# For loop run number: 19
# i = 0
# close_unit_datetime: 2021-02-20 01:35:47
# open_datetime_lifo: 2021-02-12 20:46:46
# value_close_units: 123.992358 value_open_units: 693.257239
# abs_diff_open_close_units: 569.2648810000001
# close_unit_index for current loop is: 9
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 9
# changed_value_open_units: 123.992358
# value_close_units: 123.992358
# value_open_units: 693.257239
# close_unit_index: 9
# Elif_loop_1 run number: 9 finished
# i = 1
# close_unit_index for current loop was: 9
# close_unit_index for next loop is: 10
# Total if loops: 9
# Total elif_1 loops: 9
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 19 finished
# For loop run number: 20
# i = 0
# close_unit_datetime: 2021-02-20 01:36:18
# open_datetime_lifo: 2021-02-12 20:46:46
# value_close_units: 268.817204 value_open_units: 569.2648810000001
# abs_diff_open_close_units: 300.44767700000006
# close_unit_index for current loop is: 10
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 10
# changed_value_open_units: 268.817204
# value_close_units: 268.817204
# value_open_units: 569.2648810000001
# close_unit_index: 10
# Elif_loop_1 run number: 10 finished
# i = 1
# close_unit_index for current loop was: 10
# close_unit_index for next loop is: 11
# Total if loops: 9
# Total elif_1 loops: 10
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 20 finished
# For loop run number: 21
# i = 0
# close_unit_datetime: 2021-02-20 01:37:46
# open_datetime_lifo: 2021-02-12 20:46:46
# value_close_units: 265.957447 value_open_units: 300.44767700000006
# abs_diff_open_close_units: 34.490230000000054
# close_unit_index for current loop is: 11
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 11
# changed_value_open_units: 265.957447
# value_close_units: 265.957447
# value_open_units: 300.44767700000006
# close_unit_index: 11
# Elif_loop_1 run number: 11 finished
# i = 1
# close_unit_index for current loop was: 11
# close_unit_index for next loop is: 12
# Total if loops: 9
# Total elif_1 loops: 11
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 21 finished
# For loop run number: 22
# i = 0
# close_unit_datetime: 2021-02-20 01:39:05
# open_datetime_lifo: 2021-02-12 20:46:46
# value_close_units: 255.885363 value_open_units: 34.490230000000054
# abs_diff_open_close_units: 221.39513299999996
# close_unit_index for current loop is: 12
# (close_unit_index = close_index) is: True
# If_loop run number: 10
# value_close_units: 255.885363
# value_open_units: 34.490230000000054
# close_unit_index: 12
# If_loop run number: 10 finished
# i = 0
# close_unit_index for current loop was: 12
# close_unit_index for next loop is: 12
# Total if loops: 10
# Total elif_1 loops: 11
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 22 finished
# For loop run number: 23
# i = 0
# close_unit_datetime: 2021-02-20 01:39:05
# open_datetime_lifo: 2021-02-12 20:46:46
# value_close_units: 221.39513299999996 value_open_units: 373.864733
# abs_diff_open_close_units: 152.46960000000004
# close_unit_index for current loop is: 12
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 12
# changed_value_open_units: 221.39513299999996
# value_close_units: 221.39513299999996
# value_open_units: 373.864733
# close_unit_index: 12
# Elif_loop_1 run number: 12 finished
# i = 1
# close_unit_index for current loop was: 12
# close_unit_index for next loop is: 13
# Total if loops: 10
# Total elif_1 loops: 12
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 23 finished
# For loop run number: 24
# i = 0
# close_unit_datetime: 2021-03-19 14:15:56
# open_datetime_lifo: 2021-03-11 08:54:36
# value_close_units: 531.386177 value_open_units: 62.258714
# abs_diff_open_close_units: 469.127463
# close_unit_index for current loop is: 13
# (close_unit_index = close_index) is: True
# If_loop run number: 11
# value_close_units: 531.386177
# value_open_units: 62.258714
# close_unit_index: 13
# If_loop run number: 11 finished
# i = 0
# close_unit_index for current loop was: 13
# close_unit_index for next loop is: 13
# Total if loops: 11
# Total elif_1 loops: 12
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 24 finished
# For loop run number: 25
# i = 0
# close_unit_datetime: 2021-03-19 14:15:56
# open_datetime_lifo: 2021-02-26 20:42:37
# value_close_units: 469.127463 value_open_units: 532.800877
# abs_diff_open_close_units: 63.67341400000004
# close_unit_index for current loop is: 13
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 13
# changed_value_open_units: 469.127463
# value_close_units: 469.127463
# value_open_units: 532.800877
# close_unit_index: 13
# Elif_loop_1 run number: 13 finished
# i = 1
# close_unit_index for current loop was: 13
# close_unit_index for next loop is: 14
# Total if loops: 11
# Total elif_1 loops: 13
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 25 finished
# For loop run number: 26
# i = 0
# close_unit_datetime: 2021-03-19 14:16:00
# open_datetime_lifo: 2021-02-26 20:42:37
# value_close_units: 532.800877 value_open_units: 63.67341400000004
# abs_diff_open_close_units: 469.127463
# close_unit_index for current loop is: 14
# (close_unit_index = close_index) is: True
# If_loop run number: 12
# value_close_units: 532.800877
# value_open_units: 63.67341400000004
# close_unit_index: 14
# If_loop run number: 12 finished
# i = 0
# close_unit_index for current loop was: 14
# close_unit_index for next loop is: 14
# Total if loops: 12
# Total elif_1 loops: 13
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 26 finished
# For loop run number: 27
# i = 0
# close_unit_datetime: 2021-03-19 14:16:00
# open_datetime_lifo: 2021-02-26 20:42:20
# value_close_units: 469.127463 value_open_units: 531.386177
# abs_diff_open_close_units: 62.258714
# close_unit_index for current loop is: 14
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 14
# changed_value_open_units: 469.127463
# value_close_units: 469.127463
# value_open_units: 531.386177
# close_unit_index: 14
# Elif_loop_1 run number: 14 finished
# i = 1
# close_unit_index for current loop was: 14
# close_unit_index for next loop is: 15
# Total if loops: 12
# Total elif_1 loops: 14
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 27 finished
# For loop run number: 28
# i = 0
# close_unit_datetime: 2021-03-19 14:16:03
# open_datetime_lifo: 2021-02-26 20:42:20
# value_close_units: 537.250099 value_open_units: 62.258714
# abs_diff_open_close_units: 474.991385
# close_unit_index for current loop is: 15
# (close_unit_index = close_index) is: True
# If_loop run number: 13
# value_close_units: 537.250099
# value_open_units: 62.258714
# close_unit_index: 15
# If_loop run number: 13 finished
# i = 0
# close_unit_index for current loop was: 15
# close_unit_index for next loop is: 15
# Total if loops: 13
# Total elif_1 loops: 14
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 28 finished
# For loop run number: 29
# i = 0
# close_unit_datetime: 2021-03-19 14:16:03
# open_datetime_lifo: 2021-02-26 20:37:07
# value_close_units: 474.991385 value_open_units: 537.250099
# abs_diff_open_close_units: 62.258714
# close_unit_index for current loop is: 15
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 15
# changed_value_open_units: 474.991385
# value_close_units: 474.991385
# value_open_units: 537.250099
# close_unit_index: 15
# Elif_loop_1 run number: 15 finished
# i = 1
# close_unit_index for current loop was: 15
# close_unit_index for next loop is: 16
# Total if loops: 13
# Total elif_1 loops: 15
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 29 finished
# For loop run number: 30
# i = 0
# close_unit_datetime: 2021-03-19 14:18:03
# open_datetime_lifo: 2021-02-26 20:37:07
# value_close_units: 865.576041 value_open_units: 62.258714
# abs_diff_open_close_units: 803.317327
# close_unit_index for current loop is: 16
# (close_unit_index = close_index) is: True
# If_loop run number: 14
# value_close_units: 865.576041
# value_open_units: 62.258714
# close_unit_index: 16
# If_loop run number: 14 finished
# i = 0
# close_unit_index for current loop was: 16
# close_unit_index for next loop is: 16
# Total if loops: 14
# Total elif_1 loops: 15
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 30 finished
# For loop run number: 31
# i = 0
# close_unit_datetime: 2021-03-19 14:18:03
# open_datetime_lifo: 2021-02-20 14:06:26
# value_close_units: 803.317327 value_open_units: 865.576041
# abs_diff_open_close_units: 62.258714000000055
# close_unit_index for current loop is: 16
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 16
# changed_value_open_units: 803.317327
# value_close_units: 803.317327
# value_open_units: 865.576041
# close_unit_index: 16
# Elif_loop_1 run number: 16 finished
# i = 1
# close_unit_index for current loop was: 16
# close_unit_index for next loop is: 17
# Total if loops: 14
# Total elif_1 loops: 16
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 31 finished
# For loop run number: 32
# i = 0
# close_unit_datetime: 2021-03-19 14:19:31
# open_datetime_lifo: 2021-02-20 14:06:26
# value_close_units: 62.258714 value_open_units: 62.258714000000055
# abs_diff_open_close_units: 5.684341886080802e-14
# close_unit_index for current loop is: 17
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 17
# changed_value_open_units: 62.258714
# value_close_units: 62.258714
# value_open_units: 62.258714000000055
# close_unit_index: 17
# Elif_loop_1 run number: 17 finished
# i = 1
# close_unit_index for current loop was: 17
# close_unit_index for next loop is: 18
# Total if loops: 14
# Total elif_1 loops: 17
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 32 finished
# For loop run number: 33
# i = 0
# close_unit_datetime: 2021-03-19 14:19:38
# open_datetime_lifo: 2021-02-20 14:06:26
# value_close_units: 182.223122 value_open_units: 5.684341886080802e-14
# abs_diff_open_close_units: 182.22312199999993
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# If_loop run number: 15
# value_close_units: 182.223122
# value_open_units: 5.684341886080802e-14
# close_unit_index: 18
# If_loop run number: 15 finished
# i = 0
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 18
# Total if loops: 15
# Total elif_1 loops: 17
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 33 finished
# For loop run number: 34
# i = 0
# close_unit_datetime: 2021-03-19 14:19:38
# open_datetime_lifo: 2021-02-12 20:46:46
# value_close_units: 182.22312199999993 value_open_units: 152.46960000000004
# abs_diff_open_close_units: 29.75352199999989
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# If_loop run number: 16
# value_close_units: 182.22312199999993
# value_open_units: 152.46960000000004
# close_unit_index: 18
# If_loop run number: 16 finished
# i = 0
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 18
# Total if loops: 16
# Total elif_1 loops: 17
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 34 finished
# For loop run number: 35
# i = 0
# close_unit_datetime: 2021-03-19 14:19:38
# open_datetime_lifo: 2021-02-12 20:28:47
# value_close_units: 29.75352199999989 value_open_units: 26.618399
# abs_diff_open_close_units: 3.13512299999989
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# If_loop run number: 17
# value_close_units: 29.75352199999989
# value_open_units: 26.618399
# close_unit_index: 18
# If_loop run number: 17 finished
# i = 0
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 18
# Total if loops: 17
# Total elif_1 loops: 17
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 35 finished
# For loop run number: 36
# i = 0
# close_unit_datetime: 2021-03-19 14:19:38
# open_datetime_lifo: 2021-02-11 17:20:22
# value_close_units: 3.13512299999989 value_open_units: 182.223122
# abs_diff_open_close_units: 179.0879990000001
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 18
# changed_value_open_units: 3.13512299999989
# value_close_units: 3.13512299999989
# value_open_units: 182.223122
# close_unit_index: 18
# Elif_loop_1 run number: 18 finished
# i = 1
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 19
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 36 finished
# For loop run number: 37
# i = 0
# close_unit_datetime: 2021-03-19 14:19:46
# open_datetime_lifo: 2021-02-11 17:20:22
# value_close_units: 26.618399 value_open_units: 179.0879990000001
# abs_diff_open_close_units: 152.4696000000001
# close_unit_index for current loop is: 19
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 19
# changed_value_open_units: 26.618399
# value_close_units: 26.618399
# value_open_units: 179.0879990000001
# close_unit_index: 19
# Elif_loop_1 run number: 19 finished
# i = 1
# close_unit_index for current loop was: 19
# close_unit_index for next loop is: 20
# Total if loops: 17
# Total elif_1 loops: 19
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 37 finished
# For loop run number: 38
# i = 0
# close_unit_datetime: 2021-03-19 14:21:37
# open_datetime_lifo: 2021-02-11 17:20:22
# value_close_units: 373.864733 value_open_units: 152.4696000000001
# abs_diff_open_close_units: 221.3951329999999
# close_unit_index for current loop is: 20
# (close_unit_index = close_index) is: True
# If_loop run number: 18
# value_close_units: 373.864733
# value_open_units: 152.4696000000001
# close_unit_index: 20
# If_loop run number: 18 finished
# i = 0
# close_unit_index for current loop was: 20
# close_unit_index for next loop is: 20
# Total if loops: 18
# Total elif_1 loops: 19
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 38 finished
# For loop run number: 39
# i = 0
# close_unit_datetime: 2021-03-19 14:21:37
# open_datetime_lifo: 2021-02-11 13:24:22
# value_close_units: 221.3951329999999 value_open_units: 45.221419
# abs_diff_open_close_units: 176.1737139999999
# close_unit_index for current loop is: 20
# (close_unit_index = close_index) is: True
# If_loop run number: 19
# value_close_units: 221.3951329999999
# value_open_units: 45.221419
# close_unit_index: 20
# If_loop run number: 19 finished
# i = 0
# close_unit_index for current loop was: 20
# close_unit_index for next loop is: 20
# Total if loops: 19
# Total elif_1 loops: 19
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 39 finished
# For loop run number: 40
# i = 0
# close_unit_datetime: 2021-03-19 14:21:37
# open_datetime_lifo: 2021-01-21 06:44:52
# value_close_units: 176.1737139999999 value_open_units: 174.34742
# abs_diff_open_close_units: 1.8262939999999048
# close_unit_index for current loop is: 20
# (close_unit_index = close_index) is: True
# If_loop run number: 20
# value_close_units: 176.1737139999999
# value_open_units: 174.34742
# close_unit_index: 20
# If_loop run number: 20 finished
# i = 0
# close_unit_index for current loop was: 20
# close_unit_index for next loop is: 20
# Total if loops: 20
# Total elif_1 loops: 19
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 40 finished
# For loop run number: 41
# i = 0
# close_unit_datetime: 2021-03-19 14:21:37
# open_datetime_lifo: 2021-01-20 10:12:21
# value_close_units: 1.8262939999999048 value_open_units: 242.742167
# abs_diff_open_close_units: 240.9158730000001
# close_unit_index for current loop is: 20
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 20
# changed_value_open_units: 1.8262939999999048
# value_close_units: 1.8262939999999048
# value_open_units: 242.742167
# close_unit_index: 20
# Elif_loop_1 run number: 20 finished
# i = 1
# close_unit_index for current loop was: 20
# close_unit_index for next loop is: 21
# Total if loops: 20
# Total elif_1 loops: 20
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 41 finished
# For loop run number: 42
# i = 0
# close_unit_datetime: 2021-04-14 08:28:28
# open_datetime_lifo: 2021-04-08 09:33:18
# value_close_units: 720.461095 value_open_units: 56.460644
# abs_diff_open_close_units: 664.000451
# close_unit_index for current loop is: 21
# (close_unit_index = close_index) is: True
# If_loop run number: 21
# value_close_units: 720.461095
# value_open_units: 56.460644
# close_unit_index: 21
# If_loop run number: 21 finished
# i = 0
# close_unit_index for current loop was: 21
# close_unit_index for next loop is: 21
# Total if loops: 21
# Total elif_1 loops: 20
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 42 finished
# For loop run number: 43
# i = 0
# close_unit_datetime: 2021-04-14 08:28:28
# open_datetime_lifo: 2021-01-20 10:12:21
# value_close_units: 664.000451 value_open_units: 240.9158730000001
# abs_diff_open_close_units: 423.0845779999999
# close_unit_index for current loop is: 21
# (close_unit_index = close_index) is: True
# If_loop run number: 22
# value_close_units: 664.000451
# value_open_units: 240.9158730000001
# close_unit_index: 21
# If_loop run number: 22 finished
# i = 0
# close_unit_index for current loop was: 21
# close_unit_index for next loop is: 21
# Total if loops: 22
# Total elif_1 loops: 20
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 43 finished
# For loop run number: 44
# i = 0
# close_unit_datetime: 2021-04-14 08:28:28
# open_datetime_lifo: 2021-01-16 15:39:05
# value_close_units: 423.0845779999999 value_open_units: 68.119891
# abs_diff_open_close_units: 354.9646869999999
# close_unit_index for current loop is: 21
# (close_unit_index = close_index) is: True
# If_loop run number: 23
# value_close_units: 423.0845779999999
# value_open_units: 68.119891
# close_unit_index: 21
# If_loop run number: 23 finished
# i = 0
# close_unit_index for current loop was: 21
# close_unit_index for next loop is: 21
# Total if loops: 23
# Total elif_1 loops: 20
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 44 finished
# For loop run number: 45
# i = 0
# close_unit_datetime: 2021-04-14 08:28:28
# open_datetime_lifo: 2021-01-15 14:39:40
# value_close_units: 354.9646869999999 value_open_units: 2746.953175
# abs_diff_open_close_units: 2391.988488
# close_unit_index for current loop is: 21
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 21
# changed_value_open_units: 354.9646869999999
# value_close_units: 354.9646869999999
# value_open_units: 2746.953175
# close_unit_index: 21
# Elif_loop_1 run number: 21 finished
# i = 1
# close_unit_index for current loop was: 21
# close_unit_index for next loop is: 22
# Total if loops: 23
# Total elif_1 loops: 21
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 45 finished
# For loop run number: 46
# i = 0
# close_unit_datetime: 2021-05-11 13:27:05
# open_datetime_lifo: 2021-05-10 20:10:44
# value_close_units: 101.91627 value_open_units: 101.91627
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 22
# (close_unit_index = close_index) is: True
# value_close_units: 101.91627
# value_open_units: 101.91627
# close_unit_index: 22
# Elif_loop_2 run number: 2 finished
# i = 1
# close_unit_index for current loop was: 22
# close_unit_index for next loop is: 23
# Total if loops: 23
# Total elif_1 loops: 21
# Total elif_2 loops: 2
# Total else loops: 0
# For loop run number: 46 finished
# For loop run number: 47
# i = 0
# close_unit_datetime: 2021-05-11 13:27:10
# open_datetime_lifo: 2021-05-10 09:24:04
# value_close_units: 56.460644 value_open_units: 69.99
# abs_diff_open_close_units: 13.529355999999993
# close_unit_index for current loop is: 23
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 22
# changed_value_open_units: 56.460644
# value_close_units: 56.460644
# value_open_units: 69.99
# close_unit_index: 23
# Elif_loop_1 run number: 22 finished
# i = 1
# close_unit_index for current loop was: 23
# close_unit_index for next loop is: 24
# Total if loops: 23
# Total elif_1 loops: 22
# Total elif_2 loops: 2
# Total else loops: 0
# For loop run number: 47 finished
# For loop run number: 48
# i = 0
# close_unit_datetime: 2021-05-11 13:27:17
# open_datetime_lifo: 2021-05-10 09:24:04
# value_close_units: 1273.344652 value_open_units: 13.529355999999993
# abs_diff_open_close_units: 1259.815296
# close_unit_index for current loop is: 24
# (close_unit_index = close_index) is: True
# If_loop run number: 24
# value_close_units: 1273.344652
# value_open_units: 13.529355999999993
# close_unit_index: 24
# If_loop run number: 24 finished
# i = 0
# close_unit_index for current loop was: 24
# close_unit_index for next loop is: 24
# Total if loops: 24
# Total elif_1 loops: 22
# Total elif_2 loops: 2
# Total else loops: 0
# For loop run number: 48 finished
# For loop run number: 49
# i = 0
# close_unit_datetime: 2021-05-11 13:27:17
# open_datetime_lifo: 2021-04-23 09:21:28
# value_close_units: 1259.815296 value_open_units: 1451.23839
# abs_diff_open_close_units: 191.423094
# close_unit_index for current loop is: 24
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 23
# changed_value_open_units: 1259.815296
# value_close_units: 1259.815296
# value_open_units: 1451.23839
# close_unit_index: 24
# Elif_loop_1 run number: 23 finished
# i = 1
# close_unit_index for current loop was: 24
# close_unit_index for next loop is: 25
# Total if loops: 24
# Total elif_1 loops: 23
# Total elif_2 loops: 2
# Total else loops: 0
# For loop run number: 49 finished
# For loop run number: 50
# i = 0
# close_unit_datetime: 2021-05-13 18:44:56
# open_datetime_lifo: 2021-05-12 04:30:34
# value_close_units: 1210.387324 value_open_units: 1210.387324
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 25
# (close_unit_index = close_index) is: True
# value_close_units: 1210.387324
# value_open_units: 1210.387324
# close_unit_index: 25
# Elif_loop_2 run number: 3 finished
# i = 1
# close_unit_index for current loop was: 25
# close_unit_index for next loop is: 26
# Total if loops: 24
# Total elif_1 loops: 23
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 50 finished
# For loop run number: 51
# i = 0
# close_unit_datetime: 2021-08-17 05:42:50
# open_datetime_lifo: 2021-08-09 08:52:25
# value_close_units: 473.821369 value_open_units: 85.448815
# abs_diff_open_close_units: 388.37255400000004
# close_unit_index for current loop is: 26
# (close_unit_index = close_index) is: True
# If_loop run number: 25
# value_close_units: 473.821369
# value_open_units: 85.448815
# close_unit_index: 26
# If_loop run number: 25 finished
# i = 0
# close_unit_index for current loop was: 26
# close_unit_index for next loop is: 26
# Total if loops: 25
# Total elif_1 loops: 23
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 51 finished
# For loop run number: 52
# i = 0
# close_unit_datetime: 2021-08-17 05:42:50
# open_datetime_lifo: 2021-07-28 10:58:55
# value_close_units: 388.37255400000004 value_open_units: 81.60736
# abs_diff_open_close_units: 306.76519400000006
# close_unit_index for current loop is: 26
# (close_unit_index = close_index) is: True
# If_loop run number: 26
# value_close_units: 388.37255400000004
# value_open_units: 81.60736
# close_unit_index: 26
# If_loop run number: 26 finished
# i = 0
# close_unit_index for current loop was: 26
# close_unit_index for next loop is: 26
# Total if loops: 26
# Total elif_1 loops: 23
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 52 finished
# For loop run number: 53
# i = 0
# close_unit_datetime: 2021-08-17 05:42:50
# open_datetime_lifo: 2021-05-22 05:57:54
# value_close_units: 306.76519400000006 value_open_units: 68.549493
# abs_diff_open_close_units: 238.21570100000008
# close_unit_index for current loop is: 26
# (close_unit_index = close_index) is: True
# If_loop run number: 27
# value_close_units: 306.76519400000006
# value_open_units: 68.549493
# close_unit_index: 26
# If_loop run number: 27 finished
# i = 0
# close_unit_index for current loop was: 26
# close_unit_index for next loop is: 26
# Total if loops: 27
# Total elif_1 loops: 23
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 53 finished
# For loop run number: 54
# i = 0
# close_unit_datetime: 2021-08-17 05:42:50
# open_datetime_lifo: 2021-05-20 16:39:19
# value_close_units: 238.21570100000008 value_open_units: 57.329588
# abs_diff_open_close_units: 180.88611300000008
# close_unit_index for current loop is: 26
# (close_unit_index = close_index) is: True
# If_loop run number: 28
# value_close_units: 238.21570100000008
# value_open_units: 57.329588
# close_unit_index: 26
# If_loop run number: 28 finished
# i = 0
# close_unit_index for current loop was: 26
# close_unit_index for next loop is: 26
# Total if loops: 28
# Total elif_1 loops: 23
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 54 finished
# For loop run number: 55
# i = 0
# close_unit_datetime: 2021-08-17 05:42:50
# open_datetime_lifo: 2021-05-20 07:31:30
# value_close_units: 180.88611300000008 value_open_units: 57.019044
# abs_diff_open_close_units: 123.86706900000007
# close_unit_index for current loop is: 26
# (close_unit_index = close_index) is: True
# If_loop run number: 29
# value_close_units: 180.88611300000008
# value_open_units: 57.019044
# close_unit_index: 26
# If_loop run number: 29 finished
# i = 0
# close_unit_index for current loop was: 26
# close_unit_index for next loop is: 26
# Total if loops: 29
# Total elif_1 loops: 23
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 55 finished
# For loop run number: 56
# i = 0
# close_unit_datetime: 2021-08-17 05:42:50
# open_datetime_lifo: 2021-05-19 21:19:17
# value_close_units: 123.86706900000007 value_open_units: 67.50827
# abs_diff_open_close_units: 56.358799000000076
# close_unit_index for current loop is: 26
# (close_unit_index = close_index) is: True
# If_loop run number: 30
# value_close_units: 123.86706900000007
# value_open_units: 67.50827
# close_unit_index: 26
# If_loop run number: 30 finished
# i = 0
# close_unit_index for current loop was: 26
# close_unit_index for next loop is: 26
# Total if loops: 30
# Total elif_1 loops: 23
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 56 finished
# For loop run number: 57
# i = 0
# close_unit_datetime: 2021-08-17 05:42:50
# open_datetime_lifo: 2021-05-19 19:53:15
# value_close_units: 56.358799000000076 value_open_units: 61.079892
# abs_diff_open_close_units: 4.721092999999925
# close_unit_index for current loop is: 26
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 24
# changed_value_open_units: 56.358799000000076
# value_close_units: 56.358799000000076
# value_open_units: 61.079892
# close_unit_index: 26
# Elif_loop_1 run number: 24 finished
# i = 1
# close_unit_index for current loop was: 26
# close_unit_index for next loop is: 27
# Total if loops: 30
# Total elif_1 loops: 24
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 57 finished
# For loop run number: 58
# i = 0
# close_unit_datetime: 2021-08-17 05:42:54
# open_datetime_lifo: 2021-05-19 19:53:15
# value_close_units: 480.561296 value_open_units: 4.721092999999925
# abs_diff_open_close_units: 475.8402030000001
# close_unit_index for current loop is: 27
# (close_unit_index = close_index) is: True
# If_loop run number: 31
# value_close_units: 480.561296
# value_open_units: 4.721092999999925
# close_unit_index: 27
# If_loop run number: 31 finished
# i = 0
# close_unit_index for current loop was: 27
# close_unit_index for next loop is: 27
# Total if loops: 31
# Total elif_1 loops: 24
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 58 finished
# For loop run number: 59
# i = 0
# close_unit_datetime: 2021-08-17 05:42:54
# open_datetime_lifo: 2021-05-19 16:39:30
# value_close_units: 475.8402030000001 value_open_units: 571.134845
# abs_diff_open_close_units: 95.29464199999995
# close_unit_index for current loop is: 27
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 25
# changed_value_open_units: 475.8402030000001
# value_close_units: 475.8402030000001
# value_open_units: 571.134845
# close_unit_index: 27
# Elif_loop_1 run number: 25 finished
# i = 1
# close_unit_index for current loop was: 27
# close_unit_index for next loop is: 28
# Total if loops: 31
# Total elif_1 loops: 25
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 59 finished
# For loop run number: 60
# i = 0
# close_unit_datetime: 2021-08-17 05:42:59
# open_datetime_lifo: 2021-05-19 16:39:30
# value_close_units: 280.03876 value_open_units: 95.29464199999995
# abs_diff_open_close_units: 184.74411800000007
# close_unit_index for current loop is: 28
# (close_unit_index = close_index) is: True
# If_loop run number: 32
# value_close_units: 280.03876
# value_open_units: 95.29464199999995
# close_unit_index: 28
# If_loop run number: 32 finished
# i = 0
# close_unit_index for current loop was: 28
# close_unit_index for next loop is: 28
# Total if loops: 32
# Total elif_1 loops: 25
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 60 finished
# For loop run number: 61
# i = 0
# close_unit_datetime: 2021-08-17 05:42:59
# open_datetime_lifo: 2021-05-18 19:59:21
# value_close_units: 184.74411800000007 value_open_units: 280.03876
# abs_diff_open_close_units: 95.29464199999995
# close_unit_index for current loop is: 28
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 26
# changed_value_open_units: 184.74411800000007
# value_close_units: 184.74411800000007
# value_open_units: 280.03876
# close_unit_index: 28
# Elif_loop_1 run number: 26 finished
# i = 1
# close_unit_index for current loop was: 28
# close_unit_index for next loop is: 29
# Total if loops: 32
# Total elif_1 loops: 26
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 61 finished
# For loop run number: 62
# i = 0
# close_unit_datetime: 2021-08-17 05:43:59
# open_datetime_lifo: 2021-05-18 19:59:21
# value_close_units: 1207.419206 value_open_units: 95.29464199999995
# abs_diff_open_close_units: 1112.1245640000002
# close_unit_index for current loop is: 29
# (close_unit_index = close_index) is: True
# If_loop run number: 33
# value_close_units: 1207.419206
# value_open_units: 95.29464199999995
# close_unit_index: 29
# If_loop run number: 33 finished
# i = 0
# close_unit_index for current loop was: 29
# close_unit_index for next loop is: 29
# Total if loops: 33
# Total elif_1 loops: 26
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 62 finished
# For loop run number: 63
# i = 0
# close_unit_datetime: 2021-08-17 05:43:59
# open_datetime_lifo: 2021-05-17 21:21:44
# value_close_units: 1112.1245640000002 value_open_units: 473.821369
# abs_diff_open_close_units: 638.3031950000002
# close_unit_index for current loop is: 29
# (close_unit_index = close_index) is: True
# If_loop run number: 34
# value_close_units: 1112.1245640000002
# value_open_units: 473.821369
# close_unit_index: 29
# If_loop run number: 34 finished
# i = 0
# close_unit_index for current loop was: 29
# close_unit_index for next loop is: 29
# Total if loops: 34
# Total elif_1 loops: 26
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 63 finished
# For loop run number: 64
# i = 0
# close_unit_datetime: 2021-08-17 05:43:59
# open_datetime_lifo: 2021-05-17 16:26:00
# value_close_units: 638.3031950000002 value_open_units: 480.561296
# abs_diff_open_close_units: 157.74189900000016
# close_unit_index for current loop is: 29
# (close_unit_index = close_index) is: True
# If_loop run number: 35
# value_close_units: 638.3031950000002
# value_open_units: 480.561296
# close_unit_index: 29
# If_loop run number: 35 finished
# i = 0
# close_unit_index for current loop was: 29
# close_unit_index for next loop is: 29
# Total if loops: 35
# Total elif_1 loops: 26
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 64 finished
# For loop run number: 65
# i = 0
# close_unit_datetime: 2021-08-17 05:43:59
# open_datetime_lifo: 2021-05-14 19:40:30
# value_close_units: 157.74189900000016 value_open_units: 1207.419206
# abs_diff_open_close_units: 1049.677307
# close_unit_index for current loop is: 29
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 27
# changed_value_open_units: 157.74189900000016
# value_close_units: 157.74189900000016
# value_open_units: 1207.419206
# close_unit_index: 29
# Elif_loop_1 run number: 27 finished
# i = 1
# close_unit_index for current loop was: 29
# close_unit_index for next loop is: 30
# Total if loops: 35
# Total elif_1 loops: 27
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 65 finished
# For loop run number: 66
# i = 0
# close_unit_datetime: 2021-08-22 16:26:25
# open_datetime_lifo: 2021-05-14 19:40:30
# value_close_units: 69.99 value_open_units: 1049.677307
# abs_diff_open_close_units: 979.6873069999999
# close_unit_index for current loop is: 30
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 28
# changed_value_open_units: 69.99
# value_close_units: 69.99
# value_open_units: 1049.677307
# close_unit_index: 30
# Elif_loop_1 run number: 28 finished
# i = 1
# close_unit_index for current loop was: 30
# close_unit_index for next loop is: 31
# Total if loops: 35
# Total elif_1 loops: 28
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 66 finished
# For loop run number: 67
# i = 0
# close_unit_datetime: 2021-08-22 16:26:55
# open_datetime_lifo: 2021-05-14 19:40:30
# value_close_units: 57.019044 value_open_units: 979.6873069999999
# abs_diff_open_close_units: 922.6682629999999
# close_unit_index for current loop is: 31
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 29
# changed_value_open_units: 57.019044
# value_close_units: 57.019044
# value_open_units: 979.6873069999999
# close_unit_index: 31
# Elif_loop_1 run number: 29 finished
# i = 1
# close_unit_index for current loop was: 31
# close_unit_index for next loop is: 32
# Total if loops: 35
# Total elif_1 loops: 29
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 67 finished
# For loop run number: 68
# i = 0
# close_unit_datetime: 2021-08-22 16:27:09
# open_datetime_lifo: 2021-05-14 19:40:30
# value_close_units: 571.134845 value_open_units: 922.6682629999999
# abs_diff_open_close_units: 351.53341799999987
# close_unit_index for current loop is: 32
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 30
# changed_value_open_units: 571.134845
# value_close_units: 571.134845
# value_open_units: 922.6682629999999
# close_unit_index: 32
# Elif_loop_1 run number: 30 finished
# i = 1
# close_unit_index for current loop was: 32
# close_unit_index for next loop is: 33
# Total if loops: 35
# Total elif_1 loops: 30
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 68 finished
# For loop run number: 69
# i = 0
# close_unit_datetime: 2021-08-22 16:27:17
# open_datetime_lifo: 2021-05-14 19:40:30
# value_close_units: 57.329588 value_open_units: 351.53341799999987
# abs_diff_open_close_units: 294.20382999999987
# close_unit_index for current loop is: 33
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 31
# changed_value_open_units: 57.329588
# value_close_units: 57.329588
# value_open_units: 351.53341799999987
# close_unit_index: 33
# Elif_loop_1 run number: 31 finished
# i = 1
# close_unit_index for current loop was: 33
# close_unit_index for next loop is: 34
# Total if loops: 35
# Total elif_1 loops: 31
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 69 finished
# For loop run number: 70
# i = 0
# close_unit_datetime: 2021-08-22 16:27:46
# open_datetime_lifo: 2021-05-14 19:40:30
# value_close_units: 61.079892 value_open_units: 294.20382999999987
# abs_diff_open_close_units: 233.12393799999987
# close_unit_index for current loop is: 34
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 32
# changed_value_open_units: 61.079892
# value_close_units: 61.079892
# value_open_units: 294.20382999999987
# close_unit_index: 34
# Elif_loop_1 run number: 32 finished
# i = 1
# close_unit_index for current loop was: 34
# close_unit_index for next loop is: 35
# Total if loops: 35
# Total elif_1 loops: 32
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 70 finished
# For loop run number: 71
# i = 0
# close_unit_datetime: 2021-08-23 19:55:31
# open_datetime_lifo: 2021-05-14 19:40:30
# value_close_units: 67.50827 value_open_units: 233.12393799999987
# abs_diff_open_close_units: 165.61566799999986
# close_unit_index for current loop is: 35
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 33
# changed_value_open_units: 67.50827
# value_close_units: 67.50827
# value_open_units: 233.12393799999987
# close_unit_index: 35
# Elif_loop_1 run number: 33 finished
# i = 1
# close_unit_index for current loop was: 35
# close_unit_index for next loop is: 36
# Total if loops: 35
# Total elif_1 loops: 33
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 71 finished
# For loop run number: 72
# i = 0
# close_unit_datetime: 2021-08-23 19:55:41
# open_datetime_lifo: 2021-05-14 19:40:30
# value_close_units: 68.549493 value_open_units: 165.61566799999986
# abs_diff_open_close_units: 97.06617499999986
# close_unit_index for current loop is: 36
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 34
# changed_value_open_units: 68.549493
# value_close_units: 68.549493
# value_open_units: 165.61566799999986
# close_unit_index: 36
# Elif_loop_1 run number: 34 finished
# i = 1
# close_unit_index for current loop was: 36
# close_unit_index for next loop is: 37
# Total if loops: 35
# Total elif_1 loops: 34
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 72 finished
# For loop run number: 73
# i = 0
# close_unit_datetime: 2021-08-23 19:55:51
# open_datetime_lifo: 2021-05-14 19:40:30
# value_close_units: 85.448815 value_open_units: 97.06617499999986
# abs_diff_open_close_units: 11.617359999999863
# close_unit_index for current loop is: 37
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 35
# ...
# abs_diff_open_close_units: 637.187436
# close_unit_index for current loop is: 76
# (close_unit_index = close_index) is: True
# If_loop run number: 75
# value_close_units: 830.985886
# value_open_units: 193.79845
# close_unit_index: 76
# If_loop run number: 75 finished
# i = 0
# close_unit_index for current loop was: 76
# close_unit_index for next loop is: 76
# Total if loops: 75
# Total elif_1 loops: 72
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 151 finished
# For loop run number: 152
# i = 0
# close_unit_datetime: 2022-01-10 15:33:10
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 637.187436 value_open_units: 1563.721658
# abs_diff_open_close_units: 926.5342219999999
# close_unit_index for current loop is: 76
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 73
# changed_value_open_units: 637.187436
# value_close_units: 637.187436
# value_open_units: 1563.721658
# close_unit_index: 76
# Elif_loop_1 run number: 73 finished
# i = 1
# close_unit_index for current loop was: 76
# close_unit_index for next loop is: 77
# Total if loops: 75
# Total elif_1 loops: 73
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 152 finished
# For loop run number: 153
# i = 0
# close_unit_datetime: 2022-01-10 15:33:19
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 247.035573 value_open_units: 926.5342219999999
# abs_diff_open_close_units: 679.4986489999999
# close_unit_index for current loop is: 77
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 74
# changed_value_open_units: 247.035573
# value_close_units: 247.035573
# value_open_units: 926.5342219999999
# close_unit_index: 77
# Elif_loop_1 run number: 74 finished
# i = 1
# close_unit_index for current loop was: 77
# close_unit_index for next loop is: 78
# Total if loops: 75
# Total elif_1 loops: 74
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 153 finished
# For loop run number: 154
# i = 0
# close_unit_datetime: 2022-01-10 15:33:23
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 244.140625 value_open_units: 679.4986489999999
# abs_diff_open_close_units: 435.3580239999999
# close_unit_index for current loop is: 78
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 75
# changed_value_open_units: 244.140625
# value_close_units: 244.140625
# value_open_units: 679.4986489999999
# close_unit_index: 78
# Elif_loop_1 run number: 75 finished
# i = 1
# close_unit_index for current loop was: 78
# close_unit_index for next loop is: 79
# Total if loops: 75
# Total elif_1 loops: 75
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 154 finished
# For loop run number: 155
# i = 0
# close_unit_datetime: 2022-01-10 15:33:26
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 239.463602 value_open_units: 435.3580239999999
# abs_diff_open_close_units: 195.89442199999988
# close_unit_index for current loop is: 79
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 76
# changed_value_open_units: 239.463602
# value_close_units: 239.463602
# value_open_units: 435.3580239999999
# close_unit_index: 79
# Elif_loop_1 run number: 76 finished
# i = 1
# close_unit_index for current loop was: 79
# close_unit_index for next loop is: 80
# Total if loops: 75
# Total elif_1 loops: 76
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 155 finished
# For loop run number: 156
# i = 0
# close_unit_datetime: 2022-01-10 15:33:30
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 237.868696 value_open_units: 195.89442199999988
# abs_diff_open_close_units: 41.97427400000012
# close_unit_index for current loop is: 80
# (close_unit_index = close_index) is: True
# If_loop run number: 76
# value_close_units: 237.868696
# value_open_units: 195.89442199999988
# close_unit_index: 80
# If_loop run number: 76 finished
# i = 0
# close_unit_index for current loop was: 80
# close_unit_index for next loop is: 80
# Total if loops: 76
# Total elif_1 loops: 76
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 156 finished
# For loop run number: 157
# i = 0
# close_unit_datetime: 2022-01-10 15:33:30
# open_datetime_lifo: 2020-11-09 06:58:21
# value_close_units: 41.97427400000012 value_open_units: 237.868696
# abs_diff_open_close_units: 195.89442199999988
# close_unit_index for current loop is: 80
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 77
# changed_value_open_units: 41.97427400000012
# value_close_units: 41.97427400000012
# value_open_units: 237.868696
# close_unit_index: 80
# Elif_loop_1 run number: 77 finished
# i = 1
# close_unit_index for current loop was: 80
# close_unit_index for next loop is: 81
# Total if loops: 76
# Total elif_1 loops: 77
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 157 finished
# For loop run number: 158
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-09 06:58:21
# value_close_units: 1894.150418 value_open_units: 195.89442199999988
# abs_diff_open_close_units: 1698.255996
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# If_loop run number: 77
# value_close_units: 1894.150418
# value_open_units: 195.89442199999988
# close_unit_index: 81
# If_loop run number: 77 finished
# i = 0
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 81
# Total if loops: 77
# Total elif_1 loops: 77
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 158 finished
# For loop run number: 159
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-08 06:52:09
# value_close_units: 1698.255996 value_open_units: 239.463602
# abs_diff_open_close_units: 1458.792394
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# If_loop run number: 78
# value_close_units: 1698.255996
# value_open_units: 239.463602
# close_unit_index: 81
# If_loop run number: 78 finished
# i = 0
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 81
# Total if loops: 78
# Total elif_1 loops: 77
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 159 finished
# For loop run number: 160
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-07 18:56:32
# value_close_units: 1458.792394 value_open_units: 244.140625
# abs_diff_open_close_units: 1214.651769
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# If_loop run number: 79
# value_close_units: 1458.792394
# value_open_units: 244.140625
# close_unit_index: 81
# If_loop run number: 79 finished
# i = 0
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 81
# Total if loops: 79
# Total elif_1 loops: 77
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 160 finished
# For loop run number: 161
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-06 23:29:27
# value_close_units: 1214.651769 value_open_units: 892.857143
# abs_diff_open_close_units: 321.7946260000001
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# If_loop run number: 80
# value_close_units: 1214.651769
# value_open_units: 892.857143
# close_unit_index: 81
# If_loop run number: 80 finished
# i = 0
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 81
# Total if loops: 80
# Total elif_1 loops: 77
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 161 finished
# For loop run number: 162
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-03 12:40:54
# value_close_units: 321.7946260000001 value_open_units: 268.817204
# abs_diff_open_close_units: 52.977422000000104
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# If_loop run number: 81
# value_close_units: 321.7946260000001
# value_open_units: 268.817204
# close_unit_index: 81
# If_loop run number: 81 finished
# i = 0
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 81
# Total if loops: 81
# Total elif_1 loops: 77
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 162 finished
# For loop run number: 163
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-03 03:11:56
# value_close_units: 52.977422000000104 value_open_units: 273.224044
# abs_diff_open_close_units: 220.2466219999999
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 78
# changed_value_open_units: 52.977422000000104
# value_close_units: 52.977422000000104
# value_open_units: 273.224044
# close_unit_index: 81
# Elif_loop_1 run number: 78 finished
# i = 1
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 82
# Total if loops: 81
# Total elif_1 loops: 78
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 163 finished
# For loop run number: 164
# i = 0
# close_unit_datetime: 2022-01-10 15:33:39
# open_datetime_lifo: 2020-11-03 03:11:56
# value_close_units: 643.915003 value_open_units: 220.2466219999999
# abs_diff_open_close_units: 423.66838100000007
# close_unit_index for current loop is: 82
# (close_unit_index = close_index) is: True
# If_loop run number: 82
# value_close_units: 643.915003
# value_open_units: 220.2466219999999
# close_unit_index: 82
# If_loop run number: 82 finished
# i = 0
# close_unit_index for current loop was: 82
# close_unit_index for next loop is: 82
# Total if loops: 82
# Total elif_1 loops: 78
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 164 finished
# For loop run number: 165
# i = 0
# close_unit_datetime: 2022-01-10 15:33:39
# open_datetime_lifo: 2020-11-02 12:56:38
# value_close_units: 423.66838100000007 value_open_units: 265.957447
# abs_diff_open_close_units: 157.71093400000007
# close_unit_index for current loop is: 82
# (close_unit_index = close_index) is: True
# If_loop run number: 83
# value_close_units: 423.66838100000007
# value_open_units: 265.957447
# close_unit_index: 82
# If_loop run number: 83 finished
# i = 0
# close_unit_index for current loop was: 82
# close_unit_index for next loop is: 82
# Total if loops: 83
# Total elif_1 loops: 78
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 165 finished
# For loop run number: 166
# i = 0
# close_unit_datetime: 2022-01-10 15:33:39
# open_datetime_lifo: 2020-10-28 14:15:28
# value_close_units: 157.71093400000007 value_open_units: 255.885363
# abs_diff_open_close_units: 98.17442899999995
# close_unit_index for current loop is: 82
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 79
# changed_value_open_units: 157.71093400000007
# value_close_units: 157.71093400000007
# value_open_units: 255.885363
# close_unit_index: 82
# Elif_loop_1 run number: 79 finished
# i = 1
# close_unit_index for current loop was: 82
# close_unit_index for next loop is: 83
# Total if loops: 83
# Total elif_1 loops: 79
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 166 finished
# For loop run number: 167
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 14:15:28
# value_close_units: 39.976374 value_open_units: 98.17442899999995
# abs_diff_open_close_units: 58.19805499999995
# close_unit_index for current loop is: 83
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 80
# changed_value_open_units: 39.976374
# value_close_units: 39.976374
# value_open_units: 98.17442899999995
# close_unit_index: 83
# Elif_loop_1 run number: 80 finished
# i = 1
# close_unit_index for current loop was: 83
# close_unit_index for next loop is: 84
# Total if loops: 83
# Total elif_1 loops: 80
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 167 finished
# For loop run number: 168
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 14:15:28
# value_close_units: 45.221419 value_open_units: 58.19805499999995
# abs_diff_open_close_units: 12.97663599999995
# close_unit_index for current loop is: 84
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 81
# changed_value_open_units: 45.221419
# value_close_units: 45.221419
# value_open_units: 58.19805499999995
# close_unit_index: 84
# Elif_loop_1 run number: 81 finished
# i = 1
# close_unit_index for current loop was: 84
# close_unit_index for next loop is: 85
# Total if loops: 83
# Total elif_1 loops: 81
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 168 finished
# For loop run number: 169
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 14:15:28
# value_close_units: 92.262094 value_open_units: 12.97663599999995
# abs_diff_open_close_units: 79.28545800000006
# close_unit_index for current loop is: 85
# (close_unit_index = close_index) is: True
# If_loop run number: 84
# value_close_units: 92.262094
# value_open_units: 12.97663599999995
# close_unit_index: 85
# If_loop run number: 84 finished
# i = 0
# close_unit_index for current loop was: 85
# close_unit_index for next loop is: 85
# Total if loops: 84
# Total elif_1 loops: 81
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 169 finished
# For loop run number: 170
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 08:10:57
# value_close_units: 79.28545800000006 value_open_units: 247.035573
# abs_diff_open_close_units: 167.75011499999994
# close_unit_index for current loop is: 85
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 82
# changed_value_open_units: 79.28545800000006
# value_close_units: 79.28545800000006
# value_open_units: 247.035573
# close_unit_index: 85
# Elif_loop_1 run number: 82 finished
# i = 1
# close_unit_index for current loop was: 85
# close_unit_index for next loop is: 86
# Total if loops: 84
# Total elif_1 loops: 82
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 170 finished
# For loop run number: 171
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 08:10:57
# value_close_units: 6.129467 value_open_units: 167.75011499999994
# abs_diff_open_close_units: 161.62064799999993
# close_unit_index for current loop is: 86
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 83
# changed_value_open_units: 6.129467
# value_close_units: 6.129467
# value_open_units: 167.75011499999994
# close_unit_index: 86
# Elif_loop_1 run number: 83 finished
# i = 1
# close_unit_index for current loop was: 86
# close_unit_index for next loop is: 87
# Total if loops: 84
# Total elif_1 loops: 83
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 171 finished
# For loop run number: 172
# i = 0
# close_unit_datetime: 2022-01-23 09:57:01
# open_datetime_lifo: 2020-10-28 08:10:57
# value_close_units: 88.264599 value_open_units: 161.62064799999993
# abs_diff_open_close_units: 73.35604899999993
# close_unit_index for current loop is: 87
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 84
# changed_value_open_units: 88.264599
# value_close_units: 88.264599
# value_open_units: 161.62064799999993
# close_unit_index: 87
# Elif_loop_1 run number: 84 finished
# i = 1
# close_unit_index for current loop was: 87
# close_unit_index for next loop is: 88
# Total if loops: 84
# Total elif_1 loops: 84
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 172 finished
# For loop run number: 173
# i = 0
# close_unit_datetime: 2022-01-23 09:57:01
# open_datetime_lifo: 2020-10-28 08:10:57
# value_close_units: 73.356049 value_open_units: 73.35604899999993
# abs_diff_open_close_units: 7.105427357601002e-14
# close_unit_index for current loop is: 88
# (close_unit_index = close_index) is: True
# If_loop run number: 85
# value_close_units: 73.356049
# value_open_units: 73.35604899999993
# close_unit_index: 88
# If_loop run number: 85 finished
# i = 1
# close_unit_index for current loop was: 88
# close_unit_index for next loop is: 89
# Total if loops: 85
# Total elif_1 loops: 84
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 173 finished
# ****************************************
# df_lifo_btc sum of open units: 45315.53348899999
# df_lifo_btc sum of close units: 45315.53348899999
# df_open_btc_original sum of open units: 45315.533489
# df_close_btc_original sum of close units: 45315.53348900001
# Sum of all open positions for the year 2020 in eur: 0.0
# Sum of all closed positions for the year 2020 in eur: 0.0
# Sum of all open positions for the year 2021 in eur: 23531.267697755655
# Sum of all closed positions for the year 2021 in eur: 22608.428732371813
# Sum of all open positions for the year 2022 in eur: 2916.6683126412054
# Sum of all closed positions for the year 2022 in eur: 5247.829696613308
