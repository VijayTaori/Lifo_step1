# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayTaori/Lifo_step1/blob/main/Copy_of_Detailed_lifo_eth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt
import time
import calendar
df_open = pd.read_csv('/content/et_open_alldata.csv')
df_close = pd.read_csv('/content/et_close_alldata.csv')
df_close['Close Datetime'] = pd.to_datetime(df_close['Close_unix_timestamp'],dayfirst=True,unit='s')
df_open['Open Datetime'] = pd.to_datetime(df_open['Open_unix_timestamp'],dayfirst=True,unit='s')
df_close_btc = df_close[df_close['Close Action'] =='Buy Ethereum']
df_open_btc = df_open[df_open['Open Action'] =='Buy Ethereum']
df_close_btc_original = df_close_btc
df_open_btc_original = df_open_btc
df_close_btc.reset_index(inplace=True)
df_close_btc = df_close_btc.drop('index', axis=1)
df_close_btc.reset_index(inplace=True)
df_close_btc.rename(columns={'index':'Original_Close_index'},inplace=True)
df_open_btc.reset_index(inplace=True)
df_open_btc = df_open_btc.drop('index', axis=1)
df_open_btc.reset_index(inplace=True)
df_open_btc.rename(columns={'index':'Original_Open_index'},inplace=True)
data_btc = {}
df_lifo_btc = pd.DataFrame(data_btc, 
                           columns=['Original_Open_index','Original_Close_index',
                                    'Open Position ID', 'Close Position ID',
                                    'Open Units','Close Units','Spread_Eur',
                                    'Open Amount_Eur','Amount_close_Eur',
                                    'Open Datetime', 'Close Datetime',
                                    'Open Rate_Eur', 'Close Rate_Eur',
                                    'Open Action', 'Close Action', 
                                    'Open Amount','Close Rate', 'Open Rate',
                                    'Close Spread', 'Close Profit USD',
                                    'Close_Date','Open_Date',
                                    'Close_unix_timestamp','EurOpen_y', 
                                    'EurHigh_y','EurLow_y', 'EurClose_y',
                                    'EurWeekday_y', 'Open_unix_timestamp',
                                    'EurOpen_x', 'EurHigh_x','EurLow_x', 
                                    'EurClose_x','EurWeekday_x'
                                    ]
                           )

# %%
df_close['Close Action'].unique()
# Out:
# array(['Buy Bitcoin', 'Buy Ethereum', 'Buy XRP', 'Buy Tezos', 'Buy EOS',
#        'Buy Cardano', 'Buy Litecoin', 'Buy Build and Build', 'Buy TRON',
#        'Buy Dogecoin', 'Buy Chainlink', 'Buy Uniswap', 'Buy Polygon',
#        'Buy Stellar', 'Buy Decentraland', 'Buy Aave', 'Buy IOTA',
#        'Buy Shiba (in millions)', 'Buy Enjin', 'Buy Maker',
#        'Buy Algorand', 'Buy Solana', 'Buy Polkadot', 'Buy Songbird'],
#       dtype=object)

# %%
# Let's build a index selector for df_close_btc
close_unit_index = 0
value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
final_close_unit_index = df_open_btc.shape[0]
fruit_list = list(range(400))
serial_number_for_loop = 0
serial_number_if_loop = 0
serial_number_elif_loop_1 = 0
serial_number_elif_loop_2 = 0
serial_number_else_loop = 0
for x in fruit_list:#while close_unit_index < final_close_unit_index:
  serial_number_for_loop = serial_number_for_loop + 1
  print('For loop run number:',serial_number_for_loop)
  i = 0
  #if value_close_units == 0:
  #  i = 1
  #else:
  #  i = 0
  print('i =',i)
  close_unit_index = close_unit_index + i
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  # How to set up an upper limit on this variable?? use df.shape[0]
  # Choosing first row from df_close_btc where the units are = values_of_units
  # Assign it as new DF
  # change the reset the index and the drop the 'index' column
  df_latest_row_from_close = df_close_btc[close_unit_index:(close_unit_index+1)]
  df_latest_row_from_close.reset_index(inplace=True)
  current_close_index = df_latest_row_from_close.at[0,'index']
  df_latest_row_from_close = df_latest_row_from_close.drop('index',axis=1)
  # Get the datetime value from the df_latest_row_from_close
  close_unit_datetime = df_close_btc.loc[close_unit_index,'Close Datetime']
  print('close_unit_datetime:',close_unit_datetime)
  # find all the transaction datetimes from df_open that were opened before the close_unit_datetime
  open_datetimes_b4 = df_open_btc['Open Datetime'][df_open_btc['Open Datetime'] < close_unit_datetime]
  #Latest datetime beofore close datetime
  open_datetime_lifo = open_datetimes_b4.max()
  #if open_datetime_lifo == pd.NaT:
  #  break
  #else:
  #  continue
  print('open_datetime_lifo:',open_datetime_lifo)
  '''
  Remember that even if only one value for open_datetime_lifo is chosen
  this can still result in chosing more than one rows in that case last row 
  should be chosen
  '''
  # Corresponding row for the open_datetime_lifo 
  # let's make a new DF
  df_latest_last_row_open = df_open_btc[df_open_btc['Open Datetime'] == open_datetime_lifo]
  df_latest_last_row_open = df_latest_last_row_open[::-1]
  df_latest_last_row_open = df_latest_last_row_open[0:1]
  df_latest_last_row_open.reset_index(inplace=True)
  current_open_index = df_latest_last_row_open.at[0,'index']
  df_latest_last_row_open = df_latest_last_row_open.drop('index', axis=1)
  value_open_units = df_latest_last_row_open.loc[0,'Open Units']
  print('value_close_units:',value_close_units, 'value_open_units:',value_open_units)
  abs_diff_open_close_units = abs(value_close_units - value_open_units)
  print('abs_diff_open_close_units:',abs_diff_open_close_units)
  value_open_amount = df_latest_last_row_open.loc[0,'Open Amount_Eur']
  value_close_amount = df_latest_row_from_close.loc[0,'Amount_close_Eur']
  value_close_spread_eur = df_latest_row_from_close.loc[0,'Spread_Eur']
  close_Rate_eur = df_latest_row_from_close.loc[0,'Close Rate_Eur']
  open_Rate_eur = df_latest_last_row_open.loc[0,'Open Rate_Eur']
  #Remember that 'Open_index' and 'Close_index' columns host original indices
  # This is important as df_open_btc starts to drop rows the original indices will come in handy 
  # And in case of df_close_btc this should remain equal to the indices from DataFrame
  original_open_index = df_latest_last_row_open.at[0, 'Original_Open_index']
  #Remeber that earlier defined close_unit_index is the index of units from df_close_btc DataFrame
  # close_index should essentially be equal in integer value of close_unit_index
  close_index = df_latest_row_from_close.at[0, 'Original_Close_index']
  is_it_equal = close_unit_index == close_index
  print('(close_unit_index = close_index) is:',is_it_equal)
  if value_close_units > value_open_units:
    serial_number_if_loop = serial_number_if_loop + 1
    print('If_loop run number:',serial_number_if_loop)
    #First lets extract all the values from open DF df_latest_last_row_open
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
    df_open_btc = df_open_btc.drop(current_open_index,axis=0)
    #Then reset index and drop the new column 'index' in df_open_btc
    df_open_btc.reset_index(inplace=True)
    df_open_btc = df_open_btc.drop('index',axis=1)
    #Now lets work on the Close_side
    #First define the changed values for df_latest_row_from_close
    changed_value_close_units = value_open_units
    changed_value_close_amount = changed_value_close_units * close_Rate_eur
    changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    df_latest_row_from_close.at[0,'Close Units'] = changed_value_close_units
    df_latest_row_from_close.at[0,'Amount_close_Eur'] = changed_value_close_amount
    df_latest_row_from_close.at[0,'Spread_Eur'] = changed_value_close_spread
    # Now lets extract all the values from df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
    df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('If_loop run number:',serial_number_if_loop,'finished')
  elif value_close_units < value_open_units:
    serial_number_elif_loop_1 = serial_number_elif_loop_1 + 1
    print('Elif_loop_1 run number:', serial_number_elif_loop_1)
    ## First lets extract all the values form close DF df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    #First define the changed values for df_latest_row_from_close
    ## In elif statement changed values are same as we made only one change
    changed_value_close_units = value_close_units # value_open_units in if statement was here change to value_close_unit
    changed_value_close_amount = changed_value_close_units * close_Rate_eur
    changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
    # and after that change the value of units and amount and spread in original df_close_btc
    df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
    df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    df_latest_row_from_close.at[0,'Close Units'] = changed_value_close_units
    df_latest_row_from_close.at[0,'Amount_close_Eur'] = changed_value_close_amount
    df_latest_row_from_close.at[0,'Spread_Eur'] = changed_value_close_spread
    # Now lets extract all the values from df_latest_row_from_close
    ## Now lets work on the values from open DF df_latest_last_row_lifo
    ## Remember we want to get back the values in the df_latest_row_from_close 
    ## we will have to assign changed_values for open_units and open_amount
    changed_value_open_units = value_close_units
    changed_value_open_amount = changed_value_open_units * open_Rate_eur
    df_latest_last_row_open.at[0,'Open Units'] = changed_value_close_units
    df_latest_last_row_open.at[0,'Open Amount_Eur'] = changed_value_close_amount
    ##After the values are changed extract the values which will then be reported
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    ## and then this time change the original values in the df_open_units
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_open_btc.at[current_open_index,'Open Units'] = value_open_units - changed_value_open_units
    df_open_btc.at[current_open_index,'Open Amount_Eur'] = value_open_amount - changed_value_open_amount
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_1 run number:', serial_number_elif_loop_1, 'finished')
  elif value_close_units == value_open_units:
    serial_number_elif_loop_2 = serial_number_elif_loop_2 + 1
    if value_close_units == 0:
      print('We are running value_close_units == 0 condition')
      print('This is in the Elif_loop_number_2:',serial_number_elif_loop_2)
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      print('We are breaking')
      break
    else:
      #First lets extract all the values from open DF df_latest_last_row_open
      newth_list_open_half = df_latest_last_row_open.to_dict('records')
      newth_dict_open_half = newth_list_open_half[0]
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      ### Second lets extract all the values form close DF df_latest_row_from_close
      newth_list_close_half = df_latest_row_from_close.to_dict('records')
      newth_dict_close_half = newth_list_close_half[0]
      #First define the changed values for df_latest_row_from_close
      changed_value_close_units = value_open_units
      changed_value_close_amount = changed_value_close_units * close_Rate_eur
      changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
      # and after that change the value of units and amount in original df_open_btc
      df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
      df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
      df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_2 run number:', serial_number_elif_loop_2, 'finished')
  else:
    serial_number_else_loop = serial_number_else_loop + 1
    print('Do we need to write more code? The answer is a: BIG YES!!')
    print('Or on second thought this is a silly mistake!!!')
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('serial_number_else_loop:', serial_number_else_loop, 'finished')
    print('We are breaking here!!')
    break
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  if value_close_units == 0:
    i = 1
  else:
    i = 0
  print('i =',i)
  close_unit_index = close_unit_index + i
  print('For loop run number:',serial_number_for_loop,'finished')
  print('****************************************')
# Out:
# Streaming output truncated to the last 5000 lines.
# value_close_units: 0.03358499999999984
# value_open_units: 0.119632
# close_unit_index: 7
# Elif_loop_1 run number: 8 finished
# i = 1
# For loop run number: 18 finished
# ****************************************
# For loop run number: 19
# i = 0
# close_unit_datetime: 2020-05-17 06:59:01
# open_datetime_lifo: 2020-05-03 20:39:34
# value_close_units: 0.139019 value_open_units: 0.08604700000000017
# abs_diff_open_close_units: 0.05297199999999984
# (close_unit_index = close_index) is: True
# If_loop run number: 11
# value_close_units: 0.139019
# value_open_units: 0.08604700000000017
# close_unit_index: 8
# If_loop run number: 11 finished
# i = 0
# For loop run number: 19 finished
# ****************************************
# For loop run number: 20
# i = 0
# close_unit_datetime: 2020-05-17 06:59:01
# open_datetime_lifo: 2020-04-30 10:07:35
# value_close_units: 0.05297199999999984 value_open_units: 0.118881
# abs_diff_open_close_units: 0.06590900000000016
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 9
# value_close_units: 0.05297199999999984
# value_open_units: 0.118881
# close_unit_index: 8
# Elif_loop_1 run number: 9 finished
# i = 1
# For loop run number: 20 finished
# ****************************************
# For loop run number: 21
# i = 0
# close_unit_datetime: 2020-05-17 06:59:15
# open_datetime_lifo: 2020-04-30 10:07:35
# value_close_units: 0.81045 value_open_units: 0.06590900000000016
# abs_diff_open_close_units: 0.7445409999999999
# (close_unit_index = close_index) is: True
# If_loop run number: 12
# value_close_units: 0.81045
# value_open_units: 0.06590900000000016
# close_unit_index: 9
# If_loop run number: 12 finished
# i = 0
# For loop run number: 21 finished
# ****************************************
# For loop run number: 22
# i = 0
# close_unit_datetime: 2020-05-17 06:59:15
# open_datetime_lifo: 2020-04-30 05:58:12
# value_close_units: 0.7445409999999999 value_open_units: 0.43392
# abs_diff_open_close_units: 0.3106209999999999
# (close_unit_index = close_index) is: True
# If_loop run number: 13
# value_close_units: 0.7445409999999999
# value_open_units: 0.43392
# close_unit_index: 9
# If_loop run number: 13 finished
# i = 0
# For loop run number: 22 finished
# ****************************************
# For loop run number: 23
# i = 0
# close_unit_datetime: 2020-05-17 06:59:15
# open_datetime_lifo: 2020-04-30 03:59:52
# value_close_units: 0.3106209999999999 value_open_units: 0.437347
# abs_diff_open_close_units: 0.12672600000000006
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 10
# value_close_units: 0.3106209999999999
# value_open_units: 0.437347
# close_unit_index: 9
# Elif_loop_1 run number: 10 finished
# i = 1
# For loop run number: 23 finished
# ****************************************
# For loop run number: 24
# i = 0
# close_unit_datetime: 2020-05-17 06:59:32
# open_datetime_lifo: 2020-04-30 03:59:52
# value_close_units: 0.809435 value_open_units: 0.12672600000000006
# abs_diff_open_close_units: 0.682709
# (close_unit_index = close_index) is: True
# If_loop run number: 14
# value_close_units: 0.809435
# value_open_units: 0.12672600000000006
# close_unit_index: 10
# If_loop run number: 14 finished
# i = 0
# For loop run number: 24 finished
# ****************************************
# For loop run number: 25
# i = 0
# close_unit_datetime: 2020-05-17 06:59:32
# open_datetime_lifo: 2020-04-29 11:16:53
# value_close_units: 0.682709 value_open_units: 0.753294
# abs_diff_open_close_units: 0.07058500000000001
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 11
# value_close_units: 0.682709
# value_open_units: 0.753294
# close_unit_index: 10
# Elif_loop_1 run number: 11 finished
# i = 1
# For loop run number: 25 finished
# ****************************************
# For loop run number: 26
# i = 0
# close_unit_datetime: 2020-05-17 06:59:46
# open_datetime_lifo: 2020-04-29 11:16:53
# value_close_units: 0.536565 value_open_units: 0.07058500000000001
# abs_diff_open_close_units: 0.46597999999999995
# (close_unit_index = close_index) is: True
# If_loop run number: 15
# value_close_units: 0.536565
# value_open_units: 0.07058500000000001
# close_unit_index: 11
# If_loop run number: 15 finished
# i = 0
# For loop run number: 26 finished
# ****************************************
# For loop run number: 27
# i = 0
# close_unit_datetime: 2020-05-17 06:59:46
# open_datetime_lifo: 2020-04-29 06:26:59
# value_close_units: 0.46597999999999995 value_open_units: 0.481839
# abs_diff_open_close_units: 0.015859000000000067
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 12
# value_close_units: 0.46597999999999995
# value_open_units: 0.481839
# close_unit_index: 11
# Elif_loop_1 run number: 12 finished
# i = 1
# For loop run number: 27 finished
# ****************************************
# For loop run number: 28
# i = 0
# close_unit_datetime: 2020-05-17 12:27:25
# open_datetime_lifo: 2020-04-29 06:26:59
# value_close_units: 0.132125 value_open_units: 0.015859000000000067
# abs_diff_open_close_units: 0.11626599999999992
# (close_unit_index = close_index) is: True
# If_loop run number: 16
# value_close_units: 0.132125
# value_open_units: 0.015859000000000067
# close_unit_index: 12
# If_loop run number: 16 finished
# i = 0
# For loop run number: 28 finished
# ****************************************
# For loop run number: 29
# i = 0
# close_unit_datetime: 2020-05-17 12:27:25
# open_datetime_lifo: 2020-04-28 19:58:27
# value_close_units: 0.11626599999999992 value_open_units: 0.505995
# abs_diff_open_close_units: 0.38972900000000005
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 13
# value_close_units: 0.11626599999999992
# value_open_units: 0.505995
# close_unit_index: 12
# Elif_loop_1 run number: 13 finished
# i = 1
# For loop run number: 29 finished
# ****************************************
# For loop run number: 30
# i = 0
# close_unit_datetime: 2020-05-17 12:27:39
# open_datetime_lifo: 2020-04-28 19:58:27
# value_close_units: 0.131962 value_open_units: 0.38972900000000005
# abs_diff_open_close_units: 0.2577670000000001
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 14
# value_close_units: 0.131962
# value_open_units: 0.38972900000000005
# close_unit_index: 13
# Elif_loop_1 run number: 14 finished
# i = 1
# For loop run number: 30 finished
# ****************************************
# For loop run number: 31
# i = 0
# close_unit_datetime: 2020-05-17 12:28:45
# open_datetime_lifo: 2020-04-28 19:58:27
# value_close_units: 0.130195 value_open_units: 0.2577670000000001
# abs_diff_open_close_units: 0.12757200000000007
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 15
# value_close_units: 0.130195
# value_open_units: 0.2577670000000001
# close_unit_index: 14
# Elif_loop_1 run number: 15 finished
# i = 1
# For loop run number: 31 finished
# ****************************************
# For loop run number: 32
# i = 0
# close_unit_datetime: 2020-05-17 12:36:32
# open_datetime_lifo: 2020-04-28 19:58:27
# value_close_units: 0.509792 value_open_units: 0.12757200000000007
# abs_diff_open_close_units: 0.38221999999999995
# (close_unit_index = close_index) is: True
# If_loop run number: 17
# value_close_units: 0.509792
# value_open_units: 0.12757200000000007
# close_unit_index: 15
# If_loop run number: 17 finished
# i = 0
# For loop run number: 32 finished
# ****************************************
# For loop run number: 33
# i = 0
# close_unit_datetime: 2020-05-17 12:36:32
# open_datetime_lifo: 2020-04-27 08:44:40
# value_close_units: 0.38221999999999995 value_open_units: 0.251308
# abs_diff_open_close_units: 0.13091199999999997
# (close_unit_index = close_index) is: True
# If_loop run number: 18
# value_close_units: 0.38221999999999995
# value_open_units: 0.251308
# close_unit_index: 15
# If_loop run number: 18 finished
# i = 0
# For loop run number: 33 finished
# ****************************************
# For loop run number: 34
# i = 0
# close_unit_datetime: 2020-05-17 12:36:32
# open_datetime_lifo: 2020-04-26 12:52:10
# value_close_units: 0.13091199999999997 value_open_units: 0.602389
# abs_diff_open_close_units: 0.471477
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 16
# value_close_units: 0.13091199999999997
# value_open_units: 0.602389
# close_unit_index: 15
# Elif_loop_1 run number: 16 finished
# i = 1
# For loop run number: 34 finished
# ****************************************
# For loop run number: 35
# i = 0
# close_unit_datetime: 2020-05-17 12:36:48
# open_datetime_lifo: 2020-04-26 12:52:10
# value_close_units: 0.127338 value_open_units: 0.471477
# abs_diff_open_close_units: 0.344139
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 17
# value_close_units: 0.127338
# value_open_units: 0.471477
# close_unit_index: 16
# Elif_loop_1 run number: 17 finished
# i = 1
# For loop run number: 35 finished
# ****************************************
# For loop run number: 36
# i = 0
# close_unit_datetime: 2020-05-17 12:37:02
# open_datetime_lifo: 2020-04-26 12:52:10
# value_close_units: 0.127275 value_open_units: 0.344139
# abs_diff_open_close_units: 0.21686399999999997
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 18
# value_close_units: 0.127275
# value_open_units: 0.344139
# close_unit_index: 17
# Elif_loop_1 run number: 18 finished
# i = 1
# For loop run number: 36 finished
# ****************************************
# For loop run number: 37
# i = 0
# close_unit_datetime: 2020-05-18 03:33:30
# open_datetime_lifo: 2020-04-26 12:52:10
# value_close_units: 0.124555 value_open_units: 0.21686399999999997
# abs_diff_open_close_units: 0.09230899999999997
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 19
# value_close_units: 0.124555
# value_open_units: 0.21686399999999997
# close_unit_index: 18
# Elif_loop_1 run number: 19 finished
# i = 1
# For loop run number: 37 finished
# ****************************************
# For loop run number: 38
# i = 0
# close_unit_datetime: 2020-05-18 03:33:44
# open_datetime_lifo: 2020-04-26 12:52:10
# value_close_units: 0.495252 value_open_units: 0.09230899999999997
# abs_diff_open_close_units: 0.40294300000000005
# (close_unit_index = close_index) is: True
# If_loop run number: 19
# value_close_units: 0.495252
# value_open_units: 0.09230899999999997
# close_unit_index: 19
# If_loop run number: 19 finished
# i = 0
# For loop run number: 38 finished
# ****************************************
# For loop run number: 39
# i = 0
# close_unit_datetime: 2020-05-18 03:33:44
# open_datetime_lifo: 2020-04-25 13:21:51
# value_close_units: 0.40294300000000005 value_open_units: 0.127275
# abs_diff_open_close_units: 0.275668
# (close_unit_index = close_index) is: True
# If_loop run number: 20
# value_close_units: 0.40294300000000005
# value_open_units: 0.127275
# close_unit_index: 19
# If_loop run number: 20 finished
# i = 0
# For loop run number: 39 finished
# ****************************************
# For loop run number: 40
# i = 0
# close_unit_datetime: 2020-05-18 03:33:44
# open_datetime_lifo: 2020-04-24 23:55:24
# value_close_units: 0.275668 value_open_units: 0.131962
# abs_diff_open_close_units: 0.14370600000000003
# (close_unit_index = close_index) is: True
# If_loop run number: 21
# value_close_units: 0.275668
# value_open_units: 0.131962
# close_unit_index: 19
# If_loop run number: 21 finished
# i = 0
# For loop run number: 40 finished
# ****************************************
# For loop run number: 41
# i = 0
# close_unit_datetime: 2020-05-18 03:33:44
# open_datetime_lifo: 2020-04-24 16:03:38
# value_close_units: 0.14370600000000003 value_open_units: 0.132125
# abs_diff_open_close_units: 0.011581000000000036
# (close_unit_index = close_index) is: True
# If_loop run number: 22
# value_close_units: 0.14370600000000003
# value_open_units: 0.132125
# close_unit_index: 19
# If_loop run number: 22 finished
# i = 0
# For loop run number: 41 finished
# ****************************************
# For loop run number: 42
# i = 0
# close_unit_datetime: 2020-05-18 03:33:44
# open_datetime_lifo: 2020-04-23 18:51:13
# value_close_units: 0.011581000000000036 value_open_units: 0.130195
# abs_diff_open_close_units: 0.11861399999999997
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 20
# value_close_units: 0.011581000000000036
# value_open_units: 0.130195
# close_unit_index: 19
# Elif_loop_1 run number: 20 finished
# i = 1
# For loop run number: 42 finished
# ****************************************
# For loop run number: 43
# i = 0
# close_unit_datetime: 2020-05-18 04:03:58
# open_datetime_lifo: 2020-04-23 18:51:13
# value_close_units: 0.753294 value_open_units: 0.11861399999999997
# abs_diff_open_close_units: 0.63468
# (close_unit_index = close_index) is: True
# If_loop run number: 23
# value_close_units: 0.753294
# value_open_units: 0.11861399999999997
# close_unit_index: 20
# If_loop run number: 23 finished
# i = 0
# For loop run number: 43 finished
# ****************************************
# For loop run number: 44
# i = 0
# close_unit_datetime: 2020-05-18 04:03:58
# open_datetime_lifo: 2020-04-20 20:49:50
# value_close_units: 0.63468 value_open_units: 0.144201
# abs_diff_open_close_units: 0.490479
# (close_unit_index = close_index) is: True
# If_loop run number: 24
# value_close_units: 0.63468
# value_open_units: 0.144201
# close_unit_index: 20
# If_loop run number: 24 finished
# i = 0
# For loop run number: 44 finished
# ****************************************
# For loop run number: 45
# i = 0
# close_unit_datetime: 2020-05-18 04:03:58
# open_datetime_lifo: 2020-04-18 21:32:57
# value_close_units: 0.490479 value_open_units: 0.81045
# abs_diff_open_close_units: 0.319971
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 21
# value_close_units: 0.490479
# value_open_units: 0.81045
# close_unit_index: 20
# Elif_loop_1 run number: 21 finished
# i = 1
# For loop run number: 45 finished
# ****************************************
# For loop run number: 46
# i = 0
# close_unit_datetime: 2020-05-18 07:12:37
# open_datetime_lifo: 2020-04-18 21:32:57
# value_close_units: 0.481839 value_open_units: 0.319971
# abs_diff_open_close_units: 0.161868
# (close_unit_index = close_index) is: True
# If_loop run number: 25
# value_close_units: 0.481839
# value_open_units: 0.319971
# close_unit_index: 21
# If_loop run number: 25 finished
# i = 0
# For loop run number: 46 finished
# ****************************************
# For loop run number: 47
# i = 0
# close_unit_datetime: 2020-05-18 07:12:37
# open_datetime_lifo: 2020-04-18 16:50:04
# value_close_units: 0.161868 value_open_units: 0.809435
# abs_diff_open_close_units: 0.647567
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 22
# value_close_units: 0.161868
# value_open_units: 0.809435
# close_unit_index: 21
# Elif_loop_1 run number: 22 finished
# i = 1
# For loop run number: 47 finished
# ****************************************
# For loop run number: 48
# i = 0
# close_unit_datetime: 2020-05-18 07:16:01
# open_datetime_lifo: 2020-04-18 16:50:04
# value_close_units: 0.119632 value_open_units: 0.647567
# abs_diff_open_close_units: 0.527935
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 23
# value_close_units: 0.119632
# value_open_units: 0.647567
# close_unit_index: 22
# Elif_loop_1 run number: 23 finished
# i = 1
# For loop run number: 48 finished
# ****************************************
# For loop run number: 49
# i = 0
# close_unit_datetime: 2020-05-18 07:16:09
# open_datetime_lifo: 2020-04-18 16:50:04
# value_close_units: 0.118881 value_open_units: 0.527935
# abs_diff_open_close_units: 0.40905400000000003
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 24
# value_close_units: 0.118881
# value_open_units: 0.527935
# close_unit_index: 23
# Elif_loop_1 run number: 24 finished
# i = 1
# For loop run number: 49 finished
# ****************************************
# For loop run number: 50
# i = 0
# close_unit_datetime: 2020-05-18 07:16:17
# open_datetime_lifo: 2020-04-18 16:50:04
# value_close_units: 0.118286 value_open_units: 0.40905400000000003
# abs_diff_open_close_units: 0.290768
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 25
# value_close_units: 0.118286
# value_open_units: 0.40905400000000003
# close_unit_index: 24
# Elif_loop_1 run number: 25 finished
# i = 1
# For loop run number: 50 finished
# ****************************************
# For loop run number: 51
# i = 0
# close_unit_datetime: 2020-05-23 20:25:08
# open_datetime_lifo: 2020-05-23 04:05:02
# value_close_units: 0.128874 value_open_units: 0.943874
# abs_diff_open_close_units: 0.815
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 26
# value_close_units: 0.128874
# value_open_units: 0.943874
# close_unit_index: 25
# Elif_loop_1 run number: 26 finished
# i = 1
# For loop run number: 51 finished
# ****************************************
# For loop run number: 52
# i = 0
# close_unit_datetime: 2020-05-23 20:26:12
# open_datetime_lifo: 2020-05-23 04:05:02
# value_close_units: 0.12827 value_open_units: 0.815
# abs_diff_open_close_units: 0.68673
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 27
# value_close_units: 0.12827
# value_open_units: 0.815
# close_unit_index: 26
# Elif_loop_1 run number: 27 finished
# i = 1
# For loop run number: 52 finished
# ****************************************
# For loop run number: 53
# i = 0
# close_unit_datetime: 2020-05-23 20:26:26
# open_datetime_lifo: 2020-05-23 04:05:02
# value_close_units: 0.253849 value_open_units: 0.68673
# abs_diff_open_close_units: 0.43288099999999996
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 28
# value_close_units: 0.253849
# value_open_units: 0.68673
# close_unit_index: 27
# Elif_loop_1 run number: 28 finished
# i = 1
# For loop run number: 53 finished
# ****************************************
# For loop run number: 54
# i = 0
# close_unit_datetime: 2020-05-23 20:26:39
# open_datetime_lifo: 2020-05-23 04:05:02
# value_close_units: 0.608923 value_open_units: 0.43288099999999996
# abs_diff_open_close_units: 0.17604200000000003
# (close_unit_index = close_index) is: True
# If_loop run number: 26
# value_close_units: 0.608923
# value_open_units: 0.43288099999999996
# close_unit_index: 28
# If_loop run number: 26 finished
# i = 0
# For loop run number: 54 finished
# ****************************************
# For loop run number: 55
# i = 0
# close_unit_datetime: 2020-05-23 20:26:39
# open_datetime_lifo: 2020-05-22 06:22:56
# value_close_units: 0.17604200000000003 value_open_units: 0.493971
# abs_diff_open_close_units: 0.31792899999999996
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 29
# value_close_units: 0.17604200000000003
# value_open_units: 0.493971
# close_unit_index: 28
# Elif_loop_1 run number: 29 finished
# i = 1
# For loop run number: 55 finished
# ****************************************
# For loop run number: 56
# i = 0
# close_unit_datetime: 2020-05-23 20:27:09
# open_datetime_lifo: 2020-05-22 06:22:56
# value_close_units: 1.011341 value_open_units: 0.31792899999999996
# abs_diff_open_close_units: 0.6934120000000001
# (close_unit_index = close_index) is: True
# If_loop run number: 27
# value_close_units: 1.011341
# value_open_units: 0.31792899999999996
# close_unit_index: 29
# If_loop run number: 27 finished
# i = 0
# For loop run number: 56 finished
# ****************************************
# For loop run number: 57
# i = 0
# close_unit_datetime: 2020-05-23 20:27:09
# open_datetime_lifo: 2020-05-22 05:58:23
# value_close_units: 0.6934120000000001 value_open_units: 0.499121
# abs_diff_open_close_units: 0.19429100000000016
# (close_unit_index = close_index) is: True
# If_loop run number: 28
# value_close_units: 0.6934120000000001
# value_open_units: 0.499121
# close_unit_index: 29
# If_loop run number: 28 finished
# i = 0
# For loop run number: 57 finished
# ****************************************
# For loop run number: 58
# i = 0
# close_unit_datetime: 2020-05-23 20:27:09
# open_datetime_lifo: 2020-05-22 04:05:40
# value_close_units: 0.19429100000000016 value_open_units: 0.500655
# abs_diff_open_close_units: 0.3063639999999998
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 30
# value_close_units: 0.19429100000000016
# value_open_units: 0.500655
# close_unit_index: 29
# Elif_loop_1 run number: 30 finished
# i = 1
# For loop run number: 58 finished
# ****************************************
# For loop run number: 59
# i = 0
# close_unit_datetime: 2020-05-23 20:27:19
# open_datetime_lifo: 2020-05-22 04:05:40
# value_close_units: 0.500655 value_open_units: 0.3063639999999998
# abs_diff_open_close_units: 0.19429100000000016
# (close_unit_index = close_index) is: True
# If_loop run number: 29
# value_close_units: 0.500655
# value_open_units: 0.3063639999999998
# close_unit_index: 30
# If_loop run number: 29 finished
# i = 0
# For loop run number: 59 finished
# ****************************************
# For loop run number: 60
# i = 0
# close_unit_datetime: 2020-05-23 20:27:19
# open_datetime_lifo: 2020-05-21 20:28:13
# value_close_units: 0.19429100000000016 value_open_units: 0.496108
# abs_diff_open_close_units: 0.30181699999999984
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 31
# value_close_units: 0.19429100000000016
# value_open_units: 0.496108
# close_unit_index: 30
# Elif_loop_1 run number: 31 finished
# i = 1
# For loop run number: 60 finished
# ****************************************
# For loop run number: 61
# i = 0
# close_unit_datetime: 2020-05-23 20:27:28
# open_datetime_lifo: 2020-05-21 20:28:13
# value_close_units: 0.499121 value_open_units: 0.30181699999999984
# abs_diff_open_close_units: 0.19730400000000015
# (close_unit_index = close_index) is: True
# If_loop run number: 30
# value_close_units: 0.499121
# value_open_units: 0.30181699999999984
# close_unit_index: 31
# If_loop run number: 30 finished
# i = 0
# For loop run number: 61 finished
# ****************************************
# For loop run number: 62
# i = 0
# close_unit_datetime: 2020-05-23 20:27:28
# open_datetime_lifo: 2020-05-21 18:56:01
# value_close_units: 0.19730400000000015 value_open_units: 0.128874
# abs_diff_open_close_units: 0.06843000000000016
# (close_unit_index = close_index) is: True
# If_loop run number: 31
# value_close_units: 0.19730400000000015
# value_open_units: 0.128874
# close_unit_index: 31
# If_loop run number: 31 finished
# i = 0
# For loop run number: 62 finished
# ****************************************
# For loop run number: 63
# i = 0
# close_unit_datetime: 2020-05-23 20:27:28
# open_datetime_lifo: 2020-05-21 18:50:01
# value_close_units: 0.06843000000000016 value_open_units: 0.12827
# abs_diff_open_close_units: 0.05983999999999984
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 32
# value_close_units: 0.06843000000000016
# value_open_units: 0.12827
# close_unit_index: 31
# Elif_loop_1 run number: 32 finished
# i = 1
# For loop run number: 63 finished
# ****************************************
# For loop run number: 64
# i = 0
# close_unit_datetime: 2020-05-23 20:27:36
# open_datetime_lifo: 2020-05-21 18:50:01
# value_close_units: 0.496108 value_open_units: 0.05983999999999984
# abs_diff_open_close_units: 0.43626800000000016
# (close_unit_index = close_index) is: True
# If_loop run number: 32
# value_close_units: 0.496108
# value_open_units: 0.05983999999999984
# close_unit_index: 32
# If_loop run number: 32 finished
# i = 0
# For loop run number: 64 finished
# ****************************************
# For loop run number: 65
# i = 0
# close_unit_datetime: 2020-05-23 20:27:36
# open_datetime_lifo: 2020-05-21 18:04:01
# value_close_units: 0.43626800000000016 value_open_units: 0.253849
# abs_diff_open_close_units: 0.18241900000000016
# (close_unit_index = close_index) is: True
# If_loop run number: 33
# value_close_units: 0.43626800000000016
# value_open_units: 0.253849
# close_unit_index: 32
# If_loop run number: 33 finished
# i = 0
# For loop run number: 65 finished
# ****************************************
# For loop run number: 66
# i = 0
# close_unit_datetime: 2020-05-23 20:27:36
# open_datetime_lifo: 2020-05-21 18:02:00
# value_close_units: 0.18241900000000016 value_open_units: 0.608923
# abs_diff_open_close_units: 0.4265039999999998
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 33
# value_close_units: 0.18241900000000016
# value_open_units: 0.608923
# close_unit_index: 32
# Elif_loop_1 run number: 33 finished
# i = 1
# For loop run number: 66 finished
# ****************************************
# For loop run number: 67
# i = 0
# close_unit_datetime: 2020-05-23 20:27:45
# open_datetime_lifo: 2020-05-21 18:02:00
# value_close_units: 0.493971 value_open_units: 0.4265039999999998
# abs_diff_open_close_units: 0.06746700000000017
# (close_unit_index = close_index) is: True
# If_loop run number: 34
# value_close_units: 0.493971
# value_open_units: 0.4265039999999998
# close_unit_index: 33
# If_loop run number: 34 finished
# i = 0
# For loop run number: 67 finished
# ****************************************
# For loop run number: 68
# i = 0
# close_unit_datetime: 2020-05-23 20:27:45
# open_datetime_lifo: 2020-05-21 14:43:48
# value_close_units: 0.06746700000000017 value_open_units: 1.011341
# abs_diff_open_close_units: 0.9438739999999999
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 34
# value_close_units: 0.06746700000000017
# value_open_units: 1.011341
# close_unit_index: 33
# Elif_loop_1 run number: 34 finished
# i = 1
# For loop run number: 68 finished
# ****************************************
# For loop run number: 69
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-05-21 14:43:48
# value_close_units: 0.483534 value_open_units: 0.9438739999999999
# abs_diff_open_close_units: 0.46033999999999986
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 35
# value_close_units: 0.483534
# value_open_units: 0.9438739999999999
# close_unit_index: 34
# Elif_loop_1 run number: 35 finished
# i = 1
# For loop run number: 69 finished
# ****************************************
# For loop run number: 70
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-05-21 14:43:48
# value_close_units: 0.437347 value_open_units: 0.46033999999999986
# abs_diff_open_close_units: 0.022992999999999875
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 36
# value_close_units: 0.437347
# value_open_units: 0.46033999999999986
# close_unit_index: 35
# Elif_loop_1 run number: 36 finished
# i = 1
# For loop run number: 70 finished
# ****************************************
# For loop run number: 71
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-05-21 14:43:48
# value_close_units: 0.474347 value_open_units: 0.022992999999999875
# abs_diff_open_close_units: 0.45135400000000014
# (close_unit_index = close_index) is: True
# If_loop run number: 35
# value_close_units: 0.474347
# value_open_units: 0.022992999999999875
# close_unit_index: 36
# If_loop run number: 35 finished
# i = 0
# For loop run number: 71 finished
# ****************************************
# For loop run number: 72
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-05-21 13:33:06
# value_close_units: 0.45135400000000014 value_open_units: 0.483534
# abs_diff_open_close_units: 0.032179999999999875
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 37
# value_close_units: 0.45135400000000014
# value_open_units: 0.483534
# close_unit_index: 36
# Elif_loop_1 run number: 37 finished
# i = 1
# For loop run number: 72 finished
# ****************************************
# For loop run number: 73
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-05-21 13:33:06
# value_close_units: 0.43392 value_open_units: 0.032179999999999875
# abs_diff_open_close_units: 0.4017400000000001
# (close_unit_index = close_index) is: True
# If_loop run number: 36
# value_close_units: 0.43392
# value_open_units: 0.032179999999999875
# close_unit_index: 37
# If_loop run number: 36 finished
# i = 0
# For loop run number: 73 finished
# ****************************************
# For loop run number: 74
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-05-21 03:57:18
# value_close_units: 0.4017400000000001 value_open_units: 0.474347
# abs_diff_open_close_units: 0.07260699999999992
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 38
# value_close_units: 0.4017400000000001
# value_open_units: 0.474347
# close_unit_index: 37
# Elif_loop_1 run number: 38 finished
# i = 1
# For loop run number: 74 finished
# ****************************************
# For loop run number: 75
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-05-21 03:57:18
# value_close_units: 0.943874 value_open_units: 0.07260699999999992
# abs_diff_open_close_units: 0.871267
# (close_unit_index = close_index) is: True
# If_loop run number: 37
# value_close_units: 0.943874
# value_open_units: 0.07260699999999992
# close_unit_index: 38
# If_loop run number: 37 finished
# i = 0
# For loop run number: 75 finished
# ****************************************
# For loop run number: 76
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-05-20 20:32:16
# value_close_units: 0.871267 value_open_units: 1.0
# abs_diff_open_close_units: 0.128733
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 39
# value_close_units: 0.871267
# value_open_units: 1.0
# close_unit_index: 38
# Elif_loop_1 run number: 39 finished
# i = 1
# For loop run number: 76 finished
# ****************************************
# For loop run number: 77
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-05-20 20:32:16
# value_close_units: 1.0 value_open_units: 0.128733
# abs_diff_open_close_units: 0.871267
# (close_unit_index = close_index) is: True
# If_loop run number: 38
# value_close_units: 1.0
# value_open_units: 0.128733
# close_unit_index: 39
# If_loop run number: 38 finished
# i = 0
# For loop run number: 77 finished
# ****************************************
# For loop run number: 78
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-04-18 16:50:04
# value_close_units: 0.871267 value_open_units: 0.290768
# abs_diff_open_close_units: 0.580499
# (close_unit_index = close_index) is: True
# If_loop run number: 39
# value_close_units: 0.871267
# value_open_units: 0.290768
# close_unit_index: 39
# If_loop run number: 39 finished
# i = 0
# For loop run number: 78 finished
# ****************************************
# For loop run number: 79
# i = 0
# close_unit_datetime: 2020-05-23 20:39:19
# open_datetime_lifo: 2020-04-17 16:40:29
# value_close_units: 0.580499 value_open_units: 0.580499
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 0.580499
# value_open_units: 0.580499
# close_unit_index: 39
# Elif_loop_2 run number: 1 finished
# i = 1
# For loop run number: 79 finished
# ****************************************
# For loop run number: 80
# i = 0
# close_unit_datetime: 2020-06-22 20:19:12
# open_datetime_lifo: 2020-06-15 19:24:31
# value_close_units: 0.103276 value_open_units: 0.106249
# abs_diff_open_close_units: 0.0029729999999999895
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 40
# value_close_units: 0.103276
# value_open_units: 0.106249
# close_unit_index: 40
# Elif_loop_1 run number: 40 finished
# i = 1
# For loop run number: 80 finished
# ****************************************
# For loop run number: 81
# i = 0
# close_unit_datetime: 2020-06-22 20:19:12
# open_datetime_lifo: 2020-06-15 19:24:31
# value_close_units: 0.106249 value_open_units: 0.0029729999999999895
# abs_diff_open_close_units: 0.103276
# (close_unit_index = close_index) is: True
# If_loop run number: 40
# value_close_units: 0.106249
# value_open_units: 0.0029729999999999895
# close_unit_index: 41
# If_loop run number: 40 finished
# i = 0
# For loop run number: 81 finished
# ****************************************
# For loop run number: 82
# i = 0
# close_unit_datetime: 2020-06-22 20:19:12
# open_datetime_lifo: 2020-06-11 17:24:50
# value_close_units: 0.103276 value_open_units: 0.422816
# abs_diff_open_close_units: 0.31954000000000005
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 41
# value_close_units: 0.103276
# value_open_units: 0.422816
# close_unit_index: 41
# Elif_loop_1 run number: 41 finished
# i = 1
# For loop run number: 82 finished
# ****************************************
# For loop run number: 83
# i = 0
# close_unit_datetime: 2020-06-22 20:19:12
# open_datetime_lifo: 2020-06-11 17:24:50
# value_close_units: 0.422816 value_open_units: 0.31954000000000005
# abs_diff_open_close_units: 0.10327599999999998
# (close_unit_index = close_index) is: True
# If_loop run number: 41
# value_close_units: 0.422816
# value_open_units: 0.31954000000000005
# close_unit_index: 42
# If_loop run number: 41 finished
# i = 0
# For loop run number: 83 finished
# ****************************************
# For loop run number: 84
# i = 0
# close_unit_datetime: 2020-06-22 20:19:12
# open_datetime_lifo: 2020-06-07 17:05:47
# value_close_units: 0.10327599999999998 value_open_units: 0.104323
# abs_diff_open_close_units: 0.0010470000000000201
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 42
# value_close_units: 0.10327599999999998
# value_open_units: 0.104323
# close_unit_index: 42
# Elif_loop_1 run number: 42 finished
# i = 1
# For loop run number: 84 finished
# ****************************************
# For loop run number: 85
# i = 0
# close_unit_datetime: 2020-06-22 20:19:12
# open_datetime_lifo: 2020-06-07 17:05:47
# value_close_units: 0.104323 value_open_units: 0.0010470000000000201
# abs_diff_open_close_units: 0.10327599999999998
# (close_unit_index = close_index) is: True
# If_loop run number: 42
# value_close_units: 0.104323
# value_open_units: 0.0010470000000000201
# close_unit_index: 43
# If_loop run number: 42 finished
# i = 0
# For loop run number: 85 finished
# ****************************************
# For loop run number: 86
# i = 0
# close_unit_datetime: 2020-06-22 20:19:12
# open_datetime_lifo: 2020-06-04 10:35:14
# value_close_units: 0.10327599999999998 value_open_units: 0.103276
# abs_diff_open_close_units: 2.7755575615628914e-17
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 43
# value_close_units: 0.10327599999999998
# value_open_units: 0.103276
# close_unit_index: 43
# Elif_loop_1 run number: 43 finished
# i = 1
# For loop run number: 86 finished
# ****************************************
# For loop run number: 87
# i = 0
# close_unit_datetime: 2020-07-13 13:37:37
# open_datetime_lifo: 2020-07-05 20:36:46
# value_close_units: 0.659492 value_open_units: 0.659492
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 0.659492
# value_open_units: 0.659492
# close_unit_index: 44
# Elif_loop_2 run number: 2 finished
# i = 1
# For loop run number: 87 finished
# ****************************************
# For loop run number: 88
# i = 0
# close_unit_datetime: 2020-07-13 13:37:37
# open_datetime_lifo: 2020-06-25 15:02:35
# value_close_units: 0.406384 value_open_units: 0.207736
# abs_diff_open_close_units: 0.19864800000000002
# (close_unit_index = close_index) is: True
# If_loop run number: 43
# value_close_units: 0.406384
# value_open_units: 0.207736
# close_unit_index: 45
# If_loop run number: 43 finished
# i = 0
# For loop run number: 88 finished
# ****************************************
# For loop run number: 89
# i = 0
# close_unit_datetime: 2020-07-13 13:37:37
# open_datetime_lifo: 2020-06-23 22:19:35
# value_close_units: 0.19864800000000002 value_open_units: 0.406384
# abs_diff_open_close_units: 0.207736
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 44
# value_close_units: 0.19864800000000002
# value_open_units: 0.406384
# close_unit_index: 45
# Elif_loop_1 run number: 44 finished
# i = 1
# For loop run number: 89 finished
# ****************************************
# For loop run number: 90
# i = 0
# close_unit_datetime: 2020-07-13 13:37:37
# open_datetime_lifo: 2020-06-23 22:19:35
# value_close_units: 0.207736 value_open_units: 0.207736
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 0.207736
# value_open_units: 0.207736
# close_unit_index: 46
# Elif_loop_2 run number: 3 finished
# i = 1
# For loop run number: 90 finished
# ****************************************
# For loop run number: 91
# i = 0
# close_unit_datetime: 2020-08-10 16:18:11
# open_datetime_lifo: 2020-08-09 06:55:39
# value_close_units: 0.48672 value_open_units: 0.462998
# abs_diff_open_close_units: 0.023721999999999965
# (close_unit_index = close_index) is: True
# If_loop run number: 44
# value_close_units: 0.48672
# value_open_units: 0.462998
# close_unit_index: 47
# If_loop run number: 44 finished
# i = 0
# For loop run number: 91 finished
# ****************************************
# For loop run number: 92
# i = 0
# close_unit_datetime: 2020-08-10 16:18:11
# open_datetime_lifo: 2020-07-30 04:30:41
# value_close_units: 0.023721999999999965 value_open_units: 0.5
# abs_diff_open_close_units: 0.47627800000000003
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 45
# value_close_units: 0.023721999999999965
# value_open_units: 0.5
# close_unit_index: 47
# Elif_loop_1 run number: 45 finished
# i = 1
# For loop run number: 92 finished
# ****************************************
# For loop run number: 93
# i = 0
# close_unit_datetime: 2020-08-10 16:18:11
# open_datetime_lifo: 2020-07-30 04:30:41
# value_close_units: 0.462998 value_open_units: 0.47627800000000003
# abs_diff_open_close_units: 0.013280000000000014
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 46
# value_close_units: 0.462998
# value_open_units: 0.47627800000000003
# close_unit_index: 48
# Elif_loop_1 run number: 46 finished
# i = 1
# For loop run number: 93 finished
# ****************************************
# For loop run number: 94
# i = 0
# close_unit_datetime: 2020-08-10 16:18:11
# open_datetime_lifo: 2020-07-30 04:30:41
# value_close_units: 0.5 value_open_units: 0.013280000000000014
# abs_diff_open_close_units: 0.48672
# (close_unit_index = close_index) is: True
# If_loop run number: 45
# value_close_units: 0.5
# value_open_units: 0.013280000000000014
# close_unit_index: 49
# If_loop run number: 45 finished
# i = 0
# For loop run number: 94 finished
# ****************************************
# For loop run number: 95
# i = 0
# close_unit_datetime: 2020-08-10 16:18:11
# open_datetime_lifo: 2020-07-25 21:39:54
# value_close_units: 0.48672 value_open_units: 0.48672
# abs_diff_open_close_units: 0.0
# (close_unit_index = close_index) is: True
# value_close_units: 0.48672
# value_open_units: 0.48672
# close_unit_index: 49
# Elif_loop_2 run number: 4 finished
# i = 1
# For loop run number: 95 finished
# ****************************************
# For loop run number: 96
# i = 0
# close_unit_datetime: 2020-08-27 08:18:41
# open_datetime_lifo: 2020-08-21 18:19:39
# value_close_units: 0.225094 value_open_units: 0.498777
# abs_diff_open_close_units: 0.273683
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 47
# value_close_units: 0.225094
# value_open_units: 0.498777
# close_unit_index: 50
# Elif_loop_1 run number: 47 finished
# i = 1
# For loop run number: 96 finished
# ****************************************
# For loop run number: 97
# i = 0
# close_unit_datetime: 2020-08-28 21:42:09
# open_datetime_lifo: 2020-08-21 18:19:39
# value_close_units: 0.457748 value_open_units: 0.273683
# abs_diff_open_close_units: 0.18406499999999998
# (close_unit_index = close_index) is: True
# If_loop run number: 46
# value_close_units: 0.457748
# value_open_units: 0.273683
# close_unit_index: 51
# If_loop run number: 46 finished
# i = 0
# For loop run number: 97 finished
# ****************************************
# For loop run number: 98
# i = 0
# close_unit_datetime: 2020-08-28 21:42:09
# open_datetime_lifo: 2020-08-18 14:26:34
# value_close_units: 0.18406499999999998 value_open_units: 0.23482
# abs_diff_open_close_units: 0.05075500000000002
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 48
# value_close_units: 0.18406499999999998
# value_open_units: 0.23482
# close_unit_index: 51
# Elif_loop_1 run number: 48 finished
# i = 1
# For loop run number: 98 finished
# ****************************************
# For loop run number: 99
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-10-02 08:55:41
# value_close_units: 0.247362 value_open_units: 0.128346
# abs_diff_open_close_units: 0.11901600000000001
# (close_unit_index = close_index) is: True
# If_loop run number: 47
# value_close_units: 0.247362
# value_open_units: 0.128346
# close_unit_index: 52
# If_loop run number: 47 finished
# i = 0
# For loop run number: 99 finished
# ****************************************
# For loop run number: 100
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-29 18:28:52
# value_close_units: 0.11901600000000001 value_open_units: 0.069665
# abs_diff_open_close_units: 0.049351000000000006
# (close_unit_index = close_index) is: True
# If_loop run number: 48
# value_close_units: 0.11901600000000001
# value_open_units: 0.069665
# close_unit_index: 52
# If_loop run number: 48 finished
# i = 0
# For loop run number: 100 finished
# ****************************************
# For loop run number: 101
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-29 00:00:20
# value_close_units: 0.049351000000000006 value_open_units: 0.123879
# abs_diff_open_close_units: 0.074528
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 49
# value_close_units: 0.049351000000000006
# value_open_units: 0.123879
# close_unit_index: 52
# Elif_loop_1 run number: 49 finished
# i = 1
# For loop run number: 101 finished
# ****************************************
# For loop run number: 102
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-29 00:00:20
# value_close_units: 0.128346 value_open_units: 0.074528
# abs_diff_open_close_units: 0.05381799999999999
# (close_unit_index = close_index) is: True
# If_loop run number: 49
# value_close_units: 0.128346
# value_open_units: 0.074528
# close_unit_index: 53
# If_loop run number: 49 finished
# i = 0
# For loop run number: 102 finished
# ****************************************
# For loop run number: 103
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-28 08:18:42
# value_close_units: 0.05381799999999999 value_open_units: 0.121905
# abs_diff_open_close_units: 0.06808700000000001
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 50
# value_close_units: 0.05381799999999999
# value_open_units: 0.121905
# close_unit_index: 53
# Elif_loop_1 run number: 50 finished
# i = 1
# For loop run number: 103 finished
# ****************************************
# For loop run number: 104
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-28 08:18:42
# value_close_units: 0.070325 value_open_units: 0.06808700000000001
# abs_diff_open_close_units: 0.00223799999999999
# (close_unit_index = close_index) is: True
# If_loop run number: 50
# value_close_units: 0.070325
# value_open_units: 0.06808700000000001
# close_unit_index: 54
# If_loop run number: 50 finished
# i = 0
# For loop run number: 104 finished
# ****************************************
# For loop run number: 105
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-27 06:12:38
# value_close_units: 0.00223799999999999 value_open_units: 0.069012
# abs_diff_open_close_units: 0.06677400000000001
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 51
# value_close_units: 0.00223799999999999
# value_open_units: 0.069012
# close_unit_index: 54
# Elif_loop_1 run number: 51 finished
# i = 1
# For loop run number: 105 finished
# ****************************************
# For loop run number: 106
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-27 06:12:38
# value_close_units: 0.15533 value_open_units: 0.06677400000000001
# abs_diff_open_close_units: 0.08855599999999998
# (close_unit_index = close_index) is: True
# If_loop run number: 51
# value_close_units: 0.15533
# value_open_units: 0.06677400000000001
# close_unit_index: 55
# If_loop run number: 51 finished
# i = 0
# For loop run number: 106 finished
# ****************************************
# For loop run number: 107
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-25 18:04:00
# value_close_units: 0.08855599999999998 value_open_units: 0.070325
# abs_diff_open_close_units: 0.018230999999999983
# (close_unit_index = close_index) is: True
# If_loop run number: 52
# value_close_units: 0.08855599999999998
# value_open_units: 0.070325
# close_unit_index: 55
# If_loop run number: 52 finished
# i = 0
# For loop run number: 107 finished
# ****************************************
# For loop run number: 108
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-25 12:41:33
# value_close_units: 0.018230999999999983 value_open_units: 0.071894
# abs_diff_open_close_units: 0.053663000000000016
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 52
# value_close_units: 0.018230999999999983
# value_open_units: 0.071894
# close_unit_index: 55
# Elif_loop_1 run number: 52 finished
# i = 1
# For loop run number: 108 finished
# ****************************************
# For loop run number: 109
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-25 12:41:33
# value_close_units: 0.072796 value_open_units: 0.053663000000000016
# abs_diff_open_close_units: 0.019132999999999983
# (close_unit_index = close_index) is: True
# If_loop run number: 53
# value_close_units: 0.072796
# value_open_units: 0.053663000000000016
# close_unit_index: 56
# If_loop run number: 53 finished
# i = 0
# For loop run number: 109 finished
# ****************************************
# For loop run number: 110
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-23 20:49:27
# value_close_units: 0.019132999999999983 value_open_units: 0.311056
# abs_diff_open_close_units: 0.29192300000000004
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 53
# value_close_units: 0.019132999999999983
# value_open_units: 0.311056
# close_unit_index: 56
# Elif_loop_1 run number: 53 finished
# i = 1
# For loop run number: 110 finished
# ****************************************
# For loop run number: 111
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-23 20:49:27
# value_close_units: 0.071894 value_open_units: 0.29192300000000004
# abs_diff_open_close_units: 0.22002900000000003
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 54
# value_close_units: 0.071894
# value_open_units: 0.29192300000000004
# close_unit_index: 57
# Elif_loop_1 run number: 54 finished
# i = 1
# For loop run number: 111 finished
# ****************************************
# For loop run number: 112
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-23 20:49:27
# value_close_units: 0.123879 value_open_units: 0.22002900000000003
# abs_diff_open_close_units: 0.09615000000000003
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 55
# value_close_units: 0.123879
# value_open_units: 0.22002900000000003
# close_unit_index: 58
# Elif_loop_1 run number: 55 finished
# i = 1
# For loop run number: 112 finished
# ****************************************
# For loop run number: 113
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-23 20:49:27
# value_close_units: 0.218583 value_open_units: 0.09615000000000003
# abs_diff_open_close_units: 0.12243299999999997
# (close_unit_index = close_index) is: True
# If_loop run number: 54
# value_close_units: 0.218583
# value_open_units: 0.09615000000000003
# close_unit_index: 59
# If_loop run number: 54 finished
# i = 0
# For loop run number: 113 finished
# ****************************************
# For loop run number: 114
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-23 19:10:27
# value_close_units: 0.12243299999999997 value_open_units: 0.076128
# abs_diff_open_close_units: 0.04630499999999997
# (close_unit_index = close_index) is: True
# If_loop run number: 55
# value_close_units: 0.12243299999999997
# value_open_units: 0.076128
# close_unit_index: 59
# If_loop run number: 55 finished
# i = 0
# For loop run number: 114 finished
# ****************************************
# For loop run number: 115
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-21 14:23:03
# value_close_units: 0.04630499999999997 value_open_units: 0.072796
# abs_diff_open_close_units: 0.02649100000000003
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 56
# value_close_units: 0.04630499999999997
# value_open_units: 0.072796
# close_unit_index: 59
# Elif_loop_1 run number: 56 finished
# i = 1
# For loop run number: 115 finished
# ****************************************
# For loop run number: 116
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-21 14:23:03
# value_close_units: 0.23482 value_open_units: 0.02649100000000003
# abs_diff_open_close_units: 0.208329
# (close_unit_index = close_index) is: True
# If_loop run number: 56
# value_close_units: 0.23482
# value_open_units: 0.02649100000000003
# close_unit_index: 60
# If_loop run number: 56 finished
# i = 0
# For loop run number: 116 finished
# ****************************************
# For loop run number: 117
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-16 12:49:17
# value_close_units: 0.208329 value_open_units: 0.218583
# abs_diff_open_close_units: 0.010254000000000013
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 57
# value_close_units: 0.208329
# value_open_units: 0.218583
# close_unit_index: 60
# Elif_loop_1 run number: 57 finished
# i = 1
# For loop run number: 117 finished
# ****************************************
# For loop run number: 118
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# ...
# (close_unit_index = close_index) is: True
# If_loop run number: 152
# value_close_units: 0.3227330000000004
# value_open_units: 0.04153
# close_unit_index: 171
# If_loop run number: 152 finished
# i = 0
# For loop run number: 323 finished
# ****************************************
# For loop run number: 324
# i = 0
# close_unit_datetime: 2022-05-11 07:32:34
# open_datetime_lifo: 2020-11-30 16:51:21
# value_close_units: 0.28120300000000037 value_open_units: 0.098529
# abs_diff_open_close_units: 0.18267400000000036
# (close_unit_index = close_index) is: True
# If_loop run number: 153
# value_close_units: 0.28120300000000037
# value_open_units: 0.098529
# close_unit_index: 171
# If_loop run number: 153 finished
# i = 0
# For loop run number: 324 finished
# ****************************************
# For loop run number: 325
# i = 0
# close_unit_datetime: 2022-05-11 07:32:34
# open_datetime_lifo: 2020-11-23 21:47:38
# value_close_units: 0.18267400000000036 value_open_units: 0.081051
# abs_diff_open_close_units: 0.10162300000000037
# (close_unit_index = close_index) is: True
# If_loop run number: 154
# value_close_units: 0.18267400000000036
# value_open_units: 0.081051
# close_unit_index: 171
# If_loop run number: 154 finished
# i = 0
# For loop run number: 325 finished
# ****************************************
# For loop run number: 326
# i = 0
# close_unit_datetime: 2022-05-11 07:32:34
# open_datetime_lifo: 2020-11-23 21:47:38
# value_close_units: 0.10162300000000037 value_open_units: 0.040525
# abs_diff_open_close_units: 0.06109800000000037
# (close_unit_index = close_index) is: True
# If_loop run number: 155
# value_close_units: 0.10162300000000037
# value_open_units: 0.040525
# close_unit_index: 171
# If_loop run number: 155 finished
# i = 0
# For loop run number: 326 finished
# ****************************************
# For loop run number: 327
# i = 0
# close_unit_datetime: 2022-05-11 07:32:34
# open_datetime_lifo: 2020-11-23 21:47:38
# value_close_units: 0.06109800000000037 value_open_units: 0.020263
# abs_diff_open_close_units: 0.04083500000000037
# (close_unit_index = close_index) is: True
# If_loop run number: 156
# value_close_units: 0.06109800000000037
# value_open_units: 0.020263
# close_unit_index: 171
# If_loop run number: 156 finished
# i = 0
# For loop run number: 327 finished
# ****************************************
# For loop run number: 328
# i = 0
# close_unit_datetime: 2022-05-11 07:32:34
# open_datetime_lifo: 2020-11-23 21:47:38
# value_close_units: 0.04083500000000037 value_open_units: 0.020262
# abs_diff_open_close_units: 0.020573000000000372
# (close_unit_index = close_index) is: True
# If_loop run number: 157
# value_close_units: 0.04083500000000037
# value_open_units: 0.020262
# close_unit_index: 171
# If_loop run number: 157 finished
# i = 0
# For loop run number: 328 finished
# ****************************************
# For loop run number: 329
# i = 0
# close_unit_datetime: 2022-05-11 07:32:34
# open_datetime_lifo: 2020-11-23 21:05:46
# value_close_units: 0.020573000000000372 value_open_units: 0.164989
# abs_diff_open_close_units: 0.14441599999999963
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 166
# value_close_units: 0.020573000000000372
# value_open_units: 0.164989
# close_unit_index: 171
# Elif_loop_1 run number: 166 finished
# i = 1
# For loop run number: 329 finished
# ****************************************
# For loop run number: 330
# i = 0
# close_unit_datetime: 2022-05-11 07:32:38
# open_datetime_lifo: 2020-11-23 21:05:46
# value_close_units: 0.331602 value_open_units: 0.14441599999999963
# abs_diff_open_close_units: 0.18718600000000038
# (close_unit_index = close_index) is: True
# If_loop run number: 158
# value_close_units: 0.331602
# value_open_units: 0.14441599999999963
# close_unit_index: 172
# If_loop run number: 158 finished
# i = 0
# For loop run number: 330 finished
# ****************************************
# For loop run number: 331
# i = 0
# close_unit_datetime: 2022-05-11 07:32:38
# open_datetime_lifo: 2020-11-22 17:43:36
# value_close_units: 0.18718600000000038 value_open_units: 0.044523
# abs_diff_open_close_units: 0.14266300000000037
# (close_unit_index = close_index) is: True
# If_loop run number: 159
# value_close_units: 0.18718600000000038
# value_open_units: 0.044523
# close_unit_index: 172
# If_loop run number: 159 finished
# i = 0
# For loop run number: 331 finished
# ****************************************
# For loop run number: 332
# i = 0
# close_unit_datetime: 2022-05-11 07:32:38
# open_datetime_lifo: 2020-11-21 13:56:41
# value_close_units: 0.14266300000000037 value_open_units: 0.047081
# abs_diff_open_close_units: 0.09558200000000037
# (close_unit_index = close_index) is: True
# If_loop run number: 160
# value_close_units: 0.14266300000000037
# value_open_units: 0.047081
# close_unit_index: 172
# If_loop run number: 160 finished
# i = 0
# For loop run number: 332 finished
# ****************************************
# For loop run number: 333
# i = 0
# close_unit_datetime: 2022-05-11 07:32:38
# open_datetime_lifo: 2020-11-21 08:56:44
# value_close_units: 0.09558200000000037 value_open_units: 0.189746
# abs_diff_open_close_units: 0.09416399999999962
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 167
# value_close_units: 0.09558200000000037
# value_open_units: 0.189746
# close_unit_index: 172
# Elif_loop_1 run number: 167 finished
# i = 1
# For loop run number: 333 finished
# ****************************************
# For loop run number: 334
# i = 0
# close_unit_datetime: 2022-05-11 07:32:42
# open_datetime_lifo: 2020-11-21 08:56:44
# value_close_units: 0.30181 value_open_units: 0.09416399999999962
# abs_diff_open_close_units: 0.20764600000000039
# (close_unit_index = close_index) is: True
# If_loop run number: 161
# value_close_units: 0.30181
# value_open_units: 0.09416399999999962
# close_unit_index: 173
# If_loop run number: 161 finished
# i = 0
# For loop run number: 334 finished
# ****************************************
# For loop run number: 335
# i = 0
# close_unit_datetime: 2022-05-11 07:32:42
# open_datetime_lifo: 2020-11-20 21:38:06
# value_close_units: 0.20764600000000039 value_open_units: 0.104958
# abs_diff_open_close_units: 0.10268800000000039
# (close_unit_index = close_index) is: True
# If_loop run number: 162
# value_close_units: 0.20764600000000039
# value_open_units: 0.104958
# close_unit_index: 173
# If_loop run number: 162 finished
# i = 0
# For loop run number: 335 finished
# ****************************************
# For loop run number: 336
# i = 0
# close_unit_datetime: 2022-05-11 07:32:42
# open_datetime_lifo: 2020-11-16 20:58:29
# value_close_units: 0.10268800000000039 value_open_units: 0.191735
# abs_diff_open_close_units: 0.0890469999999996
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 168
# value_close_units: 0.10268800000000039
# value_open_units: 0.191735
# close_unit_index: 173
# Elif_loop_1 run number: 168 finished
# i = 1
# For loop run number: 336 finished
# ****************************************
# For loop run number: 337
# i = 0
# close_unit_datetime: 2022-05-11 07:40:28
# open_datetime_lifo: 2020-11-16 20:58:29
# value_close_units: 0.299925 value_open_units: 0.0890469999999996
# abs_diff_open_close_units: 0.2108780000000004
# (close_unit_index = close_index) is: True
# If_loop run number: 163
# value_close_units: 0.299925
# value_open_units: 0.0890469999999996
# close_unit_index: 174
# If_loop run number: 163 finished
# i = 0
# For loop run number: 337 finished
# ****************************************
# For loop run number: 338
# i = 0
# close_unit_datetime: 2022-05-11 07:40:28
# open_datetime_lifo: 2020-11-16 19:43:33
# value_close_units: 0.2108780000000004 value_open_units: 0.257341
# abs_diff_open_close_units: 0.04646299999999959
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 169
# value_close_units: 0.2108780000000004
# value_open_units: 0.257341
# close_unit_index: 174
# Elif_loop_1 run number: 169 finished
# i = 1
# For loop run number: 338 finished
# ****************************************
# For loop run number: 339
# i = 0
# close_unit_datetime: 2022-05-11 07:40:31
# open_datetime_lifo: 2020-11-16 19:43:33
# value_close_units: 0.299497 value_open_units: 0.04646299999999959
# abs_diff_open_close_units: 0.2530340000000004
# (close_unit_index = close_index) is: True
# If_loop run number: 164
# value_close_units: 0.299497
# value_open_units: 0.04646299999999959
# close_unit_index: 175
# If_loop run number: 164 finished
# i = 0
# For loop run number: 339 finished
# ****************************************
# For loop run number: 340
# i = 0
# close_unit_datetime: 2022-05-11 07:40:31
# open_datetime_lifo: 2020-11-16 17:31:50
# value_close_units: 0.2530340000000004 value_open_units: 0.206347
# abs_diff_open_close_units: 0.04668700000000042
# (close_unit_index = close_index) is: True
# If_loop run number: 165
# value_close_units: 0.2530340000000004
# value_open_units: 0.206347
# close_unit_index: 175
# If_loop run number: 165 finished
# i = 0
# For loop run number: 340 finished
# ****************************************
# For loop run number: 341
# i = 0
# close_unit_datetime: 2022-05-11 07:40:31
# open_datetime_lifo: 2020-11-08 06:50:57
# value_close_units: 0.04668700000000042 value_open_units: 0.056147
# abs_diff_open_close_units: 0.00945999999999958
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 170
# value_close_units: 0.04668700000000042
# value_open_units: 0.056147
# close_unit_index: 175
# Elif_loop_1 run number: 170 finished
# i = 1
# For loop run number: 341 finished
# ****************************************
# For loop run number: 342
# i = 0
# close_unit_datetime: 2022-05-11 07:40:35
# open_datetime_lifo: 2020-11-08 06:50:57
# value_close_units: 0.168389 value_open_units: 0.00945999999999958
# abs_diff_open_close_units: 0.15892900000000043
# (close_unit_index = close_index) is: True
# If_loop run number: 166
# value_close_units: 0.168389
# value_open_units: 0.00945999999999958
# close_unit_index: 176
# If_loop run number: 166 finished
# i = 0
# For loop run number: 342 finished
# ****************************************
# For loop run number: 343
# i = 0
# close_unit_datetime: 2022-05-11 07:40:35
# open_datetime_lifo: 2020-11-07 15:21:37
# value_close_units: 0.15892900000000043 value_open_units: 0.227298
# abs_diff_open_close_units: 0.06836899999999957
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 171
# value_close_units: 0.15892900000000043
# value_open_units: 0.227298
# close_unit_index: 176
# Elif_loop_1 run number: 171 finished
# i = 1
# For loop run number: 343 finished
# ****************************************
# For loop run number: 344
# i = 0
# close_unit_datetime: 2022-05-11 07:40:38
# open_datetime_lifo: 2020-11-07 15:21:37
# value_close_units: 0.12085 value_open_units: 0.06836899999999957
# abs_diff_open_close_units: 0.05248100000000043
# (close_unit_index = close_index) is: True
# If_loop run number: 167
# value_close_units: 0.12085
# value_open_units: 0.06836899999999957
# close_unit_index: 177
# If_loop run number: 167 finished
# i = 0
# For loop run number: 344 finished
# ****************************************
# For loop run number: 345
# i = 0
# close_unit_datetime: 2022-05-11 07:40:38
# open_datetime_lifo: 2020-11-07 14:01:59
# value_close_units: 0.05248100000000043 value_open_units: 0.053369
# abs_diff_open_close_units: 0.0008879999999995697
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 172
# value_close_units: 0.05248100000000043
# value_open_units: 0.053369
# close_unit_index: 177
# Elif_loop_1 run number: 172 finished
# i = 1
# For loop run number: 345 finished
# ****************************************
# For loop run number: 346
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-11-07 14:01:59
# value_close_units: 0.252729 value_open_units: 0.0008879999999995697
# abs_diff_open_close_units: 0.2518410000000004
# (close_unit_index = close_index) is: True
# If_loop run number: 168
# value_close_units: 0.252729
# value_open_units: 0.0008879999999995697
# close_unit_index: 178
# If_loop run number: 168 finished
# i = 0
# For loop run number: 346 finished
# ****************************************
# For loop run number: 347
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-11-02 20:57:38
# value_close_units: 0.2518410000000004 value_open_units: 0.06354
# abs_diff_open_close_units: 0.18830100000000044
# (close_unit_index = close_index) is: True
# If_loop run number: 169
# value_close_units: 0.2518410000000004
# value_open_units: 0.06354
# close_unit_index: 178
# If_loop run number: 169 finished
# i = 0
# For loop run number: 347 finished
# ****************************************
# For loop run number: 348
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-10-30 10:53:00
# value_close_units: 0.18830100000000044 value_open_units: 0.065326
# abs_diff_open_close_units: 0.12297500000000045
# (close_unit_index = close_index) is: True
# If_loop run number: 170
# value_close_units: 0.18830100000000044
# value_open_units: 0.065326
# close_unit_index: 178
# If_loop run number: 170 finished
# i = 0
# For loop run number: 348 finished
# ****************************************
# For loop run number: 349
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-10-28 08:12:17
# value_close_units: 0.12297500000000045 value_open_units: 0.062841
# abs_diff_open_close_units: 0.06013400000000045
# (close_unit_index = close_index) is: True
# If_loop run number: 171
# value_close_units: 0.12297500000000045
# value_open_units: 0.062841
# close_unit_index: 178
# If_loop run number: 171 finished
# i = 0
# For loop run number: 349 finished
# ****************************************
# For loop run number: 350
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-10-22 12:56:27
# value_close_units: 0.06013400000000045 value_open_units: 0.060134
# abs_diff_open_close_units: 4.510281037539698e-16
# (close_unit_index = close_index) is: True
# If_loop run number: 172
# value_close_units: 0.06013400000000045
# value_open_units: 0.060134
# close_unit_index: 178
# If_loop run number: 172 finished
# i = 0
# For loop run number: 350 finished
# ****************************************
# For loop run number: 351
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-06-04 10:35:14
# value_close_units: 4.510281037539698e-16 value_open_units: 2.7755575615628914e-17
# abs_diff_open_close_units: 4.2327252813834093e-16
# (close_unit_index = close_index) is: True
# If_loop run number: 173
# value_close_units: 4.510281037539698e-16
# value_open_units: 2.7755575615628914e-17
# close_unit_index: 178
# If_loop run number: 173 finished
# i = 0
# For loop run number: 351 finished
# ****************************************
# For loop run number: 352
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: NaT
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-31737fe42a41> in <module>
#      51   df_latest_last_row_open = df_latest_last_row_open[0:1]
#      52   df_latest_last_row_open.reset_index(inplace=True)
# ---> 53   current_open_index = df_latest_last_row_open.at[0,'index']
#      54   df_latest_last_row_open = df_latest_last_row_open.drop('index', axis=1)
#      55   value_open_units = df_latest_last_row_open.loc[0,'Open Units']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2273             return self.obj.loc[key]
#    2274
# -> 2275         return super().__getitem__(key)
#    2276
#    2277     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2220
#    2221         key = self._convert_key(key)
# -> 2222         return self.obj._get_value(*key, takeable=self._takeable)
#    2223
#    2224     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3577
#    3578         try:
# -> 3579             loc = engine.get_loc(index)
#    3580             return series._values[loc]
#    3581         except AttributeError:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %%
df_lifo_btc
# Out:
#     Original_Open_index Original_Close_index Open Position ID  \
# 0                    23                    0        619696212
# 1                    22                    0        618660312
# 2                    22                    1        618660312
# 3                    21                    1        618655118
# 4                    20                    1        618616382
# ..                  ...                  ...              ...
# 340                  71                  178        778749325
# 341                  70                  178        774584047
# 342                  69                  178        771529426
# 343                  68                  178        767030134
# 344                  40                  178        637946755
#
#     Close Position ID    Open Units   Close Units    Spread_Eur  \
# 0           609020852  1.390190e-01  1.390190e-01  4.888472e-01
# 1           609020852  3.669760e-01  3.669760e-01  1.290436e+00
# 2           606970996  1.695890e-01  1.695890e-01  6.000569e-01
# 3           606970996  1.311010e-01  1.311010e-01  4.638748e-01
# 4           606970996  1.245550e-01  1.245550e-01  4.407131e-01
# ..                ...           ...           ...           ...
# 340        1395459836  6.354000e-02  6.354000e-02  2.761317e+00
# 341        1395459836  6.532600e-02  6.532600e-02  2.838933e+00
# 342        1395459836  6.284100e-02  6.284100e-02  2.730940e+00
# 343        1395459836  6.013400e-02  6.013400e-02  2.613300e+00
# 344        1395459836  2.775558e-17  2.775558e-17  1.229786e-15
#
#      Open Amount_Eur  Amount_close_Eur       Open Datetime  ... EurHigh_y  \
# 0          23.139000      2.532564e+01 2020-05-11 18:17:49  ...  1.084952
# 1          66.853470      6.685347e+01 2020-05-10 04:02:27  ...  1.084952
# 2          29.221317      3.115574e+01 2020-05-10 04:02:27  ...  1.084952
# 3          23.113243      2.408498e+01 2020-05-10 02:01:19  ...  1.084952
# 4          23.113243      2.288240e+01 2020-05-10 00:17:54  ...  1.084952
# ..               ...               ...                 ...  ...       ...
# 340        21.506505      1.358311e+02 2020-11-02 20:57:38  ...  1.057563
# 341        21.472000      1.396491e+02 2020-10-30 10:53:00  ...  1.057563
# 342        21.332332      1.343368e+02 2020-10-28 08:12:17  ...  1.057563
# 343        21.162498      1.285500e+02 2020-10-22 12:56:27  ...  1.057563
# 344        -0.000019      5.933382e-14 2020-06-04 10:35:14  ...  1.057563
#
#      EurLow_y  EurClose_y EurWeekday_y Open_unix_timestamp  EurOpen_x  \
# 0    1.079086    1.080696       Friday          1589221069   1.084011
# 1    1.079086    1.080696       Friday          1589083347   1.083694
# 2    1.079086    1.080696       Friday          1589083347   1.083694
# 3    1.079086    1.080696       Friday          1589076079   1.083694
# 4    1.079086    1.080696       Friday          1589069874   1.083694
# ..        ...         ...          ...                 ...        ...
# 340  1.050707    1.053297    Wednesday          1604350658   1.164253
# 341  1.050707    1.053297    Wednesday          1604055180   1.167679
# 342  1.050707    1.053297    Wednesday          1603872737   1.178162
# 343  1.050707    1.053297    Wednesday          1603371387   1.185129
# 344  1.050707    1.053297    Wednesday          1591266914   1.123722
#
#      EurHigh_x  EurLow_x  EurClose_x  EurWeekday_x
# 0     1.085305  1.080427    1.083952        Monday
# 1     1.087335  1.081631    1.083717        Sunday
# 2     1.087335  1.081631    1.083717        Sunday
# 3     1.087335  1.081631    1.083717        Sunday
# 4     1.087335  1.081631    1.083717        Sunday
# ..         ...       ...         ...           ...
# 340   1.165699  1.162439    1.164212        Monday
# 341   1.170344  1.164307    1.167870        Friday
# 342   1.178828  1.171930    1.178411     Wednesday
# 343   1.186944  1.181335    1.185396      Thursday
# 344   1.136054  1.119595    1.123595      Thursday
#
# [345 rows x 34 columns]

# %%
df_open_btc
# Out:
# Empty DataFrame
# Columns: [Original_Open_index, Open Position ID, Open Action, Open Amount, Open Units, Open Datetime, Open Rate, Open_Date, Open_unix_timestamp, EurOpen_x, EurHigh_x, EurLow_x, EurClose_x, EurWeekday_x, Open Amount_Eur, Open Rate_Eur]
# Index: []

# %%
df_close_btc
# Out:
#      Original_Close_index  Close Position ID  Close Action   Close Units  \
# 0                       0          609020852  Buy Ethereum  0.000000e+00
# 1                       1          606970996  Buy Ethereum  0.000000e+00
# 2                       2          613033025  Buy Ethereum  0.000000e+00
# 3                       3          618655118  Buy Ethereum  0.000000e+00
# 4                       4          607183477  Buy Ethereum  0.000000e+00
# ..                    ...                ...           ...           ...
# 174                   174         1163370966  Buy Ethereum  0.000000e+00
# 175                   175         1163300524  Buy Ethereum  0.000000e+00
# 176                   176         1165131136  Buy Ethereum  0.000000e+00
# 177                   177         1395474358  Buy Ethereum  0.000000e+00
# 178                   178         1395459836  Buy Ethereum  4.232725e-16
#
#          Close Datetime  Close Rate  Close Spread  Close Profit USD  \
# 0   2020-05-15 03:30:41      197.65          1.92              0.01
# 1   2020-05-15 06:30:28      199.32          2.30              0.07
# 2   2020-05-16 08:01:46      197.02          0.48              0.05
# 3   2020-05-16 13:00:17      200.68          0.50              1.31
# 4   2020-05-16 13:31:29      200.44          0.97              0.37
# ..                  ...         ...           ...               ...
# 174 2022-05-11 07:40:28     2259.11         13.69           -322.44
# 175 2022-05-11 07:40:31     2258.62         13.67           -323.55
# 176 2022-05-11 07:40:35     2260.02          7.69           -197.44
# 177 2022-05-11 07:40:38     2260.01          5.52           -242.33
# 178 2022-05-11 07:40:41     2260.78         11.54           -506.85
#
#            Close_Date  Close_unix_timestamp  EurOpen_y  EurHigh_y  EurLow_y  \
# 0    15/05/2020 00:00            1589513441   1.080625   1.084952  1.079086
# 1    15/05/2020 00:00            1589524228   1.080625   1.084952  1.079086
# 2    16/05/2020 00:00            1589616106   1.080625   1.084952  1.079086
# 3    16/05/2020 00:00            1589634017   1.080625   1.084952  1.079086
# 4    16/05/2020 00:00            1589635889   1.080625   1.084952  1.079086
# ..                ...                   ...        ...        ...       ...
# 174  11/05/2022 00:00            1652254828   1.053297   1.057563  1.050707
# 175  11/05/2022 00:00            1652254831   1.053297   1.057563  1.050707
# 176  11/05/2022 00:00            1652254835   1.053297   1.057563  1.050707
# 177  11/05/2022 00:00            1652254838   1.053297   1.057563  1.050707
# 178  11/05/2022 00:00            1652254841   1.053297   1.057563  1.050707
#
#      EurClose_y EurWeekday_y  Close Rate_Eur  Amount_close_Eur    Spread_Eur
# 0      1.080696       Friday      182.173958      1.238952e-08  0.000000e+00
# 1      1.080696       Friday      183.713197     -2.643849e-08  0.000000e+00
# 2      1.080696     Saturday      181.593287     -2.864901e-09  0.000000e+00
# 3      1.080696     Saturday      184.966708     -1.728200e-09  0.000000e+00
# 4      1.080696     Saturday      184.745500     -9.392394e-09  0.000000e+00
# ..          ...          ...             ...               ...           ...
# 174    1.053297    Wednesday     2136.146972     -7.709997e-08  0.000000e+00
# 175    1.053297    Wednesday     2135.683642      1.719259e-07  0.000000e+00
# 176    1.053297    Wednesday     2137.007441     -8.254909e-08 -8.881784e-16
# 177    1.053297    Wednesday     2136.997985      1.275004e-08  0.000000e+00
# 178    1.053297    Wednesday     2137.726074      4.405481e-08  1.875423e-14
#
# [179 rows x 18 columns]

# %%
df_lifo_btc.dtypes
# Out:
# Original_Open_index              object
# Original_Close_index             object
# Open Position ID                 object
# Close Position ID                object
# Open Units                      float64
# Close Units                     float64
# Spread_Eur                      float64
# Open Amount_Eur                 float64
# Amount_close_Eur                float64
# Open Datetime            datetime64[ns]
# Close Datetime           datetime64[ns]
# Open Rate_Eur                   float64
# Close Rate_Eur                  float64
# Open Action                      object
# Close Action                     object
# Open Amount                     float64
# Close Rate                      float64
# Open Rate                       float64
# Close Spread                    float64
# Close Profit USD                float64
# Close_Date                       object
# Open_Date                        object
# Close_unix_timestamp             object
# EurOpen_y                       float64
# EurHigh_y                       float64
# EurLow_y                        float64
# EurClose_y                      float64
# EurWeekday_y                     object
# Open_unix_timestamp              object
# EurOpen_x                       float64
# EurHigh_x                       float64
# EurLow_x                        float64
# EurClose_x                      float64
# EurWeekday_x                     object
# time_difference         timedelta64[ns]
# time_difference_days            float64
# dtype: object

# %%
df_lifo_btc['time_difference'] = df_lifo_btc['Close Datetime'] - df_lifo_btc['Open Datetime']

# %%
df_lifo_btc['time_difference_days'] = df_lifo_btc['time_difference'] / np.timedelta64(1, 'D')

# %%
df_lifo_btc['time_difference_days']
# Out:
# 0        0.687269
# 1        1.069248
# 2        1.312211
# 3        1.695093
# 4        1.695741
#           ...
# 380    537.012894
# 381    537.012940
# 382    537.509225
# 383    708.617292
# 384    754.838380
# Name: time_difference_days, Length: 385, dtype: float64

# %%
df_lifo_btc_taxable = df_lifo_btc[df_lifo_btc['time_difference_days'] < 365]

# %%
df_lifo_btc_taxable.shape
# Out:
# (280, 36)

# %%
df_lifo_btc_taxable_2020 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1609455599]

# %%
df_lifo_btc_taxable_2020['Open Amount_Eur'].sum()
# Out:
# 4586.920432980788

# %%
df_lifo_btc_taxable_2020['Amount_close_Eur'].sum()
# Out:
# 4610.575717614459

# %%
df_lifo_btc_taxable_2020_2021 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1640991599]

# %%
df_lifo_btc_taxable_2021 = df_lifo_btc_taxable_2020_2021[df_lifo_btc_taxable_2020_2021['Close_unix_timestamp'] > 1609455599]

# %%
df_lifo_btc_taxable_2021['Open Amount_Eur'].sum()
# Out:
# 44244.77460060954

# %%
df_lifo_btc_taxable_2021['Amount_close_Eur'].sum()
# Out:
# 46874.71659478

# %%
df_lifo_btc_taxable_2022 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] > 1640991599]

# %%
df_lifo_btc_taxable_2022['Open Amount_Eur'].sum()
# Out:
# 19678.210917313794

# %%
df_lifo_btc_taxable_2022['Amount_close_Eur'].sum()
# Out:
# 18895.351222981324

# %%
df_open_btc
# Out:
# Empty DataFrame
# Columns: [Original_Open_index, Open Position ID, Open Action, Open Amount, Open Units, Open Datetime, Open Rate, Open_Date, Open_unix_timestamp, EurOpen_x, EurHigh_x, EurLow_x, EurClose_x, EurWeekday_x, Open Amount_Eur, Open Rate_Eur]
# Index: []

# %%
df_close_btc
# Out:
#      Original_Close_index  Close Position ID  Close Action   Close Units  \
# 0                       0          609020852  Buy Ethereum  0.000000e+00
# 1                       1          606970996  Buy Ethereum  0.000000e+00
# 2                       2          613033025  Buy Ethereum  0.000000e+00
# 3                       3          618655118  Buy Ethereum  0.000000e+00
# 4                       4          607183477  Buy Ethereum  0.000000e+00
# ..                    ...                ...           ...           ...
# 174                   174         1163370966  Buy Ethereum  0.000000e+00
# 175                   175         1163300524  Buy Ethereum  0.000000e+00
# 176                   176         1165131136  Buy Ethereum  0.000000e+00
# 177                   177         1395474358  Buy Ethereum  0.000000e+00
# 178                   178         1395459836  Buy Ethereum  4.232725e-16
#
#          Close Datetime  Close Rate  Close Spread  Close Profit USD  \
# 0   2020-05-15 03:30:41      197.65          1.92              0.01
# 1   2020-05-15 06:30:28      199.32          2.30              0.07
# 2   2020-05-16 08:01:46      197.02          0.48              0.05
# 3   2020-05-16 13:00:17      200.68          0.50              1.31
# 4   2020-05-16 13:31:29      200.44          0.97              0.37
# ..                  ...         ...           ...               ...
# 174 2022-05-11 07:40:28     2259.11         13.69           -322.44
# 175 2022-05-11 07:40:31     2258.62         13.67           -323.55
# 176 2022-05-11 07:40:35     2260.02          7.69           -197.44
# 177 2022-05-11 07:40:38     2260.01          5.52           -242.33
# 178 2022-05-11 07:40:41     2260.78         11.54           -506.85
#
#            Close_Date  Close_unix_timestamp  EurOpen_y  EurHigh_y  EurLow_y  \
# 0    15/05/2020 00:00            1589513441   1.080625   1.084952  1.079086
# 1    15/05/2020 00:00            1589524228   1.080625   1.084952  1.079086
# 2    16/05/2020 00:00            1589616106   1.080625   1.084952  1.079086
# 3    16/05/2020 00:00            1589634017   1.080625   1.084952  1.079086
# 4    16/05/2020 00:00            1589635889   1.080625   1.084952  1.079086
# ..                ...                   ...        ...        ...       ...
# 174  11/05/2022 00:00            1652254828   1.053297   1.057563  1.050707
# 175  11/05/2022 00:00            1652254831   1.053297   1.057563  1.050707
# 176  11/05/2022 00:00            1652254835   1.053297   1.057563  1.050707
# 177  11/05/2022 00:00            1652254838   1.053297   1.057563  1.050707
# 178  11/05/2022 00:00            1652254841   1.053297   1.057563  1.050707
#
#      EurClose_y EurWeekday_y  Close Rate_Eur  Amount_close_Eur    Spread_Eur
# 0      1.080696       Friday      182.173958      1.238952e-08  0.000000e+00
# 1      1.080696       Friday      183.713197     -2.643849e-08  0.000000e+00
# 2      1.080696     Saturday      181.593287     -2.864901e-09  0.000000e+00
# 3      1.080696     Saturday      184.966708     -1.728200e-09  0.000000e+00
# 4      1.080696     Saturday      184.745500     -9.392394e-09  0.000000e+00
# ..          ...          ...             ...               ...           ...
# 174    1.053297    Wednesday     2136.146972     -7.709997e-08  0.000000e+00
# 175    1.053297    Wednesday     2135.683642      1.719259e-07  0.000000e+00
# 176    1.053297    Wednesday     2137.007441     -8.254909e-08 -8.881784e-16
# 177    1.053297    Wednesday     2136.997985      1.275004e-08  0.000000e+00
# 178    1.053297    Wednesday     2137.726074      4.405481e-08  1.875423e-14
#
# [179 rows x 18 columns]
