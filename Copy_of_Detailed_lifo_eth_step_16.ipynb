# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayTaori/Lifo_step1/blob/main/Copy_of_Detailed_lifo_eth_step_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt
import time
import calendar
df_open = pd.read_csv('/content/et_open_alldata.csv')
df_close = pd.read_csv('/content/et_close_alldata.csv')
df_close['Close Datetime'] = pd.to_datetime(df_close['Close_unix_timestamp'],dayfirst=True,unit='s')
df_open['Open Datetime'] = pd.to_datetime(df_open['Open_unix_timestamp'],dayfirst=True,unit='s')
df_close_btc = df_close[df_close['Close Action'] =='Buy Ethereum']
df_open_btc = df_open[df_open['Open Action'] =='Buy Ethereum']
df_close_btc_original = df_close_btc
df_open_btc_original = df_open_btc
df_close_btc.reset_index(inplace=True)
df_close_btc = df_close_btc.drop('index', axis=1)
df_close_btc.reset_index(inplace=True)
df_close_btc.rename(columns={'index':'Original_Close_index'},inplace=True)
df_open_btc.reset_index(inplace=True)
df_open_btc = df_open_btc.drop('index', axis=1)
df_open_btc.reset_index(inplace=True)
df_open_btc.rename(columns={'index':'Original_Open_index'},inplace=True)
data_btc = {}
df_lifo_btc = pd.DataFrame(data_btc, 
                           columns=['Original_Open_index','Original_Close_index',
                                    'Open Position ID', 'Close Position ID',
                                    'Open Units','Close Units','Spread_Eur',
                                    'Open Amount_Eur','Amount_close_Eur',
                                    'Open Datetime', 'Close Datetime',
                                    'Open Rate_Eur', 'Close Rate_Eur',
                                    'Open Action', 'Close Action', 
                                    'Open Amount','Close Rate', 'Open Rate',
                                    'Close Spread', 'Close Profit USD',
                                    'Close_Date','Open_Date',
                                    'Close_unix_timestamp','EurOpen_y', 
                                    'EurHigh_y','EurLow_y', 'EurClose_y',
                                    'EurWeekday_y', 'Open_unix_timestamp',
                                    'EurOpen_x', 'EurHigh_x','EurLow_x', 
                                    'EurClose_x','EurWeekday_x'
                                    ]
                           )
# Let's build a index selector for df_close_btc
close_unit_index = 0
value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
final_close_unit_index = df_open_btc.shape[0]
serial_number_for_loop = 0
serial_number_if_loop = 0
serial_number_elif_loop_1 = 0
serial_number_elif_loop_2 = 0
serial_number_else_loop = 0
while close_unit_index < final_close_unit_index:
  serial_number_for_loop = serial_number_for_loop + 1
  print('For loop run number:',serial_number_for_loop)
  i = 0
  print('i =',i)
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  # How to set up an upper limit on this variable?? use df.shape[0]
  # Choosing first row from df_close_btc where the units are = values_of_units
  # Assign it as new DF
  # change the reset the index and the drop the 'index' column
  df_latest_row_from_close = df_close_btc[close_unit_index:(close_unit_index+1)]
  df_latest_row_from_close.reset_index(inplace=True)
  current_close_index = df_latest_row_from_close.at[0,'index']
  df_latest_row_from_close = df_latest_row_from_close.drop('index',axis=1)
  # Get the datetime value from the df_latest_row_from_close
  close_unit_datetime = df_close_btc.loc[close_unit_index,'Close Datetime']
  print('close_unit_datetime:',close_unit_datetime)
  # find all the transaction datetimes from df_open that were opened before the close_unit_datetime
  open_datetimes_b4 = df_open_btc['Open Datetime'][df_open_btc['Open Datetime'] < close_unit_datetime]
  #Latest datetime beofore close datetime
  open_datetime_lifo = open_datetimes_b4.max()
  #if open_datetime_lifo == pd.NaT:
  #  break
  #else:
  #  continue
  print('open_datetime_lifo:',open_datetime_lifo)
  '''
  Remember that even if only one value for open_datetime_lifo is chosen
  this can still result in chosing more than one rows in that case last row 
  should be chosen
  '''
  # Corresponding row for the open_datetime_lifo 
  # let's make a new DF
  df_latest_last_row_open = df_open_btc[df_open_btc['Open Datetime'] == open_datetime_lifo]
  df_latest_last_row_open = df_latest_last_row_open[::-1]
  df_latest_last_row_open = df_latest_last_row_open[0:1]
  df_latest_last_row_open.reset_index(inplace=True)
  current_open_index = df_latest_last_row_open.at[0,'index']
  df_latest_last_row_open = df_latest_last_row_open.drop('index', axis=1)
  value_open_units = df_latest_last_row_open.loc[0,'Open Units']
  print('value_close_units:',value_close_units, 'value_open_units:',value_open_units)
  abs_diff_open_close_units = abs(value_close_units - value_open_units)
  print('abs_diff_open_close_units:',abs_diff_open_close_units)
  value_open_amount = df_latest_last_row_open.loc[0,'Open Amount_Eur']
  value_close_amount = df_latest_row_from_close.loc[0,'Amount_close_Eur']
  value_close_spread_eur = df_latest_row_from_close.loc[0,'Spread_Eur']
  close_Rate_eur = df_latest_row_from_close.loc[0,'Close Rate_Eur']
  open_Rate_eur = df_latest_last_row_open.loc[0,'Open Rate_Eur']
  #Remember that 'Open_index' and 'Close_index' columns host original indices
  # This is important as df_open_btc starts to drop rows the original indices will come in handy 
  # And in case of df_close_btc this should remain equal to the indices from DataFrame
  original_open_index = df_latest_last_row_open.at[0, 'Original_Open_index']
  #Remeber that earlier defined close_unit_index is the index of units from df_close_btc DataFrame
  # close_index should essentially be equal in integer value of close_unit_index
  close_index = df_latest_row_from_close.at[0, 'Original_Close_index']
  is_it_equal = close_unit_index == close_index
  print('close_unit_index for current loop is:',close_unit_index)
  print('(close_unit_index = close_index) is:',is_it_equal)
  if value_close_units > value_open_units:
    serial_number_if_loop = serial_number_if_loop + 1
    print('If_loop run number:',serial_number_if_loop)
    #First lets extract all the values from open DF df_latest_last_row_open
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
    df_open_btc = df_open_btc.drop(current_open_index,axis=0)
    #Then reset index and drop the new column 'index' in df_open_btc
    df_open_btc.reset_index(inplace=True)
    df_open_btc = df_open_btc.drop('index',axis=1)
    #Now lets work on the Close_side
    #First define the changed values for df_latest_row_from_close
    changed_value_close_units = value_open_units
    changed_value_close_amount = changed_value_close_units * close_Rate_eur
    changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    df_latest_row_from_close.at[0,'Close Units'] = changed_value_close_units
    df_latest_row_from_close.at[0,'Amount_close_Eur'] = changed_value_close_amount
    df_latest_row_from_close.at[0,'Spread_Eur'] = changed_value_close_spread
    # Now lets extract all the values from df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
    df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('If_loop run number:',serial_number_if_loop,'finished')
  elif value_close_units < value_open_units:
    serial_number_elif_loop_1 = serial_number_elif_loop_1 + 1
    print('Elif_loop_1 run number:', serial_number_elif_loop_1)
    ## First lets extract all the values form close DF df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    #First define the changed values for df_latest_row_from_close
    ## In elif statement changed values are same as we made only one change
    # and after that change the value of units and amount and spread in original df_close_btc
    df_close_btc.at[close_unit_index,'Close Units'] = 0
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = 0
    df_close_btc.at[close_unit_index,'Spread_Eur'] = 0
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    # Now lets extract all the values from df_latest_row_from_close
    ## Now lets work on the values from open DF df_latest_last_row_lifo
    ## Remember we want to get back the values in the df_latest_row_from_close 
    ## we will have to assign changed_values for open_units and open_amount
    changed_value_open_units = value_close_units
    changed_value_open_amount = changed_value_open_units * open_Rate_eur
    print('changed_value_open_units:',changed_value_open_units)
    df_latest_last_row_open.at[0,'Open Units'] = changed_value_open_units
    df_latest_last_row_open.at[0,'Open Amount_Eur'] = changed_value_open_amount
    ##After the values are changed extract the values which will then be reported
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    ## and then this time change the original values in the df_open_units
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_open_btc.at[current_open_index,'Open Units'] = value_open_units - changed_value_open_units
    df_open_btc.at[current_open_index,'Open Amount_Eur'] = value_open_amount - changed_value_open_amount
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_1 run number:', serial_number_elif_loop_1, 'finished')
  elif value_close_units == value_open_units:
    serial_number_elif_loop_2 = serial_number_elif_loop_2 + 1
    if value_close_units == 0:
      print('We are running value_close_units == 0 condition')
      print('This is in the Elif_loop_number_2:',serial_number_elif_loop_2)
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      print('We are breaking')
      break
    else:
      #First lets extract all the values from open DF df_latest_last_row_open
      newth_list_open_half = df_latest_last_row_open.to_dict('records')
      newth_dict_open_half = newth_list_open_half[0]
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      ### Second lets extract all the values form close DF df_latest_row_from_close
      newth_list_close_half = df_latest_row_from_close.to_dict('records')
      newth_dict_close_half = newth_list_close_half[0]
      ## and then this time change the original values in the df_open_units
      newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
      # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
      df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
      #First define the changed values for df_latest_row_from_close
      changed_value_close_units = value_open_units
      changed_value_close_amount = changed_value_close_units * close_Rate_eur
      changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
      # and after that change the value of units and amount in original df_open_btc
      df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
      df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
      df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_2 run number:', serial_number_elif_loop_2, 'finished')
  else:
    serial_number_else_loop = serial_number_else_loop + 1
    print('Do we need to write more code? The answer is a: BIG YES!!')
    print('Or on second thought this is a silly mistake!!!')
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('serial_number_else_loop:', serial_number_else_loop, 'finished')
    print('We are breaking here!!')
    break
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  if value_close_units < 1.0e-10:
    i = 1
  else:
    i = 0
  print('i =',i)
  print('close_unit_index for current loop was:',close_unit_index)
  close_unit_index = close_unit_index + i
  print('close_unit_index for next loop is:',close_unit_index)
  print('Total if loops:',serial_number_if_loop)
  print('Total elif_1 loops:',serial_number_elif_loop_1)
  print('Total elif_2 loops:',serial_number_elif_loop_2)
  print('Total else loops:',serial_number_else_loop)
  print('For loop run number:',serial_number_for_loop,'finished')
  if df_close_btc['Close Units'].sum() < 1.0e-10:
    close_unit_index = final_close_unit_index
  else:
    continue
  print('****************************************')
# Out:
# Streaming output truncated to the last 5000 lines.
# (close_unit_index = close_index) is: True
# If_loop run number: 57
# value_close_units: 0.121905
# value_open_units: 0.010254000000000013
# close_unit_index: 61
# If_loop run number: 57 finished
# i = 0
# close_unit_index for current loop was: 61
# close_unit_index for next loop is: 61
# Total if loops: 57
# Total elif_1 loops: 57
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 118 finished
# For loop run number: 119
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-14 14:25:29
# value_close_units: 0.11165099999999999 value_open_units: 0.15533
# abs_diff_open_close_units: 0.04367900000000001
# close_unit_index for current loop is: 61
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 58
# changed_value_open_units: 0.11165099999999999
# value_close_units: 0.11165099999999999
# value_open_units: 0.15533
# close_unit_index: 61
# Elif_loop_1 run number: 58 finished
# i = 1
# close_unit_index for current loop was: 61
# close_unit_index for next loop is: 62
# Total if loops: 57
# Total elif_1 loops: 58
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 119 finished
# For loop run number: 120
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-14 14:25:29
# value_close_units: 0.069665 value_open_units: 0.04367900000000001
# abs_diff_open_close_units: 0.025985999999999995
# close_unit_index for current loop is: 62
# (close_unit_index = close_index) is: True
# If_loop run number: 58
# value_close_units: 0.069665
# value_open_units: 0.04367900000000001
# close_unit_index: 62
# If_loop run number: 58 finished
# i = 0
# close_unit_index for current loop was: 62
# close_unit_index for next loop is: 62
# Total if loops: 58
# Total elif_1 loops: 58
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 120 finished
# For loop run number: 121
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-05 12:37:47
# value_close_units: 0.025985999999999995 value_open_units: 0.247362
# abs_diff_open_close_units: 0.22137600000000002
# close_unit_index for current loop is: 62
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 59
# changed_value_open_units: 0.025985999999999995
# value_close_units: 0.025985999999999995
# value_open_units: 0.247362
# close_unit_index: 62
# Elif_loop_1 run number: 59 finished
# i = 1
# close_unit_index for current loop was: 62
# close_unit_index for next loop is: 63
# Total if loops: 58
# Total elif_1 loops: 59
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 121 finished
# For loop run number: 122
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-05 12:37:47
# value_close_units: 0.069012 value_open_units: 0.22137600000000002
# abs_diff_open_close_units: 0.152364
# close_unit_index for current loop is: 63
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 60
# changed_value_open_units: 0.069012
# value_close_units: 0.069012
# value_open_units: 0.22137600000000002
# close_unit_index: 63
# Elif_loop_1 run number: 60 finished
# i = 1
# close_unit_index for current loop was: 63
# close_unit_index for next loop is: 64
# Total if loops: 58
# Total elif_1 loops: 60
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 122 finished
# For loop run number: 123
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-05 12:37:47
# value_close_units: 0.273973 value_open_units: 0.152364
# abs_diff_open_close_units: 0.12160900000000002
# close_unit_index for current loop is: 64
# (close_unit_index = close_index) is: True
# If_loop run number: 59
# value_close_units: 0.273973
# value_open_units: 0.152364
# close_unit_index: 64
# If_loop run number: 59 finished
# i = 0
# close_unit_index for current loop was: 64
# close_unit_index for next loop is: 64
# Total if loops: 59
# Total elif_1 loops: 60
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 123 finished
# For loop run number: 124
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-04 14:52:38
# value_close_units: 0.12160900000000002 value_open_units: 0.273973
# abs_diff_open_close_units: 0.152364
# close_unit_index for current loop is: 64
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 61
# changed_value_open_units: 0.12160900000000002
# value_close_units: 0.12160900000000002
# value_open_units: 0.273973
# close_unit_index: 64
# Elif_loop_1 run number: 61 finished
# i = 1
# close_unit_index for current loop was: 64
# close_unit_index for next loop is: 65
# Total if loops: 59
# Total elif_1 loops: 61
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 124 finished
# For loop run number: 125
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-09-04 14:52:38
# value_close_units: 0.498777 value_open_units: 0.152364
# abs_diff_open_close_units: 0.346413
# close_unit_index for current loop is: 65
# (close_unit_index = close_index) is: True
# If_loop run number: 60
# value_close_units: 0.498777
# value_open_units: 0.152364
# close_unit_index: 65
# If_loop run number: 60 finished
# i = 0
# close_unit_index for current loop was: 65
# close_unit_index for next loop is: 65
# Total if loops: 60
# Total elif_1 loops: 61
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 125 finished
# For loop run number: 126
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-08-18 14:26:34
# value_close_units: 0.346413 value_open_units: 0.05075500000000002
# abs_diff_open_close_units: 0.295658
# close_unit_index for current loop is: 65
# (close_unit_index = close_index) is: True
# If_loop run number: 61
# value_close_units: 0.346413
# value_open_units: 0.05075500000000002
# close_unit_index: 65
# If_loop run number: 61 finished
# i = 0
# close_unit_index for current loop was: 65
# close_unit_index for next loop is: 65
# Total if loops: 61
# Total elif_1 loops: 61
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 126 finished
# For loop run number: 127
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-08-18 10:09:10
# value_close_units: 0.295658 value_open_units: 0.457748
# abs_diff_open_close_units: 0.16209
# close_unit_index for current loop is: 65
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 62
# changed_value_open_units: 0.295658
# value_close_units: 0.295658
# value_open_units: 0.457748
# close_unit_index: 65
# Elif_loop_1 run number: 62 finished
# i = 1
# close_unit_index for current loop was: 65
# close_unit_index for next loop is: 66
# Total if loops: 61
# Total elif_1 loops: 62
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 127 finished
# For loop run number: 128
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-08-18 10:09:10
# value_close_units: 0.311056 value_open_units: 0.16209
# abs_diff_open_close_units: 0.148966
# close_unit_index for current loop is: 66
# (close_unit_index = close_index) is: True
# If_loop run number: 62
# value_close_units: 0.311056
# value_open_units: 0.16209
# close_unit_index: 66
# If_loop run number: 62 finished
# i = 0
# close_unit_index for current loop was: 66
# close_unit_index for next loop is: 66
# Total if loops: 62
# Total elif_1 loops: 62
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 128 finished
# For loop run number: 129
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-08-17 20:22:27
# value_close_units: 0.148966 value_open_units: 0.225094
# abs_diff_open_close_units: 0.076128
# close_unit_index for current loop is: 66
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 63
# changed_value_open_units: 0.148966
# value_close_units: 0.148966
# value_open_units: 0.225094
# close_unit_index: 66
# Elif_loop_1 run number: 63 finished
# i = 1
# close_unit_index for current loop was: 66
# close_unit_index for next loop is: 67
# Total if loops: 62
# Total elif_1 loops: 63
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 129 finished
# For loop run number: 130
# i = 0
# close_unit_datetime: 2020-10-12 08:24:27
# open_datetime_lifo: 2020-08-17 20:22:27
# value_close_units: 0.076128 value_open_units: 0.076128
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 67
# (close_unit_index = close_index) is: True
# value_close_units: 0.076128
# value_open_units: 0.076128
# close_unit_index: 67
# Elif_loop_2 run number: 5 finished
# i = 1
# close_unit_index for current loop was: 67
# close_unit_index for next loop is: 68
# Total if loops: 62
# Total elif_1 loops: 63
# Total elif_2 loops: 5
# Total else loops: 0
# For loop run number: 130 finished
# For loop run number: 131
# i = 0
# close_unit_datetime: 2021-01-03 20:12:45
# open_datetime_lifo: 2021-01-03 14:30:17
# value_close_units: 0.32628 value_open_units: 0.32628
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 68
# (close_unit_index = close_index) is: True
# value_close_units: 0.32628
# value_open_units: 0.32628
# close_unit_index: 68
# Elif_loop_2 run number: 6 finished
# i = 1
# close_unit_index for current loop was: 68
# close_unit_index for next loop is: 69
# Total if loops: 62
# Total elif_1 loops: 63
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 131 finished
# For loop run number: 132
# i = 0
# close_unit_datetime: 2021-01-03 20:16:37
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.04153 value_open_units: 1.334812
# abs_diff_open_close_units: 1.293282
# close_unit_index for current loop is: 69
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 64
# changed_value_open_units: 0.04153
# value_close_units: 0.04153
# value_open_units: 1.334812
# close_unit_index: 69
# Elif_loop_1 run number: 64 finished
# i = 1
# close_unit_index for current loop was: 69
# close_unit_index for next loop is: 70
# Total if loops: 62
# Total elif_1 loops: 64
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 132 finished
# For loop run number: 133
# i = 0
# close_unit_datetime: 2021-01-03 20:16:43
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.044523 value_open_units: 1.293282
# abs_diff_open_close_units: 1.248759
# close_unit_index for current loop is: 70
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 65
# changed_value_open_units: 0.044523
# value_close_units: 0.044523
# value_open_units: 1.293282
# close_unit_index: 70
# Elif_loop_1 run number: 65 finished
# i = 1
# close_unit_index for current loop was: 70
# close_unit_index for next loop is: 71
# Total if loops: 62
# Total elif_1 loops: 65
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 133 finished
# For loop run number: 134
# i = 0
# close_unit_datetime: 2021-01-03 20:16:48
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.047081 value_open_units: 1.248759
# abs_diff_open_close_units: 1.201678
# close_unit_index for current loop is: 71
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 66
# changed_value_open_units: 0.047081
# value_close_units: 0.047081
# value_open_units: 1.248759
# close_unit_index: 71
# Elif_loop_1 run number: 66 finished
# i = 1
# close_unit_index for current loop was: 71
# close_unit_index for next loop is: 72
# Total if loops: 62
# Total elif_1 loops: 66
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 134 finished
# For loop run number: 135
# i = 0
# close_unit_datetime: 2021-01-03 20:16:56
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.053369 value_open_units: 1.201678
# abs_diff_open_close_units: 1.148309
# close_unit_index for current loop is: 72
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 67
# changed_value_open_units: 0.053369
# value_close_units: 0.053369
# value_open_units: 1.201678
# close_unit_index: 72
# Elif_loop_1 run number: 67 finished
# i = 1
# close_unit_index for current loop was: 72
# close_unit_index for next loop is: 73
# Total if loops: 62
# Total elif_1 loops: 67
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 135 finished
# For loop run number: 136
# i = 0
# close_unit_datetime: 2021-01-03 20:17:04
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.056147 value_open_units: 1.148309
# abs_diff_open_close_units: 1.092162
# close_unit_index for current loop is: 73
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 68
# changed_value_open_units: 0.056147
# value_close_units: 0.056147
# value_open_units: 1.148309
# close_unit_index: 73
# Elif_loop_1 run number: 68 finished
# i = 1
# close_unit_index for current loop was: 73
# close_unit_index for next loop is: 74
# Total if loops: 62
# Total elif_1 loops: 68
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 136 finished
# For loop run number: 137
# i = 0
# close_unit_datetime: 2021-01-03 20:17:09
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.060134 value_open_units: 1.092162
# abs_diff_open_close_units: 1.0320280000000002
# close_unit_index for current loop is: 74
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 69
# changed_value_open_units: 0.060134
# value_close_units: 0.060134
# value_open_units: 1.092162
# close_unit_index: 74
# Elif_loop_1 run number: 69 finished
# i = 1
# close_unit_index for current loop was: 74
# close_unit_index for next loop is: 75
# Total if loops: 62
# Total elif_1 loops: 69
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 137 finished
# For loop run number: 138
# i = 0
# close_unit_datetime: 2021-01-03 20:17:16
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.062841 value_open_units: 1.0320280000000002
# abs_diff_open_close_units: 0.9691870000000001
# close_unit_index for current loop is: 75
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 70
# changed_value_open_units: 0.062841
# value_close_units: 0.062841
# value_open_units: 1.0320280000000002
# close_unit_index: 75
# Elif_loop_1 run number: 70 finished
# i = 1
# close_unit_index for current loop was: 75
# close_unit_index for next loop is: 76
# Total if loops: 62
# Total elif_1 loops: 70
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 138 finished
# For loop run number: 139
# i = 0
# close_unit_datetime: 2021-01-03 20:17:22
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.06354 value_open_units: 0.9691870000000001
# abs_diff_open_close_units: 0.9056470000000001
# close_unit_index for current loop is: 76
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 71
# changed_value_open_units: 0.06354
# value_close_units: 0.06354
# value_open_units: 0.9691870000000001
# close_unit_index: 76
# Elif_loop_1 run number: 71 finished
# i = 1
# close_unit_index for current loop was: 76
# close_unit_index for next loop is: 77
# Total if loops: 62
# Total elif_1 loops: 71
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 139 finished
# For loop run number: 140
# i = 0
# close_unit_datetime: 2021-01-03 20:17:27
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.065326 value_open_units: 0.9056470000000001
# abs_diff_open_close_units: 0.8403210000000001
# close_unit_index for current loop is: 77
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 72
# changed_value_open_units: 0.065326
# value_close_units: 0.065326
# value_open_units: 0.9056470000000001
# close_unit_index: 77
# Elif_loop_1 run number: 72 finished
# i = 1
# close_unit_index for current loop was: 77
# close_unit_index for next loop is: 78
# Total if loops: 62
# Total elif_1 loops: 72
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 140 finished
# For loop run number: 141
# i = 0
# close_unit_datetime: 2021-01-03 21:19:17
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.134323 value_open_units: 0.8403210000000001
# abs_diff_open_close_units: 0.7059980000000001
# close_unit_index for current loop is: 78
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 73
# changed_value_open_units: 0.134323
# value_close_units: 0.134323
# value_open_units: 0.8403210000000001
# close_unit_index: 78
# Elif_loop_1 run number: 73 finished
# i = 1
# close_unit_index for current loop was: 78
# close_unit_index for next loop is: 79
# Total if loops: 62
# Total elif_1 loops: 73
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 141 finished
# For loop run number: 142
# i = 0
# close_unit_datetime: 2021-01-03 21:19:49
# open_datetime_lifo: 2021-01-01 13:56:48
# value_close_units: 0.13513 value_open_units: 0.7059980000000001
# abs_diff_open_close_units: 0.5708680000000002
# close_unit_index for current loop is: 79
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 74
# changed_value_open_units: 0.13513
# value_close_units: 0.13513
# value_open_units: 0.7059980000000001
# close_unit_index: 79
# Elif_loop_1 run number: 74 finished
# i = 1
# close_unit_index for current loop was: 79
# close_unit_index for next loop is: 80
# Total if loops: 62
# Total elif_1 loops: 74
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 142 finished
# For loop run number: 143
# i = 0
# close_unit_datetime: 2021-01-24 20:28:25
# open_datetime_lifo: 2021-01-23 20:28:13
# value_close_units: 0.064767 value_open_units: 0.020475
# abs_diff_open_close_units: 0.044292000000000005
# close_unit_index for current loop is: 80
# (close_unit_index = close_index) is: True
# If_loop run number: 63
# value_close_units: 0.064767
# value_open_units: 0.020475
# close_unit_index: 80
# If_loop run number: 63 finished
# i = 0
# close_unit_index for current loop was: 80
# close_unit_index for next loop is: 80
# Total if loops: 63
# Total elif_1 loops: 74
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 143 finished
# For loop run number: 144
# i = 0
# close_unit_datetime: 2021-01-24 20:28:25
# open_datetime_lifo: 2021-01-21 22:10:52
# value_close_units: 0.044292000000000005 value_open_units: 0.021339
# abs_diff_open_close_units: 0.022953000000000005
# close_unit_index for current loop is: 80
# (close_unit_index = close_index) is: True
# If_loop run number: 64
# value_close_units: 0.044292000000000005
# value_open_units: 0.021339
# close_unit_index: 80
# If_loop run number: 64 finished
# i = 0
# close_unit_index for current loop was: 80
# close_unit_index for next loop is: 80
# Total if loops: 64
# Total elif_1 loops: 74
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 144 finished
# For loop run number: 145
# i = 0
# close_unit_datetime: 2021-01-24 20:28:25
# open_datetime_lifo: 2021-01-21 09:47:13
# value_close_units: 0.022953000000000005 value_open_units: 0.066678
# abs_diff_open_close_units: 0.043725
# close_unit_index for current loop is: 80
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 75
# changed_value_open_units: 0.022953000000000005
# value_close_units: 0.022953000000000005
# value_open_units: 0.066678
# close_unit_index: 80
# Elif_loop_1 run number: 75 finished
# i = 1
# close_unit_index for current loop was: 80
# close_unit_index for next loop is: 81
# Total if loops: 64
# Total elif_1 loops: 75
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 145 finished
# For loop run number: 146
# i = 0
# close_unit_datetime: 2021-01-24 20:28:33
# open_datetime_lifo: 2021-01-21 09:47:13
# value_close_units: 0.064611 value_open_units: 0.043725
# abs_diff_open_close_units: 0.020886000000000002
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# If_loop run number: 65
# value_close_units: 0.064611
# value_open_units: 0.043725
# close_unit_index: 81
# If_loop run number: 65 finished
# i = 0
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 81
# Total if loops: 65
# Total elif_1 loops: 75
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 146 finished
# For loop run number: 147
# i = 0
# close_unit_datetime: 2021-01-24 20:28:33
# open_datetime_lifo: 2021-01-21 06:44:30
# value_close_units: 0.020886000000000002 value_open_units: 0.064767
# abs_diff_open_close_units: 0.043881
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 76
# changed_value_open_units: 0.020886000000000002
# value_close_units: 0.020886000000000002
# value_open_units: 0.064767
# close_unit_index: 81
# Elif_loop_1 run number: 76 finished
# i = 1
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 82
# Total if loops: 65
# Total elif_1 loops: 76
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 147 finished
# For loop run number: 148
# i = 0
# close_unit_datetime: 2021-01-24 20:28:41
# open_datetime_lifo: 2021-01-21 06:44:30
# value_close_units: 0.066678 value_open_units: 0.043881
# abs_diff_open_close_units: 0.022796999999999998
# close_unit_index for current loop is: 82
# (close_unit_index = close_index) is: True
# If_loop run number: 66
# value_close_units: 0.066678
# value_open_units: 0.043881
# close_unit_index: 82
# If_loop run number: 66 finished
# i = 0
# close_unit_index for current loop was: 82
# close_unit_index for next loop is: 82
# Total if loops: 66
# Total elif_1 loops: 76
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 148 finished
# For loop run number: 149
# i = 0
# close_unit_datetime: 2021-01-24 20:28:41
# open_datetime_lifo: 2021-01-20 10:11:54
# value_close_units: 0.022796999999999998 value_open_units: 0.064611
# abs_diff_open_close_units: 0.041814000000000004
# close_unit_index for current loop is: 82
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 77
# changed_value_open_units: 0.022796999999999998
# value_close_units: 0.022796999999999998
# value_open_units: 0.064611
# close_unit_index: 82
# Elif_loop_1 run number: 77 finished
# i = 1
# close_unit_index for current loop was: 82
# close_unit_index for next loop is: 83
# Total if loops: 66
# Total elif_1 loops: 77
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 149 finished
# For loop run number: 150
# i = 0
# close_unit_datetime: 2021-01-24 20:29:01
# open_datetime_lifo: 2021-01-20 10:11:54
# value_close_units: 0.020475 value_open_units: 0.041814000000000004
# abs_diff_open_close_units: 0.021339000000000004
# close_unit_index for current loop is: 83
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 78
# changed_value_open_units: 0.020475
# value_close_units: 0.020475
# value_open_units: 0.041814000000000004
# close_unit_index: 83
# Elif_loop_1 run number: 78 finished
# i = 1
# close_unit_index for current loop was: 83
# close_unit_index for next loop is: 84
# Total if loops: 66
# Total elif_1 loops: 78
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 150 finished
# For loop run number: 151
# i = 0
# close_unit_datetime: 2021-01-24 20:29:07
# open_datetime_lifo: 2021-01-20 10:11:54
# value_close_units: 0.019756 value_open_units: 0.021339000000000004
# abs_diff_open_close_units: 0.0015830000000000045
# close_unit_index for current loop is: 84
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 79
# changed_value_open_units: 0.019756
# value_close_units: 0.019756
# value_open_units: 0.021339000000000004
# close_unit_index: 84
# Elif_loop_1 run number: 79 finished
# i = 1
# close_unit_index for current loop was: 84
# close_unit_index for next loop is: 85
# Total if loops: 66
# Total elif_1 loops: 79
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 151 finished
# For loop run number: 152
# i = 0
# close_unit_datetime: 2021-01-24 20:29:13
# open_datetime_lifo: 2021-01-20 10:11:54
# value_close_units: 0.020049 value_open_units: 0.0015830000000000045
# abs_diff_open_close_units: 0.018465999999999996
# close_unit_index for current loop is: 85
# (close_unit_index = close_index) is: True
# If_loop run number: 67
# value_close_units: 0.020049
# value_open_units: 0.0015830000000000045
# close_unit_index: 85
# If_loop run number: 67 finished
# i = 0
# close_unit_index for current loop was: 85
# close_unit_index for next loop is: 85
# Total if loops: 67
# Total elif_1 loops: 79
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 152 finished
# For loop run number: 153
# i = 0
# close_unit_datetime: 2021-01-24 20:29:13
# open_datetime_lifo: 2021-01-16 19:01:53
# value_close_units: 0.018465999999999996 value_open_units: 0.020253
# abs_diff_open_close_units: 0.0017870000000000039
# close_unit_index for current loop is: 85
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 80
# changed_value_open_units: 0.018465999999999996
# value_close_units: 0.018465999999999996
# value_open_units: 0.020253
# close_unit_index: 85
# Elif_loop_1 run number: 80 finished
# i = 1
# close_unit_index for current loop was: 85
# close_unit_index for next loop is: 86
# Total if loops: 67
# Total elif_1 loops: 80
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 153 finished
# For loop run number: 154
# i = 0
# close_unit_datetime: 2021-01-24 20:29:36
# open_datetime_lifo: 2021-01-16 19:01:53
# value_close_units: 0.80849 value_open_units: 0.0017870000000000039
# abs_diff_open_close_units: 0.8067030000000001
# close_unit_index for current loop is: 86
# (close_unit_index = close_index) is: True
# If_loop run number: 68
# value_close_units: 0.80849
# value_open_units: 0.0017870000000000039
# close_unit_index: 86
# If_loop run number: 68 finished
# i = 0
# close_unit_index for current loop was: 86
# close_unit_index for next loop is: 86
# Total if loops: 68
# Total elif_1 loops: 80
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 154 finished
# For loop run number: 155
# i = 0
# close_unit_datetime: 2021-01-24 20:29:36
# open_datetime_lifo: 2021-01-16 15:38:51
# value_close_units: 0.8067030000000001 value_open_units: 0.019756
# abs_diff_open_close_units: 0.7869470000000001
# close_unit_index for current loop is: 86
# (close_unit_index = close_index) is: True
# If_loop run number: 69
# value_close_units: 0.8067030000000001
# value_open_units: 0.019756
# close_unit_index: 86
# If_loop run number: 69 finished
# i = 0
# close_unit_index for current loop was: 86
# close_unit_index for next loop is: 86
# Total if loops: 69
# Total elif_1 loops: 80
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 155 finished
# For loop run number: 156
# i = 0
# close_unit_datetime: 2021-01-24 20:29:36
# open_datetime_lifo: 2021-01-15 20:47:09
# value_close_units: 0.7869470000000001 value_open_units: 0.716305
# abs_diff_open_close_units: 0.0706420000000001
# close_unit_index for current loop is: 86
# (close_unit_index = close_index) is: True
# If_loop run number: 70
# value_close_units: 0.7869470000000001
# value_open_units: 0.716305
# close_unit_index: 86
# If_loop run number: 70 finished
# i = 0
# close_unit_index for current loop was: 86
# close_unit_index for next loop is: 86
# Total if loops: 70
# Total elif_1 loops: 80
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 156 finished
# For loop run number: 157
# i = 0
# close_unit_datetime: 2021-01-24 20:29:36
# open_datetime_lifo: 2021-01-15 14:36:31
# value_close_units: 0.0706420000000001 value_open_units: 0.714896
# abs_diff_open_close_units: 0.6442539999999999
# close_unit_index for current loop is: 86
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 81
# changed_value_open_units: 0.0706420000000001
# value_close_units: 0.0706420000000001
# value_open_units: 0.714896
# close_unit_index: 86
# Elif_loop_1 run number: 81 finished
# i = 1
# close_unit_index for current loop was: 86
# close_unit_index for next loop is: 87
# Total if loops: 70
# Total elif_1 loops: 81
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 157 finished
# For loop run number: 158
# i = 0
# close_unit_datetime: 2021-01-24 20:29:43
# open_datetime_lifo: 2021-01-15 14:36:31
# value_close_units: 0.405013 value_open_units: 0.6442539999999999
# abs_diff_open_close_units: 0.23924099999999987
# close_unit_index for current loop is: 87
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 82
# changed_value_open_units: 0.405013
# value_close_units: 0.405013
# value_open_units: 0.6442539999999999
# close_unit_index: 87
# Elif_loop_1 run number: 82 finished
# i = 1
# close_unit_index for current loop was: 87
# close_unit_index for next loop is: 88
# Total if loops: 70
# Total elif_1 loops: 82
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 158 finished
# For loop run number: 159
# i = 0
# close_unit_datetime: 2021-01-24 20:29:49
# open_datetime_lifo: 2021-01-15 14:36:31
# value_close_units: 0.020253 value_open_units: 0.23924099999999987
# abs_diff_open_close_units: 0.21898799999999988
# close_unit_index for current loop is: 88
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 83
# changed_value_open_units: 0.020253
# value_close_units: 0.020253
# value_open_units: 0.23924099999999987
# close_unit_index: 88
# Elif_loop_1 run number: 83 finished
# i = 1
# close_unit_index for current loop was: 88
# close_unit_index for next loop is: 89
# Total if loops: 70
# Total elif_1 loops: 83
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 159 finished
# For loop run number: 160
# i = 0
# close_unit_datetime: 2021-01-24 20:30:18
# open_datetime_lifo: 2021-01-15 14:36:31
# value_close_units: 0.405457 value_open_units: 0.21898799999999988
# abs_diff_open_close_units: 0.18646900000000013
# close_unit_index for current loop is: 89
# (close_unit_index = close_index) is: True
# If_loop run number: 71
# value_close_units: 0.405457
# value_open_units: 0.21898799999999988
# close_unit_index: 89
# If_loop run number: 71 finished
# i = 0
# close_unit_index for current loop was: 89
# close_unit_index for next loop is: 89
# Total if loops: 71
# Total elif_1 loops: 83
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 160 finished
# For loop run number: 161
# i = 0
# close_unit_datetime: 2021-01-24 20:30:18
# open_datetime_lifo: 2021-01-15 09:21:04
# value_close_units: 0.18646900000000013 value_open_units: 0.405457
# abs_diff_open_close_units: 0.21898799999999988
# close_unit_index for current loop is: 89
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 84
# changed_value_open_units: 0.18646900000000013
# value_close_units: 0.18646900000000013
# value_open_units: 0.405457
# close_unit_index: 89
# Elif_loop_1 run number: 84 finished
# i = 1
# close_unit_index for current loop was: 89
# close_unit_index for next loop is: 90
# Total if loops: 71
# Total elif_1 loops: 84
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 161 finished
# For loop run number: 162
# i = 0
# close_unit_datetime: 2021-01-24 20:30:25
# open_datetime_lifo: 2021-01-15 09:21:04
# value_close_units: 0.020288 value_open_units: 0.21898799999999988
# abs_diff_open_close_units: 0.19869999999999988
# close_unit_index for current loop is: 90
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 85
# changed_value_open_units: 0.020288
# value_close_units: 0.020288
# value_open_units: 0.21898799999999988
# close_unit_index: 90
# Elif_loop_1 run number: 85 finished
# i = 1
# close_unit_index for current loop was: 90
# close_unit_index for next loop is: 91
# Total if loops: 71
# Total elif_1 loops: 85
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 162 finished
# For loop run number: 163
# i = 0
# close_unit_datetime: 2021-01-24 20:30:37
# open_datetime_lifo: 2021-01-15 09:21:04
# value_close_units: 0.082296 value_open_units: 0.19869999999999988
# abs_diff_open_close_units: 0.11640399999999988
# close_unit_index for current loop is: 91
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 86
# changed_value_open_units: 0.082296
# value_close_units: 0.082296
# value_open_units: 0.19869999999999988
# close_unit_index: 91
# Elif_loop_1 run number: 86 finished
# i = 1
# close_unit_index for current loop was: 91
# close_unit_index for next loop is: 92
# Total if loops: 71
# Total elif_1 loops: 86
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 163 finished
# For loop run number: 164
# i = 0
# close_unit_datetime: 2021-01-24 20:30:51
# open_datetime_lifo: 2021-01-15 09:21:04
# value_close_units: 0.082995 value_open_units: 0.11640399999999988
# abs_diff_open_close_units: 0.03340899999999988
# close_unit_index for current loop is: 92
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 87
# changed_value_open_units: 0.082995
# value_close_units: 0.082995
# value_open_units: 0.11640399999999988
# close_unit_index: 92
# Elif_loop_1 run number: 87 finished
# i = 1
# close_unit_index for current loop was: 92
# close_unit_index for next loop is: 93
# Total if loops: 71
# Total elif_1 loops: 87
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 164 finished
# For loop run number: 165
# i = 0
# close_unit_datetime: 2021-02-02 13:37:58
# open_datetime_lifo: 2021-01-27 23:32:09
# value_close_units: 1.987131 value_open_units: 0.019988
# abs_diff_open_close_units: 1.967143
# close_unit_index for current loop is: 93
# (close_unit_index = close_index) is: True
# If_loop run number: 72
# value_close_units: 1.987131
# value_open_units: 0.019988
# close_unit_index: 93
# If_loop run number: 72 finished
# i = 0
# close_unit_index for current loop was: 93
# close_unit_index for next loop is: 93
# Total if loops: 72
# Total elif_1 loops: 87
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 165 finished
# For loop run number: 166
# i = 0
# close_unit_datetime: 2021-02-02 13:37:58
# open_datetime_lifo: 2021-01-27 11:54:54
# value_close_units: 1.967143 value_open_units: 0.019578
# abs_diff_open_close_units: 1.947565
# close_unit_index for current loop is: 93
# (close_unit_index = close_index) is: True
# If_loop run number: 73
# value_close_units: 1.967143
# value_open_units: 0.019578
# close_unit_index: 93
# If_loop run number: 73 finished
# i = 0
# close_unit_index for current loop was: 93
# close_unit_index for next loop is: 93
# Total if loops: 73
# Total elif_1 loops: 87
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 166 finished
# For loop run number: 167
# i = 0
# close_unit_datetime: 2021-02-02 13:37:58
# open_datetime_lifo: 2021-01-24 23:06:02
# value_close_units: 1.947565 value_open_units: 1.987131
# abs_diff_open_close_units: 0.03956599999999999
# close_unit_index for current loop is: 93
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 88
# changed_value_open_units: 1.947565
# value_close_units: 1.947565
# value_open_units: 1.987131
# close_unit_index: 93
# Elif_loop_1 run number: 88 finished
# i = 1
# close_unit_index for current loop was: 93
# close_unit_index for next loop is: 94
# Total if loops: 73
# Total elif_1 loops: 88
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 167 finished
# For loop run number: 168
# i = 0
# close_unit_datetime: 2021-03-19 14:08:03
# open_datetime_lifo: 2021-03-06 20:54:50
# value_close_units: 0.487805 value_open_units: 0.602542
# abs_diff_open_close_units: 0.11473700000000003
# close_unit_index for current loop is: 94
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 89
# changed_value_open_units: 0.487805
# value_close_units: 0.487805
# value_open_units: 0.602542
# close_unit_index: 94
# Elif_loop_1 run number: 89 finished
# i = 1
# close_unit_index for current loop was: 94
# close_unit_index for next loop is: 95
# Total if loops: 73
# Total elif_1 loops: 89
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 168 finished
# For loop run number: 169
# i = 0
# close_unit_datetime: 2021-03-19 14:08:07
# open_datetime_lifo: 2021-03-06 20:54:50
# value_close_units: 0.075283 value_open_units: 0.11473700000000003
# abs_diff_open_close_units: 0.03945400000000003
# close_unit_index for current loop is: 95
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 90
# changed_value_open_units: 0.075283
# value_close_units: 0.075283
# value_open_units: 0.11473700000000003
# close_unit_index: 95
# Elif_loop_1 run number: 90 finished
# i = 1
# close_unit_index for current loop was: 95
# close_unit_index for next loop is: 96
# Total if loops: 73
# Total elif_1 loops: 90
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 169 finished
# For loop run number: 170
# i = 0
# close_unit_datetime: 2021-03-19 14:08:12
# open_datetime_lifo: 2021-03-06 20:54:50
# value_close_units: 0.051492 value_open_units: 0.03945400000000003
# abs_diff_open_close_units: 0.012037999999999972
# close_unit_index for current loop is: 96
# (close_unit_index = close_index) is: True
# If_loop run number: 74
# value_close_units: 0.051492
# value_open_units: 0.03945400000000003
# close_unit_index: 96
# If_loop run number: 74 finished
# i = 0
# close_unit_index for current loop was: 96
# close_unit_index for next loop is: 96
# Total if loops: 74
# Total elif_1 loops: 90
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 170 finished
# For loop run number: 171
# i = 0
# close_unit_datetime: 2021-03-19 14:08:12
# open_datetime_lifo: 2021-03-03 12:38:39
# value_close_units: 0.012037999999999972 value_open_units: 0.423549
# abs_diff_open_close_units: 0.411511
# close_unit_index for current loop is: 96
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 91
# changed_value_open_units: 0.012037999999999972
# value_close_units: 0.012037999999999972
# value_open_units: 0.423549
# close_unit_index: 96
# Elif_loop_1 run number: 91 finished
# i = 1
# close_unit_index for current loop was: 96
# close_unit_index for next loop is: 97
# Total if loops: 74
# Total elif_1 loops: 91
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 171 finished
# For loop run number: 172
# i = 0
# close_unit_datetime: 2021-03-19 14:08:16
# open_datetime_lifo: 2021-03-03 12:38:39
# value_close_units: 0.013268 value_open_units: 0.411511
# abs_diff_open_close_units: 0.398243
# close_unit_index for current loop is: 97
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 92
# changed_value_open_units: 0.013268
# value_close_units: 0.013268
# value_open_units: 0.411511
# close_unit_index: 97
# Elif_loop_1 run number: 92 finished
# i = 1
# close_unit_index for current loop was: 97
# close_unit_index for next loop is: 98
# Total if loops: 74
# Total elif_1 loops: 92
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 172 finished
# For loop run number: 173
# i = 0
# close_unit_datetime: 2021-03-19 14:08:31
# open_datetime_lifo: 2021-03-03 12:38:39
# value_close_units: 0.535013 value_open_units: 0.398243
# abs_diff_open_close_units: 0.13676999999999995
# close_unit_index for current loop is: 98
# (close_unit_index = close_index) is: True
# If_loop run number: 75
# value_close_units: 0.535013
# value_open_units: 0.398243
# close_unit_index: 98
# If_loop run number: 75 finished
# i = 0
# close_unit_index for current loop was: 98
# close_unit_index for next loop is: 98
# Total if loops: 75
# Total elif_1 loops: 92
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 173 finished
# For loop run number: 174
# i = 0
# close_unit_datetime: 2021-03-19 14:08:31
# open_datetime_lifo: 2021-02-26 20:42:03
# value_close_units: 0.13676999999999995 value_open_units: 0.462854
# abs_diff_open_close_units: 0.32608400000000004
# close_unit_index for current loop is: 98
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 93
# changed_value_open_units: 0.13676999999999995
# value_close_units: 0.13676999999999995
# value_open_units: 0.462854
# close_unit_index: 98
# Elif_loop_1 run number: 93 finished
# i = 1
# close_unit_index for current loop was: 98
# close_unit_index for next loop is: 99
# Total if loops: 75
# Total elif_1 loops: 93
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 174 finished
# For loop run number: 175
# i = 0
# close_unit_datetime: 2021-03-19 14:08:35
# open_datetime_lifo: 2021-02-26 20:42:03
# value_close_units: 0.057309 value_open_units: 0.32608400000000004
# abs_diff_open_close_units: 0.26877500000000004
# close_unit_index for current loop is: 99
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 94
# changed_value_open_units: 0.057309
# value_close_units: 0.057309
# value_open_units: 0.32608400000000004
# close_unit_index: 99
# Elif_loop_1 run number: 94 finished
# i = 1
# close_unit_index for current loop was: 99
# close_unit_index for next loop is: 100
# Total if loops: 75
# Total elif_1 loops: 94
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 175 finished
# For loop run number: 176
# i = 0
# close_unit_datetime: 2021-03-19 14:08:40
# open_datetime_lifo: 2021-02-26 20:42:03
# value_close_units: 0.272732 value_open_units: 0.26877500000000004
# abs_diff_open_close_units: 0.003956999999999933
# close_unit_index for current loop is: 100
# (close_unit_index = close_index) is: True
# If_loop run number: 76
# value_close_units: 0.272732
# value_open_units: 0.26877500000000004
# close_unit_index: 100
# If_loop run number: 76 finished
# i = 0
# close_unit_index for current loop was: 100
# close_unit_index for next loop is: 100
# Total if loops: 76
# Total elif_1 loops: 94
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 176 finished
# For loop run number: 177
# i = 0
# close_unit_datetime: 2021-03-19 14:08:40
# open_datetime_lifo: 2021-02-26 20:36:41
# value_close_units: 0.003956999999999933 value_open_units: 0.461876
# abs_diff_open_close_units: 0.4579190000000001
# close_unit_index for current loop is: 100
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 95
# changed_value_open_units: 0.003956999999999933
# value_close_units: 0.003956999999999933
# value_open_units: 0.461876
# close_unit_index: 100
# Elif_loop_1 run number: 95 finished
# i = 1
# close_unit_index for current loop was: 100
# close_unit_index for next loop is: 101
# Total if loops: 76
# Total elif_1 loops: 95
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 177 finished
# For loop run number: 178
# i = 0
# close_unit_datetime: 2021-03-19 14:08:45
# open_datetime_lifo: 2021-02-26 20:36:41
# value_close_units: 0.596832 value_open_units: 0.4579190000000001
# abs_diff_open_close_units: 0.13891299999999995
# close_unit_index for current loop is: 101
# (close_unit_index = close_index) is: True
# If_loop run number: 77
# value_close_units: 0.596832
# value_open_units: 0.4579190000000001
# close_unit_index: 101
# If_loop run number: 77 finished
# i = 0
# close_unit_index for current loop was: 101
# close_unit_index for next loop is: 101
# Total if loops: 77
# Total elif_1 loops: 95
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 178 finished
# For loop run number: 179
# i = 0
# close_unit_datetime: 2021-03-19 14:08:45
# open_datetime_lifo: 2021-02-25 23:07:22
# value_close_units: 0.13891299999999995 value_open_units: 0.016451
# abs_diff_open_close_units: 0.12246199999999996
# close_unit_index for current loop is: 101
# (close_unit_index = close_index) is: True
# If_loop run number: 78
# value_close_units: 0.13891299999999995
# value_open_units: 0.016451
# close_unit_index: 101
# If_loop run number: 78 finished
# i = 0
# close_unit_index for current loop was: 101
# close_unit_index for next loop is: 101
# Total if loops: 78
# Total elif_1 loops: 95
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 179 finished
# For loop run number: 180
# i = 0
# close_unit_datetime: 2021-03-19 14:08:45
# open_datetime_lifo: 2021-02-21 19:09:03
# value_close_units: 0.12246199999999996 value_open_units: 0.075283
# abs_diff_open_close_units: 0.04717899999999996
# close_unit_index for current loop is: 101
# (close_unit_index = close_index) is: True
# If_loop run number: 79
# value_close_units: 0.12246199999999996
# value_open_units: 0.075283
# close_unit_index: 101
# If_loop run number: 79 finished
# i = 0
# close_unit_index for current loop was: 101
# close_unit_index for next loop is: 101
# Total if loops: 79
# Total elif_1 loops: 95
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 180 finished
# For loop run number: 181
# i = 0
# close_unit_datetime: 2021-03-19 14:08:45
# open_datetime_lifo: 2021-02-20 22:35:17
# value_close_units: 0.04717899999999996 value_open_units: 0.051492
# abs_diff_open_close_units: 0.004313000000000046
# close_unit_index for current loop is: 101
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 96
# changed_value_open_units: 0.04717899999999996
# value_close_units: 0.04717899999999996
# value_open_units: 0.051492
# close_unit_index: 101
# Elif_loop_1 run number: 96 finished
# i = 1
# close_unit_index for current loop was: 101
# close_unit_index for next loop is: 102
# Total if loops: 79
# Total elif_1 loops: 96
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 181 finished
# For loop run number: 182
# i = 0
# close_unit_datetime: 2021-03-19 14:08:59
# open_datetime_lifo: 2021-02-20 22:35:17
# value_close_units: 0.014124 value_open_units: 0.004313000000000046
# abs_diff_open_close_units: 0.009810999999999953
# close_unit_index for current loop is: 102
# (close_unit_index = close_index) is: True
# If_loop run number: 80
# value_close_units: 0.014124
# value_open_units: 0.004313000000000046
# close_unit_index: 102
# If_loop run number: 80 finished
# i = 0
# close_unit_index for current loop was: 102
# close_unit_index for next loop is: 102
# Total if loops: 80
# Total elif_1 loops: 96
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 182 finished
# For loop run number: 183
# i = 0
# close_unit_datetime: 2021-03-19 14:08:59
# open_datetime_lifo: 2021-02-20 13:49:58
# value_close_units: 0.009810999999999953 value_open_units: 0.487805
# abs_diff_open_close_units: 0.47799400000000003
# close_unit_index for current loop is: 102
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 97
# changed_value_open_units: 0.009810999999999953
# value_close_units: 0.009810999999999953
# value_open_units: 0.487805
# close_unit_index: 102
# Elif_loop_1 run number: 97 finished
# i = 1
# close_unit_index for current loop was: 102
# close_unit_index for next loop is: 103
# Total if loops: 80
# Total elif_1 loops: 97
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 183 finished
# For loop run number: 184
# i = 0
# close_unit_datetime: 2021-03-19 14:09:10
# open_datetime_lifo: 2021-02-20 13:49:58
# value_close_units: 0.016451 value_open_units: 0.47799400000000003
# abs_diff_open_close_units: 0.46154300000000004
# close_unit_index for current loop is: 103
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 98
# changed_value_open_units: 0.016451
# value_close_units: 0.016451
# value_open_units: 0.47799400000000003
# close_unit_index: 103
# Elif_loop_1 run number: 98 finished
# i = 1
# close_unit_index for current loop was: 103
# close_unit_index for next loop is: 104
# Total if loops: 80
# Total elif_1 loops: 98
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 184 finished
# For loop run number: 185
# i = 0
# close_unit_datetime: 2021-03-19 14:09:16
# open_datetime_lifo: 2021-02-20 13:49:58
# value_close_units: 0.019578 value_open_units: 0.46154300000000004
# abs_diff_open_close_units: 0.44196500000000005
# close_unit_index for current loop is: 104
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 99
# changed_value_open_units: 0.019578
# value_close_units: 0.019578
# value_open_units: 0.46154300000000004
# close_unit_index: 104
# Elif_loop_1 run number: 99 finished
# i = 1
# close_unit_index for current loop was: 104
# close_unit_index for next loop is: 105
# Total if loops: 80
# Total elif_1 loops: 99
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 185 finished
# For loop run number: 186
# i = 0
# close_unit_datetime: 2021-03-19 14:09:20
# open_datetime_lifo: 2021-02-20 13:49:58
# value_close_units: 0.019988 value_open_units: 0.44196500000000005
# abs_diff_open_close_units: 0.42197700000000005
# close_unit_index for current loop is: 105
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 100
# changed_value_open_units: 0.019988
# value_close_units: 0.019988
# value_open_units: 0.44196500000000005
# close_unit_index: 105
# Elif_loop_1 run number: 100 finished
# i = 1
# close_unit_index for current loop was: 105
# close_unit_index for next loop is: 106
# Total if loops: 80
# Total elif_1 loops: 100
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 186 finished
# For loop run number: 187
# i = 0
# close_unit_datetime: 2021-03-19 14:09:24
# open_datetime_lifo: 2021-02-20 13:49:58
# value_close_units: 0.021339 value_open_units: 0.42197700000000005
# abs_diff_open_close_units: 0.40063800000000005
# close_unit_index for current loop is: 106
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 101
# changed_value_open_units: 0.021339
# value_close_units: 0.021339
# value_open_units: 0.42197700000000005
# close_unit_index: 106
# Elif_loop_1 run number: 101 finished
# i = 1
# close_unit_index for current loop was: 106
# close_unit_index for next loop is: 107
# Total if loops: 80
# Total elif_1 loops: 101
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 187 finished
# For loop run number: 188
# i = 0
# close_unit_datetime: 2021-03-19 14:09:29
# open_datetime_lifo: 2021-02-20 13:49:58
# value_close_units: 0.02145 value_open_units: 0.40063800000000005
# abs_diff_open_close_units: 0.379188
# close_unit_index for current loop is: 107
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 102
# changed_value_open_units: 0.02145
# value_close_units: 0.02145
# value_open_units: 0.40063800000000005
# close_unit_index: 107
# Elif_loop_1 run number: 102 finished
# i = 1
# close_unit_index for current loop was: 107
# close_unit_index for next loop is: 108
# Total if loops: 80
# Total elif_1 loops: 102
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 188 finished
# For loop run number: 189
# i = 0
# close_unit_datetime: 2021-03-19 14:09:33
# open_datetime_lifo: 2021-02-20 13:49:58
# value_close_units: 0.022436 value_open_units: 0.379188
# abs_diff_open_close_units: 0.356752
# close_unit_index for current loop is: 108
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 103
# changed_value_open_units: 0.022436
# value_close_units: 0.022436
# ...
# If_loop run number: 156
# value_close_units: 0.06109800000000037
# value_open_units: 0.020263
# close_unit_index: 171
# If_loop run number: 156 finished
# i = 0
# close_unit_index for current loop was: 171
# close_unit_index for next loop is: 171
# Total if loops: 156
# Total elif_1 loops: 165
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 327 finished
# For loop run number: 328
# i = 0
# close_unit_datetime: 2022-05-11 07:32:34
# open_datetime_lifo: 2020-11-23 21:47:38
# value_close_units: 0.04083500000000037 value_open_units: 0.020262
# abs_diff_open_close_units: 0.020573000000000372
# close_unit_index for current loop is: 171
# (close_unit_index = close_index) is: True
# If_loop run number: 157
# value_close_units: 0.04083500000000037
# value_open_units: 0.020262
# close_unit_index: 171
# If_loop run number: 157 finished
# i = 0
# close_unit_index for current loop was: 171
# close_unit_index for next loop is: 171
# Total if loops: 157
# Total elif_1 loops: 165
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 328 finished
# For loop run number: 329
# i = 0
# close_unit_datetime: 2022-05-11 07:32:34
# open_datetime_lifo: 2020-11-23 21:05:46
# value_close_units: 0.020573000000000372 value_open_units: 0.164989
# abs_diff_open_close_units: 0.14441599999999963
# close_unit_index for current loop is: 171
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 166
# changed_value_open_units: 0.020573000000000372
# value_close_units: 0.020573000000000372
# value_open_units: 0.164989
# close_unit_index: 171
# Elif_loop_1 run number: 166 finished
# i = 1
# close_unit_index for current loop was: 171
# close_unit_index for next loop is: 172
# Total if loops: 157
# Total elif_1 loops: 166
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 329 finished
# For loop run number: 330
# i = 0
# close_unit_datetime: 2022-05-11 07:32:38
# open_datetime_lifo: 2020-11-23 21:05:46
# value_close_units: 0.331602 value_open_units: 0.14441599999999963
# abs_diff_open_close_units: 0.18718600000000038
# close_unit_index for current loop is: 172
# (close_unit_index = close_index) is: True
# If_loop run number: 158
# value_close_units: 0.331602
# value_open_units: 0.14441599999999963
# close_unit_index: 172
# If_loop run number: 158 finished
# i = 0
# close_unit_index for current loop was: 172
# close_unit_index for next loop is: 172
# Total if loops: 158
# Total elif_1 loops: 166
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 330 finished
# For loop run number: 331
# i = 0
# close_unit_datetime: 2022-05-11 07:32:38
# open_datetime_lifo: 2020-11-22 17:43:36
# value_close_units: 0.18718600000000038 value_open_units: 0.044523
# abs_diff_open_close_units: 0.14266300000000037
# close_unit_index for current loop is: 172
# (close_unit_index = close_index) is: True
# If_loop run number: 159
# value_close_units: 0.18718600000000038
# value_open_units: 0.044523
# close_unit_index: 172
# If_loop run number: 159 finished
# i = 0
# close_unit_index for current loop was: 172
# close_unit_index for next loop is: 172
# Total if loops: 159
# Total elif_1 loops: 166
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 331 finished
# For loop run number: 332
# i = 0
# close_unit_datetime: 2022-05-11 07:32:38
# open_datetime_lifo: 2020-11-21 13:56:41
# value_close_units: 0.14266300000000037 value_open_units: 0.047081
# abs_diff_open_close_units: 0.09558200000000037
# close_unit_index for current loop is: 172
# (close_unit_index = close_index) is: True
# If_loop run number: 160
# value_close_units: 0.14266300000000037
# value_open_units: 0.047081
# close_unit_index: 172
# If_loop run number: 160 finished
# i = 0
# close_unit_index for current loop was: 172
# close_unit_index for next loop is: 172
# Total if loops: 160
# Total elif_1 loops: 166
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 332 finished
# For loop run number: 333
# i = 0
# close_unit_datetime: 2022-05-11 07:32:38
# open_datetime_lifo: 2020-11-21 08:56:44
# value_close_units: 0.09558200000000037 value_open_units: 0.189746
# abs_diff_open_close_units: 0.09416399999999962
# close_unit_index for current loop is: 172
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 167
# changed_value_open_units: 0.09558200000000037
# value_close_units: 0.09558200000000037
# value_open_units: 0.189746
# close_unit_index: 172
# Elif_loop_1 run number: 167 finished
# i = 1
# close_unit_index for current loop was: 172
# close_unit_index for next loop is: 173
# Total if loops: 160
# Total elif_1 loops: 167
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 333 finished
# For loop run number: 334
# i = 0
# close_unit_datetime: 2022-05-11 07:32:42
# open_datetime_lifo: 2020-11-21 08:56:44
# value_close_units: 0.30181 value_open_units: 0.09416399999999962
# abs_diff_open_close_units: 0.20764600000000039
# close_unit_index for current loop is: 173
# (close_unit_index = close_index) is: True
# If_loop run number: 161
# value_close_units: 0.30181
# value_open_units: 0.09416399999999962
# close_unit_index: 173
# If_loop run number: 161 finished
# i = 0
# close_unit_index for current loop was: 173
# close_unit_index for next loop is: 173
# Total if loops: 161
# Total elif_1 loops: 167
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 334 finished
# For loop run number: 335
# i = 0
# close_unit_datetime: 2022-05-11 07:32:42
# open_datetime_lifo: 2020-11-20 21:38:06
# value_close_units: 0.20764600000000039 value_open_units: 0.104958
# abs_diff_open_close_units: 0.10268800000000039
# close_unit_index for current loop is: 173
# (close_unit_index = close_index) is: True
# If_loop run number: 162
# value_close_units: 0.20764600000000039
# value_open_units: 0.104958
# close_unit_index: 173
# If_loop run number: 162 finished
# i = 0
# close_unit_index for current loop was: 173
# close_unit_index for next loop is: 173
# Total if loops: 162
# Total elif_1 loops: 167
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 335 finished
# For loop run number: 336
# i = 0
# close_unit_datetime: 2022-05-11 07:32:42
# open_datetime_lifo: 2020-11-16 20:58:29
# value_close_units: 0.10268800000000039 value_open_units: 0.191735
# abs_diff_open_close_units: 0.0890469999999996
# close_unit_index for current loop is: 173
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 168
# changed_value_open_units: 0.10268800000000039
# value_close_units: 0.10268800000000039
# value_open_units: 0.191735
# close_unit_index: 173
# Elif_loop_1 run number: 168 finished
# i = 1
# close_unit_index for current loop was: 173
# close_unit_index for next loop is: 174
# Total if loops: 162
# Total elif_1 loops: 168
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 336 finished
# For loop run number: 337
# i = 0
# close_unit_datetime: 2022-05-11 07:40:28
# open_datetime_lifo: 2020-11-16 20:58:29
# value_close_units: 0.299925 value_open_units: 0.0890469999999996
# abs_diff_open_close_units: 0.2108780000000004
# close_unit_index for current loop is: 174
# (close_unit_index = close_index) is: True
# If_loop run number: 163
# value_close_units: 0.299925
# value_open_units: 0.0890469999999996
# close_unit_index: 174
# If_loop run number: 163 finished
# i = 0
# close_unit_index for current loop was: 174
# close_unit_index for next loop is: 174
# Total if loops: 163
# Total elif_1 loops: 168
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 337 finished
# For loop run number: 338
# i = 0
# close_unit_datetime: 2022-05-11 07:40:28
# open_datetime_lifo: 2020-11-16 19:43:33
# value_close_units: 0.2108780000000004 value_open_units: 0.257341
# abs_diff_open_close_units: 0.04646299999999959
# close_unit_index for current loop is: 174
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 169
# changed_value_open_units: 0.2108780000000004
# value_close_units: 0.2108780000000004
# value_open_units: 0.257341
# close_unit_index: 174
# Elif_loop_1 run number: 169 finished
# i = 1
# close_unit_index for current loop was: 174
# close_unit_index for next loop is: 175
# Total if loops: 163
# Total elif_1 loops: 169
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 338 finished
# For loop run number: 339
# i = 0
# close_unit_datetime: 2022-05-11 07:40:31
# open_datetime_lifo: 2020-11-16 19:43:33
# value_close_units: 0.299497 value_open_units: 0.04646299999999959
# abs_diff_open_close_units: 0.2530340000000004
# close_unit_index for current loop is: 175
# (close_unit_index = close_index) is: True
# If_loop run number: 164
# value_close_units: 0.299497
# value_open_units: 0.04646299999999959
# close_unit_index: 175
# If_loop run number: 164 finished
# i = 0
# close_unit_index for current loop was: 175
# close_unit_index for next loop is: 175
# Total if loops: 164
# Total elif_1 loops: 169
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 339 finished
# For loop run number: 340
# i = 0
# close_unit_datetime: 2022-05-11 07:40:31
# open_datetime_lifo: 2020-11-16 17:31:50
# value_close_units: 0.2530340000000004 value_open_units: 0.206347
# abs_diff_open_close_units: 0.04668700000000042
# close_unit_index for current loop is: 175
# (close_unit_index = close_index) is: True
# If_loop run number: 165
# value_close_units: 0.2530340000000004
# value_open_units: 0.206347
# close_unit_index: 175
# If_loop run number: 165 finished
# i = 0
# close_unit_index for current loop was: 175
# close_unit_index for next loop is: 175
# Total if loops: 165
# Total elif_1 loops: 169
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 340 finished
# For loop run number: 341
# i = 0
# close_unit_datetime: 2022-05-11 07:40:31
# open_datetime_lifo: 2020-11-08 06:50:57
# value_close_units: 0.04668700000000042 value_open_units: 0.056147
# abs_diff_open_close_units: 0.00945999999999958
# close_unit_index for current loop is: 175
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 170
# changed_value_open_units: 0.04668700000000042
# value_close_units: 0.04668700000000042
# value_open_units: 0.056147
# close_unit_index: 175
# Elif_loop_1 run number: 170 finished
# i = 1
# close_unit_index for current loop was: 175
# close_unit_index for next loop is: 176
# Total if loops: 165
# Total elif_1 loops: 170
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 341 finished
# For loop run number: 342
# i = 0
# close_unit_datetime: 2022-05-11 07:40:35
# open_datetime_lifo: 2020-11-08 06:50:57
# value_close_units: 0.168389 value_open_units: 0.00945999999999958
# abs_diff_open_close_units: 0.15892900000000043
# close_unit_index for current loop is: 176
# (close_unit_index = close_index) is: True
# If_loop run number: 166
# value_close_units: 0.168389
# value_open_units: 0.00945999999999958
# close_unit_index: 176
# If_loop run number: 166 finished
# i = 0
# close_unit_index for current loop was: 176
# close_unit_index for next loop is: 176
# Total if loops: 166
# Total elif_1 loops: 170
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 342 finished
# For loop run number: 343
# i = 0
# close_unit_datetime: 2022-05-11 07:40:35
# open_datetime_lifo: 2020-11-07 15:21:37
# value_close_units: 0.15892900000000043 value_open_units: 0.227298
# abs_diff_open_close_units: 0.06836899999999957
# close_unit_index for current loop is: 176
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 171
# changed_value_open_units: 0.15892900000000043
# value_close_units: 0.15892900000000043
# value_open_units: 0.227298
# close_unit_index: 176
# Elif_loop_1 run number: 171 finished
# i = 1
# close_unit_index for current loop was: 176
# close_unit_index for next loop is: 177
# Total if loops: 166
# Total elif_1 loops: 171
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 343 finished
# For loop run number: 344
# i = 0
# close_unit_datetime: 2022-05-11 07:40:38
# open_datetime_lifo: 2020-11-07 15:21:37
# value_close_units: 0.12085 value_open_units: 0.06836899999999957
# abs_diff_open_close_units: 0.05248100000000043
# close_unit_index for current loop is: 177
# (close_unit_index = close_index) is: True
# If_loop run number: 167
# value_close_units: 0.12085
# value_open_units: 0.06836899999999957
# close_unit_index: 177
# If_loop run number: 167 finished
# i = 0
# close_unit_index for current loop was: 177
# close_unit_index for next loop is: 177
# Total if loops: 167
# Total elif_1 loops: 171
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 344 finished
# For loop run number: 345
# i = 0
# close_unit_datetime: 2022-05-11 07:40:38
# open_datetime_lifo: 2020-11-07 14:01:59
# value_close_units: 0.05248100000000043 value_open_units: 0.053369
# abs_diff_open_close_units: 0.0008879999999995697
# close_unit_index for current loop is: 177
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 172
# changed_value_open_units: 0.05248100000000043
# value_close_units: 0.05248100000000043
# value_open_units: 0.053369
# close_unit_index: 177
# Elif_loop_1 run number: 172 finished
# i = 1
# close_unit_index for current loop was: 177
# close_unit_index for next loop is: 178
# Total if loops: 167
# Total elif_1 loops: 172
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 345 finished
# For loop run number: 346
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-11-07 14:01:59
# value_close_units: 0.252729 value_open_units: 0.0008879999999995697
# abs_diff_open_close_units: 0.2518410000000004
# close_unit_index for current loop is: 178
# (close_unit_index = close_index) is: True
# If_loop run number: 168
# value_close_units: 0.252729
# value_open_units: 0.0008879999999995697
# close_unit_index: 178
# If_loop run number: 168 finished
# i = 0
# close_unit_index for current loop was: 178
# close_unit_index for next loop is: 178
# Total if loops: 168
# Total elif_1 loops: 172
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 346 finished
# For loop run number: 347
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-11-02 20:57:38
# value_close_units: 0.2518410000000004 value_open_units: 0.06354
# abs_diff_open_close_units: 0.18830100000000044
# close_unit_index for current loop is: 178
# (close_unit_index = close_index) is: True
# If_loop run number: 169
# value_close_units: 0.2518410000000004
# value_open_units: 0.06354
# close_unit_index: 178
# If_loop run number: 169 finished
# i = 0
# close_unit_index for current loop was: 178
# close_unit_index for next loop is: 178
# Total if loops: 169
# Total elif_1 loops: 172
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 347 finished
# For loop run number: 348
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-10-30 10:53:00
# value_close_units: 0.18830100000000044 value_open_units: 0.065326
# abs_diff_open_close_units: 0.12297500000000045
# close_unit_index for current loop is: 178
# (close_unit_index = close_index) is: True
# If_loop run number: 170
# value_close_units: 0.18830100000000044
# value_open_units: 0.065326
# close_unit_index: 178
# If_loop run number: 170 finished
# i = 0
# close_unit_index for current loop was: 178
# close_unit_index for next loop is: 178
# Total if loops: 170
# Total elif_1 loops: 172
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 348 finished
# For loop run number: 349
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-10-28 08:12:17
# value_close_units: 0.12297500000000045 value_open_units: 0.062841
# abs_diff_open_close_units: 0.06013400000000045
# close_unit_index for current loop is: 178
# (close_unit_index = close_index) is: True
# If_loop run number: 171
# value_close_units: 0.12297500000000045
# value_open_units: 0.062841
# close_unit_index: 178
# If_loop run number: 171 finished
# i = 0
# close_unit_index for current loop was: 178
# close_unit_index for next loop is: 178
# Total if loops: 171
# Total elif_1 loops: 172
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 349 finished
# For loop run number: 350
# i = 0
# close_unit_datetime: 2022-05-11 07:40:41
# open_datetime_lifo: 2020-10-22 12:56:27
# value_close_units: 0.06013400000000045 value_open_units: 0.060134
# abs_diff_open_close_units: 4.510281037539698e-16
# close_unit_index for current loop is: 178
# (close_unit_index = close_index) is: True
# If_loop run number: 172
# value_close_units: 0.06013400000000045
# value_open_units: 0.060134
# close_unit_index: 178
# If_loop run number: 172 finished
# i = 1
# close_unit_index for current loop was: 178
# close_unit_index for next loop is: 179
# Total if loops: 172
# Total elif_1 loops: 172
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 350 finished
# ****************************************

# %%
print('df_lifo_btc sum of open units:',df_lifo_btc['Open Units'].sum())
print('df_lifo_btc sum of close units:',df_lifo_btc['Close Units'].sum())
print('df_open_btc_original sum of open units:',df_open_btc_original['Open Units'].sum())
print('df_close_btc_original sum of close units:',df_close_btc_original['Close Units'].sum())
# Out:
# df_lifo_btc sum of open units: 63.123861
# df_lifo_btc sum of close units: 63.123861
# df_open_btc_original sum of open units: 63.123861
# df_close_btc_original sum of close units: 63.123861

# %%
df_lifo_btc['time_difference'] = df_lifo_btc['Close Datetime'] - df_lifo_btc['Open Datetime']
df_lifo_btc['time_difference_days'] = df_lifo_btc['time_difference'] / np.timedelta64(1, 'D')
df_lifo_btc_taxable = df_lifo_btc[df_lifo_btc['time_difference_days'] < 365]
df_lifo_btc_taxable_2020 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1609455599]
df_lifo_btc_taxable_2020_2021 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1640991599]
df_lifo_btc_taxable_2021 = df_lifo_btc_taxable_2020_2021[df_lifo_btc_taxable_2020_2021['Close_unix_timestamp'] > 1609455599]
df_lifo_btc_taxable_2022 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] > 1640991599]
print('Sum of all open positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Amount_close_Eur'].sum())
# Out:
# Sum of all open positions for the year 2020 in eur: 4999.3660732202225
# Sum of all closed positions for the year 2020 in eur: 5090.286860390001
# Sum of all open positions for the year 2021 in eur: 43748.324966774715
# Sum of all closed positions for the year 2021 in eur: 47124.49179078
# Sum of all open positions for the year 2022 in eur: 16977.025957100028
# Sum of all closed positions for the year 2022 in eur: 18895.351222981324

# %%
df_open_btc

# %%
df_close_btc

# %%
df_lifo_btc

# %%
df_close['Close Action'].unique()
# Out:
# array(['Buy Bitcoin', 'Buy Ethereum', 'Buy XRP', 'Buy Tezos', 'Buy EOS',
#        'Buy Cardano', 'Buy Litecoin', 'Buy Build and Build', 'Buy TRON',
#        'Buy Dogecoin', 'Buy Chainlink', 'Buy Uniswap', 'Buy Polygon',
#        'Buy Stellar', 'Buy Decentraland', 'Buy Aave', 'Buy IOTA',
#        'Buy Shiba (in millions)', 'Buy Enjin', 'Buy Maker',
#        'Buy Algorand', 'Buy Solana', 'Buy Polkadot', 'Buy Songbird'],
#       dtype=object)
