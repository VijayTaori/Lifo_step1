# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayTaori/Lifo_step1/blob/main/Copy_of_Detailed_lifo_xrp_step_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt
import time
import calendar
df_open = pd.read_csv('/content/et_open_alldata.csv')
df_close = pd.read_csv('/content/et_close_alldata.csv')
df_close['Close Datetime'] = pd.to_datetime(df_close['Close_unix_timestamp'],dayfirst=True,unit='s')
df_open['Open Datetime'] = pd.to_datetime(df_open['Open_unix_timestamp'],dayfirst=True,unit='s')
df_close_btc = df_close[df_close['Close Action'] =='Buy XRP']
df_open_btc = df_open[df_open['Open Action'] =='Buy XRP']
df_close_btc_original = df_close_btc
df_open_btc_original = df_open_btc
df_close_btc.reset_index(inplace=True)
df_close_btc = df_close_btc.drop('index', axis=1)
df_close_btc.reset_index(inplace=True)
df_close_btc.rename(columns={'index':'Original_Close_index'},inplace=True)
df_open_btc.reset_index(inplace=True)
df_open_btc = df_open_btc.drop('index', axis=1)
df_open_btc.reset_index(inplace=True)
df_open_btc.rename(columns={'index':'Original_Open_index'},inplace=True)
data_btc = {}
df_lifo_btc = pd.DataFrame(data_btc, 
                           columns=['Original_Open_index','Original_Close_index',
                                    'Open Position ID', 'Close Position ID',
                                    'Open Units','Close Units','Spread_Eur',
                                    'Open Amount_Eur','Amount_close_Eur',
                                    'Open Datetime', 'Close Datetime',
                                    'Open Rate_Eur', 'Close Rate_Eur',
                                    'Open Action', 'Close Action', 
                                    'Open Amount','Close Rate', 'Open Rate',
                                    'Close Spread', 'Close Profit USD',
                                    'Close_Date','Open_Date',
                                    'Close_unix_timestamp','EurOpen_y', 
                                    'EurHigh_y','EurLow_y', 'EurClose_y',
                                    'EurWeekday_y', 'Open_unix_timestamp',
                                    'EurOpen_x', 'EurHigh_x','EurLow_x', 
                                    'EurClose_x','EurWeekday_x'
                                    ]
                           )
# Let's build a index selector for df_close_btc
close_unit_index = 0
value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
final_close_unit_index = df_open_btc.shape[0]
serial_number_for_loop = 0
serial_number_if_loop = 0
serial_number_elif_loop_1 = 0
serial_number_elif_loop_2 = 0
serial_number_else_loop = 0
while close_unit_index < final_close_unit_index:
  serial_number_for_loop = serial_number_for_loop + 1
  print('For loop run number:',serial_number_for_loop)
  i = 0
  print('i =',i)
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  # How to set up an upper limit on this variable?? use df.shape[0]
  # Choosing first row from df_close_btc where the units are = values_of_units
  # Assign it as new DF
  # change the reset the index and the drop the 'index' column
  df_latest_row_from_close = df_close_btc[close_unit_index:(close_unit_index+1)]
  df_latest_row_from_close.reset_index(inplace=True)
  current_close_index = df_latest_row_from_close.at[0,'index']
  df_latest_row_from_close = df_latest_row_from_close.drop('index',axis=1)
  # Get the datetime value from the df_latest_row_from_close
  close_unit_datetime = df_close_btc.loc[close_unit_index,'Close Datetime']
  print('close_unit_datetime:',close_unit_datetime)
  # find all the transaction datetimes from df_open that were opened before the close_unit_datetime
  open_datetimes_b4 = df_open_btc['Open Datetime'][df_open_btc['Open Datetime'] < close_unit_datetime]
  #Latest datetime beofore close datetime
  open_datetime_lifo = open_datetimes_b4.max()
  #if open_datetime_lifo == pd.NaT:
  #  break
  #else:
  #  continue
  print('open_datetime_lifo:',open_datetime_lifo)
  '''
  Remember that even if only one value for open_datetime_lifo is chosen
  this can still result in chosing more than one rows in that case last row 
  should be chosen
  '''
  # Corresponding row for the open_datetime_lifo 
  # let's make a new DF
  df_latest_last_row_open = df_open_btc[df_open_btc['Open Datetime'] == open_datetime_lifo]
  df_latest_last_row_open = df_latest_last_row_open[::-1]
  df_latest_last_row_open = df_latest_last_row_open[0:1]
  df_latest_last_row_open.reset_index(inplace=True)
  current_open_index = df_latest_last_row_open.at[0,'index']
  df_latest_last_row_open = df_latest_last_row_open.drop('index', axis=1)
  value_open_units = df_latest_last_row_open.loc[0,'Open Units']
  print('value_close_units:',value_close_units, 'value_open_units:',value_open_units)
  abs_diff_open_close_units = abs(value_close_units - value_open_units)
  print('abs_diff_open_close_units:',abs_diff_open_close_units)
  value_open_amount = df_latest_last_row_open.loc[0,'Open Amount_Eur']
  value_close_amount = df_latest_row_from_close.loc[0,'Amount_close_Eur']
  value_close_spread_eur = df_latest_row_from_close.loc[0,'Spread_Eur']
  close_Rate_eur = df_latest_row_from_close.loc[0,'Close Rate_Eur']
  open_Rate_eur = df_latest_last_row_open.loc[0,'Open Rate_Eur']
  #Remember that 'Open_index' and 'Close_index' columns host original indices
  # This is important as df_open_btc starts to drop rows the original indices will come in handy 
  # And in case of df_close_btc this should remain equal to the indices from DataFrame
  original_open_index = df_latest_last_row_open.at[0, 'Original_Open_index']
  #Remeber that earlier defined close_unit_index is the index of units from df_close_btc DataFrame
  # close_index should essentially be equal in integer value of close_unit_index
  close_index = df_latest_row_from_close.at[0, 'Original_Close_index']
  is_it_equal = close_unit_index == close_index
  print('close_unit_index for current loop is:',close_unit_index)
  print('(close_unit_index = close_index) is:',is_it_equal)
  if value_close_units > value_open_units:
    serial_number_if_loop = serial_number_if_loop + 1
    print('If_loop run number:',serial_number_if_loop)
    #First lets extract all the values from open DF df_latest_last_row_open
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
    df_open_btc = df_open_btc.drop(current_open_index,axis=0)
    #Then reset index and drop the new column 'index' in df_open_btc
    df_open_btc.reset_index(inplace=True)
    df_open_btc = df_open_btc.drop('index',axis=1)
    #Now lets work on the Close_side
    #First define the changed values for df_latest_row_from_close
    changed_value_close_units = value_open_units
    changed_value_close_amount = changed_value_close_units * close_Rate_eur
    changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    df_latest_row_from_close.at[0,'Close Units'] = changed_value_close_units
    df_latest_row_from_close.at[0,'Amount_close_Eur'] = changed_value_close_amount
    df_latest_row_from_close.at[0,'Spread_Eur'] = changed_value_close_spread
    # Now lets extract all the values from df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
    df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('If_loop run number:',serial_number_if_loop,'finished')
  elif value_close_units < value_open_units:
    serial_number_elif_loop_1 = serial_number_elif_loop_1 + 1
    print('Elif_loop_1 run number:', serial_number_elif_loop_1)
    ## First lets extract all the values form close DF df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    #First define the changed values for df_latest_row_from_close
    ## In elif statement changed values are same as we made only one change
    # and after that change the value of units and amount and spread in original df_close_btc
    df_close_btc.at[close_unit_index,'Close Units'] = 0
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = 0
    df_close_btc.at[close_unit_index,'Spread_Eur'] = 0
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    # Now lets extract all the values from df_latest_row_from_close
    ## Now lets work on the values from open DF df_latest_last_row_lifo
    ## Remember we want to get back the values in the df_latest_row_from_close 
    ## we will have to assign changed_values for open_units and open_amount
    changed_value_open_units = value_close_units
    changed_value_open_amount = changed_value_open_units * open_Rate_eur
    print('changed_value_open_units:',changed_value_open_units)
    df_latest_last_row_open.at[0,'Open Units'] = changed_value_open_units
    df_latest_last_row_open.at[0,'Open Amount_Eur'] = changed_value_open_amount
    ##After the values are changed extract the values which will then be reported
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    ## and then this time change the original values in the df_open_units
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_open_btc.at[current_open_index,'Open Units'] = value_open_units - changed_value_open_units
    df_open_btc.at[current_open_index,'Open Amount_Eur'] = value_open_amount - changed_value_open_amount
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_1 run number:', serial_number_elif_loop_1, 'finished')
  elif value_close_units == value_open_units:
    serial_number_elif_loop_2 = serial_number_elif_loop_2 + 1
    if value_close_units == 0:
      print('We are running value_close_units == 0 condition')
      print('This is in the Elif_loop_number_2:',serial_number_elif_loop_2)
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      print('We are breaking')
      break
    else:
      #First lets extract all the values from open DF df_latest_last_row_open
      newth_list_open_half = df_latest_last_row_open.to_dict('records')
      newth_dict_open_half = newth_list_open_half[0]
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      ### Second lets extract all the values form close DF df_latest_row_from_close
      newth_list_close_half = df_latest_row_from_close.to_dict('records')
      newth_dict_close_half = newth_list_close_half[0]
      ## and then this time change the original values in the df_open_units
      newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
      # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
      df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
      #First define the changed values for df_latest_row_from_close
      changed_value_close_units = value_open_units
      changed_value_close_amount = changed_value_close_units * close_Rate_eur
      changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
      # and after that change the value of units and amount in original df_open_btc
      df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
      df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
      df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_2 run number:', serial_number_elif_loop_2, 'finished')
  else:
    serial_number_else_loop = serial_number_else_loop + 1
    print('Do we need to write more code? The answer is a: BIG YES!!')
    print('Or on second thought this is a silly mistake!!!')
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('serial_number_else_loop:', serial_number_else_loop, 'finished')
    print('We are breaking here!!')
    break
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  if value_close_units < 1.0e-10:
    i = 1
  else:
    i = 0
  print('i =',i)
  print('close_unit_index for current loop was:',close_unit_index)
  close_unit_index = close_unit_index + i
  print('close_unit_index for next loop is:',close_unit_index)
  print('Total if loops:',serial_number_if_loop)
  print('Total elif_1 loops:',serial_number_elif_loop_1)
  print('Total elif_2 loops:',serial_number_elif_loop_2)
  print('Total else loops:',serial_number_else_loop)
  print('For loop run number:',serial_number_for_loop,'finished')
  if df_close_btc['Close Units'].sum() < 1.0e-10:
    close_unit_index = final_close_unit_index
  else:
    continue
  print('****************************************')
# Out:
# For loop run number: 1
# i = 0
# close_unit_datetime: 2020-05-15 03:32:44
# open_datetime_lifo: 2020-05-10 06:53:27
# value_close_units: 126.518219 value_open_units: 400.4004
# abs_diff_open_close_units: 273.882181
# close_unit_index for current loop is: 0
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 1
# changed_value_open_units: 126.518219
# value_close_units: 126.518219
# value_open_units: 400.4004
# close_unit_index: 0
# Elif_loop_1 run number: 1 finished
# i = 1
# close_unit_index for current loop was: 0
# close_unit_index for next loop is: 1
# Total if loops: 0
# Total elif_1 loops: 1
# Total elif_2 loops: 0
# Total else loops: 0
# For loop run number: 1 finished
# For loop run number: 2
# i = 0
# close_unit_datetime: 2020-05-16 13:01:32
# open_datetime_lifo: 2020-05-15 21:11:01
# value_close_units: 126.518219 value_open_units: 126.518219
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 1
# (close_unit_index = close_index) is: True
# value_close_units: 126.518219
# value_open_units: 126.518219
# close_unit_index: 1
# Elif_loop_2 run number: 1 finished
# i = 1
# close_unit_index for current loop was: 1
# close_unit_index for next loop is: 2
# Total if loops: 0
# Total elif_1 loops: 1
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 2 finished
# For loop run number: 3
# i = 0
# close_unit_datetime: 2020-05-17 07:01:47
# open_datetime_lifo: 2020-05-10 06:53:27
# value_close_units: 263.157895 value_open_units: 273.882181
# abs_diff_open_close_units: 10.724286000000006
# close_unit_index for current loop is: 2
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 2
# changed_value_open_units: 263.157895
# value_close_units: 263.157895
# value_open_units: 273.882181
# close_unit_index: 2
# Elif_loop_1 run number: 2 finished
# i = 1
# close_unit_index for current loop was: 2
# close_unit_index for next loop is: 3
# Total if loops: 0
# Total elif_1 loops: 2
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 3 finished
# For loop run number: 4
# i = 0
# close_unit_datetime: 2020-05-17 07:01:56
# open_datetime_lifo: 2020-05-10 06:53:27
# value_close_units: 131.440589 value_open_units: 10.724286000000006
# abs_diff_open_close_units: 120.71630299999998
# close_unit_index for current loop is: 3
# (close_unit_index = close_index) is: True
# If_loop run number: 1
# value_close_units: 131.440589
# value_open_units: 10.724286000000006
# close_unit_index: 3
# If_loop run number: 1 finished
# i = 0
# close_unit_index for current loop was: 3
# close_unit_index for next loop is: 3
# Total if loops: 1
# Total elif_1 loops: 2
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 4 finished
# For loop run number: 5
# i = 0
# close_unit_datetime: 2020-05-17 07:01:56
# open_datetime_lifo: 2020-05-10 00:23:22
# value_close_units: 120.71630299999998 value_open_units: 126.518219
# abs_diff_open_close_units: 5.80191600000002
# close_unit_index for current loop is: 3
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 3
# changed_value_open_units: 120.71630299999998
# value_close_units: 120.71630299999998
# value_open_units: 126.518219
# close_unit_index: 3
# Elif_loop_1 run number: 3 finished
# i = 1
# close_unit_index for current loop was: 3
# close_unit_index for next loop is: 4
# Total if loops: 1
# Total elif_1 loops: 3
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 5 finished
# For loop run number: 6
# i = 0
# close_unit_datetime: 2020-05-17 07:02:05
# open_datetime_lifo: 2020-05-10 00:23:22
# value_close_units: 127.877238 value_open_units: 5.80191600000002
# abs_diff_open_close_units: 122.07532199999999
# close_unit_index for current loop is: 4
# (close_unit_index = close_index) is: True
# If_loop run number: 2
# value_close_units: 127.877238
# value_open_units: 5.80191600000002
# close_unit_index: 4
# If_loop run number: 2 finished
# i = 0
# close_unit_index for current loop was: 4
# close_unit_index for next loop is: 4
# Total if loops: 2
# Total elif_1 loops: 3
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 6 finished
# For loop run number: 7
# i = 0
# close_unit_datetime: 2020-05-17 07:02:05
# open_datetime_lifo: 2020-05-10 00:20:33
# value_close_units: 122.07532199999999 value_open_units: 263.157895
# abs_diff_open_close_units: 141.08257300000002
# close_unit_index for current loop is: 4
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 4
# changed_value_open_units: 122.07532199999999
# value_close_units: 122.07532199999999
# value_open_units: 263.157895
# close_unit_index: 4
# Elif_loop_1 run number: 4 finished
# i = 1
# close_unit_index for current loop was: 4
# close_unit_index for next loop is: 5
# Total if loops: 2
# Total elif_1 loops: 4
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 7 finished
# For loop run number: 8
# i = 0
# close_unit_datetime: 2020-05-17 07:02:17
# open_datetime_lifo: 2020-05-10 00:20:33
# value_close_units: 127.291242 value_open_units: 141.08257300000002
# abs_diff_open_close_units: 13.791331000000028
# close_unit_index for current loop is: 5
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 5
# changed_value_open_units: 127.291242
# value_close_units: 127.291242
# value_open_units: 141.08257300000002
# close_unit_index: 5
# Elif_loop_1 run number: 5 finished
# i = 1
# close_unit_index for current loop was: 5
# close_unit_index for next loop is: 6
# Total if loops: 2
# Total elif_1 loops: 5
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 8 finished
# For loop run number: 9
# i = 0
# close_unit_datetime: 2020-05-17 07:02:24
# open_datetime_lifo: 2020-05-10 00:20:33
# value_close_units: 126.582278 value_open_units: 13.791331000000028
# abs_diff_open_close_units: 112.79094699999997
# close_unit_index for current loop is: 6
# (close_unit_index = close_index) is: True
# If_loop run number: 3
# value_close_units: 126.582278
# value_open_units: 13.791331000000028
# close_unit_index: 6
# If_loop run number: 3 finished
# i = 0
# close_unit_index for current loop was: 6
# close_unit_index for next loop is: 6
# Total if loops: 3
# Total elif_1 loops: 5
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 9 finished
# For loop run number: 10
# i = 0
# close_unit_datetime: 2020-05-17 07:02:24
# open_datetime_lifo: 2020-05-10 00:17:26
# value_close_units: 112.79094699999997 value_open_units: 122.249389
# abs_diff_open_close_units: 9.45844200000002
# close_unit_index for current loop is: 6
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 6
# changed_value_open_units: 112.79094699999997
# value_close_units: 112.79094699999997
# value_open_units: 122.249389
# close_unit_index: 6
# Elif_loop_1 run number: 6 finished
# i = 1
# close_unit_index for current loop was: 6
# close_unit_index for next loop is: 7
# Total if loops: 3
# Total elif_1 loops: 6
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 10 finished
# For loop run number: 11
# i = 0
# close_unit_datetime: 2020-05-17 07:02:35
# open_datetime_lifo: 2020-05-10 00:17:26
# value_close_units: 400.4004 value_open_units: 9.45844200000002
# abs_diff_open_close_units: 390.941958
# close_unit_index for current loop is: 7
# (close_unit_index = close_index) is: True
# If_loop run number: 4
# value_close_units: 400.4004
# value_open_units: 9.45844200000002
# close_unit_index: 7
# If_loop run number: 4 finished
# i = 0
# close_unit_index for current loop was: 7
# close_unit_index for next loop is: 7
# Total if loops: 4
# Total elif_1 loops: 6
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 11 finished
# For loop run number: 12
# i = 0
# close_unit_datetime: 2020-05-17 07:02:35
# open_datetime_lifo: 2020-05-10 00:15:38
# value_close_units: 390.941958 value_open_units: 119.38873
# abs_diff_open_close_units: 271.553228
# close_unit_index for current loop is: 7
# (close_unit_index = close_index) is: True
# If_loop run number: 5
# value_close_units: 390.941958
# value_open_units: 119.38873
# close_unit_index: 7
# If_loop run number: 5 finished
# i = 0
# close_unit_index for current loop was: 7
# close_unit_index for next loop is: 7
# Total if loops: 5
# Total elif_1 loops: 6
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 12 finished
# For loop run number: 13
# i = 0
# close_unit_datetime: 2020-05-17 07:02:35
# open_datetime_lifo: 2020-04-30 05:19:47
# value_close_units: 271.553228 value_open_units: 423.190859
# abs_diff_open_close_units: 151.637631
# close_unit_index for current loop is: 7
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 7
# changed_value_open_units: 271.553228
# value_close_units: 271.553228
# value_open_units: 423.190859
# close_unit_index: 7
# Elif_loop_1 run number: 7 finished
# i = 1
# close_unit_index for current loop was: 7
# close_unit_index for next loop is: 8
# Total if loops: 5
# Total elif_1 loops: 7
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 13 finished
# For loop run number: 14
# i = 0
# close_unit_datetime: 2020-05-20 12:37:31
# open_datetime_lifo: 2020-04-30 05:19:47
# value_close_units: 122.249389 value_open_units: 151.637631
# abs_diff_open_close_units: 29.388242000000005
# close_unit_index for current loop is: 8
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 8
# changed_value_open_units: 122.249389
# value_close_units: 122.249389
# value_open_units: 151.637631
# close_unit_index: 8
# Elif_loop_1 run number: 8 finished
# i = 1
# close_unit_index for current loop was: 8
# close_unit_index for next loop is: 9
# Total if loops: 5
# Total elif_1 loops: 8
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 14 finished
# For loop run number: 15
# i = 0
# close_unit_datetime: 2020-05-20 12:38:28
# open_datetime_lifo: 2020-04-30 05:19:47
# value_close_units: 119.38873 value_open_units: 29.388242000000005
# abs_diff_open_close_units: 90.00048799999999
# close_unit_index for current loop is: 9
# (close_unit_index = close_index) is: True
# If_loop run number: 6
# value_close_units: 119.38873
# value_open_units: 29.388242000000005
# close_unit_index: 9
# If_loop run number: 6 finished
# i = 0
# close_unit_index for current loop was: 9
# close_unit_index for next loop is: 9
# Total if loops: 6
# Total elif_1 loops: 8
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 15 finished
# For loop run number: 16
# i = 0
# close_unit_datetime: 2020-05-20 12:38:28
# open_datetime_lifo: 2020-04-28 19:56:34
# value_close_units: 90.00048799999999 value_open_units: 465.116279
# abs_diff_open_close_units: 375.11579100000006
# close_unit_index for current loop is: 9
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 9
# changed_value_open_units: 90.00048799999999
# value_close_units: 90.00048799999999
# value_open_units: 465.116279
# close_unit_index: 9
# Elif_loop_1 run number: 9 finished
# i = 1
# close_unit_index for current loop was: 9
# close_unit_index for next loop is: 10
# Total if loops: 6
# Total elif_1 loops: 9
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 16 finished
# For loop run number: 17
# i = 0
# close_unit_datetime: 2020-05-23 20:24:19
# open_datetime_lifo: 2020-05-23 08:18:03
# value_close_units: 130.480167 value_open_units: 953.815261
# abs_diff_open_close_units: 823.335094
# close_unit_index for current loop is: 10
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 10
# changed_value_open_units: 130.480167
# value_close_units: 130.480167
# value_open_units: 953.815261
# close_unit_index: 10
# Elif_loop_1 run number: 10 finished
# i = 1
# close_unit_index for current loop was: 10
# close_unit_index for next loop is: 11
# Total if loops: 6
# Total elif_1 loops: 10
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 17 finished
# For loop run number: 18
# i = 0
# close_unit_datetime: 2020-05-23 20:28:55
# open_datetime_lifo: 2020-05-23 08:18:03
# value_close_units: 256.937307 value_open_units: 823.335094
# abs_diff_open_close_units: 566.3977870000001
# close_unit_index for current loop is: 11
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 11
# changed_value_open_units: 256.937307
# value_close_units: 256.937307
# value_open_units: 823.335094
# close_unit_index: 11
# Elif_loop_1 run number: 11 finished
# i = 1
# close_unit_index for current loop was: 11
# close_unit_index for next loop is: 12
# Total if loops: 6
# Total elif_1 loops: 11
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 18 finished
# For loop run number: 19
# i = 0
# close_unit_datetime: 2020-05-23 20:29:02
# open_datetime_lifo: 2020-05-23 08:18:03
# value_close_units: 127.681307 value_open_units: 566.3977870000001
# abs_diff_open_close_units: 438.7164800000001
# close_unit_index for current loop is: 12
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 12
# changed_value_open_units: 127.681307
# value_close_units: 127.681307
# value_open_units: 566.3977870000001
# close_unit_index: 12
# Elif_loop_1 run number: 12 finished
# i = 1
# close_unit_index for current loop was: 12
# close_unit_index for next loop is: 13
# Total if loops: 6
# Total elif_1 loops: 12
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 19 finished
# For loop run number: 20
# i = 0
# close_unit_datetime: 2020-05-23 20:29:10
# open_datetime_lifo: 2020-05-23 08:18:03
# value_close_units: 510.464523 value_open_units: 438.7164800000001
# abs_diff_open_close_units: 71.74804299999988
# close_unit_index for current loop is: 13
# (close_unit_index = close_index) is: True
# If_loop run number: 7
# value_close_units: 510.464523
# value_open_units: 438.7164800000001
# close_unit_index: 13
# If_loop run number: 7 finished
# i = 0
# close_unit_index for current loop was: 13
# close_unit_index for next loop is: 13
# Total if loops: 7
# Total elif_1 loops: 12
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 20 finished
# For loop run number: 21
# i = 0
# close_unit_datetime: 2020-05-23 20:29:10
# open_datetime_lifo: 2020-05-22 05:58:57
# value_close_units: 71.74804299999988 value_open_units: 509.683996
# abs_diff_open_close_units: 437.9359530000001
# close_unit_index for current loop is: 13
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 13
# changed_value_open_units: 71.74804299999988
# value_close_units: 71.74804299999988
# value_open_units: 509.683996
# close_unit_index: 13
# Elif_loop_1 run number: 13 finished
# i = 1
# close_unit_index for current loop was: 13
# close_unit_index for next loop is: 14
# Total if loops: 7
# Total elif_1 loops: 13
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 21 finished
# For loop run number: 22
# i = 0
# close_unit_datetime: 2020-05-23 20:29:18
# open_datetime_lifo: 2020-05-22 05:58:57
# value_close_units: 509.683996 value_open_units: 437.9359530000001
# abs_diff_open_close_units: 71.74804299999988
# close_unit_index for current loop is: 14
# (close_unit_index = close_index) is: True
# If_loop run number: 8
# value_close_units: 509.683996
# value_open_units: 437.9359530000001
# close_unit_index: 14
# If_loop run number: 8 finished
# i = 0
# close_unit_index for current loop was: 14
# close_unit_index for next loop is: 14
# Total if loops: 8
# Total elif_1 loops: 13
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 22 finished
# For loop run number: 23
# i = 0
# close_unit_datetime: 2020-05-23 20:29:18
# open_datetime_lifo: 2020-05-21 22:43:24
# value_close_units: 71.74804299999988 value_open_units: 126.326427
# abs_diff_open_close_units: 54.57838400000011
# close_unit_index for current loop is: 14
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 14
# changed_value_open_units: 71.74804299999988
# value_close_units: 71.74804299999988
# value_open_units: 126.326427
# close_unit_index: 14
# Elif_loop_1 run number: 14 finished
# i = 1
# close_unit_index for current loop was: 14
# close_unit_index for next loop is: 15
# Total if loops: 8
# Total elif_1 loops: 14
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 23 finished
# For loop run number: 24
# i = 0
# close_unit_datetime: 2020-05-23 20:29:29
# open_datetime_lifo: 2020-05-21 22:43:24
# value_close_units: 126.326427 value_open_units: 54.57838400000011
# abs_diff_open_close_units: 71.74804299999988
# close_unit_index for current loop is: 15
# (close_unit_index = close_index) is: True
# If_loop run number: 9
# value_close_units: 126.326427
# value_open_units: 54.57838400000011
# close_unit_index: 15
# If_loop run number: 9 finished
# i = 0
# close_unit_index for current loop was: 15
# close_unit_index for next loop is: 15
# Total if loops: 9
# Total elif_1 loops: 14
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 24 finished
# For loop run number: 25
# i = 0
# close_unit_datetime: 2020-05-23 20:29:29
# open_datetime_lifo: 2020-05-21 20:22:12
# value_close_units: 71.74804299999988 value_open_units: 510.464523
# abs_diff_open_close_units: 438.7164800000001
# close_unit_index for current loop is: 15
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 15
# changed_value_open_units: 71.74804299999988
# value_close_units: 71.74804299999988
# value_open_units: 510.464523
# close_unit_index: 15
# Elif_loop_1 run number: 15 finished
# i = 1
# close_unit_index for current loop was: 15
# close_unit_index for next loop is: 16
# Total if loops: 9
# Total elif_1 loops: 15
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 25 finished
# For loop run number: 26
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-05-21 20:22:12
# value_close_units: 953.815261 value_open_units: 438.7164800000001
# abs_diff_open_close_units: 515.0987809999999
# close_unit_index for current loop is: 16
# (close_unit_index = close_index) is: True
# If_loop run number: 10
# value_close_units: 953.815261
# value_open_units: 438.7164800000001
# close_unit_index: 16
# If_loop run number: 10 finished
# i = 0
# close_unit_index for current loop was: 16
# close_unit_index for next loop is: 16
# Total if loops: 10
# Total elif_1 loops: 15
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 26 finished
# For loop run number: 27
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-05-21 14:43:00
# value_close_units: 515.0987809999999 value_open_units: 130.480167
# abs_diff_open_close_units: 384.6186139999999
# close_unit_index for current loop is: 16
# (close_unit_index = close_index) is: True
# If_loop run number: 11
# value_close_units: 515.0987809999999
# value_open_units: 130.480167
# close_unit_index: 16
# If_loop run number: 11 finished
# i = 0
# close_unit_index for current loop was: 16
# close_unit_index for next loop is: 16
# Total if loops: 11
# Total elif_1 loops: 15
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 27 finished
# For loop run number: 28
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-05-21 14:38:28
# value_close_units: 384.6186139999999 value_open_units: 256.937307
# abs_diff_open_close_units: 127.68130699999995
# close_unit_index for current loop is: 16
# (close_unit_index = close_index) is: True
# If_loop run number: 12
# value_close_units: 384.6186139999999
# value_open_units: 256.937307
# close_unit_index: 16
# If_loop run number: 12 finished
# i = 0
# close_unit_index for current loop was: 16
# close_unit_index for next loop is: 16
# Total if loops: 12
# Total elif_1 loops: 15
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 28 finished
# For loop run number: 29
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-05-21 14:38:01
# value_close_units: 127.68130699999995 value_open_units: 127.681307
# abs_diff_open_close_units: 5.684341886080802e-14
# close_unit_index for current loop is: 16
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 16
# changed_value_open_units: 127.68130699999995
# value_close_units: 127.68130699999995
# value_open_units: 127.681307
# close_unit_index: 16
# Elif_loop_1 run number: 16 finished
# i = 1
# close_unit_index for current loop was: 16
# close_unit_index for next loop is: 17
# Total if loops: 12
# Total elif_1 loops: 16
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 29 finished
# For loop run number: 30
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-05-21 14:38:01
# value_close_units: 465.116279 value_open_units: 5.684341886080802e-14
# abs_diff_open_close_units: 465.11627899999996
# close_unit_index for current loop is: 17
# (close_unit_index = close_index) is: True
# If_loop run number: 13
# value_close_units: 465.116279
# value_open_units: 5.684341886080802e-14
# close_unit_index: 17
# If_loop run number: 13 finished
# i = 0
# close_unit_index for current loop was: 17
# close_unit_index for next loop is: 17
# Total if loops: 13
# Total elif_1 loops: 16
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 30 finished
# For loop run number: 31
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-04-28 19:56:34
# value_close_units: 465.11627899999996 value_open_units: 375.11579100000006
# abs_diff_open_close_units: 90.0004879999999
# close_unit_index for current loop is: 17
# (close_unit_index = close_index) is: True
# If_loop run number: 14
# value_close_units: 465.11627899999996
# value_open_units: 375.11579100000006
# close_unit_index: 17
# If_loop run number: 14 finished
# i = 0
# close_unit_index for current loop was: 17
# close_unit_index for next loop is: 17
# Total if loops: 14
# Total elif_1 loops: 16
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 31 finished
# For loop run number: 32
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-04-25 13:21:20
# value_close_units: 90.0004879999999 value_open_units: 126.582278
# abs_diff_open_close_units: 36.5817900000001
# close_unit_index for current loop is: 17
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 17
# changed_value_open_units: 90.0004879999999
# value_close_units: 90.0004879999999
# value_open_units: 126.582278
# close_unit_index: 17
# Elif_loop_1 run number: 17 finished
# i = 1
# close_unit_index for current loop was: 17
# close_unit_index for next loop is: 18
# Total if loops: 14
# Total elif_1 loops: 17
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 32 finished
# For loop run number: 33
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-04-25 13:21:20
# value_close_units: 423.190859 value_open_units: 36.5817900000001
# abs_diff_open_close_units: 386.60906899999986
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# If_loop run number: 15
# value_close_units: 423.190859
# value_open_units: 36.5817900000001
# close_unit_index: 18
# If_loop run number: 15 finished
# i = 0
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 18
# Total if loops: 15
# Total elif_1 loops: 17
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 33 finished
# For loop run number: 34
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-04-24 19:20:38
# value_close_units: 386.60906899999986 value_open_units: 127.877238
# abs_diff_open_close_units: 258.73183099999983
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# If_loop run number: 16
# value_close_units: 386.60906899999986
# value_open_units: 127.877238
# close_unit_index: 18
# If_loop run number: 16 finished
# i = 0
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 18
# Total if loops: 16
# Total elif_1 loops: 17
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 34 finished
# For loop run number: 35
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-04-23 16:55:28
# value_close_units: 258.73183099999983 value_open_units: 127.291242
# abs_diff_open_close_units: 131.44058899999982
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# If_loop run number: 17
# value_close_units: 258.73183099999983
# value_open_units: 127.291242
# close_unit_index: 18
# If_loop run number: 17 finished
# i = 0
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 18
# Total if loops: 17
# Total elif_1 loops: 17
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 35 finished
# For loop run number: 36
# i = 0
# close_unit_datetime: 2020-05-23 20:41:44
# open_datetime_lifo: 2020-04-22 20:47:13
# value_close_units: 131.44058899999982 value_open_units: 131.440589
# abs_diff_open_close_units: 1.7053025658242404e-13
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 18
# changed_value_open_units: 131.44058899999982
# value_close_units: 131.44058899999982
# value_open_units: 131.440589
# close_unit_index: 18
# Elif_loop_1 run number: 18 finished
# i = 1
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 19
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 1
# Total else loops: 0
# For loop run number: 36 finished
# For loop run number: 37
# i = 0
# close_unit_datetime: 2020-07-10 19:54:03
# open_datetime_lifo: 2020-06-30 05:25:09
# value_close_units: 1119.820829 value_open_units: 1119.820829
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 19
# (close_unit_index = close_index) is: True
# value_close_units: 1119.820829
# value_open_units: 1119.820829
# close_unit_index: 19
# Elif_loop_2 run number: 2 finished
# i = 1
# close_unit_index for current loop was: 19
# close_unit_index for next loop is: 20
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 2
# Total else loops: 0
# For loop run number: 37 finished
# For loop run number: 38
# i = 0
# close_unit_datetime: 2020-07-10 19:54:12
# open_datetime_lifo: 2020-06-25 03:33:27
# value_close_units: 550.055006 value_open_units: 550.055006
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 20
# (close_unit_index = close_index) is: True
# value_close_units: 550.055006
# value_open_units: 550.055006
# close_unit_index: 20
# Elif_loop_2 run number: 3 finished
# i = 1
# close_unit_index for current loop was: 20
# close_unit_index for next loop is: 21
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 3
# Total else loops: 0
# For loop run number: 38 finished
# For loop run number: 39
# i = 0
# close_unit_datetime: 2020-07-10 19:54:22
# open_datetime_lifo: 2020-06-11 16:59:55
# value_close_units: 264.830508 value_open_units: 264.830508
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 21
# (close_unit_index = close_index) is: True
# value_close_units: 264.830508
# value_open_units: 264.830508
# close_unit_index: 21
# Elif_loop_2 run number: 4 finished
# i = 1
# close_unit_index for current loop was: 21
# close_unit_index for next loop is: 22
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 39 finished
# For loop run number: 40
# i = 0
# close_unit_datetime: 2020-07-13 13:39:49
# open_datetime_lifo: 2020-06-05 13:52:20
# value_close_units: 122.54902 value_open_units: 122.54902
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 22
# (close_unit_index = close_index) is: True
# value_close_units: 122.54902
# value_open_units: 122.54902
# close_unit_index: 22
# Elif_loop_2 run number: 5 finished
# i = 1
# close_unit_index for current loop was: 22
# close_unit_index for next loop is: 23
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 5
# Total else loops: 0
# For loop run number: 40 finished
# For loop run number: 41
# i = 0
# close_unit_datetime: 2020-07-13 13:39:49
# open_datetime_lifo: 2020-06-04 10:36:44
# value_close_units: 121.477162 value_open_units: 121.477162
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 23
# (close_unit_index = close_index) is: True
# value_close_units: 121.477162
# value_open_units: 121.477162
# close_unit_index: 23
# Elif_loop_2 run number: 6 finished
# i = 1
# close_unit_index for current loop was: 23
# close_unit_index for next loop is: 24
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 41 finished
# For loop run number: 42
# i = 0
# close_unit_datetime: 2020-08-05 18:54:05
# open_datetime_lifo: 2020-07-29 21:14:04
# value_close_units: 399.840064 value_open_units: 399.840064
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 24
# (close_unit_index = close_index) is: True
# value_close_units: 399.840064
# value_open_units: 399.840064
# close_unit_index: 24
# Elif_loop_2 run number: 7 finished
# i = 1
# close_unit_index for current loop was: 24
# close_unit_index for next loop is: 25
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 42 finished
# For loop run number: 43
# i = 0
# close_unit_datetime: 2020-08-05 18:54:05
# open_datetime_lifo: 2020-07-25 21:38:57
# value_close_units: 458.085204 value_open_units: 458.085204
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 25
# (close_unit_index = close_index) is: True
# value_close_units: 458.085204
# value_open_units: 458.085204
# close_unit_index: 25
# Elif_loop_2 run number: 8 finished
# i = 1
# close_unit_index for current loop was: 25
# close_unit_index for next loop is: 26
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 8
# Total else loops: 0
# For loop run number: 43 finished
# For loop run number: 44
# i = 0
# close_unit_datetime: 2020-08-28 10:03:53
# open_datetime_lifo: 2020-08-27 17:05:37
# value_close_units: 768.935025 value_open_units: 768.935025
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 26
# (close_unit_index = close_index) is: True
# value_close_units: 768.935025
# value_open_units: 768.935025
# close_unit_index: 26
# Elif_loop_2 run number: 9 finished
# i = 1
# close_unit_index for current loop was: 26
# close_unit_index for next loop is: 27
# Total if loops: 17
# Total elif_1 loops: 18
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 44 finished
# For loop run number: 45
# i = 0
# close_unit_datetime: 2020-10-07 14:45:25
# open_datetime_lifo: 2020-10-02 05:49:01
# value_close_units: 100.969305 value_open_units: 214.316331
# abs_diff_open_close_units: 113.34702599999999
# close_unit_index for current loop is: 27
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 19
# changed_value_open_units: 100.969305
# value_close_units: 100.969305
# value_open_units: 214.316331
# close_unit_index: 27
# Elif_loop_1 run number: 19 finished
# i = 1
# close_unit_index for current loop was: 27
# close_unit_index for next loop is: 28
# Total if loops: 17
# Total elif_1 loops: 19
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 45 finished
# For loop run number: 46
# i = 0
# close_unit_datetime: 2020-10-07 14:45:33
# open_datetime_lifo: 2020-10-02 05:49:01
# value_close_units: 101.461039 value_open_units: 113.34702599999999
# abs_diff_open_close_units: 11.885986999999986
# close_unit_index for current loop is: 28
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 20
# changed_value_open_units: 101.461039
# value_close_units: 101.461039
# value_open_units: 113.34702599999999
# close_unit_index: 28
# Elif_loop_1 run number: 20 finished
# i = 1
# close_unit_index for current loop was: 28
# close_unit_index for next loop is: 29
# Total if loops: 17
# Total elif_1 loops: 20
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 46 finished
# For loop run number: 47
# i = 0
# close_unit_datetime: 2020-10-07 14:45:41
# open_datetime_lifo: 2020-10-02 05:49:01
# value_close_units: 102.711586 value_open_units: 11.885986999999986
# abs_diff_open_close_units: 90.82559900000001
# close_unit_index for current loop is: 29
# (close_unit_index = close_index) is: True
# If_loop run number: 18
# value_close_units: 102.711586
# value_open_units: 11.885986999999986
# close_unit_index: 29
# If_loop run number: 18 finished
# i = 0
# close_unit_index for current loop was: 29
# close_unit_index for next loop is: 29
# Total if loops: 18
# Total elif_1 loops: 20
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 47 finished
# For loop run number: 48
# i = 0
# close_unit_datetime: 2020-10-07 14:45:41
# open_datetime_lifo: 2020-10-01 16:16:48
# value_close_units: 90.82559900000001 value_open_units: 104.821803
# abs_diff_open_close_units: 13.996203999999992
# close_unit_index for current loop is: 29
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 21
# changed_value_open_units: 90.82559900000001
# value_close_units: 90.82559900000001
# value_open_units: 104.821803
# close_unit_index: 29
# Elif_loop_1 run number: 21 finished
# i = 1
# close_unit_index for current loop was: 29
# close_unit_index for next loop is: 30
# Total if loops: 18
# Total elif_1 loops: 21
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 48 finished
# For loop run number: 49
# i = 0
# close_unit_datetime: 2020-10-07 14:45:50
# open_datetime_lifo: 2020-10-01 16:16:48
# value_close_units: 103.691414 value_open_units: 13.996203999999992
# abs_diff_open_close_units: 89.69521
# close_unit_index for current loop is: 30
# (close_unit_index = close_index) is: True
# If_loop run number: 19
# value_close_units: 103.691414
# value_open_units: 13.996203999999992
# close_unit_index: 30
# If_loop run number: 19 finished
# i = 0
# close_unit_index for current loop was: 30
# close_unit_index for next loop is: 30
# Total if loops: 19
# Total elif_1 loops: 21
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 49 finished
# For loop run number: 50
# i = 0
# close_unit_datetime: 2020-10-07 14:45:50
# open_datetime_lifo: 2020-09-29 18:30:49
# value_close_units: 89.69521 value_open_units: 102.711586
# abs_diff_open_close_units: 13.016375999999994
# close_unit_index for current loop is: 30
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 22
# changed_value_open_units: 89.69521
# value_close_units: 89.69521
# value_open_units: 102.711586
# close_unit_index: 30
# Elif_loop_1 run number: 22 finished
# i = 1
# close_unit_index for current loop was: 30
# close_unit_index for next loop is: 31
# Total if loops: 19
# Total elif_1 loops: 22
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 50 finished
# For loop run number: 51
# i = 0
# close_unit_datetime: 2020-10-07 18:28:00
# open_datetime_lifo: 2020-09-29 18:30:49
# value_close_units: 214.316331 value_open_units: 13.016375999999994
# abs_diff_open_close_units: 201.299955
# close_unit_index for current loop is: 31
# (close_unit_index = close_index) is: True
# If_loop run number: 20
# value_close_units: 214.316331
# value_open_units: 13.016375999999994
# close_unit_index: 31
# If_loop run number: 20 finished
# i = 0
# close_unit_index for current loop was: 31
# close_unit_index for next loop is: 31
# Total if loops: 20
# Total elif_1 loops: 22
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 51 finished
# For loop run number: 52
# i = 0
# close_unit_datetime: 2020-10-07 18:28:00
# open_datetime_lifo: 2020-09-27 06:11:12
# value_close_units: 201.299955 value_open_units: 101.461039
# abs_diff_open_close_units: 99.83891600000001
# close_unit_index for current loop is: 31
# (close_unit_index = close_index) is: True
# If_loop run number: 21
# value_close_units: 201.299955
# value_open_units: 101.461039
# close_unit_index: 31
# If_loop run number: 21 finished
# i = 0
# close_unit_index for current loop was: 31
# close_unit_index for next loop is: 31
# Total if loops: 21
# Total elif_1 loops: 22
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 52 finished
# For loop run number: 53
# i = 0
# close_unit_datetime: 2020-10-07 18:28:00
# open_datetime_lifo: 2020-09-25 12:42:15
# value_close_units: 99.83891600000001 value_open_units: 103.691414
# abs_diff_open_close_units: 3.852497999999983
# close_unit_index for current loop is: 31
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 23
# changed_value_open_units: 99.83891600000001
# value_close_units: 99.83891600000001
# value_open_units: 103.691414
# close_unit_index: 31
# Elif_loop_1 run number: 23 finished
# i = 1
# close_unit_index for current loop was: 31
# close_unit_index for next loop is: 32
# Total if loops: 21
# Total elif_1 loops: 23
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 53 finished
# For loop run number: 54
# i = 0
# close_unit_datetime: 2020-10-07 18:28:00
# open_datetime_lifo: 2020-09-25 12:42:15
# value_close_units: 111.308994 value_open_units: 3.852497999999983
# abs_diff_open_close_units: 107.45649600000002
# close_unit_index for current loop is: 32
# (close_unit_index = close_index) is: True
# If_loop run number: 22
# value_close_units: 111.308994
# value_open_units: 3.852497999999983
# close_unit_index: 32
# If_loop run number: 22 finished
# i = 0
# close_unit_index for current loop was: 32
# close_unit_index for next loop is: 32
# Total if loops: 22
# Total elif_1 loops: 23
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 54 finished
# For loop run number: 55
# i = 0
# close_unit_datetime: 2020-10-07 18:28:00
# open_datetime_lifo: 2020-09-23 20:52:01
# value_close_units: 107.45649600000002 value_open_units: 111.308994
# abs_diff_open_close_units: 3.852497999999983
# close_unit_index for current loop is: 32
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 24
# changed_value_open_units: 107.45649600000002
# value_close_units: 107.45649600000002
# value_open_units: 111.308994
# close_unit_index: 32
# Elif_loop_1 run number: 24 finished
# i = 1
# close_unit_index for current loop was: 32
# close_unit_index for next loop is: 33
# Total if loops: 22
# Total elif_1 loops: 24
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 55 finished
# For loop run number: 56
# i = 0
# close_unit_datetime: 2020-10-07 18:28:00
# open_datetime_lifo: 2020-09-23 20:52:01
# value_close_units: 104.821803 value_open_units: 3.852497999999983
# abs_diff_open_close_units: 100.96930500000002
# close_unit_index for current loop is: 33
# (close_unit_index = close_index) is: True
# If_loop run number: 23
# value_close_units: 104.821803
# value_open_units: 3.852497999999983
# close_unit_index: 33
# If_loop run number: 23 finished
# i = 0
# close_unit_index for current loop was: 33
# close_unit_index for next loop is: 33
# Total if loops: 23
# Total elif_1 loops: 24
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 56 finished
# For loop run number: 57
# i = 0
# close_unit_datetime: 2020-10-07 18:28:00
# open_datetime_lifo: 2020-09-14 06:58:00
# value_close_units: 100.96930500000002 value_open_units: 100.969305
# abs_diff_open_close_units: 1.4210854715202004e-14
# close_unit_index for current loop is: 33
# (close_unit_index = close_index) is: True
# If_loop run number: 24
# value_close_units: 100.96930500000002
# value_open_units: 100.969305
# close_unit_index: 33
# If_loop run number: 24 finished
# i = 1
# close_unit_index for current loop was: 33
# close_unit_index for next loop is: 34
# Total if loops: 24
# Total elif_1 loops: 24
# Total elif_2 loops: 9
# Total else loops: 0
# For loop run number: 57 finished
# For loop run number: 58
# i = 0
# close_unit_datetime: 2020-11-10 09:11:24
# open_datetime_lifo: 2020-11-08 06:54:46
# value_close_units: 98.000784 value_open_units: 98.000784
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 34
# (close_unit_index = close_index) is: True
# value_close_units: 98.000784
# value_open_units: 98.000784
# close_unit_index: 34
# Elif_loop_2 run number: 10 finished
# i = 1
# close_unit_index for current loop was: 34
# close_unit_index for next loop is: 35
# Total if loops: 24
# Total elif_1 loops: 24
# Total elif_2 loops: 10
# Total else loops: 0
# For loop run number: 58 finished
# For loop run number: 59
# i = 0
# close_unit_datetime: 2020-11-16 19:38:20
# open_datetime_lifo: 2020-11-03 03:33:01
# value_close_units: 106.382979 value_open_units: 107.991361
# abs_diff_open_close_units: 1.6083819999999918
# close_unit_index for current loop is: 35
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 25
# changed_value_open_units: 106.382979
# value_close_units: 106.382979
# value_open_units: 107.991361
# close_unit_index: 35
# Elif_loop_1 run number: 25 finished
# i = 1
# close_unit_index for current loop was: 35
# close_unit_index for next loop is: 36
# Total if loops: 24
# Total elif_1 loops: 25
# Total elif_2 loops: 10
# Total else loops: 0
# For loop run number: 59 finished
# For loop run number: 60
# i = 0
# close_unit_datetime: 2020-11-16 19:38:20
# open_datetime_lifo: 2020-11-03 03:33:01
# value_close_units: 104.690117 value_open_units: 1.6083819999999918
# abs_diff_open_close_units: 103.08173500000001
# close_unit_index for current loop is: 36
# (close_unit_index = close_index) is: True
# If_loop run number: 25
# value_close_units: 104.690117
# value_open_units: 1.6083819999999918
# close_unit_index: 36
# If_loop run number: 25 finished
# i = 0
# close_unit_index for current loop was: 36
# close_unit_index for next loop is: 36
# Total if loops: 25
# Total elif_1 loops: 25
# Total elif_2 loops: 10
# Total else loops: 0
# For loop run number: 60 finished
# For loop run number: 61
# i = 0
# close_unit_datetime: 2020-11-16 19:38:20
# open_datetime_lifo: 2020-11-03 03:11:56
# value_close_units: 103.08173500000001 value_open_units: 106.382979
# abs_diff_open_close_units: 3.301243999999997
# close_unit_index for current loop is: 36
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 26
# changed_value_open_units: 103.08173500000001
# value_close_units: 103.08173500000001
# value_open_units: 106.382979
# close_unit_index: 36
# Elif_loop_1 run number: 26 finished
# i = 1
# close_unit_index for current loop was: 36
# close_unit_index for next loop is: 37
# Total if loops: 25
# Total elif_1 loops: 26
# Total elif_2 loops: 10
# Total else loops: 0
# For loop run number: 61 finished
# For loop run number: 62
# i = 0
# close_unit_datetime: 2020-11-16 19:38:20
# open_datetime_lifo: 2020-11-03 03:11:56
# value_close_units: 105.130362 value_open_units: 3.301243999999997
# abs_diff_open_close_units: 101.82911800000001
# close_unit_index for current loop is: 37
# (close_unit_index = close_index) is: True
# If_loop run number: 26
# value_close_units: 105.130362
# value_open_units: 3.301243999999997
# close_unit_index: 37
# If_loop run number: 26 finished
# i = 0
# close_unit_index for current loop was: 37
# close_unit_index for next loop is: 37
# Total if loops: 26
# Total elif_1 loops: 26
# Total elif_2 loops: 10
# Total else loops: 0
# For loop run number: 62 finished
# For loop run number: 63
# i = 0
# close_unit_datetime: 2020-11-16 19:38:20
# open_datetime_lifo: 2020-11-02 21:16:39
# value_close_units: 101.82911800000001 value_open_units: 104.690117
# abs_diff_open_close_units: 2.8609989999999925
# close_unit_index for current loop is: 37
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 27
# changed_value_open_units: 101.82911800000001
# value_close_units: 101.82911800000001
# value_open_units: 104.690117
# close_unit_index: 37
# Elif_loop_1 run number: 27 finished
# i = 1
# close_unit_index for current loop was: 37
# close_unit_index for next loop is: 38
# Total if loops: 26
# Total elif_1 loops: 27
# Total elif_2 loops: 10
# Total else loops: 0
# For loop run number: 63 finished
# For loop run number: 64
# i = 0
# close_unit_datetime: 2020-11-16 19:38:20
# open_datetime_lifo: 2020-11-02 21:16:39
# value_close_units: 107.991361 value_open_units: 2.8609989999999925
# abs_diff_open_close_units: 105.130362
# close_unit_index for current loop is: 38
# (close_unit_index = close_index) is: True
# If_loop run number: 27
# value_close_units: 107.991361
# value_open_units: 2.8609989999999925
# close_unit_index: 38
# If_loop run number: 27 finished
# i = 0
# close_unit_index for current loop was: 38
# close_unit_index for next loop is: 38
# Total if loops: 27
# Total elif_1 loops: 27
# Total elif_2 loops: 10
# Total else loops: 0
# For loop run number: 64 finished
# For loop run number: 65
# i = 0
# close_unit_datetime: 2020-11-16 19:38:20
# open_datetime_lifo: 2020-10-30 10:26:48
# value_close_units: 105.130362 value_open_units: 105.130362
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 38
# (close_unit_index = close_index) is: True
# value_close_units: 105.130362
# value_open_units: 105.130362
# close_unit_index: 38
# Elif_loop_2 run number: 11 finished
# i = 1
# close_unit_index for current loop was: 38
# close_unit_index for next loop is: 39
# Total if loops: 27
# Total elif_1 loops: 27
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 65 finished
# For loop run number: 66
# i = 0
# close_unit_datetime: 2020-11-25 20:48:23
# open_datetime_lifo: 2020-11-21 13:56:51
# value_close_units: 58.207218 value_open_units: 58.207218
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 39
# (close_unit_index = close_index) is: True
# value_close_units: 58.207218
# value_open_units: 58.207218
# close_unit_index: 39
# Elif_loop_2 run number: 12 finished
# i = 1
# close_unit_index for current loop was: 39
# close_unit_index for next loop is: 40
# Total if loops: 27
# Total elif_1 loops: 27
# Total elif_2 loops: 12
# Total else loops: 0
# For loop run number: 66 finished
# For loop run number: 67
# i = 0
# close_unit_datetime: 2020-12-16 09:06:59
# open_datetime_lifo: 2020-11-30 16:51:08
# value_close_units: 76.161462 value_open_units: 76.161462
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 40
# (close_unit_index = close_index) is: True
# value_close_units: 76.161462
# value_open_units: 76.161462
# close_unit_index: 40
# Elif_loop_2 run number: 13 finished
# i = 1
# close_unit_index for current loop was: 40
# close_unit_index for next loop is: 41
# Total if loops: 27
# Total elif_1 loops: 27
# Total elif_2 loops: 13
# Total else loops: 0
# For loop run number: 67 finished
# For loop run number: 68
# i = 0
# close_unit_datetime: 2020-12-23 08:00:35
# open_datetime_lifo: 2020-12-23 06:53:20
# value_close_units: 52.977326 value_open_units: 65.806791
# abs_diff_open_close_units: 12.829465000000006
# close_unit_index for current loop is: 41
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 28
# changed_value_open_units: 52.977326
# value_close_units: 52.977326
# value_open_units: 65.806791
# close_unit_index: 41
# Elif_loop_1 run number: 28 finished
# i = 1
# close_unit_index for current loop was: 41
# close_unit_index for next loop is: 42
# Total if loops: 27
# Total elif_1 loops: 28
# Total elif_2 loops: 13
# Total else loops: 0
# For loop run number: 68 finished
# For loop run number: 69
# i = 0
# close_unit_datetime: 2020-12-23 08:00:35
# open_datetime_lifo: 2020-12-23 06:53:20
# value_close_units: 209.951711 value_open_units: 12.829465000000006
# abs_diff_open_close_units: 197.122246
# close_unit_index for current loop is: 42
# (close_unit_index = close_index) is: True
# If_loop run number: 28
# value_close_units: 209.951711
# value_open_units: 12.829465000000006
# close_unit_index: 42
# If_loop run number: 28 finished
# i = 0
# close_unit_index for current loop was: 42
# close_unit_index for next loop is: 42
# Total if loops: 28
# Total elif_1 loops: 28
# Total elif_2 loops: 13
# Total else loops: 0
# For loop run number: 69 finished
# For loop run number: 70
# i = 0
# close_unit_datetime: 2020-12-23 08:00:35
# open_datetime_lifo: 2020-12-22 21:49:36
# value_close_units: 197.122246 value_open_units: 474.045982
# abs_diff_open_close_units: 276.92373599999996
# close_unit_index for current loop is: 42
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 29
# changed_value_open_units: 197.122246
# value_close_units: 197.122246
# value_open_units: 474.045982
# close_unit_index: 42
# Elif_loop_1 run number: 29 finished
# i = 1
# close_unit_index for current loop was: 42
# close_unit_index for next loop is: 43
# Total if loops: 28
# Total elif_1 loops: 29
# Total elif_2 loops: 13
# Total else loops: 0
# For loop run number: 70 finished
# For loop run number: 71
# i = 0
# close_unit_datetime: 2020-12-23 08:00:35
# open_datetime_lifo: 2020-12-22 21:49:36
# value_close_units: 474.045982 value_open_units: 276.92373599999996
# abs_diff_open_close_units: 197.12224600000002
# close_unit_index for current loop is: 43
# (close_unit_index = close_index) is: True
# If_loop run number: 29
# value_close_units: 474.045982
# value_open_units: 276.92373599999996
# close_unit_index: 43
# If_loop run number: 29 finished
# i = 0
# close_unit_index for current loop was: 43
# close_unit_index for next loop is: 43
# Total if loops: 29
# Total elif_1 loops: 29
# Total elif_2 loops: 13
# Total else loops: 0
# For loop run number: 71 finished
# For loop run number: 72
# i = 0
# close_unit_datetime: 2020-12-23 08:00:35
# open_datetime_lifo: 2020-12-22 17:40:00
# value_close_units: 197.12224600000002 value_open_units: 52.977326
# abs_diff_open_close_units: 144.14492
# close_unit_index for current loop is: 43
# (close_unit_index = close_index) is: True
# If_loop run number: 30
# value_close_units: 197.12224600000002
# value_open_units: 52.977326
# close_unit_index: 43
# If_loop run number: 30 finished
# i = 0
# close_unit_index for current loop was: 43
# close_unit_index for next loop is: 43
# Total if loops: 30
# Total elif_1 loops: 29
# Total elif_2 loops: 13
# Total else loops: 0
# For loop run number: 72 finished
# For loop run number: 73
# i = 0
# close_unit_datetime: 2020-12-23 08:00:35
# open_datetime_lifo: 2020-12-22 16:27:05
# value_close_units: 144.14492 value_open_units: 209.951711
# abs_diff_open_close_units: 65.80679099999998
# close_unit_index for current loop is: 43
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 30
# changed_value_open_units: 144.14492
# value_close_units: 144.14492
# value_open_units: 209.951711
# close_unit_index: 43
# Elif_loop_1 run number: 30 finished
# i = 1
# close_unit_index for current loop was: 43
# close_unit_index for next loop is: 44
# Total if loops: 30
# Total elif_1 loops: 30
# Total elif_2 loops: 13
# Total else loops: 0
# For loop run number: 73 finished
# For loop run number: 74
# i = 0
# ...
# close_unit_index for next loop is: 66
# Total if loops: 48
# Total elif_1 loops: 49
# Total elif_2 loops: 15
# Total else loops: 0
# For loop run number: 112 finished
# For loop run number: 113
# i = 0
# close_unit_datetime: 2021-01-25 10:47:22
# open_datetime_lifo: 2021-01-20 10:13:28
# value_close_units: 335.345406 value_open_units: 93.07520499999998
# abs_diff_open_close_units: 242.27020100000004
# close_unit_index for current loop is: 66
# (close_unit_index = close_index) is: True
# If_loop run number: 49
# value_close_units: 335.345406
# value_open_units: 93.07520499999998
# close_unit_index: 66
# If_loop run number: 49 finished
# i = 0
# close_unit_index for current loop was: 66
# close_unit_index for next loop is: 66
# Total if loops: 49
# Total elif_1 loops: 49
# Total elif_2 loops: 15
# Total else loops: 0
# For loop run number: 113 finished
# For loop run number: 114
# i = 0
# close_unit_datetime: 2021-01-25 10:47:22
# open_datetime_lifo: 2021-01-19 23:57:09
# value_close_units: 242.27020100000004 value_open_units: 335.345406
# abs_diff_open_close_units: 93.07520499999998
# close_unit_index for current loop is: 66
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 50
# changed_value_open_units: 242.27020100000004
# value_close_units: 242.27020100000004
# value_open_units: 335.345406
# close_unit_index: 66
# Elif_loop_1 run number: 50 finished
# i = 1
# close_unit_index for current loop was: 66
# close_unit_index for next loop is: 67
# Total if loops: 49
# Total elif_1 loops: 50
# Total elif_2 loops: 15
# Total else loops: 0
# For loop run number: 114 finished
# For loop run number: 115
# i = 0
# close_unit_datetime: 2021-01-25 10:47:22
# open_datetime_lifo: 2021-01-19 23:57:09
# value_close_units: 93.075205 value_open_units: 93.07520499999998
# abs_diff_open_close_units: 1.4210854715202004e-14
# close_unit_index for current loop is: 67
# (close_unit_index = close_index) is: True
# If_loop run number: 50
# value_close_units: 93.075205
# value_open_units: 93.07520499999998
# close_unit_index: 67
# If_loop run number: 50 finished
# i = 1
# close_unit_index for current loop was: 67
# close_unit_index for next loop is: 68
# Total if loops: 50
# Total elif_1 loops: 50
# Total elif_2 loops: 15
# Total else loops: 0
# For loop run number: 115 finished
# For loop run number: 116
# i = 0
# close_unit_datetime: 2021-01-25 10:47:22
# open_datetime_lifo: 2021-01-11 14:09:44
# value_close_units: 91.608648 value_open_units: 91.608648
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 68
# (close_unit_index = close_index) is: True
# value_close_units: 91.608648
# value_open_units: 91.608648
# close_unit_index: 68
# Elif_loop_2 run number: 16 finished
# i = 1
# close_unit_index for current loop was: 68
# close_unit_index for next loop is: 69
# Total if loops: 50
# Total elif_1 loops: 50
# Total elif_2 loops: 16
# Total else loops: 0
# For loop run number: 116 finished
# For loop run number: 117
# i = 0
# close_unit_datetime: 2021-02-01 13:41:01
# open_datetime_lifo: 2021-01-30 14:02:56
# value_close_units: 1164.144354 value_open_units: 1164.144354
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 69
# (close_unit_index = close_index) is: True
# value_close_units: 1164.144354
# value_open_units: 1164.144354
# close_unit_index: 69
# Elif_loop_2 run number: 17 finished
# i = 1
# close_unit_index for current loop was: 69
# close_unit_index for next loop is: 70
# Total if loops: 50
# Total elif_1 loops: 50
# Total elif_2 loops: 17
# Total else loops: 0
# For loop run number: 117 finished
# For loop run number: 118
# i = 0
# close_unit_datetime: 2021-02-21 19:08:39
# open_datetime_lifo: 2021-02-16 14:17:02
# value_close_units: 46.47704 value_open_units: 46.47704
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 70
# (close_unit_index = close_index) is: True
# value_close_units: 46.47704
# value_open_units: 46.47704
# close_unit_index: 70
# Elif_loop_2 run number: 18 finished
# i = 1
# close_unit_index for current loop was: 70
# close_unit_index for next loop is: 71
# Total if loops: 50
# Total elif_1 loops: 50
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 118 finished
# For loop run number: 119
# i = 0
# close_unit_datetime: 2021-02-21 19:08:39
# open_datetime_lifo: 2021-02-15 07:43:48
# value_close_units: 42.603954 value_open_units: 43.440487
# abs_diff_open_close_units: 0.8365329999999958
# close_unit_index for current loop is: 71
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 51
# changed_value_open_units: 42.603954
# value_close_units: 42.603954
# value_open_units: 43.440487
# close_unit_index: 71
# Elif_loop_1 run number: 51 finished
# i = 1
# close_unit_index for current loop was: 71
# close_unit_index for next loop is: 72
# Total if loops: 50
# Total elif_1 loops: 51
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 119 finished
# For loop run number: 120
# i = 0
# close_unit_datetime: 2021-02-21 19:08:39
# open_datetime_lifo: 2021-02-15 07:43:48
# value_close_units: 170.926518 value_open_units: 0.8365329999999958
# abs_diff_open_close_units: 170.08998499999998
# close_unit_index for current loop is: 72
# (close_unit_index = close_index) is: True
# If_loop run number: 51
# value_close_units: 170.926518
# value_open_units: 0.8365329999999958
# close_unit_index: 72
# If_loop run number: 51 finished
# i = 0
# close_unit_index for current loop was: 72
# close_unit_index for next loop is: 72
# Total if loops: 51
# Total elif_1 loops: 51
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 120 finished
# For loop run number: 121
# i = 0
# close_unit_datetime: 2021-02-21 19:08:39
# open_datetime_lifo: 2021-02-14 10:10:20
# value_close_units: 170.08998499999998 value_open_units: 170.926518
# abs_diff_open_close_units: 0.8365330000000029
# close_unit_index for current loop is: 72
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 52
# changed_value_open_units: 170.08998499999998
# value_close_units: 170.08998499999998
# value_open_units: 170.926518
# close_unit_index: 72
# Elif_loop_1 run number: 52 finished
# i = 1
# close_unit_index for current loop was: 72
# close_unit_index for next loop is: 73
# Total if loops: 51
# Total elif_1 loops: 52
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 121 finished
# For loop run number: 122
# i = 0
# close_unit_datetime: 2021-02-21 19:08:39
# open_datetime_lifo: 2021-02-14 10:10:20
# value_close_units: 43.440487 value_open_units: 0.8365330000000029
# abs_diff_open_close_units: 42.603953999999995
# close_unit_index for current loop is: 73
# (close_unit_index = close_index) is: True
# If_loop run number: 52
# value_close_units: 43.440487
# value_open_units: 0.8365330000000029
# close_unit_index: 73
# If_loop run number: 52 finished
# i = 0
# close_unit_index for current loop was: 73
# close_unit_index for next loop is: 73
# Total if loops: 52
# Total elif_1 loops: 52
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 122 finished
# For loop run number: 123
# i = 0
# close_unit_datetime: 2021-02-21 19:08:39
# open_datetime_lifo: 2021-02-12 20:28:20
# value_close_units: 42.603953999999995 value_open_units: 42.603954
# abs_diff_open_close_units: 7.105427357601002e-15
# close_unit_index for current loop is: 73
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 53
# changed_value_open_units: 42.603953999999995
# value_close_units: 42.603953999999995
# value_open_units: 42.603954
# close_unit_index: 73
# Elif_loop_1 run number: 53 finished
# i = 1
# close_unit_index for current loop was: 73
# close_unit_index for next loop is: 74
# Total if loops: 52
# Total elif_1 loops: 53
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 123 finished
# For loop run number: 124
# i = 0
# close_unit_datetime: 2021-04-27 17:03:00
# open_datetime_lifo: 2021-04-24 19:31:05
# value_close_units: 45.462811 value_open_units: 22.630578
# abs_diff_open_close_units: 22.832233000000002
# close_unit_index for current loop is: 74
# (close_unit_index = close_index) is: True
# If_loop run number: 53
# value_close_units: 45.462811
# value_open_units: 22.630578
# close_unit_index: 74
# If_loop run number: 53 finished
# i = 0
# close_unit_index for current loop was: 74
# close_unit_index for next loop is: 74
# Total if loops: 53
# Total elif_1 loops: 53
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 124 finished
# For loop run number: 125
# i = 0
# close_unit_datetime: 2021-04-27 17:03:00
# open_datetime_lifo: 2021-04-23 20:18:44
# value_close_units: 22.832233000000002 value_open_units: 43.399011
# abs_diff_open_close_units: 20.566778
# close_unit_index for current loop is: 74
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 54
# changed_value_open_units: 22.832233000000002
# value_close_units: 22.832233000000002
# value_open_units: 43.399011
# close_unit_index: 74
# Elif_loop_1 run number: 54 finished
# i = 1
# close_unit_index for current loop was: 74
# close_unit_index for next loop is: 75
# Total if loops: 53
# Total elif_1 loops: 54
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 125 finished
# For loop run number: 126
# i = 0
# close_unit_datetime: 2021-04-27 17:03:03
# open_datetime_lifo: 2021-04-23 20:18:44
# value_close_units: 22.630578 value_open_units: 20.566778
# abs_diff_open_close_units: 2.0638000000000005
# close_unit_index for current loop is: 75
# (close_unit_index = close_index) is: True
# If_loop run number: 54
# value_close_units: 22.630578
# value_open_units: 20.566778
# close_unit_index: 75
# If_loop run number: 54 finished
# i = 0
# close_unit_index for current loop was: 75
# close_unit_index for next loop is: 75
# Total if loops: 54
# Total elif_1 loops: 54
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 126 finished
# For loop run number: 127
# i = 0
# close_unit_datetime: 2021-04-27 17:03:03
# open_datetime_lifo: 2021-04-23 13:10:29
# value_close_units: 2.0638000000000005 value_open_units: 45.462811
# abs_diff_open_close_units: 43.399011
# close_unit_index for current loop is: 75
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 55
# changed_value_open_units: 2.0638000000000005
# value_close_units: 2.0638000000000005
# value_open_units: 45.462811
# close_unit_index: 75
# Elif_loop_1 run number: 55 finished
# i = 1
# close_unit_index for current loop was: 75
# close_unit_index for next loop is: 76
# Total if loops: 54
# Total elif_1 loops: 55
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 127 finished
# For loop run number: 128
# i = 0
# close_unit_datetime: 2021-08-17 06:58:51
# open_datetime_lifo: 2021-05-22 21:30:29
# value_close_units: 28.216704 value_open_units: 108.29543
# abs_diff_open_close_units: 80.07872599999999
# close_unit_index for current loop is: 76
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 56
# changed_value_open_units: 28.216704
# value_close_units: 28.216704
# value_open_units: 108.29543
# close_unit_index: 76
# Elif_loop_1 run number: 56 finished
# i = 1
# close_unit_index for current loop was: 76
# close_unit_index for next loop is: 77
# Total if loops: 54
# Total elif_1 loops: 56
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 128 finished
# For loop run number: 129
# i = 0
# close_unit_datetime: 2021-08-17 06:58:54
# open_datetime_lifo: 2021-05-22 21:30:29
# value_close_units: 95.328885 value_open_units: 80.07872599999999
# abs_diff_open_close_units: 15.25015900000001
# close_unit_index for current loop is: 77
# (close_unit_index = close_index) is: True
# If_loop run number: 55
# value_close_units: 95.328885
# value_open_units: 80.07872599999999
# close_unit_index: 77
# If_loop run number: 55 finished
# i = 0
# close_unit_index for current loop was: 77
# close_unit_index for next loop is: 77
# Total if loops: 55
# Total elif_1 loops: 56
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 129 finished
# For loop run number: 130
# i = 0
# close_unit_datetime: 2021-08-17 06:58:54
# open_datetime_lifo: 2021-05-22 05:56:22
# value_close_units: 15.25015900000001 value_open_units: 28.216704
# abs_diff_open_close_units: 12.96654499999999
# close_unit_index for current loop is: 77
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 57
# changed_value_open_units: 15.25015900000001
# value_close_units: 15.25015900000001
# value_open_units: 28.216704
# close_unit_index: 77
# Elif_loop_1 run number: 57 finished
# i = 1
# close_unit_index for current loop was: 77
# close_unit_index for next loop is: 78
# Total if loops: 55
# Total elif_1 loops: 57
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 130 finished
# For loop run number: 131
# i = 0
# close_unit_datetime: 2021-08-17 06:58:58
# open_datetime_lifo: 2021-05-22 05:56:22
# value_close_units: 108.29543 value_open_units: 12.96654499999999
# abs_diff_open_close_units: 95.32888500000001
# close_unit_index for current loop is: 78
# (close_unit_index = close_index) is: True
# If_loop run number: 56
# value_close_units: 108.29543
# value_open_units: 12.96654499999999
# close_unit_index: 78
# If_loop run number: 56 finished
# i = 0
# close_unit_index for current loop was: 78
# close_unit_index for next loop is: 78
# Total if loops: 56
# Total elif_1 loops: 57
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 131 finished
# For loop run number: 132
# i = 0
# close_unit_datetime: 2021-08-17 06:58:58
# open_datetime_lifo: 2021-05-21 14:21:12
# value_close_units: 95.32888500000001 value_open_units: 95.328885
# abs_diff_open_close_units: 1.4210854715202004e-14
# close_unit_index for current loop is: 78
# (close_unit_index = close_index) is: True
# If_loop run number: 57
# value_close_units: 95.32888500000001
# value_open_units: 95.328885
# close_unit_index: 78
# If_loop run number: 57 finished
# i = 1
# close_unit_index for current loop was: 78
# close_unit_index for next loop is: 79
# Total if loops: 57
# Total elif_1 loops: 57
# Total elif_2 loops: 18
# Total else loops: 0
# For loop run number: 132 finished
# For loop run number: 133
# i = 0
# close_unit_datetime: 2021-08-17 06:59:01
# open_datetime_lifo: 2021-04-23 13:10:29
# value_close_units: 43.399011 value_open_units: 43.399011
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 79
# (close_unit_index = close_index) is: True
# value_close_units: 43.399011
# value_open_units: 43.399011
# close_unit_index: 79
# Elif_loop_2 run number: 19 finished
# i = 1
# close_unit_index for current loop was: 79
# close_unit_index for next loop is: 80
# Total if loops: 57
# Total elif_1 loops: 57
# Total elif_2 loops: 19
# Total else loops: 0
# For loop run number: 133 finished
# For loop run number: 134
# i = 0
# close_unit_datetime: 2021-12-18 23:37:17
# open_datetime_lifo: 2021-10-06 12:51:41
# value_close_units: 145.450259 value_open_units: 330.267874
# abs_diff_open_close_units: 184.81761500000002
# close_unit_index for current loop is: 80
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 58
# changed_value_open_units: 145.450259
# value_close_units: 145.450259
# value_open_units: 330.267874
# close_unit_index: 80
# Elif_loop_1 run number: 58 finished
# i = 1
# close_unit_index for current loop was: 80
# close_unit_index for next loop is: 81
# Total if loops: 57
# Total elif_1 loops: 58
# Total elif_2 loops: 19
# Total else loops: 0
# For loop run number: 134 finished
# For loop run number: 135
# i = 0
# close_unit_datetime: 2021-12-18 23:37:21
# open_datetime_lifo: 2021-10-06 12:51:41
# value_close_units: 330.267874 value_open_units: 184.81761500000002
# abs_diff_open_close_units: 145.450259
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# If_loop run number: 58
# value_close_units: 330.267874
# value_open_units: 184.81761500000002
# close_unit_index: 81
# If_loop run number: 58 finished
# i = 0
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 81
# Total if loops: 58
# Total elif_1 loops: 58
# Total elif_2 loops: 19
# Total else loops: 0
# For loop run number: 135 finished
# For loop run number: 136
# i = 0
# close_unit_datetime: 2021-12-18 23:37:21
# open_datetime_lifo: 2021-10-06 12:50:04
# value_close_units: 145.450259 value_open_units: 145.450259
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 81
# (close_unit_index = close_index) is: True
# value_close_units: 145.450259
# value_open_units: 145.450259
# close_unit_index: 81
# Elif_loop_2 run number: 20 finished
# i = 1
# close_unit_index for current loop was: 81
# close_unit_index for next loop is: 82
# Total if loops: 58
# Total elif_1 loops: 58
# Total elif_2 loops: 20
# Total else loops: 0
# For loop run number: 136 finished
# ****************************************

# %%
print('df_lifo_btc sum of open units:',df_lifo_btc['Open Units'].sum())
print('df_lifo_btc sum of close units:',df_lifo_btc['Close Units'].sum())
print('df_open_btc_original sum of open units:',df_open_btc_original['Open Units'].sum())
print('df_close_btc_original sum of close units:',df_close_btc_original['Close Units'].sum())
# Out:
# df_lifo_btc sum of open units: 26547.566137
# df_lifo_btc sum of close units: 26547.566137
# df_open_btc_original sum of open units: 26547.566137
# df_close_btc_original sum of close units: 26547.566137

# %%
df_lifo_btc['time_difference'] = df_lifo_btc['Close Datetime'] - df_lifo_btc['Open Datetime']
df_lifo_btc['time_difference_days'] = df_lifo_btc['time_difference'] / np.timedelta64(1, 'D')
df_lifo_btc_taxable = df_lifo_btc[df_lifo_btc['time_difference_days'] < 365]
df_lifo_btc_taxable_2020 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1609455599]
df_lifo_btc_taxable_2020_2021 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1640991599]
df_lifo_btc_taxable_2021 = df_lifo_btc_taxable_2020_2021[df_lifo_btc_taxable_2020_2021['Close_unix_timestamp'] > 1609455599]
df_lifo_btc_taxable_2022 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] > 1640991599]
print('Sum of all open positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Amount_close_Eur'].sum())
# Out:
# Sum of all open positions for the year 2020 in eur: 5499.467402580808
# Sum of all closed positions for the year 2020 in eur: 4608.026455811074
# Sum of all open positions for the year 2021 in eur: 1727.9062227606428
# Sum of all closed positions for the year 2021 in eur: 1803.2077628191034
# Sum of all open positions for the year 2022 in eur: 0.0
# Sum of all closed positions for the year 2022 in eur: 0.0

# %%
df_open_btc

# %%
df_close_btc

# %%
df_lifo_btc

# %%
df_close['Close Action'].unique()
# Out:
# array(['Buy Bitcoin', 'Buy Ethereum', 'Buy XRP', 'Buy Tezos', 'Buy EOS',
#        'Buy Cardano', 'Buy Litecoin', 'Buy Build and Build', 'Buy TRON',
#        'Buy Dogecoin', 'Buy Chainlink', 'Buy Uniswap', 'Buy Polygon',
#        'Buy Stellar', 'Buy Decentraland', 'Buy Aave', 'Buy IOTA',
#        'Buy Shiba (in millions)', 'Buy Enjin', 'Buy Maker',
#        'Buy Algorand', 'Buy Solana', 'Buy Polkadot', 'Buy Songbird'],
#       dtype=object)
