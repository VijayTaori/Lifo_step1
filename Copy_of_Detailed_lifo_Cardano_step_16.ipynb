# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayTaori/Lifo_step1/blob/main/Copy_of_Detailed_lifo_Cardano_step_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt
import time
import calendar
df_open = pd.read_csv('/content/et_open_alldata.csv')
df_close = pd.read_csv('/content/et_close_alldata.csv')
df_close['Close Datetime'] = pd.to_datetime(df_close['Close_unix_timestamp'],dayfirst=True,unit='s')
df_open['Open Datetime'] = pd.to_datetime(df_open['Open_unix_timestamp'],dayfirst=True,unit='s')
df_close_btc = df_close[df_close['Close Action'] =='Buy Cardano']
df_open_btc = df_open[df_open['Open Action'] =='Buy Cardano']
df_close_btc_original = df_close_btc
df_open_btc_original = df_open_btc
df_close_btc.reset_index(inplace=True)
df_close_btc = df_close_btc.drop('index', axis=1)
df_close_btc.reset_index(inplace=True)
df_close_btc.rename(columns={'index':'Original_Close_index'},inplace=True)
df_open_btc.reset_index(inplace=True)
df_open_btc = df_open_btc.drop('index', axis=1)
df_open_btc.reset_index(inplace=True)
df_open_btc.rename(columns={'index':'Original_Open_index'},inplace=True)
data_btc = {}
df_lifo_btc = pd.DataFrame(data_btc, 
                           columns=['Original_Open_index','Original_Close_index',
                                    'Open Position ID', 'Close Position ID',
                                    'Open Units','Close Units','Spread_Eur',
                                    'Open Amount_Eur','Amount_close_Eur',
                                    'Open Datetime', 'Close Datetime',
                                    'Open Rate_Eur', 'Close Rate_Eur',
                                    'Open Action', 'Close Action', 
                                    'Open Amount','Close Rate', 'Open Rate',
                                    'Close Spread', 'Close Profit USD',
                                    'Close_Date','Open_Date',
                                    'Close_unix_timestamp','EurOpen_y', 
                                    'EurHigh_y','EurLow_y', 'EurClose_y',
                                    'EurWeekday_y', 'Open_unix_timestamp',
                                    'EurOpen_x', 'EurHigh_x','EurLow_x', 
                                    'EurClose_x','EurWeekday_x'
                                    ]
                           )
# Let's build a index selector for df_close_btc
close_unit_index = 0
value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
final_close_unit_index = df_open_btc.shape[0]
serial_number_for_loop = 0
serial_number_if_loop = 0
serial_number_elif_loop_1 = 0
serial_number_elif_loop_2 = 0
serial_number_else_loop = 0
while close_unit_index < final_close_unit_index:
  serial_number_for_loop = serial_number_for_loop + 1
  print('For loop run number:',serial_number_for_loop)
  i = 0
  print('i =',i)
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  # How to set up an upper limit on this variable?? use df.shape[0]
  # Choosing first row from df_close_btc where the units are = values_of_units
  # Assign it as new DF
  # change the reset the index and the drop the 'index' column
  df_latest_row_from_close = df_close_btc[close_unit_index:(close_unit_index+1)]
  df_latest_row_from_close.reset_index(inplace=True)
  current_close_index = df_latest_row_from_close.at[0,'index']
  df_latest_row_from_close = df_latest_row_from_close.drop('index',axis=1)
  # Get the datetime value from the df_latest_row_from_close
  close_unit_datetime = df_close_btc.loc[close_unit_index,'Close Datetime']
  print('close_unit_datetime:',close_unit_datetime)
  # find all the transaction datetimes from df_open that were opened before the close_unit_datetime
  open_datetimes_b4 = df_open_btc['Open Datetime'][df_open_btc['Open Datetime'] < close_unit_datetime]
  #Latest datetime beofore close datetime
  open_datetime_lifo = open_datetimes_b4.max()
  #if open_datetime_lifo == pd.NaT:
  #  break
  #else:
  #  continue
  print('open_datetime_lifo:',open_datetime_lifo)
  '''
  Remember that even if only one value for open_datetime_lifo is chosen
  this can still result in chosing more than one rows in that case last row 
  should be chosen
  '''
  # Corresponding row for the open_datetime_lifo 
  # let's make a new DF
  df_latest_last_row_open = df_open_btc[df_open_btc['Open Datetime'] == open_datetime_lifo]
  df_latest_last_row_open = df_latest_last_row_open[::-1]
  df_latest_last_row_open = df_latest_last_row_open[0:1]
  df_latest_last_row_open.reset_index(inplace=True)
  current_open_index = df_latest_last_row_open.at[0,'index']
  df_latest_last_row_open = df_latest_last_row_open.drop('index', axis=1)
  value_open_units = df_latest_last_row_open.loc[0,'Open Units']
  print('value_close_units:',value_close_units, 'value_open_units:',value_open_units)
  abs_diff_open_close_units = abs(value_close_units - value_open_units)
  print('abs_diff_open_close_units:',abs_diff_open_close_units)
  value_open_amount = df_latest_last_row_open.loc[0,'Open Amount_Eur']
  value_close_amount = df_latest_row_from_close.loc[0,'Amount_close_Eur']
  value_close_spread_eur = df_latest_row_from_close.loc[0,'Spread_Eur']
  close_Rate_eur = df_latest_row_from_close.loc[0,'Close Rate_Eur']
  open_Rate_eur = df_latest_last_row_open.loc[0,'Open Rate_Eur']
  #Remember that 'Open_index' and 'Close_index' columns host original indices
  # This is important as df_open_btc starts to drop rows the original indices will come in handy 
  # And in case of df_close_btc this should remain equal to the indices from DataFrame
  original_open_index = df_latest_last_row_open.at[0, 'Original_Open_index']
  #Remeber that earlier defined close_unit_index is the index of units from df_close_btc DataFrame
  # close_index should essentially be equal in integer value of close_unit_index
  close_index = df_latest_row_from_close.at[0, 'Original_Close_index']
  is_it_equal = close_unit_index == close_index
  print('close_unit_index for current loop is:',close_unit_index)
  print('(close_unit_index = close_index) is:',is_it_equal)
  if value_close_units > value_open_units:
    serial_number_if_loop = serial_number_if_loop + 1
    print('If_loop run number:',serial_number_if_loop)
    #First lets extract all the values from open DF df_latest_last_row_open
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
    df_open_btc = df_open_btc.drop(current_open_index,axis=0)
    #Then reset index and drop the new column 'index' in df_open_btc
    df_open_btc.reset_index(inplace=True)
    df_open_btc = df_open_btc.drop('index',axis=1)
    #Now lets work on the Close_side
    #First define the changed values for df_latest_row_from_close
    changed_value_close_units = value_open_units
    changed_value_close_amount = changed_value_close_units * close_Rate_eur
    changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    df_latest_row_from_close.at[0,'Close Units'] = changed_value_close_units
    df_latest_row_from_close.at[0,'Amount_close_Eur'] = changed_value_close_amount
    df_latest_row_from_close.at[0,'Spread_Eur'] = changed_value_close_spread
    # Now lets extract all the values from df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
    df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('If_loop run number:',serial_number_if_loop,'finished')
  elif value_close_units < value_open_units:
    serial_number_elif_loop_1 = serial_number_elif_loop_1 + 1
    print('Elif_loop_1 run number:', serial_number_elif_loop_1)
    ## First lets extract all the values form close DF df_latest_row_from_close
    newth_list_close_half = df_latest_row_from_close.to_dict('records')
    newth_dict_close_half = newth_list_close_half[0]
    #First define the changed values for df_latest_row_from_close
    ## In elif statement changed values are same as we made only one change
    # and after that change the value of units and amount and spread in original df_close_btc
    df_close_btc.at[close_unit_index,'Close Units'] = 0
    df_close_btc.at[close_unit_index,'Amount_close_Eur'] = 0
    df_close_btc.at[close_unit_index,'Spread_Eur'] = 0
    #First change the values of 'units' and 'amount' and 'spread' in the df_latest_row_from_close
    # These values will be reported
    # Now lets extract all the values from df_latest_row_from_close
    ## Now lets work on the values from open DF df_latest_last_row_lifo
    ## Remember we want to get back the values in the df_latest_row_from_close 
    ## we will have to assign changed_values for open_units and open_amount
    changed_value_open_units = value_close_units
    changed_value_open_amount = changed_value_open_units * open_Rate_eur
    print('changed_value_open_units:',changed_value_open_units)
    df_latest_last_row_open.at[0,'Open Units'] = changed_value_open_units
    df_latest_last_row_open.at[0,'Open Amount_Eur'] = changed_value_open_amount
    ##After the values are changed extract the values which will then be reported
    newth_list_open_half = df_latest_last_row_open.to_dict('records')
    newth_dict_open_half = newth_list_open_half[0]
    ## and then this time change the original values in the df_open_units
    newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
    # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
    df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
    # and after that change the value of units and amount in original df_open_btc
    df_open_btc.at[current_open_index,'Open Units'] = value_open_units - changed_value_open_units
    df_open_btc.at[current_open_index,'Open Amount_Eur'] = value_open_amount - changed_value_open_amount
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_1 run number:', serial_number_elif_loop_1, 'finished')
  elif value_close_units == value_open_units:
    serial_number_elif_loop_2 = serial_number_elif_loop_2 + 1
    if value_close_units == 0:
      print('We are running value_close_units == 0 condition')
      print('This is in the Elif_loop_number_2:',serial_number_elif_loop_2)
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      print('We are breaking')
      break
    else:
      #First lets extract all the values from open DF df_latest_last_row_open
      newth_list_open_half = df_latest_last_row_open.to_dict('records')
      newth_dict_open_half = newth_list_open_half[0]
      #Then permanently delete the first row of the open DF df_latest_last_row_open from df_open_btc
      df_open_btc = df_open_btc.drop(current_open_index,axis=0)
      #Then reset index and drop the new column 'index' in df_open_btc
      df_open_btc.reset_index(inplace=True)
      df_open_btc = df_open_btc.drop('index',axis=1)
      ### Second lets extract all the values form close DF df_latest_row_from_close
      newth_list_close_half = df_latest_row_from_close.to_dict('records')
      newth_dict_close_half = newth_list_close_half[0]
      ## and then this time change the original values in the df_open_units
      newth_whole_dict = {**newth_dict_open_half,**newth_dict_close_half}
      # Now append the newth_whole_dict to the new records DataFrame df_lifo_btc
      df_lifo_btc = df_lifo_btc.append(newth_whole_dict, ignore_index=True)
      #First define the changed values for df_latest_row_from_close
      changed_value_close_units = value_open_units
      changed_value_close_amount = changed_value_close_units * close_Rate_eur
      changed_value_close_spread = changed_value_close_units * value_close_spread_eur/value_close_units
      # and after that change the value of units and amount in original df_open_btc
      df_close_btc.at[close_unit_index,'Close Units'] = value_close_units - changed_value_close_units
      df_close_btc.at[close_unit_index,'Amount_close_Eur'] = value_close_amount - changed_value_close_amount
      df_close_btc.at[close_unit_index,'Spread_Eur'] = value_close_spread_eur - changed_value_close_spread
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('Elif_loop_2 run number:', serial_number_elif_loop_2, 'finished')
  else:
    serial_number_else_loop = serial_number_else_loop + 1
    print('Do we need to write more code? The answer is a: BIG YES!!')
    print('Or on second thought this is a silly mistake!!!')
    print('value_close_units:',value_close_units)
    print('value_open_units:',value_open_units)
    print('close_unit_index:',close_unit_index)
    print('serial_number_else_loop:', serial_number_else_loop, 'finished')
    print('We are breaking here!!')
    break
  value_close_units = df_close_btc.loc[close_unit_index, 'Close Units']
  if value_close_units < 1.0e-10:
    i = 1
  else:
    i = 0
  print('i =',i)
  print('close_unit_index for current loop was:',close_unit_index)
  close_unit_index = close_unit_index + i
  print('close_unit_index for next loop is:',close_unit_index)
  print('Total if loops:',serial_number_if_loop)
  print('Total elif_1 loops:',serial_number_elif_loop_1)
  print('Total elif_2 loops:',serial_number_elif_loop_2)
  print('Total else loops:',serial_number_else_loop)
  print('For loop run number:',serial_number_for_loop,'finished')
  if df_close_btc['Close Units'].sum() < 1.0e-10:
    close_unit_index = final_close_unit_index
  else:
    continue
  print('****************************************')
# Out:
# Streaming output truncated to the last 5000 lines.
# For loop run number: 7
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-08 13:20:19
# value_close_units: 605.326877 value_open_units: 392.464678
# abs_diff_open_close_units: 212.86219899999998
# close_unit_index for current loop is: 5
# (close_unit_index = close_index) is: True
# If_loop run number: 2
# value_close_units: 605.326877
# value_open_units: 392.464678
# close_unit_index: 5
# If_loop run number: 2 finished
# i = 0
# close_unit_index for current loop was: 5
# close_unit_index for next loop is: 5
# Total if loops: 2
# Total elif_1 loops: 1
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 7 finished
# For loop run number: 8
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-08 05:37:30
# value_close_units: 212.86219899999998 value_open_units: 3039.513678
# abs_diff_open_close_units: 2826.6514789999997
# close_unit_index for current loop is: 5
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 2
# changed_value_open_units: 212.86219899999998
# value_close_units: 212.86219899999998
# value_open_units: 3039.513678
# close_unit_index: 5
# Elif_loop_1 run number: 2 finished
# i = 1
# close_unit_index for current loop was: 5
# close_unit_index for next loop is: 6
# Total if loops: 2
# Total elif_1 loops: 2
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 8 finished
# For loop run number: 9
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-08 05:37:30
# value_close_units: 283.446712 value_open_units: 2826.6514789999997
# abs_diff_open_close_units: 2543.2047669999997
# close_unit_index for current loop is: 6
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 3
# changed_value_open_units: 283.446712
# value_close_units: 283.446712
# value_open_units: 2826.6514789999997
# close_unit_index: 6
# Elif_loop_1 run number: 3 finished
# i = 1
# close_unit_index for current loop was: 6
# close_unit_index for next loop is: 7
# Total if loops: 2
# Total elif_1 loops: 3
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 9 finished
# For loop run number: 10
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-08 05:37:30
# value_close_units: 293.42723 value_open_units: 2543.2047669999997
# abs_diff_open_close_units: 2249.777537
# close_unit_index for current loop is: 7
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 4
# changed_value_open_units: 293.42723
# value_close_units: 293.42723
# value_open_units: 2543.2047669999997
# close_unit_index: 7
# Elif_loop_1 run number: 4 finished
# i = 1
# close_unit_index for current loop was: 7
# close_unit_index for next loop is: 8
# Total if loops: 2
# Total elif_1 loops: 4
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 10 finished
# For loop run number: 11
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-08 05:37:30
# value_close_units: 316.455696 value_open_units: 2249.777537
# abs_diff_open_close_units: 1933.321841
# close_unit_index for current loop is: 8
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 5
# changed_value_open_units: 316.455696
# value_close_units: 316.455696
# value_open_units: 2249.777537
# close_unit_index: 8
# Elif_loop_1 run number: 5 finished
# i = 1
# close_unit_index for current loop was: 8
# close_unit_index for next loop is: 9
# Total if loops: 2
# Total elif_1 loops: 5
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 11 finished
# For loop run number: 12
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-08 05:37:30
# value_close_units: 288.018433 value_open_units: 1933.321841
# abs_diff_open_close_units: 1645.303408
# close_unit_index for current loop is: 9
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 6
# changed_value_open_units: 288.018433
# value_close_units: 288.018433
# value_open_units: 1933.321841
# close_unit_index: 9
# Elif_loop_1 run number: 6 finished
# i = 1
# close_unit_index for current loop was: 9
# close_unit_index for next loop is: 10
# Total if loops: 2
# Total elif_1 loops: 6
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 12 finished
# For loop run number: 13
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-08 05:37:30
# value_close_units: 1943.493151 value_open_units: 1645.303408
# abs_diff_open_close_units: 298.1897429999999
# close_unit_index for current loop is: 10
# (close_unit_index = close_index) is: True
# If_loop run number: 3
# value_close_units: 1943.493151
# value_open_units: 1645.303408
# close_unit_index: 10
# If_loop run number: 3 finished
# i = 0
# close_unit_index for current loop was: 10
# close_unit_index for next loop is: 10
# Total if loops: 3
# Total elif_1 loops: 6
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 13 finished
# For loop run number: 14
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-07 16:40:45
# value_close_units: 298.1897429999999 value_open_units: 1943.493151
# abs_diff_open_close_units: 1645.303408
# close_unit_index for current loop is: 10
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 7
# changed_value_open_units: 298.1897429999999
# value_close_units: 298.1897429999999
# value_open_units: 1943.493151
# close_unit_index: 10
# Elif_loop_1 run number: 7 finished
# i = 1
# close_unit_index for current loop was: 10
# close_unit_index for next loop is: 11
# Total if loops: 3
# Total elif_1 loops: 7
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 14 finished
# For loop run number: 15
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-07 16:40:45
# value_close_units: 392.464678 value_open_units: 1645.303408
# abs_diff_open_close_units: 1252.83873
# close_unit_index for current loop is: 11
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 8
# changed_value_open_units: 392.464678
# value_close_units: 392.464678
# value_open_units: 1645.303408
# close_unit_index: 11
# Elif_loop_1 run number: 8 finished
# i = 1
# close_unit_index for current loop was: 11
# close_unit_index for next loop is: 12
# Total if loops: 3
# Total elif_1 loops: 8
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 15 finished
# For loop run number: 16
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-07-07 16:40:45
# value_close_units: 3039.513678 value_open_units: 1252.83873
# abs_diff_open_close_units: 1786.6749479999999
# close_unit_index for current loop is: 12
# (close_unit_index = close_index) is: True
# If_loop run number: 4
# value_close_units: 3039.513678
# value_open_units: 1252.83873
# close_unit_index: 12
# If_loop run number: 4 finished
# i = 0
# close_unit_index for current loop was: 12
# close_unit_index for next loop is: 12
# Total if loops: 4
# Total elif_1 loops: 8
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 16 finished
# For loop run number: 17
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-06-15 19:23:14
# value_close_units: 1786.6749479999999 value_open_units: 316.455696
# abs_diff_open_close_units: 1470.2192519999999
# close_unit_index for current loop is: 12
# (close_unit_index = close_index) is: True
# If_loop run number: 5
# value_close_units: 1786.6749479999999
# value_open_units: 316.455696
# close_unit_index: 12
# If_loop run number: 5 finished
# i = 0
# close_unit_index for current loop was: 12
# close_unit_index for next loop is: 12
# Total if loops: 5
# Total elif_1 loops: 8
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 17 finished
# For loop run number: 18
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-06-10 04:45:52
# value_close_units: 1470.2192519999999 value_open_units: 605.326877
# abs_diff_open_close_units: 864.8923749999999
# close_unit_index for current loop is: 12
# (close_unit_index = close_index) is: True
# If_loop run number: 6
# value_close_units: 1470.2192519999999
# value_open_units: 605.326877
# close_unit_index: 12
# If_loop run number: 6 finished
# i = 0
# close_unit_index for current loop was: 12
# close_unit_index for next loop is: 12
# Total if loops: 6
# Total elif_1 loops: 8
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 18 finished
# For loop run number: 19
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-06-09 06:52:54
# value_close_units: 864.8923749999999 value_open_units: 288.018433
# abs_diff_open_close_units: 576.8739419999999
# close_unit_index for current loop is: 12
# (close_unit_index = close_index) is: True
# If_loop run number: 7
# value_close_units: 864.8923749999999
# value_open_units: 288.018433
# close_unit_index: 12
# If_loop run number: 7 finished
# i = 0
# close_unit_index for current loop was: 12
# close_unit_index for next loop is: 12
# Total if loops: 7
# Total elif_1 loops: 8
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 19 finished
# For loop run number: 20
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-06-07 17:07:56
# value_close_units: 576.8739419999999 value_open_units: 293.42723
# abs_diff_open_close_units: 283.44671199999993
# close_unit_index for current loop is: 12
# (close_unit_index = close_index) is: True
# If_loop run number: 8
# value_close_units: 576.8739419999999
# value_open_units: 293.42723
# close_unit_index: 12
# If_loop run number: 8 finished
# i = 0
# close_unit_index for current loop was: 12
# close_unit_index for next loop is: 12
# Total if loops: 8
# Total elif_1 loops: 8
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 20 finished
# For loop run number: 21
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-06-05 13:52:47
# value_close_units: 283.44671199999993 value_open_units: 284.738041
# abs_diff_open_close_units: 1.2913290000000757
# close_unit_index for current loop is: 12
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 9
# changed_value_open_units: 283.44671199999993
# value_close_units: 283.44671199999993
# value_open_units: 284.738041
# close_unit_index: 12
# Elif_loop_1 run number: 9 finished
# i = 1
# close_unit_index for current loop was: 12
# close_unit_index for next loop is: 13
# Total if loops: 8
# Total elif_1 loops: 9
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 21 finished
# For loop run number: 22
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-06-05 13:52:47
# value_close_units: 284.738041 value_open_units: 1.2913290000000757
# abs_diff_open_close_units: 283.44671199999993
# close_unit_index for current loop is: 13
# (close_unit_index = close_index) is: True
# If_loop run number: 9
# value_close_units: 284.738041
# value_open_units: 1.2913290000000757
# close_unit_index: 13
# If_loop run number: 9 finished
# i = 0
# close_unit_index for current loop was: 13
# close_unit_index for next loop is: 13
# Total if loops: 9
# Total elif_1 loops: 9
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 22 finished
# For loop run number: 23
# i = 0
# close_unit_datetime: 2020-07-13 13:39:17
# open_datetime_lifo: 2020-06-04 10:35:58
# value_close_units: 283.44671199999993 value_open_units: 283.446712
# abs_diff_open_close_units: 5.684341886080802e-14
# close_unit_index for current loop is: 13
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 10
# changed_value_open_units: 283.44671199999993
# value_close_units: 283.44671199999993
# value_open_units: 283.446712
# close_unit_index: 13
# Elif_loop_1 run number: 10 finished
# i = 1
# close_unit_index for current loop was: 13
# close_unit_index for next loop is: 14
# Total if loops: 9
# Total elif_1 loops: 10
# Total elif_2 loops: 4
# Total else loops: 0
# For loop run number: 23 finished
# For loop run number: 24
# i = 0
# close_unit_datetime: 2020-08-09 04:43:29
# open_datetime_lifo: 2020-07-16 07:42:59
# value_close_units: 1963.864886 value_open_units: 1963.864886
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 14
# (close_unit_index = close_index) is: True
# value_close_units: 1963.864886
# value_open_units: 1963.864886
# close_unit_index: 14
# Elif_loop_2 run number: 5 finished
# i = 1
# close_unit_index for current loop was: 14
# close_unit_index for next loop is: 15
# Total if loops: 9
# Total elif_1 loops: 10
# Total elif_2 loops: 5
# Total else loops: 0
# For loop run number: 24 finished
# For loop run number: 25
# i = 0
# close_unit_datetime: 2020-08-09 04:43:29
# open_datetime_lifo: 2020-07-16 06:39:17
# value_close_units: 1917.177914 value_open_units: 1917.177914
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 15
# (close_unit_index = close_index) is: True
# value_close_units: 1917.177914
# value_open_units: 1917.177914
# close_unit_index: 15
# Elif_loop_2 run number: 6 finished
# i = 1
# close_unit_index for current loop was: 15
# close_unit_index for next loop is: 16
# Total if loops: 9
# Total elif_1 loops: 10
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 25 finished
# For loop run number: 26
# i = 0
# close_unit_datetime: 2020-08-27 08:16:10
# open_datetime_lifo: 2020-08-23 16:21:24
# value_close_units: 688.705234 value_open_units: 399.680256
# abs_diff_open_close_units: 289.02497800000003
# close_unit_index for current loop is: 16
# (close_unit_index = close_index) is: True
# If_loop run number: 10
# value_close_units: 688.705234
# value_open_units: 399.680256
# close_unit_index: 16
# If_loop run number: 10 finished
# i = 0
# close_unit_index for current loop was: 16
# close_unit_index for next loop is: 16
# Total if loops: 10
# Total elif_1 loops: 10
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 26 finished
# For loop run number: 27
# i = 0
# close_unit_datetime: 2020-08-27 08:16:10
# open_datetime_lifo: 2020-08-23 13:32:53
# value_close_units: 289.02497800000003 value_open_units: 406.504065
# abs_diff_open_close_units: 117.47908699999999
# close_unit_index for current loop is: 16
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 11
# changed_value_open_units: 289.02497800000003
# value_close_units: 289.02497800000003
# value_open_units: 406.504065
# close_unit_index: 16
# Elif_loop_1 run number: 11 finished
# i = 1
# close_unit_index for current loop was: 16
# close_unit_index for next loop is: 17
# Total if loops: 10
# Total elif_1 loops: 11
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 27 finished
# For loop run number: 28
# i = 0
# close_unit_datetime: 2020-08-28 07:38:53
# open_datetime_lifo: 2020-08-27 17:06:05
# value_close_units: 702.740689 value_open_units: 238.777459
# abs_diff_open_close_units: 463.96322999999995
# close_unit_index for current loop is: 17
# (close_unit_index = close_index) is: True
# If_loop run number: 11
# value_close_units: 702.740689
# value_open_units: 238.777459
# close_unit_index: 17
# If_loop run number: 11 finished
# i = 0
# close_unit_index for current loop was: 17
# close_unit_index for next loop is: 17
# Total if loops: 11
# Total elif_1 loops: 11
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 28 finished
# For loop run number: 29
# i = 0
# close_unit_datetime: 2020-08-28 07:38:53
# open_datetime_lifo: 2020-08-23 13:32:53
# value_close_units: 463.96322999999995 value_open_units: 117.47908699999999
# abs_diff_open_close_units: 346.48414299999996
# close_unit_index for current loop is: 17
# (close_unit_index = close_index) is: True
# If_loop run number: 12
# value_close_units: 463.96322999999995
# value_open_units: 117.47908699999999
# close_unit_index: 17
# If_loop run number: 12 finished
# i = 0
# close_unit_index for current loop was: 17
# close_unit_index for next loop is: 17
# Total if loops: 12
# Total elif_1 loops: 11
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 29 finished
# For loop run number: 30
# i = 0
# close_unit_datetime: 2020-08-28 07:38:53
# open_datetime_lifo: 2020-08-21 18:13:57
# value_close_units: 346.48414299999996 value_open_units: 780.640125
# abs_diff_open_close_units: 434.15598200000005
# close_unit_index for current loop is: 17
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 12
# changed_value_open_units: 346.48414299999996
# value_close_units: 346.48414299999996
# value_open_units: 780.640125
# close_unit_index: 17
# Elif_loop_1 run number: 12 finished
# i = 1
# close_unit_index for current loop was: 17
# close_unit_index for next loop is: 18
# Total if loops: 12
# Total elif_1 loops: 12
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 30 finished
# For loop run number: 31
# i = 0
# close_unit_datetime: 2020-08-28 10:06:54
# open_datetime_lifo: 2020-08-21 18:13:57
# value_close_units: 761.035008 value_open_units: 434.15598200000005
# abs_diff_open_close_units: 326.8790259999999
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# If_loop run number: 13
# value_close_units: 761.035008
# value_open_units: 434.15598200000005
# close_unit_index: 18
# If_loop run number: 13 finished
# i = 0
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 18
# Total if loops: 13
# Total elif_1 loops: 12
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 31 finished
# For loop run number: 32
# i = 0
# close_unit_datetime: 2020-08-28 10:06:54
# open_datetime_lifo: 2020-08-19 20:11:58
# value_close_units: 326.8790259999999 value_open_units: 761.035008
# abs_diff_open_close_units: 434.15598200000005
# close_unit_index for current loop is: 18
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 13
# changed_value_open_units: 326.8790259999999
# value_close_units: 326.8790259999999
# value_open_units: 761.035008
# close_unit_index: 18
# Elif_loop_1 run number: 13 finished
# i = 1
# close_unit_index for current loop was: 18
# close_unit_index for next loop is: 19
# Total if loops: 13
# Total elif_1 loops: 13
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 32 finished
# For loop run number: 33
# i = 0
# close_unit_datetime: 2020-08-28 10:07:02
# open_datetime_lifo: 2020-08-19 20:11:58
# value_close_units: 780.640125 value_open_units: 434.15598200000005
# abs_diff_open_close_units: 346.48414299999996
# close_unit_index for current loop is: 19
# (close_unit_index = close_index) is: True
# If_loop run number: 14
# value_close_units: 780.640125
# value_open_units: 434.15598200000005
# close_unit_index: 19
# If_loop run number: 14 finished
# i = 0
# close_unit_index for current loop was: 19
# close_unit_index for next loop is: 19
# Total if loops: 14
# Total elif_1 loops: 13
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 33 finished
# For loop run number: 34
# i = 0
# close_unit_datetime: 2020-08-28 10:07:02
# open_datetime_lifo: 2020-08-18 07:43:07
# value_close_units: 346.48414299999996 value_open_units: 702.740689
# abs_diff_open_close_units: 356.256546
# close_unit_index for current loop is: 19
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 14
# changed_value_open_units: 346.48414299999996
# value_close_units: 346.48414299999996
# value_open_units: 702.740689
# close_unit_index: 19
# Elif_loop_1 run number: 14 finished
# i = 1
# close_unit_index for current loop was: 19
# close_unit_index for next loop is: 20
# Total if loops: 14
# Total elif_1 loops: 14
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 34 finished
# For loop run number: 35
# i = 0
# close_unit_datetime: 2020-10-12 09:06:04
# open_datetime_lifo: 2020-09-30 04:00:08
# value_close_units: 399.680256 value_open_units: 250.25025
# abs_diff_open_close_units: 149.430006
# close_unit_index for current loop is: 20
# (close_unit_index = close_index) is: True
# If_loop run number: 15
# value_close_units: 399.680256
# value_open_units: 250.25025
# close_unit_index: 20
# If_loop run number: 15 finished
# i = 0
# close_unit_index for current loop was: 20
# close_unit_index for next loop is: 20
# Total if loops: 15
# Total elif_1 loops: 14
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 35 finished
# For loop run number: 36
# i = 0
# close_unit_datetime: 2020-10-12 09:06:04
# open_datetime_lifo: 2020-09-29 16:28:03
# value_close_units: 149.430006 value_open_units: 440.881764
# abs_diff_open_close_units: 291.451758
# close_unit_index for current loop is: 20
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 15
# changed_value_open_units: 149.430006
# value_close_units: 149.430006
# value_open_units: 440.881764
# close_unit_index: 20
# Elif_loop_1 run number: 15 finished
# i = 1
# close_unit_index for current loop was: 20
# close_unit_index for next loop is: 21
# Total if loops: 15
# Total elif_1 loops: 15
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 36 finished
# For loop run number: 37
# i = 0
# close_unit_datetime: 2020-10-12 09:06:10
# open_datetime_lifo: 2020-09-29 16:28:03
# value_close_units: 406.504065 value_open_units: 291.451758
# abs_diff_open_close_units: 115.05230700000004
# close_unit_index for current loop is: 21
# (close_unit_index = close_index) is: True
# If_loop run number: 16
# value_close_units: 406.504065
# value_open_units: 291.451758
# close_unit_index: 21
# If_loop run number: 16 finished
# i = 0
# close_unit_index for current loop was: 21
# close_unit_index for next loop is: 21
# Total if loops: 16
# Total elif_1 loops: 15
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 37 finished
# For loop run number: 38
# i = 0
# close_unit_datetime: 2020-10-12 09:06:10
# open_datetime_lifo: 2020-09-28 05:45:33
# value_close_units: 115.05230700000004 value_open_units: 237.191651
# abs_diff_open_close_units: 122.13934399999997
# close_unit_index for current loop is: 21
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 16
# changed_value_open_units: 115.05230700000004
# value_close_units: 115.05230700000004
# value_open_units: 237.191651
# close_unit_index: 21
# Elif_loop_1 run number: 16 finished
# i = 1
# close_unit_index for current loop was: 21
# close_unit_index for next loop is: 22
# Total if loops: 16
# Total elif_1 loops: 16
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 38 finished
# For loop run number: 39
# i = 0
# close_unit_datetime: 2020-10-12 09:09:01
# open_datetime_lifo: 2020-09-28 05:45:33
# value_close_units: 238.777459 value_open_units: 122.13934399999997
# abs_diff_open_close_units: 116.63811500000003
# close_unit_index for current loop is: 22
# (close_unit_index = close_index) is: True
# If_loop run number: 17
# value_close_units: 238.777459
# value_open_units: 122.13934399999997
# close_unit_index: 22
# If_loop run number: 17 finished
# i = 0
# close_unit_index for current loop was: 22
# close_unit_index for next loop is: 22
# Total if loops: 17
# Total elif_1 loops: 16
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 39 finished
# For loop run number: 40
# i = 0
# close_unit_datetime: 2020-10-12 09:09:01
# open_datetime_lifo: 2020-09-27 06:15:01
# value_close_units: 116.63811500000003 value_open_units: 248.508946
# abs_diff_open_close_units: 131.87083099999998
# close_unit_index for current loop is: 22
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 17
# changed_value_open_units: 116.63811500000003
# value_close_units: 116.63811500000003
# value_open_units: 248.508946
# close_unit_index: 22
# Elif_loop_1 run number: 17 finished
# i = 1
# close_unit_index for current loop was: 22
# close_unit_index for next loop is: 23
# Total if loops: 17
# Total elif_1 loops: 17
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 40 finished
# For loop run number: 41
# i = 0
# close_unit_datetime: 2020-10-12 09:09:08
# open_datetime_lifo: 2020-09-27 06:15:01
# value_close_units: 237.191651 value_open_units: 131.87083099999998
# abs_diff_open_close_units: 105.32082000000003
# close_unit_index for current loop is: 23
# (close_unit_index = close_index) is: True
# If_loop run number: 18
# value_close_units: 237.191651
# value_open_units: 131.87083099999998
# close_unit_index: 23
# If_loop run number: 18 finished
# i = 0
# close_unit_index for current loop was: 23
# close_unit_index for next loop is: 23
# Total if loops: 18
# Total elif_1 loops: 17
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 41 finished
# For loop run number: 42
# i = 0
# close_unit_datetime: 2020-10-12 09:09:08
# open_datetime_lifo: 2020-09-25 12:38:44
# value_close_units: 105.32082000000003 value_open_units: 265.392781
# abs_diff_open_close_units: 160.071961
# close_unit_index for current loop is: 23
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 18
# changed_value_open_units: 105.32082000000003
# value_close_units: 105.32082000000003
# value_open_units: 265.392781
# close_unit_index: 23
# Elif_loop_1 run number: 18 finished
# i = 1
# close_unit_index for current loop was: 23
# close_unit_index for next loop is: 24
# Total if loops: 18
# Total elif_1 loops: 18
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 42 finished
# For loop run number: 43
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-25 12:38:44
# value_close_units: 914.866582 value_open_units: 160.071961
# abs_diff_open_close_units: 754.794621
# close_unit_index for current loop is: 24
# (close_unit_index = close_index) is: True
# If_loop run number: 19
# value_close_units: 914.866582
# value_open_units: 160.071961
# close_unit_index: 24
# If_loop run number: 19 finished
# i = 0
# close_unit_index for current loop was: 24
# close_unit_index for next loop is: 24
# Total if loops: 19
# Total elif_1 loops: 18
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 43 finished
# For loop run number: 44
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-21 14:39:37
# value_close_units: 754.794621 value_open_units: 914.866582
# abs_diff_open_close_units: 160.071961
# close_unit_index for current loop is: 24
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 19
# changed_value_open_units: 754.794621
# value_close_units: 754.794621
# value_open_units: 914.866582
# close_unit_index: 24
# Elif_loop_1 run number: 19 finished
# i = 1
# close_unit_index for current loop was: 24
# close_unit_index for next loop is: 25
# Total if loops: 19
# Total elif_1 loops: 19
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 44 finished
# For loop run number: 45
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-21 14:39:37
# value_close_units: 440.881764 value_open_units: 160.071961
# abs_diff_open_close_units: 280.809803
# close_unit_index for current loop is: 25
# (close_unit_index = close_index) is: True
# If_loop run number: 20
# value_close_units: 440.881764
# value_open_units: 160.071961
# close_unit_index: 25
# If_loop run number: 20 finished
# i = 0
# close_unit_index for current loop was: 25
# close_unit_index for next loop is: 25
# Total if loops: 20
# Total elif_1 loops: 19
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 45 finished
# For loop run number: 46
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-14 14:26:53
# value_close_units: 280.809803 value_open_units: 761.42132
# abs_diff_open_close_units: 480.61151700000005
# close_unit_index for current loop is: 25
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 20
# changed_value_open_units: 280.809803
# value_close_units: 280.809803
# value_open_units: 761.42132
# close_unit_index: 25
# Elif_loop_1 run number: 20 finished
# i = 1
# close_unit_index for current loop was: 25
# close_unit_index for next loop is: 26
# Total if loops: 20
# Total elif_1 loops: 20
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 46 finished
# For loop run number: 47
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-14 14:26:53
# value_close_units: 250.25025 value_open_units: 480.61151700000005
# abs_diff_open_close_units: 230.36126700000005
# close_unit_index for current loop is: 26
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 21
# changed_value_open_units: 250.25025
# value_close_units: 250.25025
# value_open_units: 480.61151700000005
# close_unit_index: 26
# Elif_loop_1 run number: 21 finished
# i = 1
# close_unit_index for current loop was: 26
# close_unit_index for next loop is: 27
# Total if loops: 20
# Total elif_1 loops: 21
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 47 finished
# For loop run number: 48
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-14 14:26:53
# value_close_units: 248.508946 value_open_units: 230.36126700000005
# abs_diff_open_close_units: 18.147678999999954
# close_unit_index for current loop is: 27
# (close_unit_index = close_index) is: True
# If_loop run number: 21
# value_close_units: 248.508946
# value_open_units: 230.36126700000005
# close_unit_index: 27
# If_loop run number: 21 finished
# i = 0
# close_unit_index for current loop was: 27
# close_unit_index for next loop is: 27
# Total if loops: 21
# Total elif_1 loops: 21
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 48 finished
# For loop run number: 49
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-07 11:01:28
# value_close_units: 18.147678999999954 value_open_units: 282.485876
# abs_diff_open_close_units: 264.33819700000004
# close_unit_index for current loop is: 27
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 22
# changed_value_open_units: 18.147678999999954
# value_close_units: 18.147678999999954
# value_open_units: 282.485876
# close_unit_index: 27
# Elif_loop_1 run number: 22 finished
# i = 1
# close_unit_index for current loop was: 27
# close_unit_index for next loop is: 28
# Total if loops: 21
# Total elif_1 loops: 22
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 49 finished
# For loop run number: 50
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-07 11:01:28
# value_close_units: 282.485876 value_open_units: 264.33819700000004
# abs_diff_open_close_units: 18.147678999999982
# close_unit_index for current loop is: 28
# (close_unit_index = close_index) is: True
# If_loop run number: 22
# value_close_units: 282.485876
# value_open_units: 264.33819700000004
# close_unit_index: 28
# If_loop run number: 22 finished
# i = 0
# close_unit_index for current loop was: 28
# close_unit_index for next loop is: 28
# Total if loops: 22
# Total elif_1 loops: 22
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 50 finished
# For loop run number: 51
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-03 23:31:52
# value_close_units: 18.147678999999982 value_open_units: 747.368421
# abs_diff_open_close_units: 729.220742
# close_unit_index for current loop is: 28
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 23
# changed_value_open_units: 18.147678999999982
# value_close_units: 18.147678999999982
# value_open_units: 747.368421
# close_unit_index: 28
# Elif_loop_1 run number: 23 finished
# i = 1
# close_unit_index for current loop was: 28
# close_unit_index for next loop is: 29
# Total if loops: 22
# Total elif_1 loops: 23
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 51 finished
# For loop run number: 52
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-09-03 23:31:52
# value_close_units: 761.42132 value_open_units: 729.220742
# abs_diff_open_close_units: 32.200578000000064
# close_unit_index for current loop is: 29
# (close_unit_index = close_index) is: True
# If_loop run number: 23
# value_close_units: 761.42132
# value_open_units: 729.220742
# close_unit_index: 29
# If_loop run number: 23 finished
# i = 0
# close_unit_index for current loop was: 29
# close_unit_index for next loop is: 29
# Total if loops: 23
# Total elif_1 loops: 23
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 52 finished
# For loop run number: 53
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-08-18 07:43:07
# value_close_units: 32.200578000000064 value_open_units: 356.256546
# abs_diff_open_close_units: 324.05596799999995
# close_unit_index for current loop is: 29
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 24
# changed_value_open_units: 32.200578000000064
# value_close_units: 32.200578000000064
# value_open_units: 356.256546
# close_unit_index: 29
# Elif_loop_1 run number: 24 finished
# i = 1
# close_unit_index for current loop was: 29
# close_unit_index for next loop is: 30
# Total if loops: 23
# Total elif_1 loops: 24
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 53 finished
# For loop run number: 54
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-08-18 07:43:07
# value_close_units: 265.392781 value_open_units: 324.05596799999995
# abs_diff_open_close_units: 58.66318699999994
# close_unit_index for current loop is: 30
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 25
# changed_value_open_units: 265.392781
# value_close_units: 265.392781
# value_open_units: 324.05596799999995
# close_unit_index: 30
# Elif_loop_1 run number: 25 finished
# i = 1
# close_unit_index for current loop was: 30
# close_unit_index for next loop is: 31
# Total if loops: 23
# Total elif_1 loops: 25
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 54 finished
# For loop run number: 55
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-08-18 07:43:07
# value_close_units: 747.368421 value_open_units: 58.66318699999994
# abs_diff_open_close_units: 688.705234
# close_unit_index for current loop is: 31
# (close_unit_index = close_index) is: True
# If_loop run number: 24
# value_close_units: 747.368421
# value_open_units: 58.66318699999994
# close_unit_index: 31
# If_loop run number: 24 finished
# i = 0
# close_unit_index for current loop was: 31
# close_unit_index for next loop is: 31
# Total if loops: 24
# Total elif_1 loops: 25
# Total elif_2 loops: 6
# Total else loops: 0
# For loop run number: 55 finished
# For loop run number: 56
# i = 0
# close_unit_datetime: 2020-10-15 09:58:32
# open_datetime_lifo: 2020-08-17 20:22:55
# value_close_units: 688.705234 value_open_units: 688.705234
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 31
# (close_unit_index = close_index) is: True
# value_close_units: 688.705234
# value_open_units: 688.705234
# close_unit_index: 31
# Elif_loop_2 run number: 7 finished
# i = 1
# close_unit_index for current loop was: 31
# close_unit_index for next loop is: 32
# Total if loops: 24
# Total elif_1 loops: 25
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 56 finished
# For loop run number: 57
# i = 0
# close_unit_datetime: 2020-12-29 05:31:44
# open_datetime_lifo: 2020-12-23 22:13:50
# value_close_units: 6250.0 value_open_units: 720.461095
# abs_diff_open_close_units: 5529.538905
# close_unit_index for current loop is: 32
# (close_unit_index = close_index) is: True
# If_loop run number: 25
# value_close_units: 6250.0
# value_open_units: 720.461095
# close_unit_index: 32
# If_loop run number: 25 finished
# i = 0
# close_unit_index for current loop was: 32
# close_unit_index for next loop is: 32
# Total if loops: 25
# Total elif_1 loops: 25
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 57 finished
# For loop run number: 58
# i = 0
# close_unit_datetime: 2020-12-29 05:31:44
# open_datetime_lifo: 2020-12-21 16:16:53
# value_close_units: 5529.538905 value_open_units: 639.795266
# abs_diff_open_close_units: 4889.743639
# close_unit_index for current loop is: 32
# (close_unit_index = close_index) is: True
# If_loop run number: 26
# value_close_units: 5529.538905
# value_open_units: 639.795266
# close_unit_index: 32
# If_loop run number: 26 finished
# i = 0
# close_unit_index for current loop was: 32
# close_unit_index for next loop is: 32
# Total if loops: 26
# Total elif_1 loops: 25
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 58 finished
# For loop run number: 59
# i = 0
# close_unit_datetime: 2020-12-29 05:31:44
# open_datetime_lifo: 2020-12-19 17:12:02
# value_close_units: 4889.743639 value_open_units: 2870.264064
# abs_diff_open_close_units: 2019.4795750000003
# close_unit_index for current loop is: 32
# (close_unit_index = close_index) is: True
# If_loop run number: 27
# value_close_units: 4889.743639
# value_open_units: 2870.264064
# close_unit_index: 32
# If_loop run number: 27 finished
# i = 0
# close_unit_index for current loop was: 32
# close_unit_index for next loop is: 32
# Total if loops: 27
# Total elif_1 loops: 25
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 59 finished
# For loop run number: 60
# i = 0
# close_unit_datetime: 2020-12-29 05:31:44
# open_datetime_lifo: 2020-12-17 07:06:48
# value_close_units: 2019.4795750000003 value_open_units: 1179.941003
# abs_diff_open_close_units: 839.5385720000004
# close_unit_index for current loop is: 32
# (close_unit_index = close_index) is: True
# If_loop run number: 28
# value_close_units: 2019.4795750000003
# value_open_units: 1179.941003
# close_unit_index: 32
# If_loop run number: 28 finished
# i = 0
# close_unit_index for current loop was: 32
# close_unit_index for next loop is: 32
# Total if loops: 28
# Total elif_1 loops: 25
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 60 finished
# For loop run number: 61
# i = 0
# close_unit_datetime: 2020-12-29 05:31:44
# open_datetime_lifo: 2020-12-10 14:20:24
# value_close_units: 839.5385720000004 value_open_units: 6.129467
# abs_diff_open_close_units: 833.4091050000004
# close_unit_index for current loop is: 32
# (close_unit_index = close_index) is: True
# If_loop run number: 29
# value_close_units: 839.5385720000004
# value_open_units: 6.129467
# close_unit_index: 32
# If_loop run number: 29 finished
# i = 0
# close_unit_index for current loop was: 32
# close_unit_index for next loop is: 32
# Total if loops: 29
# Total elif_1 loops: 25
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 61 finished
# For loop run number: 62
# i = 0
# close_unit_datetime: 2020-12-29 05:31:44
# open_datetime_lifo: 2020-12-09 11:34:35
# value_close_units: 833.4091050000004 value_open_units: 1894.150418
# abs_diff_open_close_units: 1060.7413129999995
# close_unit_index for current loop is: 32
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 26
# changed_value_open_units: 833.4091050000004
# value_close_units: 833.4091050000004
# value_open_units: 1894.150418
# close_unit_index: 32
# Elif_loop_1 run number: 26 finished
# i = 1
# close_unit_index for current loop was: 32
# close_unit_index for next loop is: 33
# Total if loops: 29
# Total elif_1 loops: 26
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 62 finished
# For loop run number: 63
# i = 0
# close_unit_datetime: 2020-12-29 05:31:53
# open_datetime_lifo: 2020-12-09 11:34:35
# value_close_units: 440.17359 value_open_units: 1060.7413129999995
# abs_diff_open_close_units: 620.5677229999995
# close_unit_index for current loop is: 33
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 27
# changed_value_open_units: 440.17359
# value_close_units: 440.17359
# value_open_units: 1060.7413129999995
# close_unit_index: 33
# Elif_loop_1 run number: 27 finished
# i = 1
# close_unit_index for current loop was: 33
# close_unit_index for next loop is: 34
# Total if loops: 29
# Total elif_1 loops: 27
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 63 finished
# For loop run number: 64
# i = 0
# close_unit_datetime: 2020-12-29 05:32:02
# open_datetime_lifo: 2020-12-09 11:34:35
# value_close_units: 1179.941003 value_open_units: 620.5677229999995
# abs_diff_open_close_units: 559.3732800000004
# close_unit_index for current loop is: 34
# (close_unit_index = close_index) is: True
# If_loop run number: 30
# value_close_units: 1179.941003
# value_open_units: 620.5677229999995
# close_unit_index: 34
# If_loop run number: 30 finished
# i = 0
# close_unit_index for current loop was: 34
# close_unit_index for next loop is: 34
# Total if loops: 30
# Total elif_1 loops: 27
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 64 finished
# For loop run number: 65
# i = 0
# close_unit_datetime: 2020-12-29 05:32:02
# open_datetime_lifo: 2020-12-04 10:47:57
# value_close_units: 559.3732800000004 value_open_units: 6250.0
# abs_diff_open_close_units: 5690.626719999999
# close_unit_index for current loop is: 34
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 28
# changed_value_open_units: 559.3732800000004
# value_close_units: 559.3732800000004
# value_open_units: 6250.0
# close_unit_index: 34
# Elif_loop_1 run number: 28 finished
# i = 1
# close_unit_index for current loop was: 34
# close_unit_index for next loop is: 35
# Total if loops: 30
# Total elif_1 loops: 28
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 65 finished
# For loop run number: 66
# i = 0
# close_unit_datetime: 2020-12-29 05:32:10
# open_datetime_lifo: 2020-12-04 10:47:57
# value_close_units: 405.327157 value_open_units: 5690.626719999999
# abs_diff_open_close_units: 5285.299563
# close_unit_index for current loop is: 35
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 29
# changed_value_open_units: 405.327157
# value_close_units: 405.327157
# value_open_units: 5690.626719999999
# close_unit_index: 35
# Elif_loop_1 run number: 29 finished
# i = 1
# close_unit_index for current loop was: 35
# close_unit_index for next loop is: 36
# Total if loops: 30
# Total elif_1 loops: 29
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 66 finished
# For loop run number: 67
# i = 0
# close_unit_datetime: 2020-12-29 05:32:19
# open_datetime_lifo: 2020-12-04 10:47:57
# value_close_units: 2870.264064 value_open_units: 5285.299563
# abs_diff_open_close_units: 2415.0354989999996
# close_unit_index for current loop is: 36
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 30
# changed_value_open_units: 2870.264064
# value_close_units: 2870.264064
# value_open_units: 5285.299563
# close_unit_index: 36
# Elif_loop_1 run number: 30 finished
# i = 1
# close_unit_index for current loop was: 36
# close_unit_index for next loop is: 37
# Total if loops: 30
# Total elif_1 loops: 30
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 67 finished
# For loop run number: 68
# i = 0
# close_unit_datetime: 2021-01-03 20:27:47
# open_datetime_lifo: 2021-01-03 14:32:21
# value_close_units: 1030.927835 value_open_units: 979.911808
# abs_diff_open_close_units: 51.01602700000001
# close_unit_index for current loop is: 37
# (close_unit_index = close_index) is: True
# If_loop run number: 31
# value_close_units: 1030.927835
# value_open_units: 979.911808
# close_unit_index: 37
# If_loop run number: 31 finished
# i = 0
# close_unit_index for current loop was: 37
# close_unit_index for next loop is: 37
# Total if loops: 31
# Total elif_1 loops: 30
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 68 finished
# For loop run number: 69
# i = 0
# close_unit_datetime: 2021-01-03 20:27:47
# open_datetime_lifo: 2021-01-03 12:01:24
# value_close_units: 51.01602700000001 value_open_units: 1030.927835
# abs_diff_open_close_units: 979.911808
# close_unit_index for current loop is: 37
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 31
# changed_value_open_units: 51.01602700000001
# value_close_units: 51.01602700000001
# value_open_units: 1030.927835
# close_unit_index: 37
# Elif_loop_1 run number: 31 finished
# i = 1
# close_unit_index for current loop was: 37
# close_unit_index for next loop is: 38
# Total if loops: 31
# Total elif_1 loops: 31
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 69 finished
# For loop run number: 70
# i = 0
# close_unit_datetime: 2021-01-03 20:27:52
# open_datetime_lifo: 2021-01-03 12:01:24
# value_close_units: 1074.113856 value_open_units: 979.911808
# abs_diff_open_close_units: 94.20204799999999
# close_unit_index for current loop is: 38
# (close_unit_index = close_index) is: True
# If_loop run number: 32
# value_close_units: 1074.113856
# value_open_units: 979.911808
# close_unit_index: 38
# If_loop run number: 32 finished
# i = 0
# close_unit_index for current loop was: 38
# close_unit_index for next loop is: 38
# Total if loops: 32
# Total elif_1 loops: 31
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 70 finished
# For loop run number: 71
# i = 0
# close_unit_datetime: 2021-01-03 20:27:52
# open_datetime_lifo: 2021-01-01 14:13:37
# value_close_units: 94.20204799999999 value_open_units: 2689.618074
# abs_diff_open_close_units: 2595.416026
# close_unit_index for current loop is: 38
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 32
# changed_value_open_units: 94.20204799999999
# value_close_units: 94.20204799999999
# value_open_units: 2689.618074
# close_unit_index: 38
# Elif_loop_1 run number: 32 finished
# i = 1
# close_unit_index for current loop was: 38
# close_unit_index for next loop is: 39
# Total if loops: 32
# Total elif_1 loops: 32
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 71 finished
# For loop run number: 72
# i = 0
# close_unit_datetime: 2021-01-03 20:48:25
# open_datetime_lifo: 2021-01-01 14:13:37
# value_close_units: 979.911808 value_open_units: 2595.416026
# abs_diff_open_close_units: 1615.504218
# close_unit_index for current loop is: 39
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 33
# changed_value_open_units: 979.911808
# value_close_units: 979.911808
# value_open_units: 2595.416026
# close_unit_index: 39
# Elif_loop_1 run number: 33 finished
# i = 1
# close_unit_index for current loop was: 39
# close_unit_index for next loop is: 40
# Total if loops: 32
# Total elif_1 loops: 33
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 72 finished
# For loop run number: 73
# i = 0
# close_unit_datetime: 2021-01-03 20:48:30
# open_datetime_lifo: 2021-01-01 14:13:37
# value_close_units: 2689.618074 value_open_units: 1615.504218
# abs_diff_open_close_units: 1074.113856
# close_unit_index for current loop is: 40
# (close_unit_index = close_index) is: True
# If_loop run number: 33
# value_close_units: 2689.618074
# value_open_units: 1615.504218
# close_unit_index: 40
# If_loop run number: 33 finished
# i = 0
# close_unit_index for current loop was: 40
# close_unit_index for next loop is: 40
# Total if loops: 33
# Total elif_1 loops: 33
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 73 finished
# For loop run number: 74
# i = 0
# close_unit_datetime: 2021-01-03 20:48:30
# open_datetime_lifo: 2021-01-01 08:52:58
# value_close_units: 1074.113856 value_open_units: 554.938957
# abs_diff_open_close_units: 519.174899
# close_unit_index for current loop is: 40
# (close_unit_index = close_index) is: True
# If_loop run number: 34
# value_close_units: 1074.113856
# value_open_units: 554.938957
# close_unit_index: 40
# If_loop run number: 34 finished
# i = 0
# close_unit_index for current loop was: 40
# close_unit_index for next loop is: 40
# Total if loops: 34
# Total elif_1 loops: 33
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 74 finished
# For loop run number: 75
# i = 0
# close_unit_datetime: 2021-01-03 20:48:30
# open_datetime_lifo: 2020-12-31 15:17:08
# value_close_units: 519.174899 value_open_units: 549.450549
# abs_diff_open_close_units: 30.27565000000004
# close_unit_index for current loop is: 40
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 34
# changed_value_open_units: 519.174899
# value_close_units: 519.174899
# value_open_units: 549.450549
# close_unit_index: 40
# Elif_loop_1 run number: 34 finished
# i = 1
# close_unit_index for current loop was: 40
# close_unit_index for next loop is: 41
# Total if loops: 34
# Total elif_1 loops: 34
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 75 finished
# For loop run number: 76
# i = 0
# close_unit_datetime: 2021-01-03 20:48:38
# open_datetime_lifo: 2020-12-31 15:17:08
# value_close_units: 549.450549 value_open_units: 30.27565000000004
# abs_diff_open_close_units: 519.174899
# close_unit_index for current loop is: 41
# (close_unit_index = close_index) is: True
# If_loop run number: 35
# value_close_units: 549.450549
# value_open_units: 30.27565000000004
# close_unit_index: 41
# If_loop run number: 35 finished
# i = 0
# close_unit_index for current loop was: 41
# close_unit_index for next loop is: 41
# Total if loops: 35
# Total elif_1 loops: 34
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 76 finished
# For loop run number: 77
# i = 0
# close_unit_datetime: 2021-01-03 20:48:38
# open_datetime_lifo: 2020-12-30 20:01:26
# value_close_units: 519.174899 value_open_units: 1074.113856
# abs_diff_open_close_units: 554.938957
# close_unit_index for current loop is: 41
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 35
# changed_value_open_units: 519.174899
# value_close_units: 519.174899
# value_open_units: 1074.113856
# close_unit_index: 41
# Elif_loop_1 run number: 35 finished
# i = 1
# close_unit_index for current loop was: 41
# close_unit_index for next loop is: 42
# Total if loops: 35
# Total elif_1 loops: 35
# Total elif_2 loops: 7
# Total else loops: 0
# For loop run number: 77 finished
# For loop run number: 78
# i = 0
# close_unit_datetime: 2021-01-03 20:49:11
# open_datetime_lifo: 2020-12-30 20:01:26
# value_close_units: 554.938957 value_open_units: 554.938957
# abs_diff_open_close_units: 0.0
# close_unit_index for current loop is: 42
# (close_unit_index = close_index) is: True
# value_close_units: 554.938957
# value_open_units: 554.938957
# close_unit_index: 42
# Elif_loop_2 run number: 8 finished
# i = 1
# close_unit_index for current loop was: 42
# close_unit_index for next loop is: 43
# Total if loops: 35
# Total elif_1 loops: 35
# Total elif_2 loops: 8
# Total else loops: 0
# For loop run number: 78 finished
# For loop run number: 79
# i = 0
# close_unit_datetime: 2021-02-02 20:56:41
# open_datetime_lifo: 2021-01-23 20:28:31
# value_close_units: 230.167296 value_open_units: 76.077768
# ...
# close_unit_index for next loop is: 113
# Total if loops: 103
# Total elif_1 loops: 102
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 216 finished
# For loop run number: 217
# i = 0
# close_unit_datetime: 2022-01-10 15:33:10
# open_datetime_lifo: 2020-11-21 13:56:03
# value_close_units: 830.9858860000006 value_open_units: 193.79845
# abs_diff_open_close_units: 637.1874360000006
# close_unit_index for current loop is: 113
# (close_unit_index = close_index) is: True
# If_loop run number: 104
# value_close_units: 830.9858860000006
# value_open_units: 193.79845
# close_unit_index: 113
# If_loop run number: 104 finished
# i = 0
# close_unit_index for current loop was: 113
# close_unit_index for next loop is: 113
# Total if loops: 104
# Total elif_1 loops: 102
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 217 finished
# For loop run number: 218
# i = 0
# close_unit_datetime: 2022-01-10 15:33:10
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 637.1874360000006 value_open_units: 1563.721658
# abs_diff_open_close_units: 926.5342219999993
# close_unit_index for current loop is: 113
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 103
# changed_value_open_units: 637.1874360000006
# value_close_units: 637.1874360000006
# value_open_units: 1563.721658
# close_unit_index: 113
# Elif_loop_1 run number: 103 finished
# i = 1
# close_unit_index for current loop was: 113
# close_unit_index for next loop is: 114
# Total if loops: 104
# Total elif_1 loops: 103
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 218 finished
# For loop run number: 219
# i = 0
# close_unit_datetime: 2022-01-10 15:33:19
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 247.035573 value_open_units: 926.5342219999993
# abs_diff_open_close_units: 679.4986489999993
# close_unit_index for current loop is: 114
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 104
# changed_value_open_units: 247.035573
# value_close_units: 247.035573
# value_open_units: 926.5342219999993
# close_unit_index: 114
# Elif_loop_1 run number: 104 finished
# i = 1
# close_unit_index for current loop was: 114
# close_unit_index for next loop is: 115
# Total if loops: 104
# Total elif_1 loops: 104
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 219 finished
# For loop run number: 220
# i = 0
# close_unit_datetime: 2022-01-10 15:33:23
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 244.140625 value_open_units: 679.4986489999993
# abs_diff_open_close_units: 435.3580239999993
# close_unit_index for current loop is: 115
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 105
# changed_value_open_units: 244.140625
# value_close_units: 244.140625
# value_open_units: 679.4986489999993
# close_unit_index: 115
# Elif_loop_1 run number: 105 finished
# i = 1
# close_unit_index for current loop was: 115
# close_unit_index for next loop is: 116
# Total if loops: 104
# Total elif_1 loops: 105
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 220 finished
# For loop run number: 221
# i = 0
# close_unit_datetime: 2022-01-10 15:33:26
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 239.463602 value_open_units: 435.3580239999993
# abs_diff_open_close_units: 195.8944219999993
# close_unit_index for current loop is: 116
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 106
# changed_value_open_units: 239.463602
# value_close_units: 239.463602
# value_open_units: 435.3580239999993
# close_unit_index: 116
# Elif_loop_1 run number: 106 finished
# i = 1
# close_unit_index for current loop was: 116
# close_unit_index for next loop is: 117
# Total if loops: 104
# Total elif_1 loops: 106
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 221 finished
# For loop run number: 222
# i = 0
# close_unit_datetime: 2022-01-10 15:33:30
# open_datetime_lifo: 2020-11-21 08:56:08
# value_close_units: 237.868696 value_open_units: 195.8944219999993
# abs_diff_open_close_units: 41.97427400000069
# close_unit_index for current loop is: 117
# (close_unit_index = close_index) is: True
# If_loop run number: 105
# value_close_units: 237.868696
# value_open_units: 195.8944219999993
# close_unit_index: 117
# If_loop run number: 105 finished
# i = 0
# close_unit_index for current loop was: 117
# close_unit_index for next loop is: 117
# Total if loops: 105
# Total elif_1 loops: 106
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 222 finished
# For loop run number: 223
# i = 0
# close_unit_datetime: 2022-01-10 15:33:30
# open_datetime_lifo: 2020-11-09 06:58:21
# value_close_units: 41.97427400000069 value_open_units: 237.868696
# abs_diff_open_close_units: 195.8944219999993
# close_unit_index for current loop is: 117
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 107
# changed_value_open_units: 41.97427400000069
# value_close_units: 41.97427400000069
# value_open_units: 237.868696
# close_unit_index: 117
# Elif_loop_1 run number: 107 finished
# i = 1
# close_unit_index for current loop was: 117
# close_unit_index for next loop is: 118
# Total if loops: 105
# Total elif_1 loops: 107
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 223 finished
# For loop run number: 224
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-09 06:58:21
# value_close_units: 1894.150418 value_open_units: 195.8944219999993
# abs_diff_open_close_units: 1698.2559960000006
# close_unit_index for current loop is: 118
# (close_unit_index = close_index) is: True
# If_loop run number: 106
# value_close_units: 1894.150418
# value_open_units: 195.8944219999993
# close_unit_index: 118
# If_loop run number: 106 finished
# i = 0
# close_unit_index for current loop was: 118
# close_unit_index for next loop is: 118
# Total if loops: 106
# Total elif_1 loops: 107
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 224 finished
# For loop run number: 225
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-08 06:52:09
# value_close_units: 1698.2559960000006 value_open_units: 239.463602
# abs_diff_open_close_units: 1458.7923940000005
# close_unit_index for current loop is: 118
# (close_unit_index = close_index) is: True
# If_loop run number: 107
# value_close_units: 1698.2559960000006
# value_open_units: 239.463602
# close_unit_index: 118
# If_loop run number: 107 finished
# i = 0
# close_unit_index for current loop was: 118
# close_unit_index for next loop is: 118
# Total if loops: 107
# Total elif_1 loops: 107
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 225 finished
# For loop run number: 226
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-07 18:56:32
# value_close_units: 1458.7923940000005 value_open_units: 244.140625
# abs_diff_open_close_units: 1214.6517690000005
# close_unit_index for current loop is: 118
# (close_unit_index = close_index) is: True
# If_loop run number: 108
# value_close_units: 1458.7923940000005
# value_open_units: 244.140625
# close_unit_index: 118
# If_loop run number: 108 finished
# i = 0
# close_unit_index for current loop was: 118
# close_unit_index for next loop is: 118
# Total if loops: 108
# Total elif_1 loops: 107
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 226 finished
# For loop run number: 227
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-06 23:29:27
# value_close_units: 1214.6517690000005 value_open_units: 892.857143
# abs_diff_open_close_units: 321.79462600000056
# close_unit_index for current loop is: 118
# (close_unit_index = close_index) is: True
# If_loop run number: 109
# value_close_units: 1214.6517690000005
# value_open_units: 892.857143
# close_unit_index: 118
# If_loop run number: 109 finished
# i = 0
# close_unit_index for current loop was: 118
# close_unit_index for next loop is: 118
# Total if loops: 109
# Total elif_1 loops: 107
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 227 finished
# For loop run number: 228
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-03 12:40:54
# value_close_units: 321.79462600000056 value_open_units: 268.817204
# abs_diff_open_close_units: 52.97742200000056
# close_unit_index for current loop is: 118
# (close_unit_index = close_index) is: True
# If_loop run number: 110
# value_close_units: 321.79462600000056
# value_open_units: 268.817204
# close_unit_index: 118
# If_loop run number: 110 finished
# i = 0
# close_unit_index for current loop was: 118
# close_unit_index for next loop is: 118
# Total if loops: 110
# Total elif_1 loops: 107
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 228 finished
# For loop run number: 229
# i = 0
# close_unit_datetime: 2022-01-10 15:33:34
# open_datetime_lifo: 2020-11-03 03:11:56
# value_close_units: 52.97742200000056 value_open_units: 273.224044
# abs_diff_open_close_units: 220.24662199999943
# close_unit_index for current loop is: 118
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 108
# changed_value_open_units: 52.97742200000056
# value_close_units: 52.97742200000056
# value_open_units: 273.224044
# close_unit_index: 118
# Elif_loop_1 run number: 108 finished
# i = 1
# close_unit_index for current loop was: 118
# close_unit_index for next loop is: 119
# Total if loops: 110
# Total elif_1 loops: 108
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 229 finished
# For loop run number: 230
# i = 0
# close_unit_datetime: 2022-01-10 15:33:39
# open_datetime_lifo: 2020-11-03 03:11:56
# value_close_units: 643.915003 value_open_units: 220.24662199999943
# abs_diff_open_close_units: 423.6683810000005
# close_unit_index for current loop is: 119
# (close_unit_index = close_index) is: True
# If_loop run number: 111
# value_close_units: 643.915003
# value_open_units: 220.24662199999943
# close_unit_index: 119
# If_loop run number: 111 finished
# i = 0
# close_unit_index for current loop was: 119
# close_unit_index for next loop is: 119
# Total if loops: 111
# Total elif_1 loops: 108
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 230 finished
# For loop run number: 231
# i = 0
# close_unit_datetime: 2022-01-10 15:33:39
# open_datetime_lifo: 2020-11-02 12:56:38
# value_close_units: 423.6683810000005 value_open_units: 265.957447
# abs_diff_open_close_units: 157.71093400000052
# close_unit_index for current loop is: 119
# (close_unit_index = close_index) is: True
# If_loop run number: 112
# value_close_units: 423.6683810000005
# value_open_units: 265.957447
# close_unit_index: 119
# If_loop run number: 112 finished
# i = 0
# close_unit_index for current loop was: 119
# close_unit_index for next loop is: 119
# Total if loops: 112
# Total elif_1 loops: 108
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 231 finished
# For loop run number: 232
# i = 0
# close_unit_datetime: 2022-01-10 15:33:39
# open_datetime_lifo: 2020-10-28 14:15:28
# value_close_units: 157.71093400000052 value_open_units: 255.885363
# abs_diff_open_close_units: 98.17442899999949
# close_unit_index for current loop is: 119
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 109
# changed_value_open_units: 157.71093400000052
# value_close_units: 157.71093400000052
# value_open_units: 255.885363
# close_unit_index: 119
# Elif_loop_1 run number: 109 finished
# i = 1
# close_unit_index for current loop was: 119
# close_unit_index for next loop is: 120
# Total if loops: 112
# Total elif_1 loops: 109
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 232 finished
# For loop run number: 233
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 14:15:28
# value_close_units: 39.976374 value_open_units: 98.17442899999949
# abs_diff_open_close_units: 58.19805499999949
# close_unit_index for current loop is: 120
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 110
# changed_value_open_units: 39.976374
# value_close_units: 39.976374
# value_open_units: 98.17442899999949
# close_unit_index: 120
# Elif_loop_1 run number: 110 finished
# i = 1
# close_unit_index for current loop was: 120
# close_unit_index for next loop is: 121
# Total if loops: 112
# Total elif_1 loops: 110
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 233 finished
# For loop run number: 234
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 14:15:28
# value_close_units: 45.221419 value_open_units: 58.19805499999949
# abs_diff_open_close_units: 12.976635999999495
# close_unit_index for current loop is: 121
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 111
# changed_value_open_units: 45.221419
# value_close_units: 45.221419
# value_open_units: 58.19805499999949
# close_unit_index: 121
# Elif_loop_1 run number: 111 finished
# i = 1
# close_unit_index for current loop was: 121
# close_unit_index for next loop is: 122
# Total if loops: 112
# Total elif_1 loops: 111
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 234 finished
# For loop run number: 235
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 14:15:28
# value_close_units: 92.262094 value_open_units: 12.976635999999495
# abs_diff_open_close_units: 79.28545800000052
# close_unit_index for current loop is: 122
# (close_unit_index = close_index) is: True
# If_loop run number: 113
# value_close_units: 92.262094
# value_open_units: 12.976635999999495
# close_unit_index: 122
# If_loop run number: 113 finished
# i = 0
# close_unit_index for current loop was: 122
# close_unit_index for next loop is: 122
# Total if loops: 113
# Total elif_1 loops: 111
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 235 finished
# For loop run number: 236
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 08:10:57
# value_close_units: 79.28545800000052 value_open_units: 247.035573
# abs_diff_open_close_units: 167.75011499999948
# close_unit_index for current loop is: 122
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 112
# changed_value_open_units: 79.28545800000052
# value_close_units: 79.28545800000052
# value_open_units: 247.035573
# close_unit_index: 122
# Elif_loop_1 run number: 112 finished
# i = 1
# close_unit_index for current loop was: 122
# close_unit_index for next loop is: 123
# Total if loops: 113
# Total elif_1 loops: 112
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 236 finished
# For loop run number: 237
# i = 0
# close_unit_datetime: 2022-01-23 09:57:00
# open_datetime_lifo: 2020-10-28 08:10:57
# value_close_units: 6.129467 value_open_units: 167.75011499999948
# abs_diff_open_close_units: 161.62064799999948
# close_unit_index for current loop is: 123
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 113
# changed_value_open_units: 6.129467
# value_close_units: 6.129467
# value_open_units: 167.75011499999948
# close_unit_index: 123
# Elif_loop_1 run number: 113 finished
# i = 1
# close_unit_index for current loop was: 123
# close_unit_index for next loop is: 124
# Total if loops: 113
# Total elif_1 loops: 113
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 237 finished
# For loop run number: 238
# i = 0
# close_unit_datetime: 2022-01-23 09:57:01
# open_datetime_lifo: 2020-10-28 08:10:57
# value_close_units: 88.264599 value_open_units: 161.62064799999948
# abs_diff_open_close_units: 73.35604899999947
# close_unit_index for current loop is: 124
# (close_unit_index = close_index) is: True
# Elif_loop_1 run number: 114
# changed_value_open_units: 88.264599
# value_close_units: 88.264599
# value_open_units: 161.62064799999948
# close_unit_index: 124
# Elif_loop_1 run number: 114 finished
# i = 1
# close_unit_index for current loop was: 124
# close_unit_index for next loop is: 125
# Total if loops: 113
# Total elif_1 loops: 114
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 238 finished
# For loop run number: 239
# i = 0
# close_unit_datetime: 2022-01-23 09:57:01
# open_datetime_lifo: 2020-10-28 08:10:57
# value_close_units: 73.356049 value_open_units: 73.35604899999947
# abs_diff_open_close_units: 5.258016244624741e-13
# close_unit_index for current loop is: 125
# (close_unit_index = close_index) is: True
# If_loop run number: 114
# value_close_units: 73.356049
# value_open_units: 73.35604899999947
# close_unit_index: 125
# If_loop run number: 114 finished
# i = 1
# close_unit_index for current loop was: 125
# close_unit_index for next loop is: 126
# Total if loops: 114
# Total elif_1 loops: 114
# Total elif_2 loops: 11
# Total else loops: 0
# For loop run number: 239 finished
# ****************************************

# %%
print('df_lifo_btc sum of open units:',df_lifo_btc['Open Units'].sum())
print('df_lifo_btc sum of close units:',df_lifo_btc['Close Units'].sum())
print('df_open_btc_original sum of open units:',df_open_btc_original['Open Units'].sum())
print('df_close_btc_original sum of close units:',df_close_btc_original['Close Units'].sum())
# Out:
# df_lifo_btc sum of open units: 81260.41094500001
# df_lifo_btc sum of close units: 81260.41094500001
# df_open_btc_original sum of open units: 81260.41094500001
# df_close_btc_original sum of close units: 81260.41094500001

# %%
df_lifo_btc['time_difference'] = df_lifo_btc['Close Datetime'] - df_lifo_btc['Open Datetime']
df_lifo_btc['time_difference_days'] = df_lifo_btc['time_difference'] / np.timedelta64(1, 'D')
df_lifo_btc_taxable = df_lifo_btc[df_lifo_btc['time_difference_days'] < 365]
df_lifo_btc_taxable_2020 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1609455599]
df_lifo_btc_taxable_2020_2021 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] <= 1640991599]
df_lifo_btc_taxable_2021 = df_lifo_btc_taxable_2020_2021[df_lifo_btc_taxable_2020_2021['Close_unix_timestamp'] > 1609455599]
df_lifo_btc_taxable_2022 = df_lifo_btc_taxable[df_lifo_btc_taxable['Close_unix_timestamp'] > 1640991599]
print('Sum of all open positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2020 in eur:',df_lifo_btc_taxable_2020['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2021 in eur:',df_lifo_btc_taxable_2021['Amount_close_Eur'].sum())
print('Sum of all open positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Open Amount_Eur'].sum())
print('Sum of all closed positions for the year 2022 in eur:',df_lifo_btc_taxable_2022['Amount_close_Eur'].sum())
# Out:
# Sum of all open positions for the year 2020 in eur: 3799.990703107603
# Sum of all closed positions for the year 2020 in eur: 3950.63419847
# Sum of all open positions for the year 2021 in eur: 23531.267697192194
# Sum of all closed positions for the year 2021 in eur: 22608.428731939995
# Sum of all open positions for the year 2022 in eur: 2916.6683131428117
# Sum of all closed positions for the year 2022 in eur: 5247.829696459961

# %%
df_open_btc

# %%
df_close_btc

# %%
df_lifo_btc

# %%
df_close['Close Action'].unique()
# Out:
# array(['Buy Bitcoin', 'Buy Ethereum', 'Buy XRP', 'Buy Tezos', 'Buy EOS',
#        'Buy Cardano', 'Buy Litecoin', 'Buy Build and Build', 'Buy TRON',
#        'Buy Dogecoin', 'Buy Chainlink', 'Buy Uniswap', 'Buy Polygon',
#        'Buy Stellar', 'Buy Decentraland', 'Buy Aave', 'Buy IOTA',
#        'Buy Shiba (in millions)', 'Buy Enjin', 'Buy Maker',
#        'Buy Algorand', 'Buy Solana', 'Buy Polkadot', 'Buy Songbird'],
#       dtype=object)
